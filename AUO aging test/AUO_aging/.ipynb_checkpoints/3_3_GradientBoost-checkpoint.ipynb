# %%
import os
import time
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor

from Dataset_Construction import Balance_Ratio 
from Sampling import label_divide
from AdaClassifier import train_set, multiple_set, print_badC, bad_plot, line_chart, cf_matrix
from AdaRegressor import AUC, PR_curve, multiple_curve, PR_matrix, best_threshold 
from Aging_Score import score1

os.chdir('C:/Users/Darui Yen/OneDrive/桌面/data_after_mid') 
os.getcwd()
# Out:
# 'C:\\Users\\Darui Yen\\OneDrive\\桌面\\data_after_mid'

# %% [markdown]
# ### Gradient Boost

# %%
def GradientBoostC(train_x, test_x, train_y, test_y, n_estimator = 100, LR = 1, depth = 1):
    
    clf = GradientBoostingClassifier(n_estimators = n_estimator, learning_rate = LR, max_depth = depth)
    clf.fit(train_x, train_y)
    predict_y = clf.predict(test_x)
    result = pd.DataFrame({'truth': test_y, 'predict': predict_y})
    
    return result


def GradientBoostR(train_x, test_x, train_y, test_y, n_estimator = 100, LR = 0.1, depth = 1, loss_func = 'ls'):
    
    est = GradientBoostingRegressor(n_estimators = n_estimator, learning_rate = LR, max_depth = 1, loss = loss_func)
    est.fit(train_x, train_y)
    predict_y = est.predict(test_x)
    result = pd.DataFrame({'truth': test_y, 'predict': predict_y})
    
    return result

# %% [markdown]
# ### Run all dataset

# %%
def runall_GradientBoostC(num_set, trainset_x, test_x, trainset_y, test_y, record_bad = True):
    
    table_set = pd.DataFrame()
    bad_set = pd.DataFrame()

    for i in range(num_set):
        print('\n', f'Dataset {i}:')
        
        result = GradientBoostC(trainset_x[f'set{i}'], test_x, trainset_y[f'set{i}'], test_y)
        table = cf_matrix(result, trainset_y[f'set{i}'])
        table_set = pd.concat([table_set, table]).rename(index = {0: f'dataset {i}'})
        
        if record_bad:
            bad_table = print_badC(result, test_x, Bad_Types) 
            bad_set = pd.concat([bad_set, bad_table]).rename(index = {0: f'dataset {i}'})

    if record_bad:
        return table_set, bad_set
    else:
        return table_set
    
    
def runall_GradientBoostR(num_set, trainset_x, test_x, trainset_y, test_y, thres_target = 'Recall', threshold = False, 
                          record_bad = True):
    
    table_set = pd.DataFrame()
    bad_set = pd.DataFrame()
    pr_dict = {}

    for i in range(num_set):
        print('\n', f'Dataset {i}:')

        predict = GradientBoostR(trainset_x[f'set{i}'], test_x, trainset_y[f'set{i}'], test_y)
        pr_matrix = PR_matrix(predict, trainset_y[f'set{i}'])
        pr_dict[f'set{i}'] = pr_matrix
        
        best_data, best_thres = best_threshold(pr_matrix, target = thres_target, threshold = threshold)
        table_set = pd.concat([table_set, best_data]).rename(index = {best_data.index.values[0]: f'dataset {i}'})
        
        if record_bad:
            bad_table = print_badC(predict, test_x, Bad_Types, threshold = best_thres)
            bad_set = pd.concat([bad_set, bad_table]).rename(index = {0: f'dataset {i}'})
    
    if record_bad:
        return pr_dict, table_set, bad_set
    else:
        return pr_dict, table_set

# %% [markdown]
# ## Data processing

# %%
###bad types###
bad = pd.read_csv('original_data/Bad_Types.csv').iloc[:, 1:]
Bad_Types = {bad.cb[i]:i for i in range (len(bad))}
print('Total bad types:', len(bad))

###single dataset###
test = pd.read_csv('original_data/TestingSet_0.csv').iloc[:, 2:]
train = pd.read_csv('original_data/TrainingSet_new.csv').iloc[:, 2:]
print('\ntraining data:', train.shape, '\nBalance Ratio:', Balance_Ratio(train))
print('\ntesting data:', test.shape, '\nBalance Ratio:', Balance_Ratio(test))

train_x, train_y, test_x, test_y = label_divide(train, test, 'GB')

###multiple dataset###
data_dict = multiple_set(num_set = 9)
trainset_x, trainset_y = train_set(data_dict, num_set = 9, label = 'GB')
test_x, test_y = label_divide(test, None, 'GB', train_only = True)
# Out:
# Total bad types: 62
#
# training data: (77138, 83)
# Balance Ratio: 18.17902
#
# testing data: (55903, 83)
# Balance Ratio: 3104.72222
# Dimension of dataset 0 : (77138, 83)  balance ratio: 18.17902
# Dimension of dataset 1 : (139322, 83)  balance ratio: 1.10437
# Dimension of dataset 2 : (139322, 83)  balance ratio: 1.10437
# Dimension of dataset 3 : (139322, 83)  balance ratio: 1.10437
# Dimension of dataset 4 : (138920, 83)  balance ratio: 1.11112
# Dimension of dataset 5 : (19506, 83)  balance ratio: 1.06391
# Dimension of dataset 6 : (19506, 83)  balance ratio: 1.06391
# Dimension of dataset 7 : (19506, 83)  balance ratio: 1.06391
# Dimension of dataset 8 : (19104, 83)  balance ratio: 1.11117
#
#  9 datasets are loaded.
#
# Labels of  9 datasets are divided.

# %%
start = time.time()

table_set1, bad_set1 = runall_GradientBoostC(9, trainset_x, test_x, trainset_y, test_y)
line_chart(table_set1)
bad_plot(bad_set1)

end = time.time()
print("\nRun Time：%f seconds" % (end - start))
# Out:
#  Dataset 0:
# Precision: 0.0
# Recall: 0.0
# Aging Rate: 0.00098384702073234
# Types of Bad found: []
# Types of Bad not found: [2, 2, 4, 5, 6, 7, 11, 15, 17, 22, 23, 33, 39, 40, 42, 45, 48, 49]
#
#  Dataset 1:
# Precision: 0.00025246149962130775
# Recall: 0.1111111111111111
# Aging Rate: 0.1417097472407563
# Types of Bad found: [22, 33]
# Types of Bad not found: [2, 2, 4, 5, 6, 7, 11, 15, 17, 23, 39, 40, 42, 45, 48, 49]
#
#  Dataset 2:
# Precision: 0.0002449179524859172
# Recall: 0.1111111111111111
# Aging Rate: 0.14607445038727795
# Types of Bad found: [22, 33]
# Types of Bad not found: [2, 2, 4, 5, 6, 7, 11, 15, 17, 23, 39, 40, 42, 45, 48, 49]
#
#  Dataset 3:
# Precision: 0.0
# Recall: 0.0
# Aging Rate: 0.00035776255299357814
# Types of Bad found: []
# Types of Bad not found: [2, 2, 4, 5, 6, 7, 11, 15, 17, 22, 23, 33, 39, 40, 42, 45, 48, 49]
#
#  Dataset 4:
# Precision: 0.0003240440699935191
# Recall: 0.1111111111111111
# Aging Rate: 0.11040552385381822
# Types of Bad found: [22, 33]
# Types of Bad not found: [2, 2, 4, 5, 6, 7, 11, 15, 17, 23, 39, 40, 42, 45, 48, 49]
#
#  Dataset 5:
# Precision: 0.0002524296352391771
# Recall: 0.1111111111111111
# Aging Rate: 0.141727635368406
# Types of Bad found: [22, 33]
# Types of Bad not found: [2, 2, 4, 5, 6, 7, 11, 15, 17, 23, 39, 40, 42, 45, 48, 49]
#
#  Dataset 6:
# Precision: 0.0004614142346291383
# Recall: 0.2222222222222222
# Aging Rate: 0.15507217859506645
# Types of Bad found: [5, 11, 22, 33]
# Types of Bad not found: [2, 2, 4, 6, 7, 15, 17, 23, 39, 40, 42, 45, 48, 49]
#
#  Dataset 7:
# Precision: 0.000561955605507165
# Recall: 0.1111111111111111
# Aging Rate: 0.06366384630520723
# Types of Bad found: [22, 33]
# Types of Bad not found: [2, 2, 4, 5, 6, 7, 11, 15, 17, 23, 39, 40, 42, 45, 48, 49]
#
#  Dataset 8:
# Precision: 0.0003488372093023256
# Recall: 0.16666666666666666
# Aging Rate: 0.1538378977872386
# Types of Bad found: [5, 22, 33]
# Types of Bad not found: [2, 2, 4, 6, 7, 11, 15, 17, 23, 39, 40, 42, 45, 48, 49]
# Run Time：57.625955 seconds

# %%
table_set1
# Out:
#            Balance Ratio  Train_OK  Train_NG   TP      FP    FN       TN  \
# dataset 0      18.179015   73116.0    4022.0  0.0    55.0  18.0  55830.0
# dataset 1       1.104371   73116.0   66206.0  2.0  7920.0  16.0  47965.0
# dataset 2       1.104371   73116.0   66206.0  2.0  8164.0  16.0  47721.0
# dataset 3       1.104371   73116.0   66206.0  0.0    20.0  18.0  55865.0
# dataset 4       1.111118   73116.0   65804.0  2.0  6170.0  16.0  49715.0
# dataset 5       1.063909   10055.0    9451.0  2.0  7921.0  16.0  47964.0
# dataset 6       1.063909   10055.0    9451.0  4.0  8665.0  14.0  47220.0
# dataset 7       1.063909   10055.0    9451.0  2.0  3557.0  16.0  52328.0
# dataset 8       1.111173   10055.0    9049.0  3.0  8597.0  15.0  47288.0
#
#            Precision    Recall  Aging Rate  Efficiency     Score
# dataset 0   0.000000  0.000000    0.000984    0.000000  0.000000
# dataset 1   0.000252  0.111111    0.141710    0.784075  0.000000
# dataset 2   0.000245  0.111111    0.146074    0.760647  0.000000
# dataset 3   0.000000  0.000000    0.000358    0.000000  0.000000
# dataset 4   0.000324  0.111111    0.110406    1.006391  0.077371
# dataset 5   0.000252  0.111111    0.141728    0.783976  0.000000
# dataset 6   0.000461  0.222222    0.155072    1.433024  0.197586
# dataset 7   0.000562  0.111111    0.063664    1.745278  0.112209
# dataset 8   0.000349  0.166667    0.153838    1.083391  0.122333

# %%
start = time.time()

pr_dict, table_set2, bad_set2 = runall_GradientBoostR(9, trainset_x, test_x, trainset_y, test_y, thres_target = 'Recall', 
                                                      threshold = 0.8)
line_chart(table_set2)
bad_plot(bad_set2)


end = time.time()
print("\nRun Time：%f seconds" % (end - start))
# Out:
#  Dataset 0:
# Best Threshold: 0.008826067397213321
#
# Recall: [0.94444444] ,   Precision: [0.00032711] ,   Aging Rate: [0.92964599]
# Types of Bad found: [2, 2, 4, 5, 7, 11, 15, 17, 22, 23, 33, 39, 40, 42, 45, 48, 49]
# Types of Bad not found: [6]
#
#  Dataset 1:
# Best Threshold: 0.22255148538170622
#
# Recall: [0.83333333] ,   Precision: [0.00031322] ,   Aging Rate: [0.85666243]
# Types of Bad found: [2, 2, 4, 5, 7, 11, 17, 22, 33, 39, 40, 42, 45, 48, 49]
# Types of Bad not found: [6, 15, 23]
#
#  Dataset 2:
# Best Threshold: 0.22858016398994263
#
# Recall: [0.83333333] ,   Precision: [0.00031284] ,   Aging Rate: [0.85769994]
# Types of Bad found: [2, 2, 4, 5, 7, 11, 17, 22, 33, 39, 40, 42, 45, 48, 49]
# Types of Bad not found: [6, 15, 23]
#
#  Dataset 3:
# Best Threshold: 0.04898662238969721
#
# Recall: [0.88888889] ,   Precision: [0.00040042] ,   Aging Rate: [0.7147738]
# Types of Bad found: [2, 2, 4, 5, 6, 7, 11, 15, 17, 22, 23, 33, 39, 40, 42, 49]
# Types of Bad not found: [45, 48]
#
#  Dataset 4:
# Best Threshold: 0.20259345565596623
#
# Recall: [0.83333333] ,   Precision: [0.00030474] ,   Aging Rate: [0.88050731]
# Types of Bad found: [2, 2, 4, 5, 7, 11, 17, 22, 33, 39, 40, 42, 45, 48, 49]
# Types of Bad not found: [6, 15, 23]
#
#  Dataset 5:
# Best Threshold: 0.22256487765690755
#
# Recall: [0.83333333] ,   Precision: [0.00030875] ,   Aging Rate: [0.86905891]
# Types of Bad found: [2, 2, 4, 5, 7, 11, 17, 22, 33, 39, 40, 42, 45, 48, 49]
# Types of Bad not found: [6, 15, 23]
#
#  Dataset 6:
# Best Threshold: 0.21348472682788022
#
# Recall: [0.83333333] ,   Precision: [0.0003021] ,   Aging Rate: [0.8881992]
# Types of Bad found: [2, 2, 4, 5, 7, 11, 17, 22, 33, 39, 40, 42, 45, 48, 49]
# Types of Bad not found: [6, 15, 23]
#
#  Dataset 7:
# Best Threshold: 0.2031918551866729
#
# Recall: [0.83333333] ,   Precision: [0.00039966] ,   Aging Rate: [0.67137721]
# Types of Bad found: [2, 2, 4, 5, 7, 11, 15, 17, 22, 23, 33, 39, 40, 42, 49]
# Types of Bad not found: [6, 45, 48]
#
#  Dataset 8:
# Best Threshold: 0.24073171622566789
#
# Recall: [0.83333333] ,   Precision: [0.00032611] ,   Aging Rate: [0.82280021]
# Types of Bad found: [2, 2, 4, 5, 7, 11, 15, 17, 22, 33, 39, 40, 42, 48, 49]
# Types of Bad not found: [6, 23, 45]
# Run Time：49.149912 seconds

# %%
multiple_curve(3, 3, pr_dict, table_set2, target = 'Aging Rate')
multiple_curve(3, 3, pr_dict, table_set2, target = 'Precision')
table_set2
# Out:
#            Class_Prob  train_OK  train_NG  Balance Ratio    TP       FP   FN  \
# dataset 0    0.008826   73116.0    4022.0      18.179015  17.0  51953.0  1.0
# dataset 1    0.222551   73116.0   66206.0       1.104371  15.0  47875.0  3.0
# dataset 2    0.228580   73116.0   66206.0       1.104371  15.0  47933.0  3.0
# dataset 3    0.048987   73116.0   66206.0       1.104371  16.0  39942.0  2.0
# dataset 4    0.202593   73116.0   65804.0       1.111118  15.0  49208.0  3.0
# dataset 5    0.222565   10055.0    9451.0       1.063909  15.0  48568.0  3.0
# dataset 6    0.213485   10055.0    9451.0       1.063909  15.0  49638.0  3.0
# dataset 7    0.203192   10055.0    9451.0       1.063909  15.0  37517.0  3.0
# dataset 8    0.240732   10055.0    9049.0       1.111173  15.0  45982.0  3.0
#
#                 TN    Recall  Precision  Aging Rate  Efficiency     Score
# dataset 0   3932.0  0.944444   0.000327    0.929646    1.015918  0.662126
# dataset 1   8010.0  0.833333   0.000313    0.856662    0.972767  0.000000
# dataset 2   7952.0  0.833333   0.000313    0.857700    0.971591  0.000000
# dataset 3  15943.0  0.888889   0.000400    0.714774    1.243595  0.718293
# dataset 4   6677.0  0.833333   0.000305    0.880507    0.946424  0.000000
# dataset 5   7317.0  0.833333   0.000309    0.869059    0.958892  0.000000
# dataset 6   6247.0  0.833333   0.000302    0.888199    0.938228  0.000000
# dataset 7  18368.0  0.833333   0.000400    0.671377    1.241230  0.672521
# dataset 8   9903.0  0.833333   0.000326    0.822800    1.012802  0.582940
