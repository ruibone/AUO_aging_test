# %%
import os
import numpy as np
import pandas as pd
import pickle
from tqdm.auto import tqdm
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
import optuna
from sklearn.model_selection import train_test_split

from library.Data_Preprocessing import Balance_Ratio, training_def
from library.Imbalance_Sampling import label_divide, resampling_dataset
from library.Aging_Score_Contour import score1
from library.AdaBoost import train_set, multiple_set, multiple_month, line_chart, cf_matrix, AUC, PR_curve, \
     multiple_curve, PR_matrix, best_threshold, all_optuna, optuna_history 

os.chdir('C:/Users/user/Desktop/Darui_R08621110') 
os.getcwd()
# Out:
# 'C:\\Users\\user\\Desktop\\Darui_R08621110'

# %% [markdown]
# ##

# %% [markdown]
# ### Random Forest

# %%
# classifier
def RandomForestC(train_x, test_x, train_y, test_y, config, return_prob = False):
    
    clf = RandomForestClassifier(**config, n_jobs = -1)
    clf.fit(train_x, train_y)
    predict_y = clf.predict(test_x)
    define_predict = (predict_y > 0.5).astype(int)
    if return_prob:
        result = pd.DataFrame({'truth': test_y, 'predict': predict_y})
    else:
        result = pd.DataFrame({'truth': test_y, 'predict': define_predict})
    
    return result


# regressor (optional)
def RandomForestR(train_x, test_x, train_y, test_y, config):
    
    clf = RandomForestRegressor(**config, n_jobs = -1)
    clf.fit(train_x, train_y)
    predict_y = clf.predict(test_x)
    result = pd.DataFrame({'truth': test_y, 'predict': predict_y})
    
    return result


# classifeir for all resampling datasets
def runall_ForestC(trainset_x, test_x, trainset_y, test_y, config):
    
    table_set = pd.DataFrame()
    bad_set = pd.DataFrame()
    set_index = list(config.keys())
    judge = set_index[0]

    for i, j in tqdm(enumerate(set_index)):
        print('\n', f'Data{j}:')
        if isinstance(config[judge], dict) :
            best_config = config[j]
        else :
            best_config = config
        
        result = RandomForestC(trainset_x[j], test_x, trainset_y[j], test_y, best_config)
        table = cf_matrix(result, trainset_y[j])
        table_set = pd.concat([table_set, table]).rename(index = {0: f'data{j}'})

    return table_set
    

# regressor for all resampling datasets (optional)
def runall_ForestR(num_set, trainset_x, test_x, trainset_y, test_y, config, thres_target = 'Recall', threshold = 0.8):
    
    table_set = pd.DataFrame()
    bad_set = pd.DataFrame()
    pr_dict = {}
    judge = list(config.keys())[0]

    for i in range(num_set):
        print('\n', f'Dataset {i}:')
        
        if isinstance(config[judge], dict) :
            best_config = config[f'set{i}']
        else :
            best_config = config

        predict = RandomForestR(trainset_x[f'set{i}'], test_x, trainset_y[f'set{i}'], test_y, best_config)
        pr_matrix = PR_matrix(predict, trainset_y[f'set{i}'])
        pr_dict[f'set{i}'] = pr_matrix
        
        best_data, best_thres = best_threshold(pr_matrix, target = thres_target, threshold = threshold)
        table_set = pd.concat([table_set, best_data]).rename(index = {best_data.index.values[0]: f'dataset {i}'})

    return pr_dict, table_set

# %% [markdown]
# ### Optuna

# %%
# creator of optuna study for random forest
def RandomForest_creator(train_data, mode, num_valid = 5, label = 'GB') :
    
    def objective(trial) :

        param = {
            'n_estimators': trial.suggest_categorical('n_estimators', [100, 300, 500, 1000]),
            'min_samples_split': trial.suggest_int('min_samples_split', 2, 12, step = 2),
            'max_depth': trial.suggest_int('max_depth', 3, 21, step = 3),
        }

        result_list = []
        for i in range(num_valid):

            train_good = train_data[train_data.GB == 0]
            train_bad = train_data[train_data.GB == 1]
            train_good_x, train_good_y = label_divide(train_good, None, label, train_only = True)
            train_bad_x, train_bad_y = label_divide(train_bad, None, label, train_only = True)
            train_g_x, valid_g_x, train_g_y, valid_g_y = train_test_split(train_good_x, train_good_y, test_size = 0.25)
            train_b_x, valid_b_x, train_b_y, valid_b_y = train_test_split(train_bad_x, train_bad_y, test_size = 0.25)
            train_x = pd.concat([train_g_x, train_b_x], axis = 0)
            train_y = pd.concat([train_g_y, train_b_y], axis = 0)
            valid_x = pd.concat([valid_g_x, valid_b_x], axis = 0)
            valid_y = pd.concat([valid_g_y, valid_b_y], axis = 0)

            if mode == 'C':
                result = RandomForestC(train_x, valid_x, train_y, valid_y, param)
                table = cf_matrix(result, valid_y)
                recall = table['Recall']
                precision = table['Precision']
                beta = 1
                fscore = ((1+beta**2)*recall*precision) / (recall+(beta**2)*precision)
                if recall.values > 0:
                    fscore = ((1+beta**2)*recall*precision) / (recall+(beta**2)*precision)
                else:
                    fscore = 0
                result_list.append(fscore)

            elif mode == 'R':
                result = RandomForestR(train_x, valid_x, train_y, valid_y, param)
                pr_matrix = PR_matrix(result, valid_y)
                auc = AUC(pr_matrix['Recall'], pr_matrix['Aging Rate'])
                result_list.append((-1)*auc)

        return np.mean(result_list)
    
    return objective

# %% [markdown]
# ### Full Experiment

# %%
def full_randomforest(train_month, times):
    best_param = dict()
    all_score = dict()
    prob_dict = dict()
    result_df = pd.DataFrame()

    # load relabel datasets
    runhist = {}
    kinds = {}
    for i in train_month:
        runhist[f'm{i}'] = pd.read_csv(f'relabel_runhist_m{i}.csv', index_col = 'id').iloc[:, 1:]
        kinds[f'm{i}'] = pd.read_csv(f'kind_m{i}.csv').iloc[:, 2:-3]

    #  do several times to average the random effect of resampling
    for i in tqdm(range(times)):
        # generate resampled datasets
        resampling_dataset(runhist = runhist, kinds = kinds, train_month = train_month, final_br = 1, num_os = 10)

        # load & prepare the resampled datasets 
        all_train = multiple_set(num_set = 10)
        all_train_x, all_train_y = train_set(all_train)
        all_test = pd.read_csv('test_runhist.csv').iloc[:, 2:]
        all_test_x, all_test_y = label_divide(all_test, None, 'GB', train_only = True)

        # searching for hyperparameters
        best_param[i], all_score[i] = all_optuna(all_data = all_train, 
                                         mode = 'C', 
                                         TPE_multi = False, 
                                         n_iter = 25, 
                                         filename = f'runhist_array_m2m4_m5_3criteria_RandomForest_{i}',
                                         creator = RandomForest_creator
                                        )
        # store the probability predicted by the classifier 
        for j in best_param[i].keys():
            if i == 0:
                prob_dict[j] = pd.DataFrame()
            table = RandomForestC(all_train_x[j], all_test_x, all_train_y[j], all_test_y, best_param[i][j], 
                                  return_prob = True)
            prob_dict[j] = pd.concat([prob_dict[j], table[['predict']]], axis = 1)
            
    # average to get final prediction
    for j in best_param[0].keys():
        prediction = (prob_dict[j].apply(np.sum, axis = 1) >= 0.5).astype(int)
        result = pd.DataFrame(dict(truth = all_test_y, predict = prediction))
        table = cf_matrix(result, all_train_y[j])
        result_df = pd.concat([result_df, table]).rename(index = {0: f'data{j}'})
        
    return result_df

# %% [markdown]
# ##

# %% [markdown]
# ### For a Run

# %% [markdown]
# #### Load Data

# %%
### training data ### 
training_month = range(2, 5)

data_dict, trainset_x, trainset_y = multiple_month(training_month, num_set = 10, filename = 'dataset')

print('\nCombined training data:\n')
run_train = multiple_set(num_set = 10)
run_train_x, run_train_y = train_set(run_train, num_set = 10)

### testing data ###
run_test = pd.read_csv('test_runhist.csv').iloc[:, 2:]
run_test_x, run_test_y = label_divide(run_test, None, 'GB', train_only = True)
print('\n', 'Dimension of testing data:', run_test.shape)
# Out:
# Month 2:
#
# Dimension of dataset 0 : (39009, 88)  balance ratio: 564.35
# Dimension of dataset 1 : (1404, 88)  balance ratio: 1.0
# Dimension of dataset 2 : (1368, 88)  balance ratio: 1.0
# Dimension of dataset 3 : (1376, 88)  balance ratio: 1.0
# Dimension of dataset 4 : (1378, 88)  balance ratio: 1.0
# Dimension of dataset 5 : (1370, 88)  balance ratio: 1.01
# Dimension of dataset 6 : (1369, 88)  balance ratio: 1.02
# Dimension of dataset 7 : (1317, 88)  balance ratio: 1.1
# Dimension of dataset 8 : (1380, 88)  balance ratio: 1.0
# Dimension of dataset 9 : (759, 88)  balance ratio: 10.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
# Month 3:
#
# Dimension of dataset 0 : (60396, 97)  balance ratio: 533.48
# Dimension of dataset 1 : (2304, 97)  balance ratio: 1.0
# Dimension of dataset 2 : (2226, 97)  balance ratio: 1.0
# Dimension of dataset 3 : (2256, 97)  balance ratio: 1.0
# Dimension of dataset 4 : (2258, 97)  balance ratio: 1.0
# Dimension of dataset 5 : (2271, 97)  balance ratio: 0.99
# Dimension of dataset 6 : (2243, 97)  balance ratio: 1.02
# Dimension of dataset 7 : (2158, 97)  balance ratio: 1.1
# Dimension of dataset 8 : (2260, 97)  balance ratio: 1.0
# Dimension of dataset 9 : (1243, 97)  balance ratio: 10.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
# Month 4:
#
# Dimension of dataset 0 : (57743, 100)  balance ratio: 472.3
# Dimension of dataset 1 : (2426, 100)  balance ratio: 1.0
# Dimension of dataset 2 : (2404, 100)  balance ratio: 1.0
# Dimension of dataset 3 : (2434, 100)  balance ratio: 1.0
# Dimension of dataset 4 : (2440, 100)  balance ratio: 1.0
# Dimension of dataset 5 : (2419, 100)  balance ratio: 1.02
# Dimension of dataset 6 : (2425, 100)  balance ratio: 1.01
# Dimension of dataset 7 : (2330, 100)  balance ratio: 1.1
# Dimension of dataset 8 : (2440, 100)  balance ratio: 1.0
# Dimension of dataset 9 : (1342, 100)  balance ratio: 10.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
# Combined training data:
#
# Dimension of dataset 0 : (157148, 128)  balance ratio: 515.93
# Dimension of dataset 1 : (6134, 128)  balance ratio: 1.0
# Dimension of dataset 2 : (5998, 128)  balance ratio: 1.0
# Dimension of dataset 3 : (6066, 128)  balance ratio: 1.0
# Dimension of dataset 4 : (6076, 128)  balance ratio: 1.0
# Dimension of dataset 5 : (6060, 128)  balance ratio: 1.01
# Dimension of dataset 6 : (6037, 128)  balance ratio: 1.01
# Dimension of dataset 7 : (5805, 128)  balance ratio: 1.1
# Dimension of dataset 8 : (6080, 128)  balance ratio: 1.0
# Dimension of dataset 9 : (3344, 128)  balance ratio: 10.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
#  Dimension of testing data: (48649, 128)

# %% [markdown]
# #### Search for The Best Hyperparameters

# %%
best_paramC, all_scoreC = all_optuna(all_data = run_train, 
                                     mode = 'C', 
                                     TPE_multi = False, 
                                     n_iter = 20, 
                                     filename = 'runhist_array_m2m4_m5_3criteria_RandomForest', 
                                     creator = RandomForest_creator
                                    )
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# [I 2022-03-04 09:23:37,481] A new study created in memory with name: no-name-2fd61b31-9f46-4346-ac03-f6a787cb0c92
# Dataset 1 :
# C:\Users\user\anaconda3\envs\aging\lib\site-packages\optuna\progress_bar.py:47: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
#   0%|          | 0/50 [00:00<?, ?it/s]
# Precision: 0.8973277074542897
# Recall: 0.8318122555410691
# Aging Rate: 0.4634941329856584
# Precision: 0.8758434547908233
# Recall: 0.8461538461538461
# Aging Rate: 0.4830508474576271
# Precision: 0.8773722627737226
# Recall: 0.7835723598435462
# Aging Rate: 0.44654498044328556
# [I 2022-03-04 09:23:39,190] Trial 0 finished with value: 0.8506317399212567 and parameters: {'n_estimators': 300, 'min_samples_split': 8, 'max_depth': 3}. Best is trial 0 with value: 0.8506317399212567.
# Precision: 0.9973718791064389
# Recall: 0.9895697522816167
# Aging Rate: 0.49608865710560623
# Precision: 0.9960835509138382
# Recall: 0.9947848761408083
# Aging Rate: 0.49934810951760106
# Precision: 0.9960732984293194
# Recall: 0.9921773142112125
# Aging Rate: 0.4980443285528031
# [I 2022-03-04 09:23:41,712] Trial 1 finished with value: 0.9943369255197556 and parameters: {'n_estimators': 500, 'min_samples_split': 4, 'max_depth': 15}. Best is trial 1 with value: 0.9943369255197556.
# Precision: 0.8667621776504298
# Recall: 0.788787483702738
# Aging Rate: 0.455019556714472
# Precision: 0.8583569405099151
# Recall: 0.7900912646675359
# Aging Rate: 0.4602346805736636
# Precision: 0.8462566844919787
# Recall: 0.8252933507170795
# Aging Rate: 0.4876140808344198
# [I 2022-03-04 09:23:42,648] Trial 2 finished with value: 0.8281309071802339 and parameters: {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 3}. Best is trial 1 with value: 0.9943369255197556.
# Precision: 0.996078431372549
# Recall: 0.9934810951760105
# Aging Rate: 0.49869621903520206
# Precision: 0.9921568627450981
# Recall: 0.9895697522816167
# Aging Rate: 0.49869621903520206
# Precision: 0.9921671018276762
# Recall: 0.9908735332464146
# Aging Rate: 0.49934810951760106
# [I 2022-03-04 09:23:45,228] Trial 3 finished with value: 0.9923865274378526 and parameters: {'n_estimators': 500, 'min_samples_split': 4, 'max_depth': 21}. Best is trial 1 with value: 0.9943369255197556.
# Precision: 0.9908735332464146
# Recall: 0.9908735332464146
# Aging Rate: 0.5
# Precision: 0.9934725848563969
# Recall: 0.9921773142112125
# Aging Rate: 0.49934810951760106
# Precision: 0.9921052631578947
# Recall: 0.9830508474576272
# Aging Rate: 0.4954367666232073
# [I 2022-03-04 09:23:46,289] Trial 4 finished with value: 0.990418454072222 and parameters: {'n_estimators': 100, 'min_samples_split': 6, 'max_depth': 21}. Best is trial 1 with value: 0.9943369255197556.
# Precision: 0.9920948616600791
# Recall: 0.9817470664928292
# Aging Rate: 0.49478487614080835
# Precision: 0.993368700265252
# Recall: 0.9765319426336375
# Aging Rate: 0.4915254237288136
# Precision: 0.9960578186596584
# Recall: 0.9882659713168188
# Aging Rate: 0.49608865710560623
# [I 2022-03-04 09:23:50,918] Trial 5 finished with value: 0.9879729354857473 and parameters: {'n_estimators': 1000, 'min_samples_split': 12, 'max_depth': 15}. Best is trial 1 with value: 0.9943369255197556.
# Precision: 0.9908854166666666
# Recall: 0.9921773142112125
# Aging Rate: 0.500651890482399
# Precision: 0.9973753280839895
# Recall: 0.9908735332464146
# Aging Rate: 0.49674054758800523
# Precision: 0.9934810951760105
# Recall: 0.9934810951760105
# Aging Rate: 0.5
# [I 2022-03-04 09:23:56,121] Trial 6 finished with value: 0.993041946556871 and parameters: {'n_estimators': 1000, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 1 with value: 0.9943369255197556.
# Precision: 0.9934725848563969
# Recall: 0.9921773142112125
# Aging Rate: 0.49934810951760106
# Precision: 0.994750656167979
# Recall: 0.9882659713168188
# Aging Rate: 0.49674054758800523
# Precision: 0.9908015768725361
# Recall: 0.9830508474576272
# Aging Rate: 0.49608865710560623
# [I 2022-03-04 09:23:57,085] Trial 7 finished with value: 0.9904110775858905 and parameters: {'n_estimators': 100, 'min_samples_split': 12, 'max_depth': 18}. Best is trial 1 with value: 0.9943369255197556.
# Precision: 0.9960886571056062
# Recall: 0.9960886571056062
# Aging Rate: 0.5
# Precision: 0.9973924380704041
# Recall: 0.9973924380704041
# Aging Rate: 0.5
# Precision: 0.9986876640419947
# Recall: 0.9921773142112125
# Aging Rate: 0.49674054758800523
# [I 2022-03-04 09:23:58,854] Trial 8 finished with value: 0.9963009798395727 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9867197875166003
# Recall: 0.9687092568448501
# Aging Rate: 0.4908735332464146
# Precision: 0.9830065359477124
# Recall: 0.9804432855280313
# Aging Rate: 0.49869621903520206
# Precision: 0.9816993464052287
# Recall: 0.9791395045632334
# Aging Rate: 0.49869621903520206
# [I 2022-03-04 09:24:00,588] Trial 9 finished with value: 0.97992419037149 and parameters: {'n_estimators': 300, 'min_samples_split': 6, 'max_depth': 9}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9932795698924731
# Recall: 0.9634941329856584
# Aging Rate: 0.485006518904824
# Precision: 0.9844155844155844
# Recall: 0.9882659713168188
# Aging Rate: 0.5019556714471969
# Precision: 0.9788079470198675
# Recall: 0.9634941329856584
# Aging Rate: 0.4921773142112125
# [I 2022-03-04 09:24:02,352] Trial 10 finished with value: 0.978529283058399 and parameters: {'n_estimators': 300, 'min_samples_split': 10, 'max_depth': 9}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9908972691807543
# Recall: 0.9934810951760105
# Aging Rate: 0.5013037809647979
# Precision: 0.9947848761408083
# Recall: 0.9947848761408083
# Aging Rate: 0.5
# Precision: 0.9947848761408083
# Recall: 0.9947848761408083
# Aging Rate: 0.5
# [I 2022-03-04 09:24:04,877] Trial 11 finished with value: 0.9939190840938723 and parameters: {'n_estimators': 500, 'min_samples_split': 4, 'max_depth': 15}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9973753280839895
# Recall: 0.9908735332464146
# Aging Rate: 0.49674054758800523
# Precision: 0.997364953886693
# Recall: 0.9869621903520208
# Aging Rate: 0.49478487614080835
# Precision: 0.9934469200524246
# Recall: 0.9882659713168188
# Aging Rate: 0.4973924380704042
# [I 2022-03-04 09:24:07,440] Trial 12 finished with value: 0.9923665923782399 and parameters: {'n_estimators': 500, 'min_samples_split': 2, 'max_depth': 15}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.994750656167979
# Recall: 0.9882659713168188
# Aging Rate: 0.49674054758800523
# Precision: 0.9907651715039578
# Recall: 0.9791395045632334
# Aging Rate: 0.4941329856584094
# Precision: 0.9921363040629095
# Recall: 0.9869621903520208
# Aging Rate: 0.4973924380704042
# [I 2022-03-04 09:24:09,186] Trial 13 finished with value: 0.9886527424563957 and parameters: {'n_estimators': 300, 'min_samples_split': 4, 'max_depth': 12}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.996078431372549
# Recall: 0.9934810951760105
# Aging Rate: 0.49869621903520206
# Precision: 0.9947159841479525
# Recall: 0.9817470664928292
# Aging Rate: 0.4934810951760104
# Precision: 0.9921773142112125
# Recall: 0.9921773142112125
# Aging Rate: 0.5
# [I 2022-03-04 09:24:11,755] Trial 14 finished with value: 0.9917147861580943 and parameters: {'n_estimators': 500, 'min_samples_split': 4, 'max_depth': 18}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9986876640419947
# Recall: 0.9921773142112125
# Aging Rate: 0.49674054758800523
# Precision: 0.9960629921259843
# Recall: 0.9895697522816167
# Aging Rate: 0.49674054758800523
# Precision: 0.9960578186596584
# Recall: 0.9882659713168188
# Aging Rate: 0.49608865710560623
# [I 2022-03-04 09:24:13,471] Trial 15 finished with value: 0.9934580655323432 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 18}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9841688654353562
# Recall: 0.9726205997392438
# Aging Rate: 0.4941329856584094
# Precision: 0.9869791666666666
# Recall: 0.9882659713168188
# Aging Rate: 0.500651890482399
# Precision: 0.993368700265252
# Recall: 0.9765319426336375
# Aging Rate: 0.4915254237288136
# [I 2022-03-04 09:24:15,994] Trial 16 finished with value: 0.9836203916895309 and parameters: {'n_estimators': 500, 'min_samples_split': 6, 'max_depth': 9}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9947575360419397
# Recall: 0.9895697522816167
# Aging Rate: 0.4973924380704042
# Precision: 0.9832904884318766
# Recall: 0.9973924380704041
# Aging Rate: 0.5071707953063885
# Precision: 0.9921156373193167
# Recall: 0.984354628422425
# Aging Rate: 0.49608865710560623
# [I 2022-03-04 09:24:20,579] Trial 17 finished with value: 0.9902226733896594 and parameters: {'n_estimators': 1000, 'min_samples_split': 8, 'max_depth': 12}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9986824769433466
# Recall: 0.9882659713168188
# Aging Rate: 0.49478487614080835
# Precision: 1.0
# Recall: 0.9882659713168188
# Aging Rate: 0.4941329856584094
# Precision: 0.9973718791064389
# Recall: 0.9895697522816167
# Aging Rate: 0.49608865710560623
# [I 2022-03-04 09:24:23,148] Trial 18 finished with value: 0.9936669260301204 and parameters: {'n_estimators': 500, 'min_samples_split': 4, 'max_depth': 18}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9960681520314548
# Recall: 0.9908735332464146
# Aging Rate: 0.4973924380704042
# Precision: 0.9960681520314548
# Recall: 0.9908735332464146
# Aging Rate: 0.4973924380704042
# Precision: 0.9986824769433466
# Recall: 0.9882659713168188
# Aging Rate: 0.49478487614080835
# [I 2022-03-04 09:24:24,896] Trial 19 finished with value: 0.9934583415425293 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 15}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9549071618037135
# Recall: 0.9387222946544981
# Aging Rate: 0.4915254237288136
# Precision: 0.9415670650730412
# Recall: 0.924380704041721
# Aging Rate: 0.4908735332464146
# Precision: 0.9373368146214099
# Recall: 0.9361147327249022
# Aging Rate: 0.49934810951760106
# [I 2022-03-04 09:24:26,650] Trial 20 finished with value: 0.9387885580179406 and parameters: {'n_estimators': 300, 'min_samples_split': 6, 'max_depth': 6}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9973753280839895
# Recall: 0.9908735332464146
# Aging Rate: 0.49674054758800523
# Precision: 0.9857881136950905
# Recall: 0.9947848761408083
# Aging Rate: 0.5045632333767927
# Precision: 0.9960578186596584
# Recall: 0.9882659713168188
# Aging Rate: 0.49608865710560623
# [I 2022-03-04 09:24:29,256] Trial 21 finished with value: 0.9921754859090618 and parameters: {'n_estimators': 500, 'min_samples_split': 4, 'max_depth': 15}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9934383202099738
# Recall: 0.9869621903520208
# Aging Rate: 0.49674054758800523
# Precision: 0.994750656167979
# Recall: 0.9882659713168188
# Aging Rate: 0.49674054758800523
# Precision: 0.9921363040629095
# Recall: 0.9869621903520208
# Aging Rate: 0.4973924380704042
# [I 2022-03-04 09:24:31,763] Trial 22 finished with value: 0.9904099536769871 and parameters: {'n_estimators': 500, 'min_samples_split': 4, 'max_depth': 12}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9986859395532195
# Recall: 0.9908735332464146
# Aging Rate: 0.49608865710560623
# Precision: 0.9947780678851175
# Recall: 0.9934810951760105
# Aging Rate: 0.49934810951760106
# Precision: 0.9960732984293194
# Recall: 0.9921773142112125
# Aging Rate: 0.4980443285528031
# [I 2022-03-04 09:24:34,336] Trial 23 finished with value: 0.9943383485470699 and parameters: {'n_estimators': 500, 'min_samples_split': 2, 'max_depth': 15}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9986910994764397
# Recall: 0.9947848761408083
# Aging Rate: 0.4980443285528031
# Precision: 0.9960681520314548
# Recall: 0.9908735332464146
# Aging Rate: 0.4973924380704042
# Precision: 0.9934810951760105
# Recall: 0.9934810951760105
# Aging Rate: 0.5
# [I 2022-03-04 09:24:36,859] Trial 24 finished with value: 0.9945597693809622 and parameters: {'n_estimators': 500, 'min_samples_split': 2, 'max_depth': 18}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9986876640419947
# Recall: 0.9921773142112125
# Aging Rate: 0.49674054758800523
# Precision: 0.99609375
# Recall: 0.9973924380704041
# Aging Rate: 0.500651890482399
# Precision: 0.996078431372549
# Recall: 0.9934810951760105
# Aging Rate: 0.49869621903520206
# [I 2022-03-04 09:24:39,473] Trial 25 finished with value: 0.9956475277458657 and parameters: {'n_estimators': 500, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 1.0
# Recall: 0.9817470664928292
# Aging Rate: 0.4908735332464146
# Precision: 1.0
# Recall: 0.9934810951760105
# Aging Rate: 0.49674054758800523
# Precision: 1.0
# Recall: 0.9908735332464146
# Aging Rate: 0.4954367666232073
# [I 2022-03-04 09:24:42,002] Trial 26 finished with value: 0.9943117368561792 and parameters: {'n_estimators': 500, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9986842105263158
# Recall: 0.9895697522816167
# Aging Rate: 0.4954367666232073
# Precision: 0.9960886571056062
# Recall: 0.9960886571056062
# Aging Rate: 0.5
# Precision: 0.9986893840104849
# Recall: 0.9934810951760105
# Aging Rate: 0.4973924380704042
# [I 2022-03-04 09:24:42,932] Trial 27 finished with value: 0.9954243929504788 and parameters: {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9973718791064389
# Recall: 0.9895697522816167
# Aging Rate: 0.49608865710560623
# Precision: 0.9973787680209698
# Recall: 0.9921773142112125
# Aging Rate: 0.4973924380704042
# Precision: 0.9934895833333334
# Recall: 0.9947848761408083
# Aging Rate: 0.500651890482399
# [I 2022-03-04 09:24:43,838] Trial 28 finished with value: 0.9941211823432846 and parameters: {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9960732984293194
# Recall: 0.9921773142112125
# Aging Rate: 0.4980443285528031
# Precision: 0.9947437582128777
# Recall: 0.9869621903520208
# Aging Rate: 0.49608865710560623
# Precision: 0.9933949801849405
# Recall: 0.9804432855280313
# Aging Rate: 0.4934810951760104
# [I 2022-03-04 09:24:44,768] Trial 29 finished with value: 0.9906119419925853 and parameters: {'n_estimators': 100, 'min_samples_split': 8, 'max_depth': 21}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9960369881109643
# Recall: 0.9830508474576272
# Aging Rate: 0.4934810951760104
# Precision: 0.9986910994764397
# Recall: 0.9947848761408083
# Aging Rate: 0.4980443285528031
# Precision: 0.994729907773386
# Recall: 0.984354628422425
# Aging Rate: 0.49478487614080835
# [I 2022-03-04 09:24:45,708] Trial 30 finished with value: 0.9919168483663773 and parameters: {'n_estimators': 100, 'min_samples_split': 10, 'max_depth': 18}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9986842105263158
# Recall: 0.9895697522816167
# Aging Rate: 0.4954367666232073
# Precision: 0.9960732984293194
# Recall: 0.9921773142112125
# Aging Rate: 0.4980443285528031
# Precision: 1.0
# Recall: 0.9973924380704041
# Aging Rate: 0.49869621903520206
# [I 2022-03-04 09:24:46,849] Trial 31 finished with value: 0.9956406988557635 and parameters: {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9960681520314548
# Recall: 0.9908735332464146
# Aging Rate: 0.4973924380704042
# Precision: 0.9973821989528796
# Recall: 0.9934810951760105
# Aging Rate: 0.4980443285528031
# Precision: 0.9960732984293194
# Recall: 0.9921773142112125
# Aging Rate: 0.4980443285528031
# [I 2022-03-04 09:24:47,760] Trial 32 finished with value: 0.9943377888204413 and parameters: {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9947712418300654
# Recall: 0.9921773142112125
# Aging Rate: 0.49869621903520206
# Precision: 0.9973787680209698
# Recall: 0.9921773142112125
# Aging Rate: 0.4973924380704042
# Precision: 0.9908616187989556
# Recall: 0.9895697522816167
# Aging Rate: 0.49934810951760106
# [I 2022-03-04 09:24:48,727] Trial 33 finished with value: 0.9928196969581098 and parameters: {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9947643979057592
# Recall: 0.9908735332464146
# Aging Rate: 0.4980443285528031
# Precision: 0.9857881136950905
# Recall: 0.9947848761408083
# Aging Rate: 0.5045632333767927
# Precision: 1.0
# Recall: 0.9804432855280313
# Aging Rate: 0.49022164276401564
# [I 2022-03-04 09:24:49,647] Trial 34 finished with value: 0.9910687655949267 and parameters: {'n_estimators': 100, 'min_samples_split': 4, 'max_depth': 18}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.994750656167979
# Recall: 0.9882659713168188
# Aging Rate: 0.49674054758800523
# Precision: 0.9973890339425587
# Recall: 0.9960886571056062
# Aging Rate: 0.49934810951760106
# Precision: 0.9947643979057592
# Recall: 0.9908735332464146
# Aging Rate: 0.4980443285528031
# [I 2022-03-04 09:24:50,630] Trial 35 finished with value: 0.9936837619375251 and parameters: {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9986893840104849
# Recall: 0.9934810951760105
# Aging Rate: 0.4973924380704042
# Precision: 0.9934895833333334
# Recall: 0.9947848761408083
# Aging Rate: 0.500651890482399
# Precision: 0.9907894736842106
# Recall: 0.9817470664928292
# Aging Rate: 0.4954367666232073
# [I 2022-03-04 09:24:51,536] Trial 36 finished with value: 0.992154261131487 and parameters: {'n_estimators': 100, 'min_samples_split': 4, 'max_depth': 21}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 1.0
# Recall: 0.9895697522816167
# Aging Rate: 0.49478487614080835
# Precision: 0.994750656167979
# Recall: 0.9882659713168188
# Aging Rate: 0.49674054758800523
# Precision: 0.9960681520314548
# Recall: 0.9908735332464146
# Aging Rate: 0.4973924380704042
# [I 2022-03-04 09:24:53,274] Trial 37 finished with value: 0.993239766417231 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 18}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9934810951760105
# Recall: 0.9934810951760105
# Aging Rate: 0.5
# Precision: 0.9934469200524246
# Recall: 0.9882659713168188
# Aging Rate: 0.4973924380704042
# Precision: 0.9947437582128777
# Recall: 0.9869621903520208
# Aging Rate: 0.49608865710560623
# [I 2022-03-04 09:24:58,667] Trial 38 finished with value: 0.9917228215712344 and parameters: {'n_estimators': 1000, 'min_samples_split': 4, 'max_depth': 21}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.8858381502890174
# Recall: 0.7992177314211213
# Aging Rate: 0.4511082138200782
# Precision: 0.8772919605077574
# Recall: 0.8109517601043025
# Aging Rate: 0.4621903520208605
# Precision: 0.8720770288858322
# Recall: 0.8265971316818774
# Aging Rate: 0.47392438070404175
# [I 2022-03-04 09:24:59,659] Trial 39 finished with value: 0.8439494169750322 and parameters: {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 3}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9921875
# Recall: 0.9934810951760105
# Aging Rate: 0.500651890482399
# Precision: 0.9973856209150327
# Recall: 0.9947848761408083
# Aging Rate: 0.49869621903520206
# Precision: 0.9920739762219286
# Recall: 0.9791395045632334
# Aging Rate: 0.4934810951760104
# [I 2022-03-04 09:25:00,638] Trial 40 finished with value: 0.9914939105324262 and parameters: {'n_estimators': 100, 'min_samples_split': 6, 'max_depth': 21}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9921773142112125
# Recall: 0.9921773142112125
# Aging Rate: 0.5
# Precision: 0.9857142857142858
# Recall: 0.9895697522816167
# Aging Rate: 0.5019556714471969
# Precision: 0.9973718791064389
# Recall: 0.9895697522816167
# Aging Rate: 0.49608865710560623
# [I 2022-03-04 09:25:03,267] Trial 41 finished with value: 0.9910903559789793 and parameters: {'n_estimators': 500, 'min_samples_split': 2, 'max_depth': 18}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9856957087126138
# Recall: 0.9882659713168188
# Aging Rate: 0.5013037809647979
# Precision: 0.9934640522875817
# Recall: 0.9908735332464146
# Aging Rate: 0.49869621903520206
# Precision: 0.9947643979057592
# Recall: 0.9908735332464146
# Aging Rate: 0.4980443285528031
# [I 2022-03-04 09:25:05,973] Trial 42 finished with value: 0.990653807329597 and parameters: {'n_estimators': 500, 'min_samples_split': 2, 'max_depth': 18}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9895833333333334
# Recall: 0.9908735332464146
# Aging Rate: 0.500651890482399
# Precision: 0.9934640522875817
# Recall: 0.9908735332464146
# Aging Rate: 0.49869621903520206
# Precision: 0.9934725848563969
# Recall: 0.9921773142112125
# Aging Rate: 0.49934810951760106
# [I 2022-03-04 09:25:07,683] Trial 43 finished with value: 0.9917398806426982 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.996078431372549
# Recall: 0.9934810951760105
# Aging Rate: 0.49869621903520206
# Precision: 0.994750656167979
# Recall: 0.9882659713168188
# Aging Rate: 0.49674054758800523
# Precision: 0.9960681520314548
# Recall: 0.9908735332464146
# Aging Rate: 0.4973924380704042
# [I 2022-03-04 09:25:13,134] Trial 44 finished with value: 0.9932466103649569 and parameters: {'n_estimators': 1000, 'min_samples_split': 4, 'max_depth': 21}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9934725848563969
# Recall: 0.9921773142112125
# Aging Rate: 0.49934810951760106
# Precision: 0.9896103896103896
# Recall: 0.9934810951760105
# Aging Rate: 0.5019556714471969
# Precision: 0.9973614775725593
# Recall: 0.9856584093872229
# Aging Rate: 0.4941329856584094
# [I 2022-03-04 09:25:15,675] Trial 45 finished with value: 0.9919473005912639 and parameters: {'n_estimators': 500, 'min_samples_split': 2, 'max_depth': 18}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9947643979057592
# Recall: 0.9908735332464146
# Aging Rate: 0.4980443285528031
# Precision: 0.9960681520314548
# Recall: 0.9908735332464146
# Aging Rate: 0.4973924380704042
# Precision: 0.9973718791064389
# Recall: 0.9895697522816167
# Aging Rate: 0.49608865710560623
# [I 2022-03-04 09:25:17,460] Trial 46 finished with value: 0.993244901054743 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9947780678851175
# Recall: 0.9934810951760105
# Aging Rate: 0.49934810951760106
# Precision: 0.997364953886693
# Recall: 0.9869621903520208
# Aging Rate: 0.49478487614080835
# Precision: 0.9844961240310077
# Recall: 0.9934810951760105
# Aging Rate: 0.5045632333767927
# [I 2022-03-04 09:25:18,477] Trial 47 finished with value: 0.9917445550138536 and parameters: {'n_estimators': 100, 'min_samples_split': 4, 'max_depth': 18}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9921875
# Recall: 0.9934810951760105
# Aging Rate: 0.500651890482399
# Precision: 0.9921773142112125
# Recall: 0.9921773142112125
# Aging Rate: 0.5
# Precision: 0.996078431372549
# Recall: 0.9934810951760105
# Aging Rate: 0.49869621903520206
# [I 2022-03-04 09:25:20,981] Trial 48 finished with value: 0.9932630861059429 and parameters: {'n_estimators': 500, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 8 with value: 0.9963009798395727.
# Precision: 0.9960732984293194
# Recall: 0.9921773142112125
# Aging Rate: 0.4980443285528031
# Precision: 0.9934895833333334
# Recall: 0.9947848761408083
# Aging Rate: 0.500651890482399
# [I 2022-03-04 09:25:22,940] A new study created in memory with name: no-name-36e05e52-b3d1-45e6-984c-88f944cd4914
# Precision: 0.9908616187989556
# Recall: 0.9895697522816167
# Aging Rate: 0.49934810951760106
# [I 2022-03-04 09:25:22,880] Trial 49 finished with value: 0.9928245204093956 and parameters: {'n_estimators': 300, 'min_samples_split': 4, 'max_depth': 18}. Best is trial 8 with value: 0.9963009798395727.
# Sampler is TPESampler
# Dataset 2 :
# C:\Users\user\anaconda3\envs\aging\lib\site-packages\optuna\progress_bar.py:47: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
#   0%|          | 0/50 [00:00<?, ?it/s]
# Precision: 0.8888888888888888
# Recall: 0.896
# Aging Rate: 0.504
# Precision: 0.8941018766756033
# Recall: 0.8893333333333333
# Aging Rate: 0.49733333333333335
# Precision: 0.8960526315789473
# Recall: 0.908
# Aging Rate: 0.5066666666666667
# [I 2022-03-04 09:25:25,605] Trial 0 finished with value: 0.8953760879326245 and parameters: {'n_estimators': 500, 'min_samples_split': 12, 'max_depth': 6}. Best is trial 0 with value: 0.8953760879326245.
# Precision: 0.792
# Recall: 0.792
# Aging Rate: 0.5
# Precision: 0.8151260504201681
# Recall: 0.776
# Aging Rate: 0.476
# Precision: 0.7966339410939691
# Recall: 0.7573333333333333
# Aging Rate: 0.47533333333333333
# [I 2022-03-04 09:25:27,485] Trial 1 finished with value: 0.7878562128122094 and parameters: {'n_estimators': 300, 'min_samples_split': 10, 'max_depth': 3}. Best is trial 0 with value: 0.8953760879326245.
# Precision: 0.8018433179723502
# Recall: 0.696
# Aging Rate: 0.434
# Precision: 0.8200589970501475
# Recall: 0.7413333333333333
# Aging Rate: 0.452
# Precision: 0.8118811881188119
# Recall: 0.7653333333333333
# Aging Rate: 0.4713333333333333
# [I 2022-03-04 09:25:29,287] Trial 2 finished with value: 0.7706046272644033 and parameters: {'n_estimators': 300, 'min_samples_split': 4, 'max_depth': 3}. Best is trial 0 with value: 0.8953760879326245.
# Precision: 0.882907133243607
# Recall: 0.8746666666666667
# Aging Rate: 0.49533333333333335
# Precision: 0.9099590723055935
# Recall: 0.8893333333333333
# Aging Rate: 0.4886666666666667
# Precision: 0.9142053445850914
# Recall: 0.8666666666666667
# Aging Rate: 0.474
# [I 2022-03-04 09:25:30,263] Trial 3 finished with value: 0.8893656905613619 and parameters: {'n_estimators': 100, 'min_samples_split': 10, 'max_depth': 6}. Best is trial 0 with value: 0.8953760879326245.
# Precision: 0.9013698630136986
# Recall: 0.8773333333333333
# Aging Rate: 0.4866666666666667
# Precision: 0.9032697547683923
# Recall: 0.884
# Aging Rate: 0.48933333333333334
# Precision: 0.8812415654520918
# Recall: 0.8706666666666667
# Aging Rate: 0.494
# [I 2022-03-04 09:25:35,050] Trial 4 finished with value: 0.8862141287865444 and parameters: {'n_estimators': 1000, 'min_samples_split': 8, 'max_depth': 6}. Best is trial 0 with value: 0.8953760879326245.
# Precision: 0.9828042328042328
# Recall: 0.9906666666666667
# Aging Rate: 0.504
# Precision: 0.9748344370860927
# Recall: 0.9813333333333333
# Aging Rate: 0.5033333333333333
# Precision: 0.970013037809648
# Recall: 0.992
# Aging Rate: 0.5113333333333333
# [I 2022-03-04 09:25:37,130] Trial 5 finished with value: 0.9818920665214446 and parameters: {'n_estimators': 300, 'min_samples_split': 12, 'max_depth': 15}. Best is trial 5 with value: 0.9818920665214446.
# Precision: 0.9865951742627346
# Recall: 0.9813333333333333
# Aging Rate: 0.49733333333333335
# Precision: 0.9840637450199203
# Recall: 0.988
# Aging Rate: 0.502
# Precision: 0.9827586206896551
# Recall: 0.988
# Aging Rate: 0.5026666666666667
# [I 2022-03-04 09:25:42,121] Trial 6 finished with value: 0.9851191679295482 and parameters: {'n_estimators': 1000, 'min_samples_split': 2, 'max_depth': 15}. Best is trial 6 with value: 0.9851191679295482.
# Precision: 0.7965616045845272
# Recall: 0.7413333333333333
# Aging Rate: 0.4653333333333333
# Precision: 0.7991913746630728
# Recall: 0.7906666666666666
# Aging Rate: 0.49466666666666664
# Precision: 0.8205882352941176
# Recall: 0.744
# Aging Rate: 0.4533333333333333
# [I 2022-03-04 09:25:43,881] Trial 7 finished with value: 0.7810938492481307 and parameters: {'n_estimators': 300, 'min_samples_split': 8, 'max_depth': 3}. Best is trial 6 with value: 0.9851191679295482.
# Precision: 0.8917456021650879
# Recall: 0.8786666666666667
# Aging Rate: 0.49266666666666664
# Precision: 0.889795918367347
# Recall: 0.872
# Aging Rate: 0.49
# Precision: 0.8812664907651715
# Recall: 0.8906666666666667
# Aging Rate: 0.5053333333333333
# [I 2022-03-04 09:25:44,794] Trial 8 finished with value: 0.883969183137799 and parameters: {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 6}. Best is trial 6 with value: 0.9851191679295482.
# Precision: 0.9853917662682603
# Recall: 0.9893333333333333
# Aging Rate: 0.502
# Precision: 0.9802890932982917
# Recall: 0.9946666666666667
# Aging Rate: 0.5073333333333333
# Precision: 0.9776315789473684
# Recall: 0.9906666666666667
# Aging Rate: 0.5066666666666667
# [I 2022-03-04 09:25:45,906] Trial 9 finished with value: 0.9862967074540202 and parameters: {'n_estimators': 100, 'min_samples_split': 8, 'max_depth': 21}. Best is trial 9 with value: 0.9862967074540202.
# Precision: 0.9854689564068693
# Recall: 0.9946666666666667
# Aging Rate: 0.5046666666666667
# Precision: 0.9750328515111695
# Recall: 0.9893333333333333
# Aging Rate: 0.5073333333333333
# Precision: 0.9790301441677588
# Recall: 0.996
# Aging Rate: 0.5086666666666667
# [I 2022-03-04 09:25:46,931] Trial 10 finished with value: 0.9865398856086135 and parameters: {'n_estimators': 100, 'min_samples_split': 6, 'max_depth': 21}. Best is trial 10 with value: 0.9865398856086135.
# Precision: 0.9841479524438573
# Recall: 0.9933333333333333
# Aging Rate: 0.5046666666666667
# Precision: 0.9765013054830287
# Recall: 0.9973333333333333
# Aging Rate: 0.5106666666666667
# Precision: 0.9880636604774535
# Recall: 0.9933333333333333
# Aging Rate: 0.5026666666666667
# [I 2022-03-04 09:25:48,013] Trial 11 finished with value: 0.9887393957038974 and parameters: {'n_estimators': 100, 'min_samples_split': 6, 'max_depth': 21}. Best is trial 11 with value: 0.9887393957038974.
# Precision: 0.9841059602649007
# Recall: 0.9906666666666667
# Aging Rate: 0.5033333333333333
# Precision: 0.9750982961992136
# Recall: 0.992
# Aging Rate: 0.5086666666666667
# Precision: 0.9867724867724867
# Recall: 0.9946666666666667
# Aging Rate: 0.504
# [I 2022-03-04 09:25:49,179] Trial 12 finished with value: 0.9871852677420336 and parameters: {'n_estimators': 100, 'min_samples_split': 4, 'max_depth': 21}. Best is trial 11 with value: 0.9887393957038974.
# Precision: 0.9854111405835544
# Recall: 0.9906666666666667
# Aging Rate: 0.5026666666666667
# Precision: 0.9816031537450722
# Recall: 0.996
# Aging Rate: 0.5073333333333333
# Precision: 0.9790301441677588
# Recall: 0.996
# Aging Rate: 0.5086666666666667
# [I 2022-03-04 09:25:50,325] Trial 13 finished with value: 0.9880744185017645 and parameters: {'n_estimators': 100, 'min_samples_split': 4, 'max_depth': 18}. Best is trial 11 with value: 0.9887393957038974.
# Precision: 0.9789473684210527
# Recall: 0.992
# Aging Rate: 0.5066666666666667
# Precision: 0.9828042328042328
# Recall: 0.9906666666666667
# Aging Rate: 0.504
# Precision: 0.9829172141918529
# Recall: 0.9973333333333333
# Aging Rate: 0.5073333333333333
# [I 2022-03-04 09:25:51,507] Trial 14 finished with value: 0.987407683521103 and parameters: {'n_estimators': 100, 'min_samples_split': 4, 'max_depth': 18}. Best is trial 11 with value: 0.9887393957038974.
# Precision: 0.9828042328042328
# Recall: 0.9906666666666667
# Aging Rate: 0.504
# Precision: 0.9801849405548216
# Recall: 0.9893333333333333
# Aging Rate: 0.5046666666666667
# Precision: 0.9919893190921228
# Recall: 0.9906666666666667
# Aging Rate: 0.49933333333333335
# [I 2022-03-04 09:25:54,236] Trial 15 finished with value: 0.9875950763550377 and parameters: {'n_estimators': 500, 'min_samples_split': 6, 'max_depth': 18}. Best is trial 11 with value: 0.9887393957038974.
# Precision: 0.9799465240641712
# Recall: 0.9773333333333334
# Aging Rate: 0.49866666666666665
# Precision: 0.976158940397351
# Recall: 0.9826666666666667
# Aging Rate: 0.5033333333333333
# Precision: 0.9707446808510638
# Recall: 0.9733333333333334
# Aging Rate: 0.5013333333333333
# [I 2022-03-04 09:25:55,294] Trial 16 finished with value: 0.9766924870743269 and parameters: {'n_estimators': 100, 'min_samples_split': 6, 'max_depth': 12}. Best is trial 11 with value: 0.9887393957038974.
# Precision: 0.9854497354497355
# Recall: 0.9933333333333333
# Aging Rate: 0.504
# Precision: 0.9776902887139107
# Recall: 0.9933333333333333
# Aging Rate: 0.508
# Precision: 0.9841897233201581
# Recall: 0.996
# Aging Rate: 0.506
# [I 2022-03-04 09:25:56,348] Trial 17 finished with value: 0.9882950692033776 and parameters: {'n_estimators': 100, 'min_samples_split': 4, 'max_depth': 18}. Best is trial 11 with value: 0.9887393957038974.
# Precision: 0.9764089121887287
# Recall: 0.9933333333333333
# Aging Rate: 0.5086666666666667
# Precision: 0.9893333333333333
# Recall: 0.9893333333333333
# Aging Rate: 0.5
# Precision: 0.9662775616083009
# Recall: 0.9933333333333333
# Aging Rate: 0.514
# [I 2022-03-04 09:25:59,080] Trial 18 finished with value: 0.9845834730024063 and parameters: {'n_estimators': 500, 'min_samples_split': 2, 'max_depth': 15}. Best is trial 11 with value: 0.9887393957038974.
# Precision: 0.9788079470198675
# Recall: 0.9853333333333333
# Aging Rate: 0.5033333333333333
# Precision: 0.9853137516688919
# Recall: 0.984
# Aging Rate: 0.49933333333333335
# Precision: 0.9708994708994709
# Recall: 0.9786666666666667
# Aging Rate: 0.504
# [I 2022-03-04 09:26:04,253] Trial 19 finished with value: 0.9804946115236919 and parameters: {'n_estimators': 1000, 'min_samples_split': 6, 'max_depth': 12}. Best is trial 11 with value: 0.9887393957038974.
# Precision: 0.9815546772068511
# Recall: 0.9933333333333333
# Aging Rate: 0.506
# Precision: 0.979002624671916
# Recall: 0.9946666666666667
# Aging Rate: 0.508
# Precision: 0.9854304635761589
# Recall: 0.992
# Aging Rate: 0.5033333333333333
# [I 2022-03-04 09:26:05,305] Trial 20 finished with value: 0.9876285619207931 and parameters: {'n_estimators': 100, 'min_samples_split': 4, 'max_depth': 18}. Best is trial 11 with value: 0.9887393957038974.
# Precision: 0.9879518072289156
# Recall: 0.984
# Aging Rate: 0.498
# Precision: 0.988110964332893
# Recall: 0.9973333333333333
# Aging Rate: 0.5046666666666667
# Precision: 0.9790301441677588
# Recall: 0.996
# Aging Rate: 0.5086666666666667
# [I 2022-03-04 09:26:06,520] Trial 21 finished with value: 0.9887049472310566 and parameters: {'n_estimators': 100, 'min_samples_split': 4, 'max_depth': 18}. Best is trial 11 with value: 0.9887393957038974.
# Precision: 0.988
# Recall: 0.988
# Aging Rate: 0.5
# Precision: 0.980106100795756
# Recall: 0.9853333333333333
# Aging Rate: 0.5026666666666667
# Precision: 0.9854304635761589
# Recall: 0.992
# Aging Rate: 0.5033333333333333
# [I 2022-03-04 09:26:07,858] Trial 22 finished with value: 0.9864723616314413 and parameters: {'n_estimators': 100, 'min_samples_split': 4, 'max_depth': 21}. Best is trial 11 with value: 0.9887393957038974.
# Precision: 0.9801587301587301
# Recall: 0.988
# Aging Rate: 0.504
# Precision: 0.978891820580475
# Recall: 0.9893333333333333
# Aging Rate: 0.5053333333333333
# Precision: 0.9854304635761589
# Recall: 0.992
# Aging Rate: 0.5033333333333333
# [I 2022-03-04 09:26:09,133] Trial 23 finished with value: 0.9856176481978007 and parameters: {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 18}. Best is trial 11 with value: 0.9887393957038974.
# Precision: 0.9697368421052631
# Recall: 0.9826666666666667
# Aging Rate: 0.5066666666666667
# Precision: 0.9814814814814815
# Recall: 0.9893333333333333
# Aging Rate: 0.504
# Precision: 0.9774535809018567
# Recall: 0.9826666666666667
# Aging Rate: 0.5026666666666667
# [I 2022-03-04 09:26:10,399] Trial 24 finished with value: 0.9805346327183244 and parameters: {'n_estimators': 100, 'min_samples_split': 6, 'max_depth': 15}. Best is trial 11 with value: 0.9887393957038974.
# Precision: 0.9789750328515112
# Recall: 0.9933333333333333
# Aging Rate: 0.5073333333333333
# Precision: 0.9841897233201581
# Recall: 0.996
# Aging Rate: 0.506
# Precision: 0.9841897233201581
# Recall: 0.996
# Aging Rate: 0.506
# [I 2022-03-04 09:26:11,426] Trial 25 finished with value: 0.9887404011843346 and parameters: {'n_estimators': 100, 'min_samples_split': 4, 'max_depth': 21}. Best is trial 25 with value: 0.9887404011843346.
# Precision: 0.9802631578947368
# Recall: 0.9933333333333333
# Aging Rate: 0.5066666666666667
# Precision: 0.9854111405835544
# Recall: 0.9906666666666667
# Aging Rate: 0.5026666666666667
# Precision: 0.9867549668874173
# Recall: 0.9933333333333333
# Aging Rate: 0.5033333333333333
# [I 2022-03-04 09:26:12,584] Trial 26 finished with value: 0.9882733681241321 and parameters: {'n_estimators': 100, 'min_samples_split': 6, 'max_depth': 21}. Best is trial 25 with value: 0.9887404011843346.
# Precision: 0.9893475366178429
# Recall: 0.9906666666666667
# Aging Rate: 0.5006666666666667
# Precision: 0.9803149606299213
# Recall: 0.996
# Aging Rate: 0.508
# Precision: 0.9726205997392438
# Recall: 0.9946666666666667
# Aging Rate: 0.5113333333333333
# [I 2022-03-04 09:26:13,783] Trial 27 finished with value: 0.9872073352639155 and parameters: {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 25 with value: 0.9887404011843346.
# Precision: 0.9475806451612904
# Recall: 0.94
# Aging Rate: 0.496
# Precision: 0.9379947229551451
# Recall: 0.948
# Aging Rate: 0.5053333333333333
# Precision: 0.9605978260869565
# Recall: 0.9426666666666667
# Aging Rate: 0.49066666666666664
# [I 2022-03-04 09:26:14,934] Trial 28 finished with value: 0.9460979006519966 and parameters: {'n_estimators': 100, 'min_samples_split': 8, 'max_depth': 9}. Best is trial 25 with value: 0.9887404011843346.
# Precision: 0.9752281616688396
# Recall: 0.9973333333333333
# Aging Rate: 0.5113333333333333
# Precision: 0.9852941176470589
# Recall: 0.9826666666666667
# Aging Rate: 0.49866666666666665
# Precision: 0.9840425531914894
# Recall: 0.9866666666666667
# Aging Rate: 0.5013333333333333
# [I 2022-03-04 09:26:17,539] Trial 29 finished with value: 0.9851627965432309 and parameters: {'n_estimators': 500, 'min_samples_split': 4, 'max_depth': 21}. Best is trial 25 with value: 0.9887404011843346.
# Precision: 0.9802110817941952
# Recall: 0.9906666666666667
# Aging Rate: 0.5053333333333333
# Precision: 0.9828722002635046
# Recall: 0.9946666666666667
# Aging Rate: 0.506
# Precision: 0.9841479524438573
# Recall: 0.9933333333333333
# Aging Rate: 0.5046666666666667
# [I 2022-03-04 09:26:22,341] Trial 30 finished with value: 0.9876215705236047 and parameters: {'n_estimators': 1000, 'min_samples_split': 6, 'max_depth': 18}. Best is trial 25 with value: 0.9887404011843346.
# Precision: 0.9841688654353562
# Recall: 0.9946666666666667
# Aging Rate: 0.5053333333333333
# Precision: 0.9906914893617021
# Recall: 0.9933333333333333
# Aging Rate: 0.5013333333333333
# Precision: 0.9893333333333333
# Recall: 0.9893333333333333
# Aging Rate: 0.5
# [I 2022-03-04 09:26:23,492] Trial 31 finished with value: 0.9902446354070396 and parameters: {'n_estimators': 100, 'min_samples_split': 4, 'max_depth': 18}. Best is trial 31 with value: 0.9902446354070396.
# Precision: 0.979002624671916
# Recall: 0.9946666666666667
# Aging Rate: 0.508
# Precision: 0.9866844207723036
# Recall: 0.988
# Aging Rate: 0.5006666666666667
# Precision: 0.9827814569536424
# Recall: 0.9893333333333333
# Aging Rate: 0.5033333333333333
# [I 2022-03-04 09:26:24,678] Trial 32 finished with value: 0.9867202568507641 and parameters: {'n_estimators': 100, 'min_samples_split': 4, 'max_depth': 15}. Best is trial 31 with value: 0.9902446354070396.
# Precision: 0.9853917662682603
# Recall: 0.9893333333333333
# Aging Rate: 0.502
# Precision: 0.986737400530504
# Recall: 0.992
# Aging Rate: 0.5026666666666667
# Precision: 0.9893617021276596
# Recall: 0.992
# Aging Rate: 0.5013333333333333
# [I 2022-03-04 09:26:25,663] Trial 33 finished with value: 0.989133137589801 and parameters: {'n_estimators': 100, 'min_samples_split': 4, 'max_depth': 21}. Best is trial 31 with value: 0.9902446354070396.
# Precision: 0.978891820580475
# Recall: 0.9893333333333333
# Aging Rate: 0.5053333333333333
# Precision: 0.9854881266490765
# Recall: 0.996
# Aging Rate: 0.5053333333333333
# Precision: 0.9841479524438573
# Recall: 0.9933333333333333
# Aging Rate: 0.5046666666666667
# [I 2022-03-04 09:26:26,880] Trial 34 finished with value: 0.9878401236317168 and parameters: {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 31 with value: 0.9902446354070396.
# Precision: 0.9815789473684211
# Recall: 0.9946666666666667
# Aging Rate: 0.5066666666666667
# Precision: 0.9867197875166003
# Recall: 0.9906666666666667
# Aging Rate: 0.502
# Precision: 0.9933244325767691
# Recall: 0.992
# Aging Rate: 0.49933333333333335
# [I 2022-03-04 09:26:28,692] Trial 35 finished with value: 0.9898101776018352 and parameters: {'n_estimators': 300, 'min_samples_split': 6, 'max_depth': 21}. Best is trial 31 with value: 0.9902446354070396.
# Precision: 0.9867724867724867
# Recall: 0.9946666666666667
# Aging Rate: 0.504
# Precision: 0.9920106524633822
# Recall: 0.9933333333333333
# Aging Rate: 0.5006666666666667
# Precision: 0.9802890932982917
# Recall: 0.9946666666666667
# Aging Rate: 0.5073333333333333
# [I 2022-03-04 09:26:30,675] Trial 36 finished with value: 0.9902669831853723 and parameters: {'n_estimators': 300, 'min_samples_split': 4, 'max_depth': 21}. Best is trial 36 with value: 0.9902669831853723.
# Precision: 0.9828496042216359
# Recall: 0.9933333333333333
# Aging Rate: 0.5053333333333333
# Precision: 0.9867197875166003
# Recall: 0.9906666666666667
# Aging Rate: 0.502
# Precision: 0.9750656167979003
# Recall: 0.9906666666666667
# Aging Rate: 0.508
# [I 2022-03-04 09:26:32,594] Trial 37 finished with value: 0.9865190604573906 and parameters: {'n_estimators': 300, 'min_samples_split': 4, 'max_depth': 18}. Best is trial 36 with value: 0.9902669831853723.
# Precision: 0.984251968503937
# Recall: 1.0
# Aging Rate: 0.508
# Precision: 0.9854111405835544
# Recall: 0.9906666666666667
# Aging Rate: 0.5026666666666667
# Precision: 0.9920212765957447
# Recall: 0.9946666666666667
# Aging Rate: 0.5013333333333333
# [I 2022-03-04 09:26:34,575] Trial 38 finished with value: 0.9911458724477537 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 38 with value: 0.9911458724477537.
# Precision: 0.9814323607427056
# Recall: 0.9866666666666667
# Aging Rate: 0.5026666666666667
# Precision: 0.9840848806366048
# Recall: 0.9893333333333333
# Aging Rate: 0.5026666666666667
# Precision: 0.9802890932982917
# Recall: 0.9946666666666667
# Aging Rate: 0.5073333333333333
# [I 2022-03-04 09:26:36,379] Trial 39 finished with value: 0.9860567422823644 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 15}. Best is trial 38 with value: 0.9911458724477537.
# Precision: 0.9788079470198675
# Recall: 0.9853333333333333
# Aging Rate: 0.5033333333333333
# Precision: 0.9815546772068511
# Recall: 0.9933333333333333
# Aging Rate: 0.506
# Precision: 0.9726918075422627
# Recall: 0.9973333333333333
# Aging Rate: 0.5126666666666667
# [I 2022-03-04 09:26:38,313] Trial 40 finished with value: 0.9847757134101015 and parameters: {'n_estimators': 300, 'min_samples_split': 10, 'max_depth': 18}. Best is trial 38 with value: 0.9911458724477537.
# Precision: 0.9946380697050938
# Recall: 0.9893333333333333
# Aging Rate: 0.49733333333333335
# Precision: 0.9723320158102767
# Recall: 0.984
# Aging Rate: 0.506
# Precision: 0.9853723404255319
# Recall: 0.988
# Aging Rate: 0.5013333333333333
# [I 2022-03-04 09:26:40,445] Trial 41 finished with value: 0.9855980810405433 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 38 with value: 0.9911458724477537.
# Precision: 0.9841688654353562
# Recall: 0.9946666666666667
# Aging Rate: 0.5053333333333333
# Precision: 0.9906914893617021
# Recall: 0.9933333333333333
# Aging Rate: 0.5013333333333333
# Precision: 0.9750982961992136
# Recall: 0.992
# Aging Rate: 0.5086666666666667
# [I 2022-03-04 09:26:42,319] Trial 42 finished with value: 0.9882923698566245 and parameters: {'n_estimators': 300, 'min_samples_split': 8, 'max_depth': 21}. Best is trial 38 with value: 0.9911458724477537.
# Precision: 0.9854304635761589
# Recall: 0.992
# Aging Rate: 0.5033333333333333
# Precision: 0.9907038512616202
# Recall: 0.9946666666666667
# Aging Rate: 0.502
# Precision: 0.9828496042216359
# Recall: 0.9933333333333333
# Aging Rate: 0.5053333333333333
# [I 2022-03-04 09:26:44,313] Trial 43 finished with value: 0.9898164278242935 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 38 with value: 0.9911458724477537.
# Precision: 0.9789750328515112
# Recall: 0.9933333333333333
# Aging Rate: 0.5073333333333333
# Precision: 0.9750328515111695
# Recall: 0.9893333333333333
# Aging Rate: 0.5073333333333333
# Precision: 0.9841479524438573
# Recall: 0.9933333333333333
# Aging Rate: 0.5046666666666667
# [I 2022-03-04 09:26:46,353] Trial 44 finished with value: 0.985650756064317 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 38 with value: 0.9911458724477537.
# Precision: 0.9814323607427056
# Recall: 0.9866666666666667
# Aging Rate: 0.5026666666666667
# Precision: 0.9776609724047306
# Recall: 0.992
# Aging Rate: 0.5073333333333333
# Precision: 0.9827586206896551
# Recall: 0.988
# Aging Rate: 0.5026666666666667
# [I 2022-03-04 09:26:48,339] Trial 45 finished with value: 0.9847310620461767 and parameters: {'n_estimators': 300, 'min_samples_split': 12, 'max_depth': 21}. Best is trial 38 with value: 0.9911458724477537.
# Precision: 0.9867549668874173
# Recall: 0.9933333333333333
# Aging Rate: 0.5033333333333333
# Precision: 0.9919678714859438
# Recall: 0.988
# Aging Rate: 0.498
# Precision: 0.9776021080368906
# Recall: 0.9893333333333333
# Aging Rate: 0.506
# [I 2022-03-04 09:26:50,408] Trial 46 finished with value: 0.9878153064743547 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 18}. Best is trial 38 with value: 0.9911458724477537.
# Precision: 0.9750328515111695
# Recall: 0.9893333333333333
# Aging Rate: 0.5073333333333333
# Precision: 0.9763469119579501
# Recall: 0.9906666666666667
# Aging Rate: 0.5073333333333333
# Precision: 0.9789473684210527
# Recall: 0.992
# Aging Rate: 0.5066666666666667
# [I 2022-03-04 09:26:52,398] Trial 47 finished with value: 0.9836720561357989 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 38 with value: 0.9911458724477537.
# Precision: 0.9535809018567639
# Recall: 0.9586666666666667
# Aging Rate: 0.5026666666666667
# Precision: 0.9588859416445623
# Recall: 0.964
# Aging Rate: 0.5026666666666667
# Precision: 0.9689189189189189
# Recall: 0.956
# Aging Rate: 0.49333333333333335
# [I 2022-03-04 09:26:54,287] Trial 48 finished with value: 0.9599897662906374 and parameters: {'n_estimators': 300, 'min_samples_split': 8, 'max_depth': 9}. Best is trial 38 with value: 0.9911458724477537.
# Precision: 0.9906166219839142
# Recall: 0.9853333333333333
# Aging Rate: 0.49733333333333335
# Precision: 0.988
# Recall: 0.988
# Aging Rate: 0.5
# [I 2022-03-04 09:26:56,465] A new study created in memory with name: no-name-337fb312-8516-4485-a142-2b8373a19bfe
# Precision: 0.9906666666666667
# Recall: 0.9906666666666667
# Aging Rate: 0.5
# [I 2022-03-04 09:26:56,404] Trial 49 finished with value: 0.9888781937017231 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 18}. Best is trial 38 with value: 0.9911458724477537.
# Sampler is TPESampler
# Dataset 3 :
# C:\Users\user\anaconda3\envs\aging\lib\site-packages\optuna\progress_bar.py:47: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
#   0%|          | 0/50 [00:00<?, ?it/s]
# Precision: 1.0
# Recall: 0.9025032938076416
# Aging Rate: 0.4512516469038208
# Precision: 1.0
# Recall: 0.8866930171277997
# Aging Rate: 0.44334650856389984
# Precision: 1.0
# Recall: 0.9025032938076416
# Aging Rate: 0.4512516469038208
# [I 2022-03-04 09:27:01,271] Trial 0 finished with value: 0.9458170197619894 and parameters: {'n_estimators': 1000, 'min_samples_split': 10, 'max_depth': 3}. Best is trial 0 with value: 0.9458170197619894.
# Precision: 1.0
# Recall: 0.922266139657444
# Aging Rate: 0.461133069828722
# Precision: 1.0
# Recall: 0.9104084321475626
# Aging Rate: 0.4552042160737813
# Precision: 1.0
# Recall: 0.927536231884058
# Aging Rate: 0.463768115942029
# ...
#   eff = r/ag
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# C:\Users\user\Desktop\Darui_R08621110\Master_Thesis\AUO aging test\Full_Version_Code\library\Aging_Score_Contour.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   eff = r/ag
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# C:\Users\user\Desktop\Darui_R08621110\Master_Thesis\AUO aging test\Full_Version_Code\library\Aging_Score_Contour.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   eff = r/ag
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-03-04 09:41:31,272] Trial 15 finished with value: 0.0 and parameters: {'n_estimators': 1000, 'min_samples_split': 2, 'max_depth': 3}. Best is trial 9 with value: 0.8875910303554689.
# Precision: 0.9824561403508771
# Recall: 0.7368421052631579
# Aging Rate: 0.06818181818181818
# Precision: 1.0
# Recall: 0.7894736842105263
# Aging Rate: 0.07177033492822966
# Precision: 1.0
# Recall: 0.7236842105263158
# Aging Rate: 0.06578947368421052
# [I 2022-03-04 09:41:32,992] Trial 16 finished with value: 0.8547176202743049 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 18}. Best is trial 9 with value: 0.8875910303554689.
# Precision: 0.9795918367346939
# Recall: 0.631578947368421
# Aging Rate: 0.05861244019138756
# Precision: 1.0
# Recall: 0.631578947368421
# Aging Rate: 0.05741626794258373
# Precision: 0.9565217391304348
# Recall: 0.5789473684210527
# Aging Rate: 0.05502392344497608
# [I 2022-03-04 09:41:34,737] Trial 17 finished with value: 0.7545016745989775 and parameters: {'n_estimators': 300, 'min_samples_split': 6, 'max_depth': 18}. Best is trial 9 with value: 0.8875910303554689.
# Precision: 1.0
# Recall: 0.5131578947368421
# Aging Rate: 0.04665071770334928
# Precision: 1.0
# Recall: 0.3815789473684211
# Aging Rate: 0.034688995215311005
# Precision: 1.0
# Recall: 0.3815789473684211
# Aging Rate: 0.034688995215311005
# [I 2022-03-04 09:41:36,457] Trial 18 finished with value: 0.5943409247757074 and parameters: {'n_estimators': 300, 'min_samples_split': 4, 'max_depth': 12}. Best is trial 9 with value: 0.8875910303554689.
# Precision: 0.9545454545454546
# Recall: 0.5526315789473685
# Aging Rate: 0.05263157894736842
# Precision: 1.0
# Recall: 0.631578947368421
# Aging Rate: 0.05741626794258373
# Precision: 0.9433962264150944
# Recall: 0.6578947368421053
# Aging Rate: 0.06339712918660287
# [I 2022-03-04 09:41:38,982] Trial 19 finished with value: 0.7497957822789031 and parameters: {'n_estimators': 500, 'min_samples_split': 8, 'max_depth': 18}. Best is trial 9 with value: 0.8875910303554689.
# Precision: 1.0
# Recall: 0.5657894736842105
# Aging Rate: 0.05143540669856459
# Precision: 0.9722222222222222
# Recall: 0.4605263157894737
# Aging Rate: 0.0430622009569378
# Precision: 1.0
# Recall: 0.5263157894736842
# Aging Rate: 0.04784688995215311
# [I 2022-03-04 09:41:43,901] Trial 20 finished with value: 0.6791147493480151 and parameters: {'n_estimators': 1000, 'min_samples_split': 2, 'max_depth': 12}. Best is trial 9 with value: 0.8875910303554689.
# Precision: 1.0
# Recall: 0.75
# Aging Rate: 0.06818181818181818
# Precision: 1.0
# Recall: 0.7368421052631579
# Aging Rate: 0.06698564593301436
# Precision: 1.0
# Recall: 0.8289473684210527
# Aging Rate: 0.07535885167464115
# [I 2022-03-04 09:41:45,625] Trial 21 finished with value: 0.8707008419238634 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 9 with value: 0.8875910303554689.
# Precision: 1.0
# Recall: 0.6973684210526315
# Aging Rate: 0.06339712918660287
# Precision: 0.9821428571428571
# Recall: 0.7236842105263158
# Aging Rate: 0.06698564593301436
# Precision: 1.0
# Recall: 0.6973684210526315
# Aging Rate: 0.06339712918660287
# [I 2022-03-04 09:41:47,487] Trial 22 finished with value: 0.8255813953488372 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 18}. Best is trial 9 with value: 0.8875910303554689.
# Precision: 0.9444444444444444
# Recall: 0.6710526315789473
# Aging Rate: 0.0645933014354067
# Precision: 1.0
# Recall: 0.75
# Aging Rate: 0.06818181818181818
# Precision: 0.9649122807017544
# Recall: 0.7236842105263158
# Aging Rate: 0.06818181818181818
# [I 2022-03-04 09:41:49,222] Trial 23 finished with value: 0.8229419703103913 and parameters: {'n_estimators': 300, 'min_samples_split': 4, 'max_depth': 21}. Best is trial 9 with value: 0.8875910303554689.
# Precision: 0.9833333333333333
# Recall: 0.7763157894736842
# Aging Rate: 0.07177033492822966
# Precision: 1.0
# Recall: 0.7236842105263158
# Aging Rate: 0.06578947368421052
# Precision: 1.0
# Recall: 0.7763157894736842
# Aging Rate: 0.07057416267942583
# [I 2022-03-04 09:41:50,965] Trial 24 finished with value: 0.8604719297953843 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 18}. Best is trial 9 with value: 0.8875910303554689.
# Precision: 0.9846153846153847
# Recall: 0.8421052631578947
# Aging Rate: 0.07775119617224881
# Precision: 1.0
# Recall: 0.75
# Aging Rate: 0.06818181818181818
# Precision: 0.9824561403508771
# Recall: 0.7368421052631579
# Aging Rate: 0.06818181818181818
# [I 2022-03-04 09:41:52,672] Trial 25 finished with value: 0.8690165129134894 and parameters: {'n_estimators': 300, 'min_samples_split': 4, 'max_depth': 21}. Best is trial 9 with value: 0.8875910303554689.
# Precision: 0.9636363636363636
# Recall: 0.6973684210526315
# Aging Rate: 0.06578947368421052
# Precision: 1.0
# Recall: 0.75
# Aging Rate: 0.06818181818181818
# Precision: 0.9811320754716981
# Recall: 0.6842105263157895
# Aging Rate: 0.06339712918660287
# [I 2022-03-04 09:41:54,365] Trial 26 finished with value: 0.824168237624655 and parameters: {'n_estimators': 300, 'min_samples_split': 4, 'max_depth': 21}. Best is trial 9 with value: 0.8875910303554689.
# Precision: 1.0
# Recall: 0.10526315789473684
# Aging Rate: 0.009569377990430622
# Precision: 0.7777777777777778
# Recall: 0.09210526315789473
# Aging Rate: 0.01076555023923445
# Precision: 1.0
# Recall: 0.09210526315789473
# Aging Rate: 0.008373205741626795
# [I 2022-03-04 09:41:56,098] Trial 27 finished with value: 0.17461892387477077 and parameters: {'n_estimators': 300, 'min_samples_split': 6, 'max_depth': 6}. Best is trial 9 with value: 0.8875910303554689.
# Precision: 1.0
# Recall: 0.6973684210526315
# Aging Rate: 0.06339712918660287
# Precision: 1.0
# Recall: 0.7105263157894737
# Aging Rate: 0.0645933014354067
# Precision: 0.9245283018867925
# Recall: 0.6447368421052632
# Aging Rate: 0.06339712918660287
# [I 2022-03-04 09:41:57,850] Trial 28 finished with value: 0.8040548598688133 and parameters: {'n_estimators': 300, 'min_samples_split': 4, 'max_depth': 21}. Best is trial 9 with value: 0.8875910303554689.
# Precision: 1.0
# Recall: 0.4473684210526316
# Aging Rate: 0.04066985645933014
# Precision: 0.9761904761904762
# Recall: 0.5394736842105263
# Aging Rate: 0.050239234449760764
# Precision: 0.9347826086956522
# Recall: 0.5657894736842105
# Aging Rate: 0.05502392344497608
# [I 2022-03-04 09:41:59,535] Trial 29 finished with value: 0.6726717017353305 and parameters: {'n_estimators': 300, 'min_samples_split': 8, 'max_depth': 15}. Best is trial 9 with value: 0.8875910303554689.
# Precision: 1.0
# Recall: 0.5789473684210527
# Aging Rate: 0.05263157894736842
# Precision: 0.9302325581395349
# Recall: 0.5263157894736842
# Aging Rate: 0.05143540669856459
# Precision: 0.9512195121951219
# Recall: 0.5131578947368421
# Aging Rate: 0.04904306220095694
# [I 2022-03-04 09:42:04,202] Trial 30 finished with value: 0.6907563025210083 and parameters: {'n_estimators': 1000, 'min_samples_split': 6, 'max_depth': 18}. Best is trial 9 with value: 0.8875910303554689.
# Precision: 0.9833333333333333
# Recall: 0.7763157894736842
# Aging Rate: 0.07177033492822966
# Precision: 1.0
# Recall: 0.8157894736842105
# Aging Rate: 0.07416267942583732
# Precision: 0.9838709677419355
# Recall: 0.8026315789473685
# Aging Rate: 0.07416267942583732
# [I 2022-03-04 09:42:05,928] Trial 31 finished with value: 0.8834185848252344 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 9 with value: 0.8875910303554689.
# Precision: 1.0
# Recall: 0.8552631578947368
# Aging Rate: 0.07775119617224881
# Precision: 0.9552238805970149
# Recall: 0.8421052631578947
# Aging Rate: 0.08014354066985646
# Precision: 1.0
# Recall: 0.7894736842105263
# Aging Rate: 0.07177033492822966
# [I 2022-03-04 09:42:07,762] Trial 32 finished with value: 0.8998145506280674 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 32 with value: 0.8998145506280674.
# Precision: 1.0
# Recall: 0.7236842105263158
# Aging Rate: 0.06578947368421052
# Precision: 0.9482758620689655
# Recall: 0.7236842105263158
# Aging Rate: 0.06937799043062201
# Precision: 0.967741935483871
# Recall: 0.7894736842105263
# Aging Rate: 0.07416267942583732
# [I 2022-03-04 09:42:10,362] Trial 33 finished with value: 0.8433851320893045 and parameters: {'n_estimators': 500, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 32 with value: 0.8998145506280674.
# Precision: 0.9649122807017544
# Recall: 0.7236842105263158
# Aging Rate: 0.06818181818181818
# Precision: 1.0
# Recall: 0.8289473684210527
# Aging Rate: 0.07535885167464115
# Precision: 1.0
# Recall: 0.6710526315789473
# Aging Rate: 0.061004784688995214
# [I 2022-03-04 09:42:12,103] Trial 34 finished with value: 0.8455640318720099 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 18}. Best is trial 32 with value: 0.8998145506280674.
# Precision: 1.0
# Recall: 0.631578947368421
# Aging Rate: 0.05741626794258373
# Precision: 1.0
# Recall: 0.631578947368421
# Aging Rate: 0.05741626794258373
# Precision: 1.0
# Recall: 0.7368421052631579
# Aging Rate: 0.06698564593301436
# [I 2022-03-04 09:42:13,844] Trial 35 finished with value: 0.7989573150863473 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 15}. Best is trial 32 with value: 0.8998145506280674.
# Precision: 0.9824561403508771
# Recall: 0.7368421052631579
# Aging Rate: 0.06818181818181818
# Precision: 0.9827586206896551
# Recall: 0.75
# Aging Rate: 0.06937799043062201
# Precision: 0.9795918367346939
# Recall: 0.631578947368421
# Aging Rate: 0.05861244019138756
# [I 2022-03-04 09:42:14,867] Trial 36 finished with value: 0.8202838439382036 and parameters: {'n_estimators': 100, 'min_samples_split': 4, 'max_depth': 21}. Best is trial 32 with value: 0.8998145506280674.
# Precision: 1.0
# Recall: 0.5131578947368421
# Aging Rate: 0.04665071770334928
# Precision: 0.9393939393939394
# Recall: 0.40789473684210525
# Aging Rate: 0.039473684210526314
# Precision: 0.9642857142857143
# Recall: 0.35526315789473684
# Aging Rate: 0.03349282296650718
# [I 2022-03-04 09:42:17,417] Trial 37 finished with value: 0.5887663260818427 and parameters: {'n_estimators': 500, 'min_samples_split': 12, 'max_depth': 18}. Best is trial 32 with value: 0.8998145506280674.
# Precision: 1.0
# Recall: 0.868421052631579
# Aging Rate: 0.07894736842105263
# Precision: 1.0
# Recall: 0.8026315789473685
# Aging Rate: 0.0729665071770335
# Precision: 1.0
# Recall: 0.7763157894736842
# Aging Rate: 0.07057416267942583
# [I 2022-03-04 09:42:19,189] Trial 38 finished with value: 0.8980541625893054 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 32 with value: 0.8998145506280674.
# Precision: 1.0
# Recall: 0.6578947368421053
# Aging Rate: 0.05980861244019139
# Precision: 0.9555555555555556
# Recall: 0.5657894736842105
# Aging Rate: 0.05382775119617225
# Precision: 1.0
# Recall: 0.5789473684210527
# Aging Rate: 0.05263157894736842
# [I 2022-03-04 09:42:20,893] Trial 39 finished with value: 0.7459093095456732 and parameters: {'n_estimators': 300, 'min_samples_split': 4, 'max_depth': 15}. Best is trial 32 with value: 0.8998145506280674.
# Precision: 1.0
# Recall: 0.35526315789473684
# Aging Rate: 0.03229665071770335
# Precision: 1.0
# Recall: 0.5
# Aging Rate: 0.045454545454545456
# Precision: 1.0
# Recall: 0.4473684210526316
# Aging Rate: 0.04066985645933014
# [I 2022-03-04 09:42:21,775] Trial 40 finished with value: 0.6030401098362264 and parameters: {'n_estimators': 100, 'min_samples_split': 10, 'max_depth': 21}. Best is trial 32 with value: 0.8998145506280674.
# Precision: 1.0
# Recall: 0.75
# Aging Rate: 0.06818181818181818
# Precision: 0.9833333333333333
# Recall: 0.7763157894736842
# Aging Rate: 0.07177033492822966
# Precision: 1.0
# Recall: 0.7105263157894737
# Aging Rate: 0.0645933014354067
# [I 2022-03-04 09:42:23,608] Trial 41 finished with value: 0.8518530489118725 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 32 with value: 0.8998145506280674.
# Precision: 0.9523809523809523
# Recall: 0.7894736842105263
# Aging Rate: 0.07535885167464115
# Precision: 0.9682539682539683
# Recall: 0.8026315789473685
# Aging Rate: 0.07535885167464115
# Precision: 1.0
# Recall: 0.881578947368421
# Aging Rate: 0.08014354066985646
# [I 2022-03-04 09:42:25,430] Trial 42 finished with value: 0.8926900437691804 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 32 with value: 0.8998145506280674.
# Precision: 0.9482758620689655
# Recall: 0.7236842105263158
# Aging Rate: 0.06937799043062201
# Precision: 0.95
# Recall: 0.75
# Aging Rate: 0.07177033492822966
# Precision: 1.0
# Recall: 0.75
# Aging Rate: 0.06818181818181818
# [I 2022-03-04 09:42:27,264] Trial 43 finished with value: 0.838757891216188 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 18}. Best is trial 32 with value: 0.8998145506280674.
# Precision: 1.0
# Recall: 0.7894736842105263
# Aging Rate: 0.07177033492822966
# Precision: 1.0
# Recall: 0.7763157894736842
# Aging Rate: 0.07057416267942583
# Precision: 0.9818181818181818
# Recall: 0.7105263157894737
# Aging Rate: 0.06578947368421052
# [I 2022-03-04 09:42:28,987] Trial 44 finished with value: 0.8602848320555251 and parameters: {'n_estimators': 300, 'min_samples_split': 4, 'max_depth': 21}. Best is trial 32 with value: 0.8998145506280674.
# Precision: 1.0
# Recall: 0.7236842105263158
# Aging Rate: 0.06578947368421052
# Precision: 1.0
# Recall: 0.7894736842105263
# Aging Rate: 0.07177033492822966
# Precision: 1.0
# Recall: 0.8421052631578947
# Aging Rate: 0.07655502392344497
# [I 2022-03-04 09:42:30,738] Trial 45 finished with value: 0.8787777706502448 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 32 with value: 0.8998145506280674.
# Precision: 1.0
# Recall: 0.75
# Aging Rate: 0.06818181818181818
# Precision: 1.0
# Recall: 0.8157894736842105
# Aging Rate: 0.07416267942583732
# Precision: 1.0
# Recall: 0.6710526315789473
# Aging Rate: 0.061004784688995214
# [I 2022-03-04 09:42:32,464] Trial 46 finished with value: 0.8529477293599169 and parameters: {'n_estimators': 300, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 32 with value: 0.8998145506280674.
# Precision: 1.0
# Recall: 0.618421052631579
# Aging Rate: 0.056220095693779906
# Precision: 1.0
# Recall: 0.6973684210526315
# Aging Rate: 0.06339712918660287
# Precision: 0.9649122807017544
# Recall: 0.7236842105263158
# Aging Rate: 0.06818181818181818
# [I 2022-03-04 09:42:34,201] Trial 47 finished with value: 0.8043335792686482 and parameters: {'n_estimators': 300, 'min_samples_split': 4, 'max_depth': 18}. Best is trial 32 with value: 0.8998145506280674.
# Precision: 1.0
# Recall: 0.2236842105263158
# Aging Rate: 0.02033492822966507
# Precision: 1.0
# Recall: 0.25
# Aging Rate: 0.022727272727272728
# Precision: 1.0
# Recall: 0.2631578947368421
# Aging Rate: 0.023923444976076555
# [I 2022-03-04 09:42:38,820] Trial 48 finished with value: 0.39408602150537636 and parameters: {'n_estimators': 1000, 'min_samples_split': 2, 'max_depth': 9}. Best is trial 32 with value: 0.8998145506280674.
# Precision: 1.0
# Recall: 0.8157894736842105
# Aging Rate: 0.07416267942583732
# Precision: 0.9838709677419355
# Recall: 0.8026315789473685
# Aging Rate: 0.07416267942583732
# Precision: 0.9666666666666667
# Recall: 0.7631578947368421
# Aging Rate: 0.07177033492822966
# [I 2022-03-04 09:42:39,737] Trial 49 finished with value: 0.8785166240409207 and parameters: {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 21}. Best is trial 32 with value: 0.8998145506280674.
# Sampler is TPESampler

# %%
##### optimization history plot #####
optuna_history(best_paramC, all_scoreC, num_row = 3, num_col = 3, model = 'RandomForest Classifier')
            
##### best hyperparameter table #####
param_table = pd.DataFrame(best_paramC).T
param_table
# Out:
#       n_estimators  min_samples_split  max_depth
# set1           300                  2         21
# set2           300                  2         21
# set3           500                  2         21
# set4           100                  2         21
# set5          1000                  2         15
# set6          1000                  2         18
# set7           300                  2         21
# set8           100                  2         15
# set9           300                  2         21

# %% [markdown]
# #### Classifier

# %%
table_setC = runall_ForestC(run_train_x, run_test_x, run_train_y, run_test_y, best_paramC)
line_chart(table_setC, title = 'Random Forest Classifier')
# Out:
# 0it [00:00, ?it/s]
#  Dataset1:
# Precision: 0.0010496850944716584
# Recall: 0.058823529411764705
# Aging Rate: 0.0587473534913359
#
#  Dataset2:
# Precision: 0.0011802195208308745
# Recall: 0.39215686274509803
# Aging Rate: 0.34833192871384816
#
#  Dataset3:
# Precision: 0.0011160714285714285
# Recall: 0.058823529411764705
# Aging Rate: 0.0552529342843635
#
#  Dataset4:
# Precision: 0.0008090614886731392
# Recall: 0.0196078431372549
# Aging Rate: 0.02540648317539929
#
#  Dataset5:
# Precision: 0.0021812893843916625
# Recall: 0.17647058823529413
# Aging Rate: 0.08481160969392999
#
#  Dataset6:
# Precision: 0.0013972419658586962
# Recall: 0.45098039215686275
# Aging Rate: 0.33836255627042694
#
#  Dataset7:
# Precision: 0.001182033096926714
# Recall: 0.0392156862745098
# Aging Rate: 0.03477974881292524
#
#  Dataset8:
# Precision: 0.0007380073800738007
# Recall: 0.0196078431372549
# Aging Rate: 0.027852576620279963
#
#  Dataset9:
# Precision: 0.0
# Recall: 0.0
# Aging Rate: 0.029661452445065673
# C:\Users\user\Desktop\Darui_R08621110\Master_Thesis\AUO aging test\Full_Version_Code\library\AdaBoost.py:104: RuntimeWarning: invalid value encountered in double_scalars
#   f1score = (recall*precision) / (recall + precision)

# %%
table_setC
# Out:
#           Balance Ratio  Train_OK  Train_NG    TP       FP    FN       TN  \
# dataset1       1.000000    3067.0    3067.0   3.0   2855.0  48.0  45743.0
# dataset2       1.000000    2999.0    2999.0  20.0  16926.0  31.0  31672.0
# dataset3       1.000000    3033.0    3033.0   3.0   2685.0  48.0  45913.0
# dataset4       1.000000    3038.0    3038.0   1.0   1235.0  50.0  47363.0
# dataset5       1.006623    3040.0    3020.0   9.0   4117.0  42.0  44481.0
# dataset6       1.014348    3040.0    2997.0  23.0  16438.0  28.0  32160.0
# dataset7       1.099458    3040.0    2765.0   2.0   1690.0  49.0  46908.0
# dataset8       1.000000    3040.0    3040.0   1.0   1354.0  50.0  47244.0
# dataset9      10.000000    3040.0     304.0   0.0   1443.0  51.0  47155.0
#
#           Precision    Recall  Aging Rate  Efficiency  F1 Score     Score
# dataset1   0.001050  0.058824    0.058747    1.001297  0.001031  0.040811
# dataset2   0.001180  0.392157    0.348332    1.125814  0.001177  0.295747
# dataset3   0.001116  0.058824    0.055253    1.064623  0.001095  0.042644
# dataset4   0.000809  0.019608    0.025406    0.771765  0.000777  0.000000
# dataset5   0.002181  0.176471    0.084812    2.080736  0.002155  0.198559
# dataset6   0.001397  0.450980    0.338363    1.332832  0.001393  0.382018
# dataset7   0.001182  0.039216    0.034780    1.127544  0.001147  0.029607
# dataset8   0.000738  0.019608    0.027853    0.703987  0.000711  0.000000
# dataset9   0.000000  0.000000    0.029661    0.000000       NaN  0.000000

# %% [markdown]
# #### Regressor (optional)

# %%
best_paramR, all_scoreR = all_optuna(num_set = 10, 
                                     all_data = run_train, 
                                     mode = 'R', 
                                     TPE_multi = True, 
                                     n_iter = 50,
                                     filename = 'runhist_array_m2m5_4selection_RandomForest', 
                                     creator = RandomForest_creator
                                    )

# %%
pr_dict, table_setR = runall_ForestR(10, run_train_x, run_test_x, run_train_y, run_test_y, best_paramR, 
                                     thres_target = 'Recall', threshold = 0.7)
line_chart(table_setR, title = 'Random Forest Regressor')

# %%
multiple_curve(3, 3, pr_dict, table_setR, target = 'Aging Rate')
multiple_curve(3, 3, pr_dict, table_setR, target = 'Precision')
table_setR

# %% [markdown]
# ### Full Experiment

# %%
training_month = range(2, 5)
table_setC = full_randomforest(training_month, times = 3)

# %%
line_chart(table_setC, title = 'RandomForest Classifier')
table_setC

# %% [markdown]
# ### Export

# %%
savedate = '20220405'
TPE_multi = False

table_setC['sampler'] = 'multivariate-TPE' if TPE_multi else 'univariate-TPE'
table_setC['model'] = 'RandomForest'
with pd.ExcelWriter(f'{savedate}_Classifier.xlsx', mode = 'a') as writer:
    table_setC.to_excel(writer, sheet_name = 'RandomForest')
