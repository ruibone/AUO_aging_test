# %%
import os
import numpy as np
import pandas as pd
import pickle
import random
from tqdm.auto import tqdm
import matplotlib.pyplot as plt

import lightgbm as lgb
from lightgbm import LGBMClassifier, LGBMRegressor
import optuna
from sklearn.model_selection import train_test_split
from sklearn.calibration import CalibratedClassifierCV
from scipy.optimize import minimize
import shap

from library.Data_Preprocessing import Balance_Ratio, train_col
from library.Imbalance_Sampling import label_divide
from library.Aging_Score_Contour import score1
from library.AdaBoost import train_set, multiple_set, multiple_month, line_chart, cf_matrix, AUC, PR_curve, \
     multiple_curve, PR_matrix, best_threshold, all_optuna, optuna_history 

os.chdir('C:/Users/user/Desktop/Darui_R08621110') 
os.getcwd()
# Out:
# 'C:\\Users\\user\\Desktop\\Darui_R08621110'

# %% [markdown]
# ##

# %% [markdown]
# ### lightgbm

# %%
# classifier
def LightGBMC(train_x, test_x, train_y, test_y, config):
    
    clf = LGBMClassifier(**config)
    clf.fit(train_x, train_y)
    predict_y = clf.predict_proba(test_x)[:, 1]
    define_predict = (predict_y > 0.5).astype(int)
    result = pd.DataFrame({'truth': test_y, 'predict': define_predict})
    
    return result


# regressor
def LightGBMR(train_x, test_x, train_y, test_y, config):
    
    reg = LGBMRegressor(**config)
    reg.fit(train_x, train_y)
    predict_y = reg.predict(test_x)
    result = pd.DataFrame({'truth': test_y, 'predict': predict_y})
    
    return result


# classifier for all resampling dataset 
def runall_LightGBMC(num_set, trainset_x, test_x, trainset_y, test_y, config):
    
    table_set = pd.DataFrame()
    bad_set = pd.DataFrame()
    judge = list(config.keys())[0]

    for i in range(num_set):
        print('\n', f'Dataset {i}:')
        
        if isinstance(config[judge], dict) :
            best_config = config[f'set{i}']
        else :
            best_config = config
        
        result = LightGBMC(trainset_x[f'set{i}'], test_x, trainset_y[f'set{i}'], test_y, best_config)
        table = cf_matrix(result, trainset_y[f'set{i}'])
        table_set = pd.concat([table_set, table]).rename(index = {0: f'dataset {i}'})
        
    return table_set
    
    
# regressor for all resampling dataset
def runall_LightGBMR(num_set, trainset_x, test_x, trainset_y, test_y, config, thres_target = 'Recall', threshold = 0.8):
    
    table_set = pd.DataFrame()
    bad_set = pd.DataFrame()
    pr_dict = {}
    judge = list(config.keys())[0]

    for i in range(num_set):
        print('\n', f'Dataset {i}:')
        
        if isinstance(config[judge], dict) :
            best_config = config[f'set{i}']
        else :
            best_config = config

        predict = LightGBMR(trainset_x[f'set{i}'], test_x, trainset_y[f'set{i}'], test_y, best_config)
        pr_matrix = PR_matrix(predict, trainset_y[f'set{i}'])
        pr_dict[f'set{i}'] = pr_matrix
        
        best_data, best_thres = best_threshold(pr_matrix, target = thres_target, threshold = threshold)
        table_set = pd.concat([table_set, best_data]).rename(index = {best_data.index.values[0]: f'dataset {i}'})

    return pr_dict, table_set

# %% [markdown]
# ### probability calibration (optional)

# %%
def stratified_data(train_data, cv):
    
    good = train_data[train_data.GB == 0]
    bad = train_data[train_data.GB == 1]
    good_index = random.sample(good.index.to_list(), k = len(good))
    bad_index = random.sample(bad.index.to_list(), k = len(bad))
    
    train_x_dict = {}
    train_y_dict = {}
    valid_x_dict = {}
    valid_y_dict = {}
    for i in range(cv):
        
        if (i+1) == cv:
            good_valid_index = good_index[int(np.floor((i/cv)*len(good))): ]
            bad_valid_index = bad_index[int(np.floor((i/cv)*len(bad))): ]
        else:
            good_valid_index = good_index[int(np.floor((i/cv)*len(good))) : int(np.floor(((i+1)/cv)*len(good)))]
            bad_valid_index = bad_index[int(np.floor((i/cv)*len(bad))) : int(np.floor(((i+1)/cv)*len(bad)))]
        good_train_index = [x for x in good_index if x not in good_valid_index]
        bad_train_index = [x for x in bad_index if x not in bad_valid_index]
        
        good_train = good.loc[good_train_index]
        good_valid = good.loc[good_valid_index]
        bad_train = bad.loc[bad_train_index]
        bad_valid = bad.loc[bad_valid_index]
        train = pd.concat([good_train, bad_train], axis = 0)
        valid = pd.concat([good_valid, bad_valid], axis = 0)
        train_x_dict[i], train_y_dict[i], valid_x_dict[i], valid_y_dict[i] = label_divide(train, valid, train_only = False)

    return train_x_dict, train_y_dict, valid_x_dict, valid_y_dict


def beta_map(s, a, b, c):
    return 1 / (1 + 1 / (np.power(np.exp(1), c)*(np.power(s, a) / np.power(1-s, b))))
                

def self_loss(three, test_y, predict_y):
    a, b, c = three
    new_s = beta_map(predict_y, a, b, c)
    loss = np.mean(test_y*np.log(new_s) + (1 - test_y)*np.log(1 - new_s))*(-1)
    return loss


def beta_LightGBMC(train_x, train_y, test_x, test_y, config, loss_function = self_loss):
    
    train = pd.concat([train_x, train_y], axis = 1)
    train_x_dict, train_y_dict, valid_x_dict, valid_y_dict = stratified_data(train, cv = 5)
    
    cali_param = {}
    for i in range(len(train_x_dict)):
        clf = LGBMClassifier(**config)
        clf.fit(train_x_dict[i], train_y_dict[i])
        predict_y = clf.predict_proba(valid_x_dict[i])[:, 1]
        mini_result = minimize(loss_function, [0.5, 0.5, 0.5], (valid_y_dict[i], predict_y))
        cali_param[i] = mini_result.x
        
    clf = LGBMClassifier(**config)
    clf.fit(train_x, train_y)
    predict_y = clf.predict_proba(test_x)[:, 1]
    
    cali_predict = np.array(0).astype(float)
    for i in range(len(cali_param)):
        cali_result = beta_map(predict_y, *cali_param[i])
        cali_predict = cali_predict + cali_result
    cali_predict /= len(cali_param)
      
    predict = (cali_predict > 0.5).astype(int)
    result = pd.DataFrame({'truth': test_y, 'predict': predict})

    return result


def cali_LightGBMC(train_x, train_y, test_x, test_y, config, method):
    
    clf = LGBMClassifier(**config)
    cali_clf = CalibratedClassifierCV(clf, method = method, cv = 5)
    cali_clf.fit(train_x, train_y)
    predict_y = cali_clf.predict_proba(test_x)[:, 1]
    predict = (predict_y > 0.5).astype(int)
    result = pd.DataFrame({'truth': test_y, 'predict': predict})
    
    return result 


def all_cali_LightGBMC(trainset_x, trainset_y, test_x, test_y, config_dict, method):
    
    keys = config_dict.keys()
    all_result = pd.DataFrame()
    for i in keys:
        print('\n', f'Data{i}:')
        
        if method in ['isotonic', 'sigmoid']:
            table = cali_LightGBMC(trainset_x[i], trainset_y[i], test_x, test_y, config_dict[i], method)
        elif method == 'beta':
            table = beta_LightGBMC(trainset_x[i], trainset_y[i], test_x, test_y, config_dict[i])
        result_df = cf_matrix(table, trainset_y[i])
        all_result = pd.concat([all_result, result_df], axis = 0).rename(index = {0: f'data{i}'})
        
    return all_result

# %% [markdown]
# ### optuna

# %%
def LightGBM_creator(train_data, mode, num_valid = 3, label = 'GB') :

    def objective(trial) :
    
        param = {
            'n_estimators': trial.suggest_categorical('n_estimators', [100, 500, 1000]),
            'learning_rate': trial.suggest_float('learning_rate', 0.025, 0.325, step = 0.05),
            'max_depth': trial.suggest_int('max_depth', 3, 12, step = 3),
            'num_leaves': trial.suggest_int('num_leaves', 10, 130, step = 20),
            'min_child_samples': trial.suggest_categorical('min_child_samples', [50, 100, 500, 1000, 5000]),
            'min_split_gain': trial.suggest_int('min_split_gain', 0, 12, step = 2),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.3, 0.9, step = 0.2),
            'subsample': trial.suggest_float('subsample', 0.3, 0.9, step = 0.2),
            'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-2, 10), # alpha
            'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-2, 10) # lambda
        }

        result_list = []
        for i in range(num_valid):

            train_good = train_data[train_data.GB == 0]
            train_bad = train_data[train_data.GB == 1]
            train_good_x, train_good_y = label_divide(train_good, None, label, train_only = True)
            train_bad_x, train_bad_y = label_divide(train_bad, None, label, train_only = True)
            train_g_x, valid_g_x, train_g_y, valid_g_y = train_test_split(train_good_x, train_good_y, test_size = 0.25)
            train_b_x, valid_b_x, train_b_y, valid_b_y = train_test_split(train_bad_x, train_bad_y, test_size = 0.25)
            train_x = pd.concat([train_g_x, train_b_x], axis = 0)
            train_y = pd.concat([train_g_y, train_b_y], axis = 0)
            valid_x = pd.concat([valid_g_x, valid_b_x], axis = 0)
            valid_y = pd.concat([valid_g_y, valid_b_y], axis = 0)

            if mode == 'C':
                result = LightGBMC(train_x, valid_x, train_y, valid_y, param)
                table = cf_matrix(result, valid_y)
                recall = table['Recall']
                precision = table['Precision']
                beta = 1
                if recall.values > 0:
                    fscore = ((1+beta**2)*recall*precision) / (recall+(beta**2)*precision)
                else:
                    fscore = 0
                result_list.append(fscore)

            elif mode == 'R':
                result = LightGBMR(train_x, valid_x, train_y, valid_y, param)
                pr_matrix = PR_matrix(result, valid_y)
                auc = AUC(pr_matrix['Recall'], pr_matrix['Aging Rate'])
                result_list.append((-1)*auc)

        return np.mean(result_list)

    return objective

# %% [markdown]
# ##

# %% [markdown]
# ### loading training & testing data

# %%
### training data ### 
training_month = range(2, 5)

data_dict, trainset_x, trainset_y = multiple_month(training_month, num_set = 10, filename = 'dataset')

print('\nCombined training data:\n')
run_train = multiple_set(num_set = 10)
run_train_x, run_train_y = train_set(run_train, num_set = 10)

### testing data ###
run_test = pd.read_csv('test_runhist.csv').iloc[:, 2:]
run_test_x, run_test_y = label_divide(run_test, None, 'GB', train_only = True)
print('\n', 'Dimension of testing data:', run_test.shape)
# Out:
# Month 2:
#
# Dimension of dataset 0 : (39009, 88)  balance ratio: 564.35
# Dimension of dataset 1 : (1638, 88)  balance ratio: 1.33
# Dimension of dataset 2 : (1598, 88)  balance ratio: 1.33
# Dimension of dataset 3 : (1605, 88)  balance ratio: 1.33
# Dimension of dataset 4 : (1607, 88)  balance ratio: 1.33
# Dimension of dataset 5 : (1611, 88)  balance ratio: 1.33
# Dimension of dataset 6 : (1597, 88)  balance ratio: 1.36
# Dimension of dataset 7 : (1563, 88)  balance ratio: 1.43
# Dimension of dataset 8 : (1610, 88)  balance ratio: 1.33
# Dimension of dataset 9 : (759, 88)  balance ratio: 10.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
# Month 3:
#
# Dimension of dataset 0 : (60396, 97)  balance ratio: 533.48
# Dimension of dataset 1 : (2688, 97)  balance ratio: 1.33
# Dimension of dataset 2 : (2599, 97)  balance ratio: 1.33
# Dimension of dataset 3 : (2632, 97)  balance ratio: 1.33
# Dimension of dataset 4 : (2634, 97)  balance ratio: 1.33
# Dimension of dataset 5 : (2638, 97)  balance ratio: 1.33
# Dimension of dataset 6 : (2619, 97)  balance ratio: 1.35
# Dimension of dataset 7 : (2559, 97)  balance ratio: 1.43
# Dimension of dataset 8 : (2635, 97)  balance ratio: 1.33
# Dimension of dataset 9 : (1243, 97)  balance ratio: 10.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
# Month 4:
#
# Dimension of dataset 0 : (57743, 100)  balance ratio: 472.3
# Dimension of dataset 1 : (2830, 100)  balance ratio: 1.33
# Dimension of dataset 2 : (2814, 100)  balance ratio: 1.33
# Dimension of dataset 3 : (2839, 100)  balance ratio: 1.33
# Dimension of dataset 4 : (2846, 100)  balance ratio: 1.33
# Dimension of dataset 5 : (2848, 100)  balance ratio: 1.33
# Dimension of dataset 6 : (2821, 100)  balance ratio: 1.36
# Dimension of dataset 7 : (2763, 100)  balance ratio: 1.43
# Dimension of dataset 8 : (2845, 100)  balance ratio: 1.33
# Dimension of dataset 9 : (1342, 100)  balance ratio: 10.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
# Combined training data:
#
# Dimension of dataset 0 : (157148, 128)  balance ratio: 515.93
# Dimension of dataset 1 : (7156, 128)  balance ratio: 1.33
# Dimension of dataset 2 : (7011, 128)  balance ratio: 1.33
# Dimension of dataset 3 : (7076, 128)  balance ratio: 1.33
# Dimension of dataset 4 : (7087, 128)  balance ratio: 1.33
# Dimension of dataset 5 : (7097, 128)  balance ratio: 1.33
# Dimension of dataset 6 : (7037, 128)  balance ratio: 1.36
# Dimension of dataset 7 : (6885, 128)  balance ratio: 1.43
# Dimension of dataset 8 : (7090, 128)  balance ratio: 1.33
# Dimension of dataset 9 : (3344, 128)  balance ratio: 10.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
#  Dimension of testing data: (48649, 128)

# %% [markdown]
# ### search for best hyperparameter

# %%
best_paramC, all_scoreC = all_optuna(num_set = 10, 
                                     all_data = run_train, 
                                     mode = 'C', 
                                     TPE_multi = False, 
                                     n_iter = 100,
                                     filename = 'runhist_array_m2m4_m5_3criteria_LightGBM_br1.33',
                                     creator = LightGBM_creator
                                    )
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# [I 2022-02-27 08:30:43,860] A new study created in memory with name: no-name-ef5fbb51-5951-426f-8f57-763214c71fca
# Dataset0 :
# Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   0%|          | 0/100 [00:00<?, ?it/s]
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:30:46,231] Trial 0 finished with value: 0.0 and parameters: {'n_estimators': 100, 'learning_rate': 0.17500000000000002, 'max_depth': 12, 'num_leaves': 10, 'min_child_samples': 5000, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.7, 'reg_alpha': 0.01853234292464869, 'reg_lambda': 0.05835900875406844}. Best is trial 0 with value: 0.0.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:30:49,115] Trial 1 finished with value: 0.0 and parameters: {'n_estimators': 100, 'learning_rate': 0.07500000000000001, 'max_depth': 6, 'num_leaves': 110, 'min_child_samples': 50, 'min_split_gain': 0, 'colsample_bytree': 0.3, 'subsample': 0.9, 'reg_alpha': 0.025826485102947192, 'reg_lambda': 2.1915888857156607}. Best is trial 0 with value: 0.0.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:30:51,702] Trial 2 finished with value: 0.0 and parameters: {'n_estimators': 100, 'learning_rate': 0.275, 'max_depth': 3, 'num_leaves': 50, 'min_child_samples': 50, 'min_split_gain': 8, 'colsample_bytree': 0.3, 'subsample': 0.5, 'reg_alpha': 0.03661219237548554, 'reg_lambda': 0.1284713447938873}. Best is trial 0 with value: 0.0.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:30:56,123] Trial 3 finished with value: 0.0 and parameters: {'n_estimators': 1000, 'learning_rate': 0.07500000000000001, 'max_depth': 12, 'num_leaves': 10, 'min_child_samples': 500, 'min_split_gain': 8, 'colsample_bytree': 0.5, 'subsample': 0.9, 'reg_alpha': 0.3534595340847344, 'reg_lambda': 0.020577002583254157}. Best is trial 0 with value: 0.0.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:30:59,232] Trial 4 finished with value: 0.0 and parameters: {'n_estimators': 1000, 'learning_rate': 0.325, 'max_depth': 6, 'num_leaves': 90, 'min_child_samples': 500, 'min_split_gain': 8, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.028855632114172445, 'reg_lambda': 0.30731505130669073}. Best is trial 0 with value: 0.0.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:31:03,295] Trial 5 finished with value: 0.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.325, 'max_depth': 3, 'num_leaves': 50, 'min_child_samples': 1000, 'min_split_gain': 4, 'colsample_bytree': 0.3, 'subsample': 0.3, 'reg_alpha': 2.3100565541057696, 'reg_lambda': 0.49028364845743283}. Best is trial 0 with value: 0.0.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:31:05,920] Trial 6 finished with value: 0.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.025, 'max_depth': 6, 'num_leaves': 110, 'min_child_samples': 500, 'min_split_gain': 8, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.16364265751581167, 'reg_lambda': 0.1714360650218703}. Best is trial 0 with value: 0.0.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:31:10,264] Trial 7 finished with value: 0.0 and parameters: {'n_estimators': 1000, 'learning_rate': 0.07500000000000001, 'max_depth': 3, 'num_leaves': 70, 'min_child_samples': 500, 'min_split_gain': 10, 'colsample_bytree': 0.5, 'subsample': 0.3, 'reg_alpha': 5.520143316335803, 'reg_lambda': 0.18959177521417137}. Best is trial 0 with value: 0.0.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:31:14,712] Trial 8 finished with value: 0.0 and parameters: {'n_estimators': 1000, 'learning_rate': 0.275, 'max_depth': 9, 'num_leaves': 130, 'min_child_samples': 100, 'min_split_gain': 4, 'colsample_bytree': 0.5, 'subsample': 0.5, 'reg_alpha': 0.28360913466388316, 'reg_lambda': 5.830578488215188}. Best is trial 0 with value: 0.0.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:31:18,113] Trial 9 finished with value: 0.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.07500000000000001, 'max_depth': 9, 'num_leaves': 130, 'min_child_samples': 500, 'min_split_gain': 2, 'colsample_bytree': 0.5, 'subsample': 0.7, 'reg_alpha': 0.07025981185583147, 'reg_lambda': 4.978181729693453}. Best is trial 0 with value: 0.0.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:31:20,659] Trial 10 finished with value: 0.0 and parameters: {'n_estimators': 100, 'learning_rate': 0.17500000000000002, 'max_depth': 12, 'num_leaves': 10, 'min_child_samples': 5000, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.7, 'reg_alpha': 0.010012117194083089, 'reg_lambda': 0.012429239391559254}. Best is trial 0 with value: 0.0.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:31:23,139] Trial 11 finished with value: 0.0 and parameters: {'n_estimators': 100, 'learning_rate': 0.17500000000000002, 'max_depth': 6, 'num_leaves': 90, 'min_child_samples': 5000, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.9, 'reg_alpha': 0.011238720069433552, 'reg_lambda': 1.539266796443901}. Best is trial 0 with value: 0.0.
# Precision: 0.9310344827586207
# Recall: 0.35526315789473684
# Aging Rate: 0.000738157660294754
# Precision: 0.875
# Recall: 0.3684210526315789
# Aging Rate: 0.0008145187975666251
# Precision: 0.8888888888888888
# Recall: 0.3157894736842105
# Aging Rate: 0.0006872502354468399
# [I 2022-02-27 08:31:25,630] Trial 12 finished with value: 0.4996078834266537 and parameters: {'n_estimators': 100, 'learning_rate': 0.125, 'max_depth': 9, 'num_leaves': 30, 'min_child_samples': 50, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.9, 'reg_alpha': 0.01769061152876503, 'reg_lambda': 0.057023319122738426}. Best is trial 12 with value: 0.4996078834266537.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:31:27,848] Trial 13 finished with value: 0.0 and parameters: {'n_estimators': 100, 'learning_rate': 0.225, 'max_depth': 12, 'num_leaves': 30, 'min_child_samples': 50, 'min_split_gain': 2, 'colsample_bytree': 0.9, 'subsample': 0.9, 'reg_alpha': 0.011456076002244367, 'reg_lambda': 0.04684152637149392}. Best is trial 12 with value: 0.4996078834266537.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:31:30,061] Trial 14 finished with value: 0.0 and parameters: {'n_estimators': 100, 'learning_rate': 0.125, 'max_depth': 9, 'num_leaves': 30, 'min_child_samples': 5000, 'min_split_gain': 2, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.08348194209016394, 'reg_lambda': 0.05286873724290471}. Best is trial 12 with value: 0.4996078834266537.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:31:32,302] Trial 15 finished with value: 0.0 and parameters: {'n_estimators': 100, 'learning_rate': 0.125, 'max_depth': 12, 'num_leaves': 10, 'min_child_samples': 50, 'min_split_gain': 4, 'colsample_bytree': 0.9, 'subsample': 0.9, 'reg_alpha': 0.921363375404973, 'reg_lambda': 0.04748449904070752}. Best is trial 12 with value: 0.4996078834266537.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:31:34,514] Trial 16 finished with value: 0.0 and parameters: {'n_estimators': 100, 'learning_rate': 0.225, 'max_depth': 9, 'num_leaves': 30, 'min_child_samples': 5000, 'min_split_gain': 12, 'colsample_bytree': 0.9, 'subsample': 0.7, 'reg_alpha': 0.017046555354261722, 'reg_lambda': 0.027195064781165373}. Best is trial 12 with value: 0.4996078834266537.
# Precision: 0.896551724137931
# Recall: 0.34210526315789475
# Aging Rate: 0.000738157660294754
# Precision: 0.9411764705882353
# Recall: 0.42105263157894735
# Aging Rate: 0.0008654262224145391
# Precision: 0.9428571428571428
# Recall: 0.4342105263157895
# Aging Rate: 0.0008908799348384962
# [I 2022-02-27 08:31:37,239] Trial 17 finished with value: 0.5572169572169572 and parameters: {'n_estimators': 100, 'learning_rate': 0.125, 'max_depth': 9, 'num_leaves': 50, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.06153102633902622, 'reg_lambda': 0.09416508604252234}. Best is trial 17 with value: 0.5572169572169572.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:31:39,545] Trial 18 finished with value: 0.0 and parameters: {'n_estimators': 100, 'learning_rate': 0.125, 'max_depth': 9, 'num_leaves': 50, 'min_child_samples': 100, 'min_split_gain': 2, 'colsample_bytree': 0.7, 'subsample': 0.9, 'reg_alpha': 0.07035346900836402, 'reg_lambda': 0.010492852050836755}. Best is trial 17 with value: 0.5572169572169572.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:31:41,892] Trial 19 finished with value: 0.0 and parameters: {'n_estimators': 100, 'learning_rate': 0.025, 'max_depth': 9, 'num_leaves': 70, 'min_child_samples': 100, 'min_split_gain': 6, 'colsample_bytree': 0.7, 'subsample': 0.5, 'reg_alpha': 0.15444071599037834, 'reg_lambda': 0.6700546379906482}. Best is trial 17 with value: 0.5572169572169572.
# Precision: 0.9508196721311475
# Recall: 0.7631578947368421
# Aging Rate: 0.001552676457861379
# Precision: 0.8611111111111112
# Recall: 0.8157894736842105
# Aging Rate: 0.0018326672945249065
# Precision: 0.84375
# Recall: 0.7105263157894737
# Aging Rate: 0.0016290375951332503
# [I 2022-02-27 08:31:45,905] Trial 20 finished with value: 0.8186605792445207 and parameters: {'n_estimators': 500, 'learning_rate': 0.125, 'max_depth': 6, 'num_leaves': 50, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.05382895099034868, 'reg_lambda': 0.08805122690621221}. Best is trial 20 with value: 0.8186605792445207.
# Precision: 0.8888888888888888
# Recall: 0.7368421052631579
# Aging Rate: 0.0016035838827092933
# Precision: 0.8805970149253731
# Recall: 0.7763157894736842
# Aging Rate: 0.0017053987324051213
# Precision: 0.9322033898305084
# Recall: 0.7236842105263158
# Aging Rate: 0.001501769033013465
# [I 2022-02-27 08:31:49,866] Trial 21 finished with value: 0.8152483452243645 and parameters: {'n_estimators': 500, 'learning_rate': 0.125, 'max_depth': 6, 'num_leaves': 50, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.06473585048073636, 'reg_lambda': 0.10037001623607765}. Best is trial 20 with value: 0.8186605792445207.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:31:52,473] Trial 22 finished with value: 0.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.125, 'max_depth': 6, 'num_leaves': 50, 'min_child_samples': 100, 'min_split_gain': 2, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.04673781338024941, 'reg_lambda': 0.10308980422555462}. Best is trial 20 with value: 0.8186605792445207.
# Precision: 0.9298245614035088
# Recall: 0.6973684210526315
# Aging Rate: 0.001450861608165551
# Precision: 0.9508196721311475
# Recall: 0.7631578947368421
# Aging Rate: 0.001552676457861379
# Precision: 0.9322033898305084
# Recall: 0.7236842105263158
# Aging Rate: 0.001501769033013465
# [I 2022-02-27 08:31:56,154] Trial 23 finished with value: 0.8195075414949918 and parameters: {'n_estimators': 500, 'learning_rate': 0.225, 'max_depth': 6, 'num_leaves': 70, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.12916458472085873, 'reg_lambda': 0.09697247855976061}. Best is trial 23 with value: 0.8195075414949918.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:31:58,866] Trial 24 finished with value: 0.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.225, 'max_depth': 6, 'num_leaves': 70, 'min_child_samples': 100, 'min_split_gain': 4, 'colsample_bytree': 0.7, 'subsample': 0.5, 'reg_alpha': 0.14065205554813426, 'reg_lambda': 0.22763074434246458}. Best is trial 23 with value: 0.8195075414949918.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:32:02,287] Trial 25 finished with value: 0.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.225, 'max_depth': 3, 'num_leaves': 70, 'min_child_samples': 100, 'min_split_gain': 2, 'colsample_bytree': 0.5, 'subsample': 0.7, 'reg_alpha': 0.39654651117736706, 'reg_lambda': 0.024571720622543227}. Best is trial 23 with value: 0.8195075414949918.
# Precision: 0.8888888888888888
# Recall: 0.5263157894736842
# Aging Rate: 0.0011454170590780666
# Precision: 0.8490566037735849
# Recall: 0.5921052631578947
# Aging Rate: 0.0013490467584697228
# Precision: 0.9310344827586207
# Recall: 0.7105263157894737
# Aging Rate: 0.001476315320589508
# [I 2022-02-27 08:32:06,170] Trial 26 finished with value: 0.7216005308839236 and parameters: {'n_estimators': 500, 'learning_rate': 0.275, 'max_depth': 6, 'num_leaves': 90, 'min_child_samples': 1000, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.13112816457701776, 'reg_lambda': 0.59791940698876}. Best is trial 23 with value: 0.8195075414949918.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:32:08,748] Trial 27 finished with value: 0.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.17500000000000002, 'max_depth': 6, 'num_leaves': 50, 'min_child_samples': 100, 'min_split_gain': 6, 'colsample_bytree': 0.7, 'subsample': 0.5, 'reg_alpha': 0.7837468803327585, 'reg_lambda': 0.11068362930298398}. Best is trial 23 with value: 0.8195075414949918.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:32:12,034] Trial 28 finished with value: 0.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.17500000000000002, 'max_depth': 3, 'num_leaves': 90, 'min_child_samples': 100, 'min_split_gain': 2, 'colsample_bytree': 0.5, 'subsample': 0.7, 'reg_alpha': 0.22055177439516188, 'reg_lambda': 0.07696788870550181}. Best is trial 23 with value: 0.8195075414949918.
# Precision: 0.8688524590163934
# Recall: 0.6973684210526315
# Aging Rate: 0.001552676457861379
# Precision: 0.9253731343283582
# Recall: 0.8157894736842105
# Aging Rate: 0.0017053987324051213
# Precision: 0.96875
# Recall: 0.8157894736842105
# Aging Rate: 0.0016290375951332503
# [I 2022-02-27 08:32:15,920] Trial 29 finished with value: 0.8421899268614595 and parameters: {'n_estimators': 500, 'learning_rate': 0.17500000000000002, 'max_depth': 6, 'num_leaves': 70, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.04120384455576674, 'reg_lambda': 0.36332029835893725}. Best is trial 29 with value: 0.8421899268614595.
# Precision: 0.9538461538461539
# Recall: 0.8157894736842105
# Aging Rate: 0.0016544913075572073
# Precision: 0.9180327868852459
# Recall: 0.7368421052631579
# Aging Rate: 0.001552676457861379
# Precision: 0.9242424242424242
# Recall: 0.8026315789473685
# Aging Rate: 0.0016799450199811643
# [I 2022-02-27 08:32:19,951] Trial 30 finished with value: 0.8520352672887075 and parameters: {'n_estimators': 500, 'learning_rate': 0.225, 'max_depth': 6, 'num_leaves': 70, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.5, 'reg_alpha': 0.038443262090350545, 'reg_lambda': 1.1929252949499918}. Best is trial 30 with value: 0.8520352672887075.
# Precision: 0.9230769230769231
# Recall: 0.631578947368421
# Aging Rate: 0.0013235930460457658
# Precision: 0.9384615384615385
# Recall: 0.8026315789473685
# Aging Rate: 0.0016544913075572073
# Precision: 0.8666666666666667
# Recall: 0.6842105263157895
# Aging Rate: 0.001527222745437422
# [I 2022-02-27 08:32:24,123] Trial 31 finished with value: 0.793318036434432 and parameters: {'n_estimators': 500, 'learning_rate': 0.225, 'max_depth': 6, 'num_leaves': 70, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.5, 'reg_alpha': 0.041893318551329925, 'reg_lambda': 1.2976181343662538}. Best is trial 30 with value: 0.8520352672887075.
# Precision: 0.9354838709677419
# Recall: 0.7631578947368421
# Aging Rate: 0.001578130170285336
# Precision: 0.95
# Recall: 0.75
# Aging Rate: 0.001527222745437422
# Precision: 0.868421052631579
# Recall: 0.868421052631579
# Aging Rate: 0.0019344821442207347
# [I 2022-02-27 08:32:28,248] Trial 32 finished with value: 0.8490786856313844 and parameters: {'n_estimators': 500, 'learning_rate': 0.275, 'max_depth': 6, 'num_leaves': 90, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.5, 'reg_alpha': 0.022414374709005255, 'reg_lambda': 0.3870172060579808}. Best is trial 30 with value: 0.8520352672887075.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:32:31,016] Trial 33 finished with value: 0.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.275, 'max_depth': 6, 'num_leaves': 110, 'min_child_samples': 100, 'min_split_gain': 2, 'colsample_bytree': 0.7, 'subsample': 0.3, 'reg_alpha': 0.024069431030239116, 'reg_lambda': 0.8556401788572379}. Best is trial 30 with value: 0.8520352672887075.
# Precision: 1.0
# Recall: 0.10526315789473684
# Aging Rate: 0.00020362969939165628
# Precision: 0.8888888888888888
# Recall: 0.10526315789473684
# Aging Rate: 0.0002290834118156133
# Precision: 0.8888888888888888
# Recall: 0.10526315789473684
# Aging Rate: 0.0002290834118156133
# [I 2022-02-27 08:32:35,656] Trial 34 finished with value: 0.18898225957049486 and parameters: {'n_estimators': 500, 'learning_rate': 0.275, 'max_depth': 3, 'num_leaves': 90, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.5, 'subsample': 0.5, 'reg_alpha': 0.10630660306769836, 'reg_lambda': 2.7147165839559397}. Best is trial 30 with value: 0.8520352672887075.
# Precision: 0.9
# Recall: 0.8289473684210527
# Aging Rate: 0.0017817598696769925
# Precision: 0.8666666666666667
# Recall: 0.8552631578947368
# Aging Rate: 0.0019090284317967775
# Precision: 0.896551724137931
# Recall: 0.6842105263157895
# Aging Rate: 0.001476315320589508
# [I 2022-02-27 08:32:40,076] Trial 35 finished with value: 0.8333534179776976 and parameters: {'n_estimators': 500, 'learning_rate': 0.325, 'max_depth': 6, 'num_leaves': 90, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.5, 'reg_alpha': 0.03014521900055853, 'reg_lambda': 0.3805945863792523}. Best is trial 30 with value: 0.8520352672887075.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:32:42,686] Trial 36 finished with value: 0.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.325, 'max_depth': 6, 'num_leaves': 110, 'min_child_samples': 1000, 'min_split_gain': 2, 'colsample_bytree': 0.7, 'subsample': 0.5, 'reg_alpha': 0.030625670570252526, 'reg_lambda': 0.3597727382375069}. Best is trial 30 with value: 0.8520352672887075.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:32:46,014] Trial 37 finished with value: 0.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.325, 'max_depth': 3, 'num_leaves': 90, 'min_child_samples': 100, 'min_split_gain': 4, 'colsample_bytree': 0.5, 'subsample': 0.3, 'reg_alpha': 0.02017948339024382, 'reg_lambda': 0.36293775499818154}. Best is trial 30 with value: 0.8520352672887075.
# Precision: 0.9180327868852459
# Recall: 0.7368421052631579
# Aging Rate: 0.001552676457861379
# Precision: 0.9558823529411765
# Recall: 0.8552631578947368
# Aging Rate: 0.0017308524448290783
# Precision: 0.9591836734693877
# Recall: 0.618421052631579
# Aging Rate: 0.0012472319087738946
# [I 2022-02-27 08:32:50,102] Trial 38 finished with value: 0.8240986753176532 and parameters: {'n_estimators': 500, 'learning_rate': 0.275, 'max_depth': 6, 'num_leaves': 90, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.035784247726992575, 'reg_lambda': 1.0092167678014736}. Best is trial 30 with value: 0.8520352672887075.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:32:53,252] Trial 39 finished with value: 0.0 and parameters: {'n_estimators': 1000, 'learning_rate': 0.325, 'max_depth': 6, 'num_leaves': 110, 'min_child_samples': 1000, 'min_split_gain': 2, 'colsample_bytree': 0.7, 'subsample': 0.5, 'reg_alpha': 0.0154675410144512, 'reg_lambda': 2.3554898126444006}. Best is trial 30 with value: 0.8520352672887075.
# Precision: 0.9655172413793104
# Recall: 0.3684210526315789
# Aging Rate: 0.000738157660294754
# Precision: 1.0
# Recall: 0.34210526315789475
# Aging Rate: 0.0006617965230228829
# Precision: 0.8333333333333334
# Recall: 0.2631578947368421
# Aging Rate: 0.0006108890981749688
# [I 2022-02-27 08:32:56,938] Trial 40 finished with value: 0.48104575163398694 and parameters: {'n_estimators': 500, 'learning_rate': 0.275, 'max_depth': 3, 'num_leaves': 110, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.3, 'reg_alpha': 0.02648008860560121, 'reg_lambda': 0.26946810133639126}. Best is trial 30 with value: 0.8520352672887075.
# Precision: 0.8933333333333333
# Recall: 0.881578947368421
# Aging Rate: 0.0019090284317967775
# Precision: 0.9264705882352942
# Recall: 0.8289473684210527
# Aging Rate: 0.0017308524448290783
# Precision: 0.9545454545454546
# Recall: 0.8289473684210527
# Aging Rate: 0.0016799450199811643
# [I 2022-02-27 08:33:01,529] Trial 41 finished with value: 0.8832470540683395 and parameters: {'n_estimators': 500, 'learning_rate': 0.275, 'max_depth': 6, 'num_leaves': 90, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.03941694867632034, 'reg_lambda': 0.8845915408025805}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 0.9824561403508771
# Recall: 0.7368421052631579
# Aging Rate: 0.001450861608165551
# Precision: 0.9375
# Recall: 0.7894736842105263
# Aging Rate: 0.0016290375951332503
# Precision: 0.9295774647887324
# Recall: 0.868421052631579
# Aging Rate: 0.0018072135821009495
# [I 2022-02-27 08:33:07,096] Trial 42 finished with value: 0.8657357679914072 and parameters: {'n_estimators': 500, 'learning_rate': 0.275, 'max_depth': 6, 'num_leaves': 90, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.04047277042337701, 'reg_lambda': 0.4915200738545879}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 0.8939393939393939
# Recall: 0.7763157894736842
# Aging Rate: 0.0016799450199811643
# Precision: 0.967741935483871
# Recall: 0.7894736842105263
# Aging Rate: 0.001578130170285336
# Precision: 0.9552238805970149
# Recall: 0.8421052631578947
# Aging Rate: 0.0017053987324051213
# [I 2022-02-27 08:33:12,889] Trial 43 finished with value: 0.8652186759963857 and parameters: {'n_estimators': 500, 'learning_rate': 0.275, 'max_depth': 6, 'num_leaves': 70, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.043593919543770725, 'reg_lambda': 0.49673692811098796}. Best is trial 41 with value: 0.8832470540683395.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:33:16,343] Trial 44 finished with value: 0.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.275, 'max_depth': 6, 'num_leaves': 90, 'min_child_samples': 500, 'min_split_gain': 2, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.08547332434790468, 'reg_lambda': 1.8252740481850833}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 0.9230769230769231
# Recall: 0.631578947368421
# Aging Rate: 0.0013235930460457658
# Precision: 0.98
# Recall: 0.6447368421052632
# Aging Rate: 0.0012726856211978518
# Precision: 0.896551724137931
# Recall: 0.6842105263157895
# Aging Rate: 0.001476315320589508
# [I 2022-02-27 08:33:21,610] Trial 45 finished with value: 0.7679657269209508 and parameters: {'n_estimators': 500, 'learning_rate': 0.275, 'max_depth': 6, 'num_leaves': 90, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.01439830170071586, 'reg_lambda': 3.2787469434408965}. Best is trial 41 with value: 0.8832470540683395.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:33:26,061] Trial 46 finished with value: 0.0 and parameters: {'n_estimators': 1000, 'learning_rate': 0.275, 'max_depth': 6, 'num_leaves': 110, 'min_child_samples': 100, 'min_split_gain': 12, 'colsample_bytree': 0.9, 'subsample': 0.3, 'reg_alpha': 0.022905787856359074, 'reg_lambda': 0.5499312665142592}. Best is trial 41 with value: 0.8832470540683395.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:33:29,670] Trial 47 finished with value: 0.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.225, 'max_depth': 3, 'num_leaves': 70, 'min_child_samples': 100, 'min_split_gain': 10, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.045254164282977516, 'reg_lambda': 0.9541670253355867}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 0.8666666666666667
# Recall: 0.6842105263157895
# Aging Rate: 0.001527222745437422
# Precision: 0.9032258064516129
# Recall: 0.7368421052631579
# Aging Rate: 0.001578130170285336
# Precision: 0.8870967741935484
# Recall: 0.7236842105263158
# Aging Rate: 0.001578130170285336
# [I 2022-02-27 08:33:35,397] Trial 48 finished with value: 0.7911338448422848 and parameters: {'n_estimators': 500, 'learning_rate': 0.325, 'max_depth': 6, 'num_leaves': 130, 'min_child_samples': 50, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.011593061503838582, 'reg_lambda': 0.15828694803188267}. Best is trial 41 with value: 0.8832470540683395.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:33:41,031] Trial 49 finished with value: 0.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.225, 'max_depth': 6, 'num_leaves': 70, 'min_child_samples': 500, 'min_split_gain': 2, 'colsample_bytree': 0.3, 'subsample': 0.5, 'reg_alpha': 0.09527440934154066, 'reg_lambda': 1.3330682105173857}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 0.6938775510204082
# Recall: 0.4473684210526316
# Aging Rate: 0.0012472319087738946
# Precision: 0.5625
# Recall: 0.35526315789473684
# Aging Rate: 0.0012217781963499376
# Precision: 0.6530612244897959
# Recall: 0.42105263157894735
# Aging Rate: 0.0012472319087738946
# [I 2022-02-27 08:33:46,815] Trial 50 finished with value: 0.49716129032258066 and parameters: {'n_estimators': 500, 'learning_rate': 0.275, 'max_depth': 9, 'num_leaves': 90, 'min_child_samples': 5000, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.3, 'reg_alpha': 0.03277096139254236, 'reg_lambda': 0.7071636801291958}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 0.9310344827586207
# Recall: 0.7105263157894737
# Aging Rate: 0.001476315320589508
# Precision: 0.9310344827586207
# Recall: 0.7105263157894737
# Aging Rate: 0.001476315320589508
# Precision: 0.9384615384615385
# Recall: 0.8026315789473685
# Aging Rate: 0.0016544913075572073
# [I 2022-02-27 08:33:52,217] Trial 51 finished with value: 0.8257295084859391 and parameters: {'n_estimators': 500, 'learning_rate': 0.275, 'max_depth': 6, 'num_leaves': 70, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.040996473025005774, 'reg_lambda': 0.2155207647682462}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 0.9636363636363636
# Recall: 0.6973684210526315
# Aging Rate: 0.0013999541833176368
# Precision: 0.9791666666666666
# Recall: 0.618421052631579
# Aging Rate: 0.0012217781963499376
# Precision: 0.9130434782608695
# Recall: 0.8289473684210527
# Aging Rate: 0.0017563061572530353
# [I 2022-02-27 08:33:57,967] Trial 52 finished with value: 0.8120634462379743 and parameters: {'n_estimators': 500, 'learning_rate': 0.17500000000000002, 'max_depth': 6, 'num_leaves': 70, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.05108531864311566, 'reg_lambda': 0.4255375111176466}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 0.95
# Recall: 0.75
# Aging Rate: 0.001527222745437422
# Precision: 0.9516129032258065
# Recall: 0.7763157894736842
# Aging Rate: 0.001578130170285336
# Precision: 0.8571428571428571
# Recall: 0.868421052631579
# Aging Rate: 0.0019599358566446917
# [I 2022-02-27 08:34:03,279] Trial 53 finished with value: 0.8520176186416596 and parameters: {'n_estimators': 500, 'learning_rate': 0.225, 'max_depth': 6, 'num_leaves': 90, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.021541880597474833, 'reg_lambda': 0.4936811672180674}. Best is trial 41 with value: 0.8832470540683395.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:34:06,643] Trial 54 finished with value: 0.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.225, 'max_depth': 6, 'num_leaves': 90, 'min_child_samples': 100, 'min_split_gain': 2, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 7.42075173648691, 'reg_lambda': 0.5082222247563281}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 0.9591836734693877
# Recall: 0.618421052631579
# Aging Rate: 0.0012472319087738946
# Precision: 0.9655172413793104
# Recall: 0.7368421052631579
# Aging Rate: 0.001476315320589508
# Precision: 0.8823529411764706
# Recall: 0.7894736842105263
# Aging Rate: 0.0017308524448290783
# [I 2022-02-27 08:34:14,983] Trial 55 finished with value: 0.8070514096185738 and parameters: {'n_estimators': 1000, 'learning_rate': 0.225, 'max_depth': 6, 'num_leaves': 90, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.022363549279795985, 'reg_lambda': 0.8088439027133012}. Best is trial 41 with value: 0.8832470540683395.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:34:18,467] Trial 56 finished with value: 0.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.325, 'max_depth': 9, 'num_leaves': 110, 'min_child_samples': 100, 'min_split_gain': 2, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.014376533316065952, 'reg_lambda': 1.0817354218281536}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 0.9836065573770492
# Recall: 0.7894736842105263
# Aging Rate: 0.001552676457861379
# Precision: 0.9180327868852459
# Recall: 0.7368421052631579
# Aging Rate: 0.001552676457861379
# Precision: 0.9508196721311475
# Recall: 0.7631578947368421
# Aging Rate: 0.001552676457861379
# [I 2022-02-27 08:34:23,826] Trial 57 finished with value: 0.8467153284671532 and parameters: {'n_estimators': 500, 'learning_rate': 0.275, 'max_depth': 6, 'num_leaves': 90, 'min_child_samples': 50, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.06869038239583079, 'reg_lambda': 0.2836435757373516}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 0.9818181818181818
# Recall: 0.7105263157894737
# Aging Rate: 0.0013999541833176368
# Precision: 0.9821428571428571
# Recall: 0.7236842105263158
# Aging Rate: 0.0014254078957415938
# Precision: 0.8676470588235294
# Recall: 0.7763157894736842
# Aging Rate: 0.0017308524448290783
# [I 2022-02-27 08:34:29,174] Trial 58 finished with value: 0.8257350862312695 and parameters: {'n_estimators': 500, 'learning_rate': 0.275, 'max_depth': 6, 'num_leaves': 110, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.019354569834809113, 'reg_lambda': 1.6435642236934824}. Best is trial 41 with value: 0.8832470540683395.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:34:32,795] Trial 59 finished with value: 0.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.225, 'max_depth': 9, 'num_leaves': 90, 'min_child_samples': 100, 'min_split_gain': 2, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.011735071793211026, 'reg_lambda': 0.46090654307272916}. Best is trial 41 with value: 0.8832470540683395.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:34:36,117] Trial 60 finished with value: 0.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.275, 'max_depth': 6, 'num_leaves': 70, 'min_child_samples': 5000, 'min_split_gain': 4, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.05562755525690522, 'reg_lambda': 4.027738140173173}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 0.9649122807017544
# Recall: 0.7236842105263158
# Aging Rate: 0.001450861608165551
# Precision: 0.9107142857142857
# Recall: 0.6710526315789473
# Aging Rate: 0.0014254078957415938
# Precision: 0.9027777777777778
# Recall: 0.8552631578947368
# Aging Rate: 0.0018326672945249065
# [I 2022-02-27 08:34:41,842] Trial 61 finished with value: 0.8260577734261944 and parameters: {'n_estimators': 500, 'learning_rate': 0.275, 'max_depth': 6, 'num_leaves': 90, 'min_child_samples': 50, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.07479450790893738, 'reg_lambda': 0.28512064728976394}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 1.0
# Recall: 0.39473684210526316
# Aging Rate: 0.000763611372718711
# Precision: 0.9642857142857143
# Recall: 0.35526315789473684
# Aging Rate: 0.0007127039478707969
# Precision: 0.9259259259259259
# Recall: 0.32894736842105265
# Aging Rate: 0.0006872502354468399
# [I 2022-02-27 08:34:47,437] Trial 62 finished with value: 0.5235684660945698 and parameters: {'n_estimators': 500, 'learning_rate': 0.275, 'max_depth': 6, 'num_leaves': 90, 'min_child_samples': 50, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.03370632934123263, 'reg_lambda': 8.801469260800307}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 0.9558823529411765
# Recall: 0.8552631578947368
# Aging Rate: 0.0017308524448290783
# Precision: 0.9090909090909091
# Recall: 0.7894736842105263
# Aging Rate: 0.0016799450199811643
# Precision: 0.9636363636363636
# Recall: 0.6973684210526315
# Aging Rate: 0.0013999541833176368
# [I 2022-02-27 08:34:52,795] Trial 63 finished with value: 0.8523361685521668 and parameters: {'n_estimators': 500, 'learning_rate': 0.325, 'max_depth': 6, 'num_leaves': 90, 'min_child_samples': 50, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.06635360148216214, 'reg_lambda': 0.15106922792247368}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 0.8472222222222222
# Recall: 0.8026315789473685
# Aging Rate: 0.0018326672945249065
# Precision: 0.8840579710144928
# Recall: 0.8026315789473685
# Aging Rate: 0.0017563061572530353
# Precision: 0.9117647058823529
# Recall: 0.8157894736842105
# Aging Rate: 0.0017308524448290783
# [I 2022-02-27 08:34:58,467] Trial 64 finished with value: 0.8422715819267544 and parameters: {'n_estimators': 500, 'learning_rate': 0.325, 'max_depth': 6, 'num_leaves': 70, 'min_child_samples': 50, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.02944092831842521, 'reg_lambda': 0.1429753852832827}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 0.927536231884058
# Recall: 0.8421052631578947
# Aging Rate: 0.0017563061572530353
# Precision: 0.8769230769230769
# Recall: 0.75
# Aging Rate: 0.0016544913075572073
# Precision: 0.9516129032258065
# Recall: 0.7763157894736842
# Aging Rate: 0.001578130170285336
# [I 2022-02-27 08:35:03,822] Trial 65 finished with value: 0.8487805742518811 and parameters: {'n_estimators': 500, 'learning_rate': 0.325, 'max_depth': 6, 'num_leaves': 90, 'min_child_samples': 50, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.05700314154975916, 'reg_lambda': 0.6908056721324646}. Best is trial 41 with value: 0.8832470540683395.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:35:07,514] Trial 66 finished with value: 0.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.225, 'max_depth': 6, 'num_leaves': 110, 'min_child_samples': 100, 'min_split_gain': 2, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.025546562067019, 'reg_lambda': 0.20608874886119513}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 0.9555555555555556
# Recall: 0.5657894736842105
# Aging Rate: 0.0011454170590780666
# Precision: 0.8928571428571429
# Recall: 0.6578947368421053
# Aging Rate: 0.0014254078957415938
# Precision: 0.9230769230769231
# Recall: 0.47368421052631576
# Aging Rate: 0.0009926947845343244
# [I 2022-02-27 08:35:12,889] Trial 67 finished with value: 0.6981355052501298 and parameters: {'n_estimators': 500, 'learning_rate': 0.225, 'max_depth': 6, 'num_leaves': 70, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.3, 'reg_alpha': 0.1952085451163783, 'reg_lambda': 1.1503934317999365}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 0.9047619047619048
# Recall: 0.75
# Aging Rate: 0.0016035838827092933
# Precision: 0.9180327868852459
# Recall: 0.7368421052631579
# Aging Rate: 0.001552676457861379
# Precision: 1.0
# Recall: 0.6842105263157895
# Aging Rate: 0.0013235930460457658
# [I 2022-02-27 08:35:18,490] Trial 68 finished with value: 0.8167207110224229 and parameters: {'n_estimators': 500, 'learning_rate': 0.275, 'max_depth': 6, 'num_leaves': 50, 'min_child_samples': 1000, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.018466388501980256, 'reg_lambda': 0.6196982306999517}. Best is trial 41 with value: 0.8832470540683395.
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:35:21,951] Trial 69 finished with value: 0.0 and parameters: {'n_estimators': 500, 'learning_rate': 0.225, 'max_depth': 3, 'num_leaves': 70, 'min_child_samples': 500, 'min_split_gain': 2, 'colsample_bytree': 0.7, 'subsample': 0.5, 'reg_alpha': 0.037399600022250956, 'reg_lambda': 0.793444889265173}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 0.9538461538461539
# Recall: 0.8157894736842105
# Aging Rate: 0.0016544913075572073
# Precision: 0.9014084507042254
# Recall: 0.8421052631578947
# Aging Rate: 0.0018072135821009495
# Precision: 0.9
# Recall: 0.7105263157894737
# Aging Rate: 0.001527222745437422
# [I 2022-02-27 08:35:28,139] Trial 70 finished with value: 0.8480995234973422 and parameters: {'n_estimators': 1000, 'learning_rate': 0.325, 'max_depth': 6, 'num_leaves': 90, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.05144725099487053, 'reg_lambda': 0.17696110128581244}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 0.9423076923076923
# Recall: 0.6447368421052632
# Aging Rate: 0.0013235930460457658
# Precision: 0.9285714285714286
# Recall: 0.6842105263157895
# Aging Rate: 0.0014254078957415938
# Precision: 0.9365079365079365
# Recall: 0.7763157894736842
# Aging Rate: 0.0016035838827092933
# [I 2022-02-27 08:35:33,536] Trial 71 finished with value: 0.8008082170627134 and parameters: {'n_estimators': 500, 'learning_rate': 0.325, 'max_depth': 6, 'num_leaves': 90, 'min_child_samples': 50, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.10844647094519401, 'reg_lambda': 0.5191025896983787}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 0.9104477611940298
# Recall: 0.8026315789473685
# Aging Rate: 0.0017053987324051213
# Precision: 0.9836065573770492
# Recall: 0.7894736842105263
# Aging Rate: 0.001552676457861379
# Precision: 0.8507462686567164
# Recall: 0.75
# Aging Rate: 0.0017053987324051213
# [I 2022-02-27 08:35:39,295] Trial 72 finished with value: 0.8420873530362581 and parameters: {'n_estimators': 500, 'learning_rate': 0.325, 'max_depth': 6, 'num_leaves': 90, 'min_child_samples': 50, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.06751202436629254, 'reg_lambda': 0.7329731688206655}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 0.9310344827586207
# Recall: 0.7105263157894737
# Aging Rate: 0.001476315320589508
# Precision: 0.9508196721311475
# Recall: 0.7631578947368421
# Aging Rate: 0.001552676457861379
# Precision: 0.9193548387096774
# Recall: 0.75
# Aging Rate: 0.001578130170285336
# [I 2022-02-27 08:35:45,268] Trial 73 finished with value: 0.8262574780808745 and parameters: {'n_estimators': 500, 'learning_rate': 0.325, 'max_depth': 6, 'num_leaves': 90, 'min_child_samples': 50, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.5, 'reg_alpha': 0.057487154179939035, 'reg_lambda': 0.4405709848125863}. Best is trial 41 with value: 0.8832470540683395.
# Precision: 0.90625
# Recall: 0.7631578947368421
# Aging Rate: 0.0016290375951332503
# Precision: 0.9411764705882353
# Recall: 0.8421052631578947
# Aging Rate: 0.0017308524448290783
# Precision: 0.890625
# Recall: 0.75
# Aging Rate: 0.0016290375951332503
# ...
# Precision: 0.8666666666666667
# Recall: 0.17105263157894737
# Aging Rate: 0.017942583732057416
# [I 2022-02-27 08:51:02,753] Trial 75 finished with value: 0.3150456787129113 and parameters: {'n_estimators': 1000, 'learning_rate': 0.325, 'max_depth': 3, 'num_leaves': 10, 'min_child_samples': 100, 'min_split_gain': 2, 'colsample_bytree': 0.7, 'subsample': 0.9, 'reg_alpha': 0.010316998894905312, 'reg_lambda': 0.15975833831946853}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0.8947368421052632
# Recall: 0.8947368421052632
# Aging Rate: 0.09090909090909091
# Precision: 0.8985507246376812
# Recall: 0.8157894736842105
# Aging Rate: 0.08253588516746412
# Precision: 0.9
# Recall: 0.8289473684210527
# Aging Rate: 0.08373205741626795
# [I 2022-02-27 08:51:03,356] Trial 76 finished with value: 0.8709743181761679 and parameters: {'n_estimators': 1000, 'learning_rate': 0.325, 'max_depth': 3, 'num_leaves': 30, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.9, 'reg_alpha': 0.02405736438856774, 'reg_lambda': 0.11460871980559201}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0.78125
# Recall: 0.32894736842105265
# Aging Rate: 0.03827751196172249
# Precision: 0.6842105263157895
# Recall: 0.34210526315789475
# Aging Rate: 0.045454545454545456
# Precision: 0.6923076923076923
# Recall: 0.35526315789473684
# Aging Rate: 0.04665071770334928
# [I 2022-02-27 08:51:03,881] Trial 77 finished with value: 0.4628895104104867 and parameters: {'n_estimators': 1000, 'learning_rate': 0.325, 'max_depth': 3, 'num_leaves': 30, 'min_child_samples': 500, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.9, 'reg_alpha': 0.02627002659320799, 'reg_lambda': 0.11119983099247203}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0.85
# Recall: 0.2236842105263158
# Aging Rate: 0.023923444976076555
# Precision: 0.7777777777777778
# Recall: 0.09210526315789473
# Aging Rate: 0.01076555023923445
# Precision: 0.8421052631578947
# Recall: 0.21052631578947367
# Aging Rate: 0.022727272727272728
# [I 2022-02-27 08:51:04,152] Trial 78 finished with value: 0.28523821809425526 and parameters: {'n_estimators': 100, 'learning_rate': 0.325, 'max_depth': 3, 'num_leaves': 10, 'min_child_samples': 100, 'min_split_gain': 2, 'colsample_bytree': 0.7, 'subsample': 0.9, 'reg_alpha': 0.055353461850467585, 'reg_lambda': 0.25531104658578263}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0.9666666666666667
# Recall: 0.7631578947368421
# Aging Rate: 0.07177033492822966
# Precision: 0.8611111111111112
# Recall: 0.8157894736842105
# Aging Rate: 0.0861244019138756
# Precision: 0.927536231884058
# Recall: 0.8421052631578947
# Aging Rate: 0.08253588516746412
# [I 2022-02-27 08:51:04,950] Trial 79 finished with value: 0.8578458783326938 and parameters: {'n_estimators': 1000, 'learning_rate': 0.325, 'max_depth': 3, 'num_leaves': 30, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.9, 'subsample': 0.9, 'reg_alpha': 0.02470017318276683, 'reg_lambda': 0.09111396426598369}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0.0
# Recall: 0.0
# Aging Rate: 0.0011961722488038277
# Precision: 1.0
# Recall: 0.02631578947368421
# Aging Rate: 0.0023923444976076554
# Precision: 1.0
# Recall: 0.013157894736842105
# Aging Rate: 0.0011961722488038277
# [I 2022-02-27 08:51:05,534] Trial 80 finished with value: 0.02575202575202575 and parameters: {'n_estimators': 1000, 'learning_rate': 0.275, 'max_depth': 3, 'num_leaves': 10, 'min_child_samples': 1000, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.9, 'reg_alpha': 0.01585920980839363, 'reg_lambda': 0.17684197329380708}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0.921875
# Recall: 0.7763157894736842
# Aging Rate: 0.07655502392344497
# Precision: 0.8533333333333334
# Recall: 0.8421052631578947
# Aging Rate: 0.08971291866028708
# Precision: 0.8767123287671232
# Recall: 0.8421052631578947
# Aging Rate: 0.08732057416267942
# [I 2022-02-27 08:51:06,389] Trial 81 finished with value: 0.8498665549156682 and parameters: {'n_estimators': 1000, 'learning_rate': 0.325, 'max_depth': 3, 'num_leaves': 30, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.9, 'reg_alpha': 0.01179790421242283, 'reg_lambda': 0.10940438372619447}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0.8695652173913043
# Recall: 0.7894736842105263
# Aging Rate: 0.08253588516746412
# Precision: 0.8714285714285714
# Recall: 0.8026315789473685
# Aging Rate: 0.08373205741626795
# Precision: 0.8615384615384616
# Recall: 0.7368421052631579
# Aging Rate: 0.07775119617224881
# [I 2022-02-27 08:51:07,455] Trial 82 finished with value: 0.8191762954624893 and parameters: {'n_estimators': 1000, 'learning_rate': 0.325, 'max_depth': 3, 'num_leaves': 30, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.9, 'reg_alpha': 0.03945433331033937, 'reg_lambda': 0.13018550243252638}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0.9090909090909091
# Recall: 0.7894736842105263
# Aging Rate: 0.07894736842105263
# Precision: 0.9436619718309859
# Recall: 0.881578947368421
# Aging Rate: 0.08492822966507177
# Precision: 0.8888888888888888
# Recall: 0.8421052631578947
# Aging Rate: 0.0861244019138756
# [I 2022-02-27 08:51:08,092] Trial 83 finished with value: 0.8738333044168054 and parameters: {'n_estimators': 1000, 'learning_rate': 0.275, 'max_depth': 3, 'num_leaves': 10, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.021596498114926005, 'reg_lambda': 0.06222074490452123}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0.875
# Recall: 0.8289473684210527
# Aging Rate: 0.0861244019138756
# Precision: 0.9090909090909091
# Recall: 0.7894736842105263
# Aging Rate: 0.07894736842105263
# Precision: 0.8970588235294118
# Recall: 0.8026315789473685
# Aging Rate: 0.08133971291866028
# [I 2022-02-27 08:51:08,729] Trial 84 finished with value: 0.8478813320362616 and parameters: {'n_estimators': 1000, 'learning_rate': 0.275, 'max_depth': 3, 'num_leaves': 10, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.9, 'reg_alpha': 0.0236133535535519, 'reg_lambda': 0.06243743348390646}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0.9354838709677419
# Recall: 0.7631578947368421
# Aging Rate: 0.07416267942583732
# Precision: 0.9166666666666666
# Recall: 0.868421052631579
# Aging Rate: 0.0861244019138756
# Precision: 0.9384615384615385
# Recall: 0.8026315789473685
# Aging Rate: 0.07775119617224881
# [I 2022-02-27 08:51:09,486] Trial 85 finished with value: 0.8659066096623914 and parameters: {'n_estimators': 1000, 'learning_rate': 0.275, 'max_depth': 3, 'num_leaves': 10, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.03814017359992501, 'reg_lambda': 0.08054564233712903}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0.875
# Recall: 0.18421052631578946
# Aging Rate: 0.019138755980861243
# Precision: 1.0
# Recall: 0.11842105263157894
# Aging Rate: 0.01076555023923445
# Precision: 0.7368421052631579
# Recall: 0.18421052631578946
# Aging Rate: 0.022727272727272728
# [I 2022-02-27 08:51:10,117] Trial 86 finished with value: 0.2702831246915242 and parameters: {'n_estimators': 1000, 'learning_rate': 0.275, 'max_depth': 3, 'num_leaves': 10, 'min_child_samples': 100, 'min_split_gain': 2, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.017018117933366765, 'reg_lambda': 0.06791455790588989}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0.8591549295774648
# Recall: 0.8026315789473685
# Aging Rate: 0.08492822966507177
# Precision: 0.8805970149253731
# Recall: 0.7763157894736842
# Aging Rate: 0.08014354066985646
# Precision: 0.8513513513513513
# Recall: 0.8289473684210527
# Aging Rate: 0.08851674641148326
# [I 2022-02-27 08:51:10,716] Trial 87 finished with value: 0.8317022659879804 and parameters: {'n_estimators': 1000, 'learning_rate': 0.275, 'max_depth': 3, 'num_leaves': 10, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.039530958347253425, 'reg_lambda': 0.09133531733351966}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0.9393939393939394
# Recall: 0.8157894736842105
# Aging Rate: 0.07894736842105263
# Precision: 0.8227848101265823
# Recall: 0.8552631578947368
# Aging Rate: 0.09449760765550239
# Precision: 0.8
# Recall: 0.8421052631578947
# Aging Rate: 0.09569377990430622
# [I 2022-02-27 08:51:11,304] Trial 88 finished with value: 0.8441539781839644 and parameters: {'n_estimators': 1000, 'learning_rate': 0.275, 'max_depth': 3, 'num_leaves': 30, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.054302293723985054, 'reg_lambda': 0.07844767567523606}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 1.0
# Recall: 0.18421052631578946
# Aging Rate: 0.01674641148325359
# Precision: 0.8125
# Recall: 0.17105263157894737
# Aging Rate: 0.019138755980861243
# Precision: 0.7894736842105263
# Recall: 0.19736842105263158
# Aging Rate: 0.022727272727272728
# [I 2022-02-27 08:51:11,648] Trial 89 finished with value: 0.3031697601491652 and parameters: {'n_estimators': 1000, 'learning_rate': 0.325, 'max_depth': 3, 'num_leaves': 10, 'min_child_samples': 100, 'min_split_gain': 2, 'colsample_bytree': 0.7, 'subsample': 0.9, 'reg_alpha': 0.022669646754145296, 'reg_lambda': 0.1809324423358096}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0.9393939393939394
# Recall: 0.8157894736842105
# Aging Rate: 0.07894736842105263
# Precision: 0.9047619047619048
# Recall: 0.75
# Aging Rate: 0.07535885167464115
# Precision: 0.9014084507042254
# Recall: 0.8421052631578947
# Aging Rate: 0.08492822966507177
# [I 2022-02-27 08:51:12,355] Trial 90 finished with value: 0.8547105402771775 and parameters: {'n_estimators': 1000, 'learning_rate': 0.275, 'max_depth': 3, 'num_leaves': 10, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.012626093480290375, 'reg_lambda': 0.04768502111945335}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0.9130434782608695
# Recall: 0.8289473684210527
# Aging Rate: 0.08253588516746412
# Precision: 0.8955223880597015
# Recall: 0.7894736842105263
# Aging Rate: 0.08014354066985646
# Precision: 0.8461538461538461
# Recall: 0.868421052631579
# Aging Rate: 0.09330143540669857
# [I 2022-02-27 08:51:13,280] Trial 91 finished with value: 0.8550897378483585 and parameters: {'n_estimators': 1000, 'learning_rate': 0.325, 'max_depth': 3, 'num_leaves': 10, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.014466762440388425, 'reg_lambda': 0.11754957332865079}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# invalid value encountered in double_scalars
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-27 08:51:13,550] Trial 92 finished with value: 0.0 and parameters: {'n_estimators': 1000, 'learning_rate': 0.325, 'max_depth': 3, 'num_leaves': 10, 'min_child_samples': 5000, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.01688540376835579, 'reg_lambda': 0.05766779069724862}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0.8918918918918919
# Recall: 0.868421052631579
# Aging Rate: 0.08851674641148326
# Precision: 0.8923076923076924
# Recall: 0.7631578947368421
# Aging Rate: 0.07775119617224881
# Precision: 0.8285714285714286
# Recall: 0.7631578947368421
# Aging Rate: 0.08373205741626795
# [I 2022-02-27 08:51:14,483] Trial 93 finished with value: 0.8324051944687328 and parameters: {'n_estimators': 1000, 'learning_rate': 0.275, 'max_depth': 3, 'num_leaves': 30, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.035447638679485846, 'reg_lambda': 0.0815993182107624}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0.8857142857142857
# Recall: 0.8157894736842105
# Aging Rate: 0.08373205741626795
# Precision: 0.9305555555555556
# Recall: 0.881578947368421
# Aging Rate: 0.0861244019138756
# Precision: 0.9375
# Recall: 0.7894736842105263
# Aging Rate: 0.07655502392344497
# [I 2022-02-27 08:51:15,519] Trial 94 finished with value: 0.8706211103471376 and parameters: {'n_estimators': 1000, 'learning_rate': 0.275, 'max_depth': 3, 'num_leaves': 30, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.022180500806150593, 'reg_lambda': 0.03403091351156456}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0.9090909090909091
# Recall: 0.7894736842105263
# Aging Rate: 0.07894736842105263
# Precision: 0.8648648648648649
# Recall: 0.8421052631578947
# Aging Rate: 0.08851674641148326
# Precision: 0.8787878787878788
# Recall: 0.7631578947368421
# Aging Rate: 0.07894736842105263
# [I 2022-02-27 08:51:16,125] Trial 95 finished with value: 0.8384350547730829 and parameters: {'n_estimators': 1000, 'learning_rate': 0.275, 'max_depth': 3, 'num_leaves': 30, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.02818648301316983, 'reg_lambda': 0.10274459298803094}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0.9014084507042254
# Recall: 0.8421052631578947
# Aging Rate: 0.08492822966507177
# Precision: 0.84
# Recall: 0.8289473684210527
# Aging Rate: 0.08971291866028708
# Precision: 0.8333333333333334
# Recall: 0.7894736842105263
# Aging Rate: 0.0861244019138756
# [I 2022-02-27 08:51:16,770] Trial 96 finished with value: 0.8386653987410847 and parameters: {'n_estimators': 1000, 'learning_rate': 0.275, 'max_depth': 3, 'num_leaves': 30, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.04658415348210175, 'reg_lambda': 0.04969767003799233}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0.7407407407407407
# Recall: 0.2631578947368421
# Aging Rate: 0.03229665071770335
# Precision: 0.7777777777777778
# Recall: 0.09210526315789473
# Aging Rate: 0.01076555023923445
# Precision: 0.9285714285714286
# Recall: 0.17105263157894737
# Aging Rate: 0.01674641148325359
# [I 2022-02-27 08:51:17,201] Trial 97 finished with value: 0.2806480952683123 and parameters: {'n_estimators': 1000, 'learning_rate': 0.325, 'max_depth': 3, 'num_leaves': 10, 'min_child_samples': 100, 'min_split_gain': 2, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.020286615328719896, 'reg_lambda': 0.07154658900815657}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0.9508196721311475
# Recall: 0.7631578947368421
# Aging Rate: 0.0729665071770335
# Precision: 0.828125
# Recall: 0.6973684210526315
# Aging Rate: 0.07655502392344497
# Precision: 0.8507462686567164
# Recall: 0.75
# Aging Rate: 0.08014354066985646
# [I 2022-02-27 08:51:18,123] Trial 98 finished with value: 0.8003536609376026 and parameters: {'n_estimators': 1000, 'learning_rate': 0.325, 'max_depth': 3, 'num_leaves': 30, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.022564047747510165, 'reg_lambda': 0.03507825577776349}. Best is trial 67 with value: 0.8820245711480154.
# Precision: 0.8823529411764706
# Recall: 0.7894736842105263
# Aging Rate: 0.08133971291866028
# Precision: 0.90625
# Recall: 0.7631578947368421
# Aging Rate: 0.07655502392344497
# Precision: 0.9295774647887324
# Recall: 0.868421052631579
# Aging Rate: 0.08492822966507177
# [I 2022-02-27 08:51:18,711] Trial 99 finished with value: 0.8532879818594105 and parameters: {'n_estimators': 1000, 'learning_rate': 0.275, 'max_depth': 3, 'num_leaves': 30, 'min_child_samples': 100, 'min_split_gain': 0, 'colsample_bytree': 0.7, 'subsample': 0.7, 'reg_alpha': 0.013277050379268905, 'reg_lambda': 0.213552295446154}. Best is trial 67 with value: 0.8820245711480154.
# Sampler is TPESampler

# %%
best_paramR, all_scoreR = all_optuna(num_set = 10, 
                                     all_data = run_train, 
                                     mode = 'R', 
                                     TPE_multi = False, 
                                     n_iter = 10,
                                     filename = 'runhist_array_m2m5_4selection_LightGBM',
                                     creator = LightGBM_creator
                                    )

# %%
##### optimization history plot #####
optuna_history(best_paramC, all_scoreC, num_row = 4, num_col = 3, model = 'LightGBM Classifier')
            
##### best hyperparameter table #####
param_table = pd.DataFrame(best_paramC).T
param_table
# Out:
#       n_estimators  learning_rate  max_depth  num_leaves  min_child_samples  \
# set0         500.0          0.275        6.0        90.0              100.0
# set1         500.0          0.275        6.0       110.0               50.0
# set2        1000.0          0.325        9.0       110.0               50.0
# set3        1000.0          0.125        6.0        30.0               50.0
# set4         500.0          0.275        6.0       130.0               50.0
# set5         500.0          0.325       12.0        30.0               50.0
# set6         500.0          0.175       12.0        50.0               50.0
# set7         500.0          0.225       12.0        50.0               50.0
# set8        1000.0          0.275       12.0        50.0               50.0
# set9        1000.0          0.275        3.0        10.0              100.0
#
#       min_split_gain  colsample_bytree  subsample  reg_alpha  reg_lambda
# set0             0.0               0.9        0.5   0.039417    0.884592
# set1             0.0               0.9        0.7   0.150480    0.041377
# set2             0.0               0.3        0.5   0.150877    0.431511
# set3             0.0               0.9        0.5   0.012229    2.620430
# set4             0.0               0.9        0.5   0.022894    0.260775
# set5             0.0               0.5        0.9   0.040981    0.734008
# set6             0.0               0.7        0.9   0.042523    0.066570
# set7             0.0               0.9        0.5   0.033986    0.016474
# set8             0.0               0.7        0.9   0.034316    7.335482
# set9             0.0               0.7        0.7   0.013677    0.075825

# %% [markdown]
# ##

# %% [markdown]
# ### Classifier

# %%
table_setC = runall_LightGBMC(10, run_train_x, run_test_x, run_train_y, run_test_y, best_paramC)
line_chart(table_setC, title = 'LightGBM Classifier')
# Out:
#  Dataset 0:
# Precision: 0.0
# Recall: 0.0
# Aging Rate: 4.111081419967522e-05
#
#  Dataset 1:
# Precision: 0.001409159536990438
# Recall: 0.27450980392156865
# Aging Rate: 0.20421796953688667
#
#  Dataset 2:
# Precision: 0.001515239815840084
# Recall: 0.5098039215686274
# Aging Rate: 0.3527102304261136
#
#  Dataset 3:
# Precision: 0.001518399428367274
# Recall: 0.3333333333333333
# Aging Rate: 0.2301383378897819
#
#  Dataset 4:
# Precision: 0.0011674060238150829
# Recall: 0.19607843137254902
# Aging Rate: 0.176077617217209
#
#  Dataset 5:
# Precision: 0.001152482269503546
# Recall: 0.2549019607843137
# Aging Rate: 0.23186499208616826
#
#  Dataset 6:
# Precision: 0.0011020801763328282
# Recall: 0.3137254901960784
# Aging Rate: 0.29842340027544245
#
#  Dataset 7:
# Precision: 0.001076941486179251
# Recall: 0.17647058823529413
# Aging Rate: 0.17178153713334293
#
#  Dataset 8:
# Precision: 0.0014168319637291016
# Recall: 0.29411764705882354
# Aging Rate: 0.2176200949659808
#
#  Dataset 9:
# Precision: 0.0014388489208633094
# Recall: 0.43137254901960786
# Aging Rate: 0.3142921745565171

# %%
table_setC
# Out:
#            Balance Ratio  Train_OK  Train_NG    TP       FP    FN       TN  \
# dataset 0     515.934211  156844.0     304.0   0.0      2.0  51.0  48596.0
# dataset 1       1.333225    4089.0    3067.0  14.0   9921.0  37.0  38677.0
# dataset 2       1.333111    4006.0    3005.0  26.0  17133.0  25.0  31465.0
# dataset 3       1.333004    4043.0    3033.0  17.0  11179.0  34.0  37419.0
# dataset 4       1.332785    4049.0    3038.0  10.0   8556.0  41.0  40042.0
# dataset 5       1.330706    4052.0    3045.0  13.0  11267.0  38.0  37331.0
# dataset 6       1.357454    4052.0    2985.0  16.0  14502.0  35.0  34096.0
# dataset 7       1.430286    4052.0    2833.0   9.0   8348.0  42.0  40250.0
# dataset 8       1.333772    4052.0    3038.0  15.0  10572.0  36.0  38026.0
# dataset 9      10.000000    3040.0     304.0  22.0  15268.0  29.0  33330.0
#
#            Precision    Recall  Aging Rate  Efficiency     Score
# dataset 0   0.000000  0.000000    0.000041    0.000000  0.000000
# dataset 1   0.001409  0.274510    0.204218    1.344200  0.233867
# dataset 2   0.001515  0.509804    0.352710    1.445390  0.455869
# dataset 3   0.001518  0.333333    0.230138    1.448404  0.298479
# dataset 4   0.001167  0.196078    0.176078    1.113591  0.146743
# dataset 5   0.001152  0.254902    0.231865    1.099355  0.189043
# dataset 6   0.001102  0.313725    0.298423    1.051276  0.225400
# dataset 7   0.001077  0.176471    0.171782    1.027297  0.124712
# dataset 8   0.001417  0.294118    0.217620    1.351519  0.251489
# dataset 9   0.001439  0.431373    0.314292    1.372521  0.372686

# %% [markdown]
# #### calibrated classifier (optional)

# %%
tableC_1 = all_cali_LightGBMC(run_train_x, run_train_y, run_test_x, run_test_y, best_paramC, method = 'isotonic')
tableC_2 = all_cali_LightGBMC(run_train_x, run_train_y, run_test_x, run_test_y, best_paramC, method = 'sigmoid')
tableC_3 = all_cali_LightGBMC(run_train_x, run_train_y, run_test_x, run_test_y, best_paramC, method = 'beta')

# %% [markdown]
# #### feature importance

# %%
target = 'set4'

d_train = lgb.Dataset(run_train_x[target], label = run_train_y[target])
d_test = lgb.Dataset(run_test_x, label = run_test_y)
model = lgb.train(best_paramC[target], d_train, 10000, valid_sets = [d_test], early_stopping_rounds = 50, verbose_eval=1000)
explainer = shap.Explainer(model)
shap_values = explainer.shap_values(run_train_x[target])
values = abs(shap_value.values).mean(axis = 0)[:, 1]

shap.summary_plot(shap_values, run_train_x[target])
shap.dependence_plot('label_eqp_ADIEX600', shap_values[1], run_train_x[target])
shap.dependence_plot('label_eqp_ADSPT200', shap_values[1], run_train_x[target], color = shap_values)

# %%
fig = plt.figure(figsize = (24, 8))
colname = run_train[target].columns.to_list()[:-1]
clf = LGBMClassifier(**best_paramC[target])
clf.fit(run_train_x[target], run_train_y[target])
importance = (clf.feature_importances_ / best_paramC[target]['n_estimators']).tolist()
plt.bar(colname, values, color = 'red')
plt.xticks(rotation = 90)
plt.title('20211228_LightGBM_ShapValue')
fig = plt.figure(figsize = (24, 8))
plt.bar(colname, importance, color = 'blue')
plt.xticks(rotation = 90)
plt.title('20211228_LightGBM_TreeBasedImportance')

# %% [markdown]
# ### Regressor

# %%
pr_dict, table_setR = runall_LightGBMR(10, run_train_x, run_test_x, run_train_y, run_test_y, best_paramR, 
                                       thres_target = 'Recall', threshold = 0.7)
line_chart(table_setR, title = 'LightGBM Regressor')

# %%
multiple_curve(4, 3, pr_dict, table_setR, target = 'Aging Rate')
multiple_curve(4, 3, pr_dict, table_setR, target = 'Precision')
table_setR

# %% [markdown]
# ### export

# %%
savedate = '20220301'
TPE_multi = False

table_setC['sampler'] = 'multivariate-TPE' if TPE_multi else 'univariate-TPE'
table_setC['model'] = 'LightGBM_br1.33'
with pd.ExcelWriter(f'{savedate}_Classifier.xlsx', mode = 'a') as writer:
    table_setC.to_excel(writer, sheet_name = 'LightGBM_br1.33')
