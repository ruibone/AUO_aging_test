# %%
import os
import numpy as np
import pandas as pd
import pickle
from tqdm.auto import tqdm
import matplotlib.pyplot as plt

import xgboost as xgb
import optuna
from sklearn.model_selection import train_test_split

from library.Data_Preprocessing import Balance_Ratio
from library.Imbalance_Sampling import label_divide
from library.Aging_Score_Contour import score1
from library.AdaBoost import train_set, multiple_set, multiple_month, line_chart, cf_matrix, AUC, PR_curve, \
     multiple_curve, PR_matrix, best_threshold, all_optuna, optuna_history 

os.chdir('C:/Users/user/Desktop/Darui_R08621110') 
os.getcwd()
# Out:
# 'C:\\Users\\user\\Desktop\\Darui_R08621110'

# %% [markdown]
# ##

# %% [markdown]
# ### XGBoost

# %%
# classifier
def XGBoostC(train_x, test_x, train_y, test_y, config):
    
    clf = xgb.XGBClassifier(**config, n_jobs = -1, use_label_encoder = False)
    clf.fit(train_x, train_y)
    predict_y = clf.predict_proba(test_x)[:, 1]
    define_predict = (predict_y > 0.5).astype(int)
    result = pd.DataFrame({'truth': test_y, 'predict': define_predict})
    
    return result
    

# regressor
def XGBoostR(train_x, test_x, train_y, test_y, config):
    
    reg = xgb.XGBRegressor(**config, n_jobs = -1)
    reg.fit(train_x, train_y)
    predict_y = reg.predict(test_x)
    result = pd.DataFrame({'truth': test_y, 'predict': predict_y})

    return result


# classifier for all resampling datasets
def runall_XGBoostC(trainset_x, test_x, trainset_y, test_y, config):
    
    table_set = pd.DataFrame()
    bad_set = pd.DataFrame()
    set_index = list(config.keys())
    judge = set_index[0]

    for i, j in tqdm(enumerate(set_index)):
        print('\n', f'Data{j}:')
        if isinstance(config[judge], dict) :
            best_config = config[j]
        else :
            best_config = config
            
        result = XGBoostC(trainset_x[j], test_x, trainset_y[j], test_y, best_config)    
        table = cf_matrix(result, trainset_y[j])
        table_set = pd.concat([table_set, table]).rename(index = {0: f'data{j}'})

    return table_set
    

# regressor for all resampling datasets
def runall_XGBoostR(num_set, trainset_x, test_x, trainset_y, test_y, config, thres_target = 'Recall', threshold = 0.8):
    
    table_set = pd.DataFrame()
    bad_set = pd.DataFrame()
    pr_dict = {}
    judge = list(config.keys())[0]

    for i in range(num_set):
        print('\n', f'Dataset {i}:')

        if isinstance(config[judge], dict) :
            best_config = config[f'set{i}']
        else :
            best_config = config

        predict = XGBoostR(trainset_x[f'set{i}'], test_x, trainset_y[f'set{i}'], test_y, best_config)     
        pr_matrix = PR_matrix(predict, trainset_y[f'set{i}'])
        pr_dict[f'set{i}'] = pr_matrix
        
        best_data, best_thres = best_threshold(pr_matrix, target = thres_target, threshold = threshold)
        table_set = pd.concat([table_set, best_data]).rename(index = {best_data.index.values[0]: f'dataset {i}'})
        
    return pr_dict, table_set

# %% [markdown]
# ### Optuna

# %%
# creator of optuna study for XGBoost
def XGBoost_creator(train_data, mode, num_valid = 5, label = 'GB') :
    
    def objective(trial) :

        param = {
            'eval_metric': trial.suggest_categorical('eval_metric', ['logloss']),
            'n_estimators': trial.suggest_categorical('n_estimators', [100, 300, 500, 1000]),
            'subsample': trial.suggest_float('subsample', 0.3, 0.9, step = 0.2),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.3, 0.9, step = 0.2),
            'min_child_weight': trial.suggest_int('min_child_weight', 1, 11, step = 2),
            'max_depth': trial.suggest_int('max_depth', 3, 18, step = 3),
            'learning_rate': trial.suggest_float('learning_rate', 0.025, 0.325, step = 0.05),
            'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-2, 10), # alpha
            'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-2, 10) # lambda
        }

        result_list = []
        for i in range(num_valid):

            train_good = train_data[train_data.GB == 0]
            train_bad = train_data[train_data.GB == 1]
            train_good_x, train_good_y = label_divide(train_good, None, label, train_only = True)
            train_bad_x, train_bad_y = label_divide(train_bad, None, label, train_only = True)
            train_g_x, valid_g_x, train_g_y, valid_g_y = train_test_split(train_good_x, train_good_y, test_size = 0.25)
            train_b_x, valid_b_x, train_b_y, valid_b_y = train_test_split(train_bad_x, train_bad_y, test_size = 0.25)
            train_x = pd.concat([train_g_x, train_b_x], axis = 0)
            train_y = pd.concat([train_g_y, train_b_y], axis = 0)
            valid_x = pd.concat([valid_g_x, valid_b_x], axis = 0)
            valid_y = pd.concat([valid_g_y, valid_b_y], axis = 0)

            if mode == 'C':
                result = XGBoostC(train_x, valid_x, train_y, valid_y, param)
                table = cf_matrix(result, valid_y)
                recall = table['Recall']
                precision = table['Precision']
                beta = 1
                if recall.values > 0:
                    fscore = ((1+beta**2)*recall*precision) / (recall+(beta**2)*precision)
                else:
                    fscore = 0
                result_list.append(fscore)

            elif mode == 'R':
                result = XGBoostR(train_x, valid_x, train_y, valid_y, param)
                pr_matrix = PR_matrix(result, valid_y)
                auc = AUC(pr_matrix['Recall'], pr_matrix['Aging Rate'])
                result_list.append((-1)*auc)

        return np.mean(result_list)
    
    return objective

# %% [markdown]
# ##

# %% [markdown]
# ### Load Data

# %%
### training data ### 
training_month = range(2, 5)

data_dict, trainset_x, trainset_y = multiple_month(training_month, num_set = 10, filename = 'dataset')

print('\nCombined training data:\n')
run_train = multiple_set(num_set = 10)
run_train_x, run_train_y = train_set(run_train)

### testing data ###
run_test = pd.read_csv('test_runhist.csv').iloc[:, 2:]
run_test_x, run_test_y = label_divide(run_test, None, 'GB', train_only = True)
print('\n', 'Dimension of testing data:', run_test.shape)
# Out:
# Month 2:
#
# Dimension of dataset 0 : (39009, 88)  balance ratio: 564.35
# Dimension of dataset 1 : (1404, 88)  balance ratio: 1.0
# Dimension of dataset 2 : (1364, 88)  balance ratio: 1.0
# Dimension of dataset 3 : (1376, 88)  balance ratio: 1.0
# Dimension of dataset 4 : (1378, 88)  balance ratio: 1.0
# Dimension of dataset 5 : (1370, 88)  balance ratio: 1.01
# Dimension of dataset 6 : (1375, 88)  balance ratio: 1.01
# Dimension of dataset 7 : (1317, 88)  balance ratio: 1.1
# Dimension of dataset 8 : (1380, 88)  balance ratio: 1.0
# Dimension of dataset 9 : (759, 88)  balance ratio: 10.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
# Month 3:
#
# Dimension of dataset 0 : (60396, 97)  balance ratio: 533.48
# Dimension of dataset 1 : (2304, 97)  balance ratio: 1.0
# Dimension of dataset 2 : (2208, 97)  balance ratio: 1.0
# Dimension of dataset 3 : (2256, 97)  balance ratio: 1.0
# Dimension of dataset 4 : (2258, 97)  balance ratio: 1.0
# Dimension of dataset 5 : (2271, 97)  balance ratio: 0.99
# Dimension of dataset 6 : (2244, 97)  balance ratio: 1.01
# Dimension of dataset 7 : (2158, 97)  balance ratio: 1.1
# Dimension of dataset 8 : (2260, 97)  balance ratio: 1.0
# Dimension of dataset 9 : (1243, 97)  balance ratio: 10.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
# Month 4:
#
# Dimension of dataset 0 : (57743, 100)  balance ratio: 472.3
# Dimension of dataset 1 : (2426, 100)  balance ratio: 1.0
# Dimension of dataset 2 : (2396, 100)  balance ratio: 1.0
# Dimension of dataset 3 : (2434, 100)  balance ratio: 1.0
# Dimension of dataset 4 : (2440, 100)  balance ratio: 1.0
# Dimension of dataset 5 : (2419, 100)  balance ratio: 1.02
# Dimension of dataset 6 : (2423, 100)  balance ratio: 1.01
# Dimension of dataset 7 : (2330, 100)  balance ratio: 1.1
# Dimension of dataset 8 : (2440, 100)  balance ratio: 1.0
# Dimension of dataset 9 : (1342, 100)  balance ratio: 10.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
# Combined training data:
#
# Dimension of dataset 0 : (157148, 128)  balance ratio: 515.93
# Dimension of dataset 1 : (6134, 128)  balance ratio: 1.0
# Dimension of dataset 2 : (5968, 128)  balance ratio: 1.0
# Dimension of dataset 3 : (6066, 128)  balance ratio: 1.0
# Dimension of dataset 4 : (6076, 128)  balance ratio: 1.0
# Dimension of dataset 5 : (6060, 128)  balance ratio: 1.01
# Dimension of dataset 6 : (6042, 128)  balance ratio: 1.01
# Dimension of dataset 7 : (5805, 128)  balance ratio: 1.1
# Dimension of dataset 8 : (6080, 128)  balance ratio: 1.0
# Dimension of dataset 9 : (3344, 128)  balance ratio: 10.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
#  Dimension of testing data: (48649, 128)

# %% [markdown]
# ### Search for Best Hyperparameters

# %%
best_paramC, all_scoreC = all_optuna(all_data = run_train, 
                                     mode = 'C', 
                                     TPE_multi = False, 
                                     n_iter = 100, 
                                     filename = 'runhist_array_m2m4_m5_3criteria_XGBoost_6',
                                     creator = XGBoost_creator
                                    )
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# [I 2022-03-03 17:22:51,841] A new study created in memory with name: no-name-f5a72fe8-a306-4ba5-966f-bc8b7392ec2a
# Dataset 1 :
# C:\Users\user\anaconda3\envs\aging\lib\site-packages\optuna\progress_bar.py:47: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
#   0%|          | 0/100 [00:00<?, ?it/s]
# Precision: 0.9670619235836627
# Recall: 0.9569752281616688
# Aging Rate: 0.49478487614080835
# Precision: 0.9692101740294511
# Recall: 0.9439374185136897
# Aging Rate: 0.4869621903520209
# Precision: 0.9684625492772667
# Recall: 0.9608865710560626
# Aging Rate: 0.49608865710560623
# [I 2022-03-03 17:22:54,005] Trial 0 finished with value: 0.9610195637961816 and parameters: {'eval_metric': 'logloss', 'n_estimators': 500, 'subsample': 0.3, 'colsample_bytree': 0.3, 'min_child_weight': 7, 'max_depth': 12, 'learning_rate': 0.325, 'reg_alpha': 4.563211152342992, 'reg_lambda': 0.05597407174371223}. Best is trial 0 with value: 0.9610195637961816.
# Precision: 0.9193121693121693
# Recall: 0.9061277705345502
# Aging Rate: 0.49282920469361147
# Precision: 0.9072847682119205
# Recall: 0.8930899608865711
# Aging Rate: 0.4921773142112125
# Precision: 0.9125827814569536
# Recall: 0.8983050847457628
# Aging Rate: 0.4921773142112125
# [I 2022-03-03 17:22:55,790] Trial 1 finished with value: 0.9060638036887453 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.5, 'colsample_bytree': 0.9, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.025, 'reg_alpha': 9.302359627611029, 'reg_lambda': 0.11834370957410072}. Best is trial 0 with value: 0.9610195637961816.
# Precision: 0.9908854166666666
# Recall: 0.9921773142112125
# Aging Rate: 0.500651890482399
# Precision: 0.9960732984293194
# Recall: 0.9921773142112125
# Aging Rate: 0.4980443285528031
# Precision: 0.9921875
# Recall: 0.9934810951760105
# Aging Rate: 0.500651890482399
# [I 2022-03-03 17:23:02,985] Trial 2 finished with value: 0.992828770023212 and parameters: {'eval_metric': 'logloss', 'n_estimators': 1000, 'subsample': 0.3, 'colsample_bytree': 0.9, 'min_child_weight': 1, 'max_depth': 15, 'learning_rate': 0.07500000000000001, 'reg_alpha': 0.059068556821421016, 'reg_lambda': 0.07220280998651186}. Best is trial 2 with value: 0.992828770023212.
# Precision: 0.9622132253711201
# Recall: 0.9295958279009127
# Aging Rate: 0.4830508474576271
# Precision: 0.9488859764089121
# Recall: 0.9439374185136897
# Aging Rate: 0.4973924380704042
# Precision: 0.9507772020725389
# Recall: 0.9569752281616688
# Aging Rate: 0.5032594524119948
# [I 2022-03-03 17:23:04,503] Trial 3 finished with value: 0.9486315725939464 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.5, 'colsample_bytree': 0.5, 'min_child_weight': 9, 'max_depth': 3, 'learning_rate': 0.07500000000000001, 'reg_alpha': 0.025415897970358252, 'reg_lambda': 0.016945471351329896}. Best is trial 2 with value: 0.992828770023212.
# Precision: 0.9816272965879265
# Recall: 0.9752281616688396
# Aging Rate: 0.49674054758800523
# Precision: 0.9844155844155844
# Recall: 0.9882659713168188
# Aging Rate: 0.5019556714471969
# Precision: 0.9693877551020408
# Recall: 0.9908735332464146
# Aging Rate: 0.5110821382007823
# [I 2022-03-03 17:23:05,602] Trial 4 finished with value: 0.9815890604209075 and parameters: {'eval_metric': 'logloss', 'n_estimators': 100, 'subsample': 0.5, 'colsample_bytree': 0.9, 'min_child_weight': 5, 'max_depth': 18, 'learning_rate': 0.275, 'reg_alpha': 0.9786679165562263, 'reg_lambda': 0.08267510425219624}. Best is trial 2 with value: 0.992828770023212.
# Precision: 0.
# Precision: 0.9895968790637191
# Recall: 0.9921773142112125
# Aging Rate: 0.5013037809647979
# [I 2022-03-03 17:28:32,218] Trial 62 finished with value: 0.9895881214155801 and parameters: {'eval_metric': 'logloss', 'n_estimators': 500, 'subsample': 0.5, 'colsample_bytree': 0.3, 'min_child_weight': 1, 'max_depth': 18, 'learning_rate': 0.07500000000000001, 'reg_alpha': 0.14250502000812632, 'reg_lambda': 0.019377908867936902}. Best is trial 22 with value: 0.9943635502730341.
# Precision: 0.9960681520314548
# Recall: 0.9908735332464146
# Aging Rate: 0.4973924380704042
# Precision: 0.9895561357702349
# Recall: 0.9882659713168188
# Aging Rate: 0.49934810951760106
# Precision: 0.9934725848563969
# Recall: 0.9921773142112125
# Aging Rate: 0.49934810951760106
# [I 2022-03-03 17:28:38,599] Trial 63 finished with value: 0.9917330707016445 and parameters: {'eval_metric': 'logloss', 'n_estimators': 500, 'subsample': 0.5, 'colsample_bytree': 0.3, 'min_child_weight': 1, 'max_depth': 15, 'learning_rate': 0.025, 'reg_alpha': 0.11022750531877597, 'reg_lambda': 0.04658783874098555}. Best is trial 22 with value: 0.9943635502730341.
# Precision: 0.9908376963350786
# Recall: 0.9869621903520208
# Aging Rate: 0.4980443285528031
# Precision: 0.9895833333333334
# Recall: 0.9908735332464146
# Aging Rate: 0.500651890482399
# Precision: 0.9883419689119171
# Recall: 0.9947848761408083
# Aging Rate: 0.5032594524119948
# [I 2022-03-03 17:28:43,581] Trial 64 finished with value: 0.9902257052680515 and parameters: {'eval_metric': 'logloss', 'n_estimators': 500, 'subsample': 0.5, 'colsample_bytree': 0.3, 'min_child_weight': 1, 'max_depth': 18, 'learning_rate': 0.07500000000000001, 'reg_alpha': 0.4848153658938125, 'reg_lambda': 0.031591318307925456}. Best is trial 22 with value: 0.9943635502730341.
# Precision: 0.9896103896103896
# Recall: 0.9934810951760105
# Aging Rate: 0.5019556714471969
# Precision: 0.983225806451613
# Recall: 0.9934810951760105
# Aging Rate: 0.5052151238591917
# Precision: 0.9921773142112125
# Recall: 0.9921773142112125
# Aging Rate: 0.5
# [I 2022-03-03 17:28:49,507] Trial 65 finished with value: 0.9906820424422876 and parameters: {'eval_metric': 'logloss', 'n_estimators': 500, 'subsample': 0.9, 'colsample_bytree': 0.9, 'min_child_weight': 1, 'max_depth': 18, 'learning_rate': 0.17500000000000002, 'reg_alpha': 0.23657707737668873, 'reg_lambda': 0.016116886585013743}. Best is trial 22 with value: 0.9943635502730341.
# Precision: 0.9895287958115183
# Recall: 0.9856584093872229
# Aging Rate: 0.4980443285528031
# Precision: 0.9831824062095731
# Recall: 0.9908735332464146
# Aging Rate: 0.5039113428943938
# Precision: 0.9869791666666666
# Recall: 0.9882659713168188
# Aging Rate: 0.500651890482399
# [I 2022-03-03 17:28:58,751] Trial 66 finished with value: 0.9874083158104799 and parameters: {'eval_metric': 'logloss', 'n_estimators': 1000, 'subsample': 0.5, 'colsample_bytree': 0.7, 'min_child_weight': 3, 'max_depth': 12, 'learning_rate': 0.07500000000000001, 'reg_alpha': 0.18198791964400785, 'reg_lambda': 0.022715397809091615}. Best is trial 22 with value: 0.9943635502730341.
# Precision: 0.9883268482490273
# Recall: 0.9934810951760105
# Aging Rate: 0.5026075619295959
# Precision: 0.9947780678851175
# Recall: 0.9934810951760105
# Aging Rate: 0.49934810951760106
# Precision: 0.9820051413881749
# Recall: 0.9960886571056062
# Aging Rate: 0.5071707953063885
# [I 2022-03-03 17:29:03,419] Trial 67 finished with value: 0.99134106381584 and parameters: {'eval_metric': 'logloss', 'n_estimators': 500, 'subsample': 0.9, 'colsample_bytree': 0.5, 'min_child_weight': 1, 'max_depth': 15, 'learning_rate': 0.125, 'reg_alpha': 0.02945538956221512, 'reg_lambda': 0.01245021738327692}. Best is trial 22 with value: 0.9943635502730341.
# Precision: 0.9947643979057592
# Recall: 0.9908735332464146
# Aging Rate: 0.4980443285528031
# Precision: 0.9895287958115183
# Recall: 0.9856584093872229
# Aging Rate: 0.4980443285528031
# Precision: 0.9882659713168188
# Recall: 0.9882659713168188
# Aging Rate: 0.5
# [I 2022-03-03 17:29:11,883] Trial 68 finished with value: 0.9895569784641954 and parameters: {'eval_metric': 'logloss', 'n_estimators': 1000, 'subsample': 0.3, 'colsample_bytree': 0.3, 'min_child_weight': 1, 'max_depth': 9, 'learning_rate': 0.025, 'reg_alpha': 0.07355044299827697, 'reg_lambda': 0.17567101921268144}. Best is trial 22 with value: 0.9943635502730341.
# Precision: 0.9832041343669251
# Recall: 0.9921773142112125
# Aging Rate: 0.5045632333767927
# Precision: 0.9869791666666666
# Recall: 0.9882659713168188
# Aging Rate: 0.500651890482399
# Precision: 0.9856957087126138
# Recall: 0.9882659713168188
# Aging Rate: 0.5013037809647979
# [I 2022-03-03 17:29:19,150] Trial 69 finished with value: 0.9874238868121038 and parameters: {'eval_metric': 'logloss', 'n_estimators': 1000, 'subsample': 0.7, 'colsample_bytree': 0.5, 'min_child_weight': 3, 'max_depth': 12, 'learning_rate': 0.17500000000000002, 'reg_alpha': 0.038787330042157495, 'reg_lambda': 0.010077377611577489}. Best is trial 22 with value: 0.9943635502730341.
# Precision: 0.9921875
# Recall: 0.9934810951760105
# Aging Rate: 0.500651890482399
# Precision: 0.9895968790637191
# Recall: 0.9921773142112125
# Aging Rate: 0.5013037809647979
# Precision: 0.9870801033591732
# Recall: 0.9960886571056062
# Aging Rate: 0.5045632333767927
# [I 2022-03-03 17:29:27,199] Trial 70 finished with value: 0.9917610708069787 and parameters: {'eval_metric': 'logloss', 'n_estimators': 1000, 'subsample': 0.9, 'colsample_bytree': 0.5, 'min_child_weight': 1, 'max_depth': 15, 'learning_rate': 0.275, 'reg_alpha': 0.056199421942034894, 'reg_lambda': 5.696356943772107}. Best is trial 22 with value: 0.9943635502730341.
# Precision: 0.9857328145265889
# Recall: 0.9908735332464146
# Aging Rate: 0.5026075619295959
# Precision: 0.984516129032258
# Recall: 0.9947848761408083
# Aging Rate: 0.5052151238591917
# Precision: 0.9807692307692307
# Recall: 0.9973924380704041
# Aging Rate: 0.5084745762711864
# [I 2022-03-03 17:29:28,996] Trial 71 finished with value: 0.988977114355973 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.5, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.225, 'reg_alpha': 0.08139849760201881, 'reg_lambda': 0.011956332818840586}. Best is trial 22 with value: 0.9943635502730341.
# Precision: 0.9908972691807543
# Recall: 0.9934810951760105
# Aging Rate: 0.5013037809647979
# Precision: 0.9921465968586387
# Recall: 0.9882659713168188
# Aging Rate: 0.4980443285528031
# Precision: 0.9986842105263158
# Recall: 0.9895697522816167
# Aging Rate: 0.4954367666232073
# [I 2022-03-03 17:29:31,513] Trial 72 finished with value: 0.9921653574703883 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.5, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.225, 'reg_alpha': 0.12640738458228787, 'reg_lambda': 0.01649551952680893}. Best is trial 22 with value: 0.9943635502730341.
# Precision: 0.9844559585492227
# Recall: 0.9908735332464146
# Aging Rate: 0.5032594524119948
# Precision: 0.9947575360419397
# Recall: 0.9895697522816167
# Aging Rate: 0.4973924380704042
# Precision: 0.9909326424870466
# Recall: 0.9973924380704041
# Aging Rate: 0.5032594524119948
# [I 2022-03-03 17:29:34,063] Trial 73 finished with value: 0.9913210768387927 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.5, 'min_child_weight': 1, 'max_depth': 6, 'learning_rate': 0.225, 'reg_alpha': 0.06341698012598014, 'reg_lambda': 0.01034958561900279}. Best is trial 22 with value: 0.9943635502730341.
# Precision: 0.9753886010362695
# Recall: 0.9817470664928292
# Aging Rate: 0.5032594524119948
# Precision: 0.9778357235984355
# Recall: 0.9778357235984355
# Aging Rate: 0.5
# Precision: 0.9713541666666666
# Recall: 0.9726205997392438
# Aging Rate: 0.500651890482399
# ...
# Precision: 0.967741935483871
# Recall: 0.7894736842105263
# Aging Rate: 0.07416267942583732
# Precision: 0.9705882352941176
# Recall: 0.868421052631579
# Aging Rate: 0.08133971291866028
# Precision: 0.921875
# Recall: 0.7763157894736842
# Aging Rate: 0.07655502392344497
# [I 2022-03-03 18:32:47,411] Trial 75 finished with value: 0.8763630089717047 and parameters: {'eval_metric': 'logloss', 'n_estimators': 500, 'subsample': 0.9, 'colsample_bytree': 0.3, 'min_child_weight': 1, 'max_depth': 12, 'learning_rate': 0.225, 'reg_alpha': 0.025077919911199894, 'reg_lambda': 0.017926160482528996}. Best is trial 63 with value: 0.9117072016537776.
# Precision: 0.9545454545454546
# Recall: 0.8289473684210527
# Aging Rate: 0.07894736842105263
# Precision: 0.9852941176470589
# Recall: 0.881578947368421
# Aging Rate: 0.08133971291866028
# Precision: 0.9565217391304348
# Recall: 0.868421052631579
# Aging Rate: 0.08253588516746412
# [I 2022-03-03 18:32:48,035] Trial 76 finished with value: 0.9094081089345781 and parameters: {'eval_metric': 'logloss', 'n_estimators': 100, 'subsample': 0.7, 'colsample_bytree': 0.3, 'min_child_weight': 1, 'max_depth': 18, 'learning_rate': 0.225, 'reg_alpha': 0.010019187463513863, 'reg_lambda': 0.06028522970001789}. Best is trial 63 with value: 0.9117072016537776.
# Precision: 0.9104477611940298
# Recall: 0.8026315789473685
# Aging Rate: 0.08014354066985646
# Precision: 0.9565217391304348
# Recall: 0.868421052631579
# Aging Rate: 0.08253588516746412
# Precision: 0.8783783783783784
# Recall: 0.8552631578947368
# Aging Rate: 0.08851674641148326
# [I 2022-03-03 18:32:50,159] Trial 77 finished with value: 0.8767194491332423 and parameters: {'eval_metric': 'logloss', 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.9, 'min_child_weight': 3, 'max_depth': 18, 'learning_rate': 0.225, 'reg_alpha': 0.010042771974226107, 'reg_lambda': 0.06261446636768442}. Best is trial 63 with value: 0.9117072016537776.
# Precision: 0.8767123287671232
# Recall: 0.8421052631578947
# Aging Rate: 0.08732057416267942
# Precision: 0.9852941176470589
# Recall: 0.881578947368421
# Aging Rate: 0.08133971291866028
# Precision: 0.9827586206896551
# Recall: 0.75
# Aging Rate: 0.06937799043062201
# [I 2022-03-03 18:32:51,907] Trial 78 finished with value: 0.8801207422989452 and parameters: {'eval_metric': 'logloss', 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.3, 'min_child_weight': 1, 'max_depth': 18, 'learning_rate': 0.225, 'reg_alpha': 0.20213114789758502, 'reg_lambda': 0.039300495233283085}. Best is trial 63 with value: 0.9117072016537776.
# Precision: 0.
and parameters: {'eval_metric': 'logloss', 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.3, 'min_child_weight': 1, 'max_depth': 9, 'learning_rate': 0.17500000000000002, 'reg_alpha': 0.01871231277936357, 'reg_lambda': 0.07923554539304987}. Best is trial 63 with value: 0.9117072016537776.
# Precision: 0.9846153846153847
# Recall: 0.8421052631578947
# Aging Rate: 0.07775119617224881
# Precision: 0.9552238805970149
# Recall: 0.8421052631578947
# Aging Rate: 0.08014354066985646
# Precision: 0.8904109589041096
# Recall: 0.8552631578947368
# Aging Rate: 0.08732057416267942
# [I 2022-03-03 18:33:03,955] Trial 89 finished with value: 0.8917965116737072 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.9, 'min_child_weight': 1, 'max_depth': 15, 'learning_rate': 0.225, 'reg_alpha': 0.03912736714516329, 'reg_lambda': 0.030922302571996338}. Best is trial 63 with value: 0.9117072016537776.
# Precision: 0.9666666666666667
# Recall: 0.7631578947368421
# Aging Rate: 0.07177033492822966
# Precision: 0.9692307692307692
# Recall: 0.8289473684210527
# Aging Rate: 0.07775119617224881
# Precision: 0.9508196721311475
# Recall: 0.7631578947368421
# Aging Rate: 0.0729665071770335
# [I 2022-03-03 18:33:04,592] Trial 90 finished with value: 0.8644245087381125 and parameters: {'eval_metric': 'logloss', 'n_estimators': 100, 'subsample': 0.9, 'colsample_bytree': 0.3, 'min_child_weight': 1, 'max_depth': 18, 'learning_rate': 0.225, 'reg_alpha': 0.06813509263524943, 'reg_lambda': 0.015018824586570473}. Best is trial 63 with value: 0.9117072016537776.
# Precision: 0.9666666666666667
# Recall: 0.7631578947368421
# Aging Rate: 0.07177033492822966
# Precision: 0.9516129032258065
# Recall: 0.7763157894736842
# Aging Rate: 0.07416267942583732
# Precision: 0.9428571428571428
# Recall: 0.868421052631579
# Aging Rate: 0.08373205741626795
# [I 2022-03-03 18:33:06,105] Trial 91 finished with value: 0.8707077430932667 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.9, 'min_child_weight': 1, 'max_depth': 15, 'learning_rate': 0.225, 'reg_alpha': 0.0388675005042952, 'reg_lambda': 0.030537100161005554}. Best is trial 63 with value: 0.9117072016537776.
# Precision: 0.918918918918919
# Recall: 0.8947368421052632
# Aging Rate: 0.08851674641148326
# Precision: 0.9696969696969697
# Recall: 0.8421052631578947
# Aging Rate: 0.07894736842105263
# Precision: 0.953125
# Recall: 0.8026315789473685
# Aging Rate: 0.07655502392344497
# [I 2022-03-03 18:33:07,619] Trial 92 finished with value: 0.8931678962664878 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.9, 'min_child_weight': 1, 'max_depth': 15, 'learning_rate': 0.225, 'reg_alpha': 0.028288741039076075, 'reg_lambda': 0.03494662718863117}. Best is trial 63 with value: 0.9117072016537776.
# Precision: 0.921875
# Recall: 0.7763157894736842
# Aging Rate: 0.07655502392344497
# Precision: 0.96875
# Recall: 0.8157894736842105
# Aging Rate: 0.07655502392344497
# Precision: 0.9836065573770492
# Recall: 0.7894736842105263
# Aging Rate: 0.0729665071770335
# [I 2022-03-03 18:33:09,213] Trial 93 finished with value: 0.8681612791101841 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.9, 'min_child_weight': 1, 'max_depth': 15, 'learning_rate': 0.17500000000000002, 'reg_alpha': 0.026620193182757792, 'reg_lambda': 0.061959871304514864}. Best is trial 63 with value: 0.9117072016537776.
# Precision: 0.9230769230769231
# Recall: 0.7894736842105263
# Aging Rate: 0.07775119617224881
# Precision: 0.9848484848484849
# Recall: 0.8552631578947368
# Aging Rate: 0.07894736842105263
# Precision: 0.9178082191780822
# Recall: 0.881578947368421
# Aging Rate: 0.08732057416267942
# [I 2022-03-03 18:33:10,758] Trial 94 finished with value: 0.8886285488647051 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.9, 'min_child_weight': 1, 'max_depth': 15, 'learning_rate': 0.225, 'reg_alpha': 0.0117728220351649, 'reg_lambda': 0.09567628379159625}. Best is trial 63 with value: 0.9117072016537776.
# Precision: 0.9516129032258065
# Recall: 0.7763157894736842
# Aging Rate: 0.07416267942583732
# Precision: 0.9629629629629629
# Recall: 0.6842105263157895
# Aging Rate: 0.0645933014354067
# Precision: 0.9508196721311475
# Recall: 0.7631578947368421
# Aging Rate: 0.0729665071770335
# [I 2022-03-03 18:33:12,225] Trial 95 finished with value: 0.833929264078423 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.9, 'min_child_weight': 1, 'max_depth': 9, 'learning_rate': 0.225, 'reg_alpha': 0.016001110978726155, 'reg_lambda': 0.04852611374266071}. Best is trial 63 with value: 0.9117072016537776.
# Precision: 0.9464285714285714
# Recall: 0.6973684210526315
# Aging Rate: 0.06698564593301436
# Precision: 0.9259259259259259
# Recall: 0.6578947368421053
# Aging Rate: 0.0645933014354067
# Precision: 0.9636363636363636
# Recall: 0.6973684210526315
# Aging Rate: 0.06578947368421052
# [I 2022-03-03 18:33:15,286] Trial 96 finished with value: 0.7938071258681944 and parameters: {'eval_metric': 'logloss', 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.9, 'min_child_weight': 3, 'max_depth': 15, 'learning_rate': 0.025, 'reg_alpha': 0.04903993169284953, 'reg_lambda': 0.03597509881195328}. Best is trial 63 with value: 0.9117072016537776.
# Precision: 0.9701492537313433
# Recall: 0.8552631578947368
# Aging Rate: 0.08014354066985646
# Precision: 0.8552631578947368
# Recall: 0.8552631578947368
# Aging Rate: 0.09090909090909091
# Precision: 0.9516129032258065
# Recall: 0.7763157894736842
# Aging Rate: 0.07416267942583732
# [I 2022-03-03 18:33:17,534] Trial 97 finished with value: 0.8731421769179205 and parameters: {'eval_metric': 'logloss', 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.9, 'min_child_weight': 1, 'max_depth': 18, 'learning_rate': 0.225, 'reg_alpha': 0.02178736392278901, 'reg_lambda': 0.024432772808152748}. Best is trial 63 with value: 0.9117072016537776.
# Precision: 0.9411764705882353
# Recall: 0.8421052631578947
# Aging Rate: 0.08133971291866028
# Precision: 0.9857142857142858
# Recall: 0.9078947368421053
# Aging Rate: 0.08373205741626795
# Precision: 0.9661016949152542
# Recall: 0.75
# Aging Rate: 0.07057416267942583
# [I 2022-03-03 18:33:18,283] Trial 98 finished with value: 0.8928462709284627 and parameters: {'eval_metric': 'logloss', 'n_estimators': 100, 'subsample': 0.7, 'colsample_bytree': 0.7, 'min_child_weight': 1, 'max_depth': 18, 'learning_rate': 0.17500000000000002, 'reg_alpha': 0.029503921061719424, 'reg_lambda': 0.02007804064345196}. Best is trial 63 with value: 0.9117072016537776.
# Precision: 0.9354838709677419
# Recall: 0.7631578947368421
# Aging Rate: 0.07416267942583732
# Precision: 0.9420289855072463
# Recall: 0.8552631578947368
# Aging Rate: 0.08253588516746412
# Precision: 0.8717948717948718
# Recall: 0.8947368421052632
# Aging Rate: 0.09330143540669857
# [I 2022-03-03 18:33:19,689] Trial 99 finished with value: 0.8734161057999139 and parameters: {'eval_metric': 'logloss', 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.3, 'min_child_weight': 1, 'max_depth': 3, 'learning_rate': 0.225, 'reg_alpha': 0.018380822942380044, 'reg_lambda': 0.057732844844997334}. Best is trial 63 with value: 0.9117072016537776.
# Sampler is TPESampler

# %%
##### optimization history plot #####
optuna_history(best_paramC, all_scoreC, num_row = 3, num_col = 3, model = 'XGBoost Classifier')
            
##### best hyperparameter table #####
param_table = pd.DataFrame(best_paramC).T
param_table
# Out:
#      eval_metric n_estimators subsample colsample_bytree min_child_weight  \
# set1     logloss         1000       0.9              0.5                1
# set2     logloss          300       0.9              0.3                1
# set3     logloss         1000       0.7              0.5                1
# set4     logloss         1000       0.9              0.7                1
# set5     logloss          100       0.9              0.9                1
# set6     logloss         1000       0.7              0.9                1
# set7     logloss         1000       0.9              0.5                1
# set8     logloss          300       0.9              0.5                1
# set9     logloss          100       0.7              0.3                1
#
#      max_depth learning_rate reg_alpha reg_lambda
# set1        15         0.075  0.011732   0.053356
# set2        12         0.075  0.407365   0.034093
# set3        15         0.175  0.021583   0.598046
# set4        18         0.075  0.550979   2.136572
# set5         9         0.275  0.192357   1.191226
# set6         9         0.025  0.444575   5.254399
# set7        12         0.125     0.029   0.422115
# set8        12         0.075  0.269343   0.033293
# set9         9         0.225  0.022795   0.012603

# %% [markdown]
# ##

# %% [markdown]
# ### Classifier

# %%
table_setC = runall_XGBoostC(run_train_x, run_test_x, run_train_y, run_test_y, best_paramC)
line_chart(table_setC, title = 'XGBoost Classfifer')
# Out:
# 0it [00:00, ?it/s]
#  Dataset1:
# Precision: 0.0016207455429497568
# Recall: 0.37254901960784315
# Aging Rate: 0.24097103743139633
#
#  Dataset2:
# Precision: 0.001144950767117014
# Recall: 0.29411764705882354
# Aging Rate: 0.26929638841497255
#
#  Dataset3:
# Precision: 0.001392673327278232
# Recall: 0.45098039215686275
# Aging Rate: 0.3394725482538182
#
#  Dataset4:
# Precision: 0.0015252039960344697
# Recall: 0.39215686274509803
# Aging Rate: 0.2695430533001706
#
#  Dataset5:
# Precision: 0.0017085128509879662
# Recall: 0.45098039215686275
# Aging Rate: 0.27671689037801395
#
#  Dataset6:
# Precision: 0.0011764046832110247
# Recall: 0.4117647058823529
# Aging Rate: 0.3669345721392012
#
#  Dataset7:
# Precision: 0.001447178002894356
# Recall: 0.29411764705882354
# Aging Rate: 0.21305679458981686
#
#  Dataset8:
# Precision: 0.0012807881773399014
# Recall: 0.2549019607843137
# Aging Rate: 0.20863738206335178
#
#  Dataset9:
# Precision: 0.0013403542364767832
# Recall: 0.27450980392156865
# Aging Rate: 0.21470122715780385

# %%
table_setC
# Out:
#           Balance Ratio  Train_OK  Train_NG    TP       FP    FN       TN  \
# dataset1       1.000000    3067.0    3067.0  19.0  11704.0  32.0  36894.0
# dataset2       1.000000    2984.0    2984.0  15.0  13086.0  36.0  35512.0
# dataset3       1.000000    3033.0    3033.0  23.0  16492.0  28.0  32106.0
# dataset4       1.000000    3038.0    3038.0  20.0  13093.0  31.0  35505.0
# dataset5       1.006623    3040.0    3020.0  23.0  13439.0  28.0  35159.0
# dataset6       1.012658    3040.0    3002.0  21.0  17830.0  30.0  30768.0
# dataset7       1.099458    3040.0    2765.0  15.0  10350.0  36.0  38248.0
# dataset8       1.000000    3040.0    3040.0  13.0  10137.0  38.0  38461.0
# dataset9      10.000000    3040.0     304.0  14.0  10431.0  37.0  38167.0
#
#           Precision    Recall  Aging Rate  Efficiency  F1 Score     Score
# dataset1   0.001621  0.372549    0.240971    1.546032  0.001614  0.348161
# dataset2   0.001145  0.294118    0.269296    1.092171  0.001141  0.217118
# dataset3   0.001393  0.450980    0.339473    1.328474  0.001388  0.381175
# dataset4   0.001525  0.392157    0.269543    1.454895  0.001519  0.352190
# dataset5   0.001709  0.450980    0.276717    1.629754  0.001702  0.436049
# dataset6   0.001176  0.411765    0.366935    1.122175  0.001173  0.309829
# dataset7   0.001447  0.294118    0.213057    1.380466  0.001440  0.255087
# dataset8   0.001281  0.254902    0.208637    1.221746  0.001274  0.203487
# dataset9   0.001340  0.274510    0.214701    1.278567  0.001334  0.226072

# %% [markdown]
# ### Regression (optional)

# %%
best_paramR, all_scoreR = all_optuna(num_set = 10, 
                                     all_data = run_train, 
                                     mode = 'R', 
                                     TPE_multi = True, 
                                     n_iter = 200,
                                     filename = 'runhist_array_m2m5_4selection_XGBoost', 
                                     creator = XGBoost_creator
                                    )

# %%
pr_dict, table_setR = runall_XGBoostR(10, run_train_x, run_test_x, run_train_y, run_test_y, best_paramR, 
                                       thres_target = 'Recall', threshold = 0.7)
line_chart(table_setR, title = 'XGBoost Regressor')

# %%
multiple_curve(4, 3, pr_dict, table_setR, target = 'Aging Rate')
multiple_curve(4, 3, pr_dict, table_setR, target = 'Precision')
table_setR

# %% [markdown]
# ### Export

# %%
savedate = '20220329'
TPE_multi = False

table_setC['sampler'] = 'multivariate-TPE' if TPE_multi else 'univariate-TPE'
table_setC['model'] = 'XGBoost_125'
with pd.ExcelWriter(f'{savedate}_Classifier.xlsx', mode = 'a') as writer:
    table_setC.to_excel(writer, sheet_name = 'XGBoost_125')
