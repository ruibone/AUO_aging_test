# %%
import os
import numpy as np
import pandas as pd
import pickle
from tqdm.auto import tqdm
import matplotlib.pyplot as plt

import xgboost as xgb
import optuna
from sklearn.model_selection import train_test_split

from library.Data_Preprocessing import Balance_Ratio
from library.Imbalance_Sampling import label_divide
from library.Aging_Score_Contour import score1
from library.AdaBoost import train_set, multiple_set, multiple_month, line_chart, cf_matrix, AUC, PR_curve, \
     multiple_curve, PR_matrix, best_threshold, all_optuna, optuna_history 

os.chdir('C:/Users/user/Desktop/Darui_R08621110') 
os.getcwd()
# Out:
# 'C:\\Users\\user\\Desktop\\Darui_R08621110'

# %% [markdown]
# ##

# %% [markdown]
# ### xgboost

# %%
# classifier
def XGBoostC(train_x, test_x, train_y, test_y, config):
    
    clf = xgb.XGBClassifier(**config, n_jobs = -1, use_label_encoder = False)
    clf.fit(train_x, train_y)
    predict_y = clf.predict_proba(test_x)[:, 1]
    define_predict = (predict_y > 0.5).astype(int)
    result = pd.DataFrame({'truth': test_y, 'predict': define_predict})
    
    return result
    

# regressor
def XGBoostR(train_x, test_x, train_y, test_y, config):
    
    reg = xgb.XGBRegressor(**config, n_jobs = -1)
    reg.fit(train_x, train_y)
    predict_y = reg.predict(test_x)
    result = pd.DataFrame({'truth': test_y, 'predict': predict_y})

    return result


# classifeir for all resampling datasets
def runall_XGBoostC(num_set, trainset_x, test_x, trainset_y, test_y, config):
    
    table_set = pd.DataFrame()
    bad_set = pd.DataFrame()
    judge = list(config.keys())[0]

    for i in range(num_set):
        print('\n', f'Dataset {i}:')

        if isinstance(config[judge], dict) :
            best_config = config[f'set{i}']
        else :
            best_config = config
            
        result = XGBoostC(trainset_x[f'set{i}'], test_x, trainset_y[f'set{i}'], test_y, best_config)    
        table = cf_matrix(result, trainset_y[f'set{i}'])
        table_set = pd.concat([table_set, table]).rename(index = {0: f'dataset {i}'})

    return table_set
    

# regressor for all resampling datasets
def runall_XGBoostR(num_set, trainset_x, test_x, trainset_y, test_y, config, thres_target = 'Recall', threshold = 0.8):
    
    table_set = pd.DataFrame()
    bad_set = pd.DataFrame()
    pr_dict = {}
    judge = list(config.keys())[0]

    for i in range(num_set):
        print('\n', f'Dataset {i}:')

        if isinstance(config[judge], dict) :
            best_config = config[f'set{i}']
        else :
            best_config = config

        predict = XGBoostR(trainset_x[f'set{i}'], test_x, trainset_y[f'set{i}'], test_y, best_config)     
        pr_matrix = PR_matrix(predict, trainset_y[f'set{i}'])
        pr_dict[f'set{i}'] = pr_matrix
        
        best_data, best_thres = best_threshold(pr_matrix, target = thres_target, threshold = threshold)
        table_set = pd.concat([table_set, best_data]).rename(index = {best_data.index.values[0]: f'dataset {i}'})
        
    return pr_dict, table_set

# %% [markdown]
# ### optuna

# %%
def XGBoost_creator(train_data, mode, num_valid = 3, label = 'GB') :
    
    def objective(trial) :

        param = {
            'eval_metric': trial.suggest_categorical('eval_metric', ['logloss']),
            'n_estimators': trial.suggest_categorical('n_estimators', [100, 300, 500, 1000]),
            'subsample': trial.suggest_float('subsample', 0.3, 0.9, step = 0.2),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.3, 0.9, step = 0.2),
            'min_child_weight': trial.suggest_int('min_child_weight', 1, 15, step = 2),
            'max_depth': trial.suggest_int('max_depth', 3, 15, step = 3),
            'learning_rate': trial.suggest_float('learning_rate', 0.025, 0.325, step = 0.05),
            'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-2, 10), # alpha
            'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-2, 10) # lambda
        }

        result_list = []
        for i in range(num_valid):

            train_good = train_data[train_data.GB == 0]
            train_bad = train_data[train_data.GB == 1]
            train_good_x, train_good_y = label_divide(train_good, None, label, train_only = True)
            train_bad_x, train_bad_y = label_divide(train_bad, None, label, train_only = True)
            train_g_x, valid_g_x, train_g_y, valid_g_y = train_test_split(train_good_x, train_good_y, test_size = 0.25)
            train_b_x, valid_b_x, train_b_y, valid_b_y = train_test_split(train_bad_x, train_bad_y, test_size = 0.25)
            train_x = pd.concat([train_g_x, train_b_x], axis = 0)
            train_y = pd.concat([train_g_y, train_b_y], axis = 0)
            valid_x = pd.concat([valid_g_x, valid_b_x], axis = 0)
            valid_y = pd.concat([valid_g_y, valid_b_y], axis = 0)

            if mode == 'C':
                result = XGBoostC(train_x, valid_x, train_y, valid_y, param)
                table = cf_matrix(result, valid_y)
                recall = table['Recall']
                precision = table['Precision']
                beta = 1
                if recall.values > 0:
                    fscore = ((1+beta**2)*recall*precision) / (recall+(beta**2)*precision)
                else:
                    fscore = 0
                result_list.append(fscore)

            elif mode == 'R':
                result = XGBoostR(train_x, valid_x, train_y, valid_y, param)
                pr_matrix = PR_matrix(result, valid_y)
                auc = AUC(pr_matrix['Recall'], pr_matrix['Aging Rate'])
                result_list.append((-1)*auc)

        return np.mean(result_list)
    
    return objective

# %% [markdown]
# ##

# %% [markdown]
# ### loading training & testing data

# %%
### training data ### 
training_month = range(2, 5)

data_dict, trainset_x, trainset_y = multiple_month(training_month, num_set = 10, filename = 'dataset')

print('\nCombined training data:\n')
run_train = multiple_set(num_set = 10)
run_train_x, run_train_y = train_set(run_train, num_set = 10)

### testing data ###
run_test = pd.read_csv('test_runhist.csv').iloc[:, 2:]
run_test_x, run_test_y = label_divide(run_test, None, 'GB', train_only = True)
print('\n', 'Dimension of testing data:', run_test.shape)
# Out:
# Month 2:
#
# Dimension of dataset 0 : (39009, 88)  balance ratio: 564.35
# Dimension of dataset 1 : (1638, 88)  balance ratio: 1.33
# Dimension of dataset 2 : (1598, 88)  balance ratio: 1.33
# Dimension of dataset 3 : (1605, 88)  balance ratio: 1.33
# Dimension of dataset 4 : (1607, 88)  balance ratio: 1.33
# Dimension of dataset 5 : (1611, 88)  balance ratio: 1.33
# Dimension of dataset 6 : (1597, 88)  balance ratio: 1.36
# Dimension of dataset 7 : (1563, 88)  balance ratio: 1.43
# Dimension of dataset 8 : (1610, 88)  balance ratio: 1.33
# Dimension of dataset 9 : (759, 88)  balance ratio: 10.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
# Month 3:
#
# Dimension of dataset 0 : (60396, 97)  balance ratio: 533.48
# Dimension of dataset 1 : (2688, 97)  balance ratio: 1.33
# Dimension of dataset 2 : (2599, 97)  balance ratio: 1.33
# Dimension of dataset 3 : (2632, 97)  balance ratio: 1.33
# Dimension of dataset 4 : (2634, 97)  balance ratio: 1.33
# Dimension of dataset 5 : (2638, 97)  balance ratio: 1.33
# Dimension of dataset 6 : (2619, 97)  balance ratio: 1.35
# Dimension of dataset 7 : (2559, 97)  balance ratio: 1.43
# Dimension of dataset 8 : (2635, 97)  balance ratio: 1.33
# Dimension of dataset 9 : (1243, 97)  balance ratio: 10.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
# Month 4:
#
# Dimension of dataset 0 : (57743, 100)  balance ratio: 472.3
# Dimension of dataset 1 : (2830, 100)  balance ratio: 1.33
# Dimension of dataset 2 : (2814, 100)  balance ratio: 1.33
# Dimension of dataset 3 : (2839, 100)  balance ratio: 1.33
# Dimension of dataset 4 : (2846, 100)  balance ratio: 1.33
# Dimension of dataset 5 : (2848, 100)  balance ratio: 1.33
# Dimension of dataset 6 : (2821, 100)  balance ratio: 1.36
# Dimension of dataset 7 : (2763, 100)  balance ratio: 1.43
# Dimension of dataset 8 : (2845, 100)  balance ratio: 1.33
# Dimension of dataset 9 : (1342, 100)  balance ratio: 10.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
# Combined training data:
#
# Dimension of dataset 0 : (157148, 128)  balance ratio: 515.93
# Dimension of dataset 1 : (7156, 128)  balance ratio: 1.33
# Dimension of dataset 2 : (7011, 128)  balance ratio: 1.33
# Dimension of dataset 3 : (7076, 128)  balance ratio: 1.33
# Dimension of dataset 4 : (7087, 128)  balance ratio: 1.33
# Dimension of dataset 5 : (7097, 128)  balance ratio: 1.33
# Dimension of dataset 6 : (7037, 128)  balance ratio: 1.36
# Dimension of dataset 7 : (6885, 128)  balance ratio: 1.43
# Dimension of dataset 8 : (7090, 128)  balance ratio: 1.33
# Dimension of dataset 9 : (3344, 128)  balance ratio: 10.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
#  Dimension of testing data: (48649, 128)

# %% [markdown]
# ### search for best hyperparameter

# %%
best_paramC, all_scoreC = all_optuna(num_set = 10, 
                                     all_data = run_train, 
                                     mode = 'C', 
                                     TPE_multi = False, 
                                     n_iter = 100, 
                                     filename = 'runhist_array_m2m4_m5_3criteria_XGBoost_br1.33', 
                                     creator = XGBoost_creator
                                    )
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# [I 2022-02-26 20:55:33,202] A new study created in memory with name: no-name-e7367039-8e0f-4cd3-a6c5-9b8f48d8ac8f
# Dataset0 :
# C:\Users\user\anaconda3\envs\aging\lib\site-packages\optuna\progress_bar.py:47: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
#   0%|          | 0/100 [00:00<?, ?it/s]
# Precision: 0.9459459459459459
# Recall: 0.4605263157894737
# Aging Rate: 0.0009417873596864102
# Precision: 0.8222222222222222
# Recall: 0.4868421052631579
# Aging Rate: 0.0011454170590780666
# Precision: 0.8260869565217391
# Recall: 0.5
# Aging Rate: 0.0011708707715020236
# [I 2022-02-26 20:56:24,553] Trial 0 finished with value: 0.6179966980515625 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.7, 'min_child_weight': 3, 'max_depth': 9, 'learning_rate': 0.275, 'reg_alpha': 0.016239761621595943, 'reg_lambda': 0.03731527987132997}. Best is trial 0 with value: 0.6179966980515625.
# C:\Users\user\Desktop\Darui_R08621110\Master_Thesis\AUO aging test\Full_Version_Code\library\Aging_Score_Contour.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   eff = r/ag
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# C:\Users\user\Desktop\Darui_R08621110\Master_Thesis\AUO aging test\Full_Version_Code\library\Aging_Score_Contour.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   eff = r/ag
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# C:\Users\user\Desktop\Darui_R08621110\Master_Thesis\AUO aging test\Full_Version_Code\library\Aging_Score_Contour.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   eff = r/ag
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-26 20:56:55,171] Trial 1 finished with value: 0.0 and parameters: {'eval_metric': 'logloss', 'n_estimators': 500, 'subsample': 0.3, 'colsample_bytree': 0.3, 'min_child_weight': 15, 'max_depth': 15, 'learning_rate': 0.025, 'reg_alpha': 4.292413474546139, 'reg_lambda': 0.45574771005795217}. Best is trial 0 with value: 0.6179966980515625.
# C:\Users\user\Desktop\Darui_R08621110\Master_Thesis\AUO aging test\Full_Version_Code\library\Aging_Score_Contour.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   eff = r/ag
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# C:\Users\user\Desktop\Darui_R08621110\Master_Thesis\AUO aging test\Full_Version_Code\library\Aging_Score_Contour.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   eff = r/ag
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# C:\Users\user\Desktop\Darui_R08621110\Master_Thesis\AUO aging test\Full_Version_Code\library\Aging_Score_Contour.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   eff = r/ag
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-26 20:57:26,904] Trial 2 finished with value: 0.0 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.5, 'colsample_bytree': 0.5, 'min_child_weight': 1, 'max_depth': 9, 'learning_rate': 0.025, 'reg_alpha': 0.8502099620751088, 'reg_lambda': 7.734221320021046}. Best is trial 0 with value: 0.6179966980515625.
# Precision: 0.65625
# Recall: 0.27631578947368424
# Aging Rate: 0.0008145187975666251
# Precision: 0.6052631578947368
# Recall: 0.3026315789473684
# Aging Rate: 0.0009672410721103674
# Precision: 0.85
# Recall: 0.2236842105263158
# Aging Rate: 0.0005090742484791407
# [I 2022-02-26 20:58:06,911] Trial 3 finished with value: 0.38218810916179335 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.9, 'colsample_bytree': 0.3, 'min_child_weight': 5, 'max_depth': 12, 'learning_rate': 0.275, 'reg_alpha': 0.2735064180080645, 'reg_lambda': 0.021684506150018663}. Best is trial 0 with value: 0.6179966980515625.
# C:\Users\user\Desktop\Darui_R08621110\Master_Thesis\AUO aging test\Full_Version_Code\library\Aging_Score_Contour.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   eff = r/ag
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# C:\Users\user\Desktop\Darui_R08621110\Master_Thesis\AUO aging test\Full_Version_Code\library\Aging_Score_Contour.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   eff = r/ag
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# C:\Users\user\Desktop\Darui_R08621110\Master_Thesis\AUO aging test\Full_Version_Code\library\Aging_Score_Contour.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   eff = r/ag
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-26 20:58:36,764] Trial 4 finished with value: 0.0 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.9, 'colsample_bytree': 0.3, 'min_child_weight': 15, 'max_depth': 6, 'learning_rate': 0.275, 'reg_alpha': 0.08129030025188946, 'reg_lambda': 0.1374444099739582}. Best is trial 0 with value: 0.6179966980515625.
# Precision: 1.0
# Recall: 0.02631578947368421
# Aging Rate: 5.090742484791407e-05
# Precision: 0.6666666666666666
# Recall: 0.02631578947368421
# Aging Rate: 7.63611372718711e-05
# Precision: 0.5714285714285714
# Recall: 0.05263157894736842
# Aging Rate: 0.00017817598696769923
# [I 2022-02-26 20:58:55,375] Trial 5 finished with value: 0.06610016828104369 and parameters: {'eval_metric': 'logloss', 'n_estimators': 100, 'subsample': 0.9, 'colsample_bytree': 0.7, 'min_child_weight': 7, 'max_depth': 9, 'learning_rate': 0.225, 'reg_alpha': 0.014156383817873682, 'reg_lambda': 1.1037441867648348}. Best is trial 0 with value: 0.6179966980515625.
# C:\Users\user\Desktop\Darui_R08621110\Master_Thesis\AUO aging test\Full_Version_Code\library\Aging_Score_Contour.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   eff = r/ag
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# C:\Users\user\Desktop\Darui_R08621110\Master_Thesis\AUO aging test\Full_Version_Code\library\Aging_Score_Contour.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   eff = r/ag
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# C:\Users\user\Desktop\Darui_R08621110\Master_Thesis\AUO aging test\Full_Version_Code\library\Aging_Score_Contour.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   eff = r/ag
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-26 20:59:19,826] Trial 6 finished with value: 0.0 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.5, 'colsample_bytree': 0.5, 'min_child_weight': 9, 'max_depth': 6, 'learning_rate': 0.025, 'reg_alpha': 3.1251121201271492, 'reg_lambda': 0.01369687481764283}. Best is trial 0 with value: 0.6179966980515625.
# C:\Users\user\Desktop\Darui_R08621110\Master_Thesis\AUO aging test\Full_Version_Code\library\Aging_Score_Contour.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   eff = r/ag
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# C:\Users\user\Desktop\Darui_R08621110\Master_Thesis\AUO aging test\Full_Version_Code\library\Aging_Score_Contour.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   eff = r/ag
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# C:\Users\user\Desktop\Darui_R08621110\Master_Thesis\AUO aging test\Full_Version_Code\library\Aging_Score_Contour.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   eff = r/ag
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-02-26 20:59:57,936] Trial 7 finished with value: 0.0 and parameters: {'eval_metric': 'logloss', 'n_estimators': 500, 'subsample': 0.3, 'colsample_bytree': 0.3, 'min_child_weight': 9, 'max_depth': 12, 'learning_rate': 0.275, 'reg_alpha': 0.2761887367468201, 'reg_lambda': 4.959298452824571}. Best is trial 0 with value: 0.6179966980515625.
# Precision: 0.625
# Recall: 0.13157894736842105
# Aging Rate: 0.00040725939878331256
# Precision: 0.6
# Recall: 0.07894736842105263
# Aging Rate: 0.00025453712423957034
# Precision: 0.8333333333333334
# Recall: 0.13157894736842105
# Aging Rate: 0.0003054445490874844
# [I 2022-02-26 21:00:45,108] Trial 8 finished with value: 0.19473297178049453 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.5, 'min_child_weight': 3, 'max_depth': 12, 'learning_rate': 0.225, 'reg_alpha':
and parameters: {'eval_metric': 'logloss', 'n_estimators': 500, 'subsample': 0.9, 'colsample_bytree': 0.5, 'min_child_weight': 1, 'max_depth': 15, 'learning_rate': 0.325, 'reg_alpha': 0.015722758529642288, 'reg_lambda': 0.012693267884307668}. Best is trial 63 with value: 0.8605847953216376.
# Precision: 0.6805555555555556
# Recall: 0.6447368421052632
# Aging Rate: 0.0018326672945249065
# Precision: 0.8103448275862069
# Recall: 0.618421052631579
# Aging Rate: 0.001476315320589508
# Precision: 0.7761194029850746
# Recall: 0.6842105263157895
# Aging Rate: 0.0017053987324051213
# [I 2022-02-26 23:25:48,168] Trial 67 finished with value: 0.6969758089161076 and parameters: {'eval_metric': 'logloss', 'n_estimators': 500, 'subsample': 0.9, 'colsample_bytree': 0.5, 'min_child_weight': 3, 'max_depth': 15, 'learning_rate': 0.325, 'reg_alpha': 0.013051164268698016, 'reg_lambda': 0.017370496287746548}. Best is trial 63 with value: 0.8605847953216376.
# Precision: 0.819672131147541
# Recall: 0.6578947368421053
# Aging Rate: 0.001552676457861379
# Precision: 0.7794117647058824
# Recall: 0.6973684210526315
# Aging Rate: 0.0017308524448290783
# Precision: 0.9245283018867925
# Recall: 0.6447368421052632
# Aging Rate: 0.0013490467584697228
# [I 2022-02-26 23:27:14,170] Trial 68 finished with value: 0.7419093469636672 and parameters: {'eval_metric': 'logloss', 'n_estimators': 500, 'subsample': 0.9, 'colsample_bytree': 0.5, 'min_child_weight': 3, 'max_depth': 15, 'learning_rate': 0.325, 'reg_alpha': 0.018617182439997347, 'reg_lambda': 0.025425052119733327}. Best is trial 63 with value: 0.8605847953216376.
# Precision: 0.8636363636363636
# Recall: 0.75
# Aging Rate: 0.0016799450199811643
# Precision: 0.7714285714285715
# Recall: 0.7105263157894737
# Aging Rate: 0.0017817598696769925
# Precision: 0.7887323943661971
# Recall: 0.7368421052631579
# Aging Rate: 0.0018072135821009495
# ...
# Precision: 0.9436619718309859
# Recall: 0.881578947368421
# Aging Rate: 0.08492822966507177
# Precision: 0.9206349206349206
# Recall: 0.7631578947368421
# Aging Rate: 0.07535885167464115
# Precision: 0.927536231884058
# Recall: 0.8421052631578947
# Aging Rate: 0.08253588516746412
# [I 2022-02-27 01:57:21,819] Trial 75 finished with value: 0.8762852068802381 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.7, 'min_child_weight': 1, 'max_depth': 9, 'learning_rate': 0.225, 'reg_alpha': 0.015011875395869172, 'reg_lambda': 0.30062195743598397}. Best is trial 72 with value: 0.9008460868483265.
# Precision: 0.8823529411764706
# Recall: 0.7894736842105263
# Aging Rate: 0.08133971291866028
# Precision: 0.8888888888888888
# Recall: 0.7368421052631579
# Aging Rate: 0.07535885167464115
# Precision: 0.9285714285714286
# Recall: 0.8552631578947368
# Aging Rate: 0.08373205741626795
# [I 2022-02-27 01:57:23,333] Trial 76 finished with value: 0.8431665626402988 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.7, 'min_child_weight': 3, 'max_depth': 6, 'learning_rate': 0.225, 'reg_alpha': 0.012490038101972675, 'reg_lambda': 0.8738206335783281}. Best is trial 72 with value: 0.9008460868483265.
# Precision: 0.9436619718309859
# Recall: 0.881578947368421
# Aging Rate: 0.08492822966507177
# Precision: 0.9649122807017544
# Recall: 0.7236842105263158
# Aging Rate: 0.06818181818181818
# Precision: 0.9142857142857143
# Recall: 0.8421052631578947
# Aging Rate: 0.08373205741626795
# [I 2022-02-27 01:57:25,070] Trial 77 finished with value: 0.8717815412634652 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.7, 'min_child_weight': 1, 'max_depth': 9, 'learning_rate': 0.17500000000000002, 'reg_alpha': 0.02336933519557612, 'reg_lambda': 0.34710007511036245}. Best is trial 72 with value: 0.9008460868483265.
# Precision: 0.9393939393939394
# Recall: 0.8157894736842105
# Aging Rate: 0.07894736842105263
# Precision: 0.9508196721311475
# Recall: 0.7631578947368421
# Aging Rate: 0.0729665071770335
# Precision: 0.9565217391304348
# Recall: 0.868421052631579
# Aging Rate: 0.08253588516746412
# [I 2022-02-27 01:57:26,707] Trial 78 finished with value: 0.8767665308910262 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.7, 'min_child_weight': 1, 'max_depth': 9, 'learning_rate': 0.225, 'reg_alpha': 0.016780443209132478, 'reg_lambda': 0.14971957241853462}. Best is trial 72 with value: 0.9008460868483265.
# Precision: 0.9137931034482759
# Recall: 0.6973684210526315
# Aging Rate: 0.06937799043062201
# Precision: 0.9137931034482759
# Recall: 0.6973684210526315
# Aging Rate: 0.06937799043062201
# Precision: 0.9242424242424242
# Recall: 0.8026315789473685
# Aging Rate: 0.07894736842105263
# [I 2022-02-27 01:57:28,309] Trial 79 finished with value: 0.8137481606054235 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.7, 'min_child_weight': 3, 'max_depth': 9, 'learning_rate': 0.275, 'reg_alpha': 0.0352611225172283, 'reg_lambda': 0.40927570867690605}. Best is trial 72 with value: 0.9008460868483265.
# Precision: 0.9402985074626866
# Recall: 0.8289473684210527
# Aging Rate: 0.08014354066985646
# Precision: 0.9846153846153847
# Recall: 0.8421052631578947
# Aging Rate: 0.07775119617224881
# Precision: 0.9428571428571428
# Recall: 0.868421052631579
# Aging Rate: 0.08373205741626795
# [I 2022-02-27 01:57:30,048] Trial 80 finished with value: 0.8976766295332311 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.7, 'min_child_weight': 1, 'max_depth': 9, 'learning_rate': 0.225, 'reg_alpha': 0.01004816508220722, 'reg_lambda': 0.6321959110751132}. Best is trial 72 with value: 0.9008460868483265.
# Precision: 0.9701492537313433
# Recall: 0.8552631578947368
# Aging Rate: 0.08014354066985646
# Precision: 0.9473684210526315
# Recall: 0.7105263157894737
# Aging Rate: 0.06818181818181818
# Precision: 0.9516129032258065
# Recall: 0.7763157894736842
# Aging Rate: 0.07416267942583732
# [I 2022-02-27 01:57:31,578] Trial 81 finished with value: 0.8587311493489983 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.7, 'min_child_weight': 1, 'max_depth': 9, 'learning_rate': 0.225, 'reg_alpha': 0.010029546258382288, 'reg_lambda': 0.7093261435638355}. Best is trial 72 with value: 0.9008460868483265.
# Precision: 0.9014084507042254
# Recall: 0.8421052631578947
# Aging Rate: 0.08492822966507177
# Precision: 0.9523809523809523
# Recall: 0.7894736842105263
# Aging Rate: 0.07535885167464115
# Precision: 0.8955223880597015
# Recall: 0.7894736842105263
# Aging Rate: 0.08014354066985646
# [I 2022-02-27 01:57:33,373] Trial 82 finished with value: 0.8577394969995176 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.7, 'min_child_weight': 1, 'max_depth': 9, 'learning_rate': 0.225, 'reg_alpha': 0.01412983904218441, 'reg_lambda': 0.2834781141656802}. Best is trial 72 with value: 0.9008460868483265.
# Precision: 0.9473684210526315
# Recall: 0.7105263157894737
# Aging Rate: 0.06818181818181818
# Precision: 0.9253731343283582
# Recall: 0.8157894736842105
# Aging Rate: 0.08014354066985646
# Precision: 0.9558823529411765
# Recall: 0.8552631578947368
# Aging Rate: 0.08133971291866028
# [I 2022-02-27 01:57:34,949] Trial 83 finished with value: 0.8606469066995381 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.7, 'min_child_weight': 1, 'max_depth': 9, 'learning_rate': 0.17500000000000002, 'reg_alpha': 0.020133342268459406, 'reg_lambda': 0.6141452742768055}. Best is trial 72 with value: 0.9008460868483265.
# Precision: 0.9846153846153847
# Recall: 0.8421052631578947
# Aging Rate: 0.07775119617224881
# Precision: 0.953125
# Recall: 0.8026315789473685
# Aging Rate: 0.07655502392344497
# Precision: 0.9516129032258065
# Recall: 0.7763157894736842
# Aging Rate: 0.07416267942583732
# [I 2022-02-27 01:57:36,686] Trial 84 finished with value: 0.8781008178788013 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.7, 'min_child_weight': 1, 'max_depth': 9, 'learning_rate': 0.225, 'reg_alpha': 0.017187681198835895, 'reg_lambda': 0.4766846263139238}. Best is trial 72 with value: 0.9008460868483265.
# Precision: 0.9807692307692307
# Recall: 0.6710526315789473
# Aging Rate: 0.06220095693779904
# Precision: 0.9230769230769231
# Recall: 0.7894736842105263
# Aging Rate: 0.07775119617224881
# Precision: 0.9411764705882353
# Recall: 0.8421052631578947
# Aging Rate: 0.08133971291866028
# [I 2022-02-27 01:57:38,028] Trial 85 finished with value: 0.8456092395587076 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.7, 'min_child_weight': 3, 'max_depth': 6, 'learning_rate': 0.275, 'reg_alpha': 0.027328285340353278, 'reg_lambda': 0.840945940502837}. Best is trial 72 with value: 0.9008460868483265.
# Precision: 0.9193548387096774
# Recall: 0.75
# Aging Rate: 0.07416267942583732
# Precision: 0.984375
# Recall: 0.8289473684210527
# Aging Rate: 0.07655502392344497
# Precision: 0.9836065573770492
# Recall: 0.7894736842105263
# Aging Rate: 0.0729665071770335
# [I 2022-02-27 01:57:39,848] Trial 86 finished with value: 0.8673331217602879 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.7, 'min_child_weight': 1, 'max_depth': 9, 'learning_rate': 0.17500000000000002, 'reg_alpha': 0.010246301901937883, 'reg_lambda': 1.6082513701662027}. Best is trial 72 with value: 0.9008460868483265.
# Precision: 0.9014084507042254
# Recall: 0.8421052631578947
# Aging Rate: 0.08492822966507177
# Precision: 0.9705882352941176
# Recall: 0.868421052631579
# Aging Rate: 0.08133971291866028
# Precision: 0.9428571428571428
# Recall: 0.868421052631579
# Aging Rate: 0.08373205741626795
# [I 2022-02-27 01:57:41,439] Trial 87 finished with value: 0.8971748516758301 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.7, 'min_child_weight': 1, 'max_depth': 9, 'learning_rate': 0.225, 'reg_alpha': 0.012238310680722288, 'reg_lambda': 0.3281887540219172}. Best is trial 72 with value: 0.9008460868483265.
# Precision: 0.890625
# Recall: 0.75
# Aging Rate: 0.07655502392344497
# Precision: 0.9428571428571428
# Recall: 0.868421052631579
# Aging Rate: 0.08373205741626795
# Precision: 0.967741935483871
# Recall: 0.7894736842105263
# Aging Rate: 0.07416267942583732
and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.7, 'min_child_weight': 1, 'max_depth': 9, 'learning_rate': 0.17500000000000002, 'reg_alpha': 0.02025845376557597, 'reg_lambda': 0.5435582588020118}. Best is trial 90 with value: 0.9037115726770898.
# Precision: 0.9375
# Recall: 0.7894736842105263
# Aging Rate: 0.07655502392344497
# Precision: 1.0
# Recall: 0.8552631578947368
# Aging Rate: 0.07775119617224881
# Precision: 0.9090909090909091
# Recall: 0.6578947368421053
# Aging Rate: 0.06578947368421052
# [I 2022-02-27 01:57:57,614] Trial 97 finished with value: 0.8474958171238827 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.7, 'min_child_weight': 3, 'max_depth': 9, 'learning_rate': 0.225, 'reg_alpha': 0.010094620525590658, 'reg_lambda': 1.3439463291934202}. Best is trial 90 with value: 0.9037115726770898.
# Precision: 0.967741935483871
# Recall: 0.7894736842105263
# Aging Rate: 0.07416267942583732
# Precision: 0.9027777777777778
# Recall: 0.8552631578947368
# Aging Rate: 0.0861244019138756
# Precision: 0.9090909090909091
# Recall: 0.7894736842105263
# Aging Rate: 0.07894736842105263
# [I 2022-02-27 01:57:59,403] Trial 98 finished with value: 0.8643380061016313 and parameters: {'eval_metric': 'logloss', 'n_estimators': 300, 'subsample': 0.7, 'colsample_bytree': 0.7, 'min_child_weight': 1, 'max_depth': 12, 'learning_rate': 0.225, 'reg_alpha': 0.01430949119443976, 'reg_lambda': 0.8569917080258982}. Best is trial 90 with value: 0.9037115726770898.
# Precision: 0.9166666666666666
# Recall: 0.868421052631579
# Aging Rate: 0.0861244019138756
# Precision: 0.9850746268656716
# Recall: 0.868421052631579
# Aging Rate: 0.08014354066985646
# Precision: 0.9814814814814815
# Recall: 0.6973684210526315
# Aging Rate: 0.0645933014354067
# [I 2022-02-27 01:58:01,698] Trial 99 finished with value: 0.8767844767844767 and parameters: {'eval_metric': 'logloss', 'n_estimators': 500, 'subsample': 0.7, 'colsample_bytree': 0.7, 'min_child_weight': 3, 'max_depth': 12, 'learning_rate': 0.17500000000000002, 'reg_alpha': 0.030496597248244786, 'reg_lambda': 0.3152782842074078}. Best is trial 90 with value: 0.9037115726770898.
# Sampler is TPESampler

# %%
best_paramR, all_scoreR = all_optuna(num_set = 10, 
                                     all_data = run_train, 
                                     mode = 'R', 
                                     TPE_multi = True, 
                                     n_iter = 200,
                                     filename = 'runhist_array_m2m5_4selection_XGBoost', 
                                     creator = XGBoost_creator
                                    )

# %% [markdown]
# ### optimization history & hyperparameter importance

# %%
##### optimization history plot #####
optuna_history(best_paramC, all_scoreC, num_row = 4, num_col = 3, model = 'XGBoost Classifier')
            
##### best hyperparameter table #####
param_table = pd.DataFrame(best_paramC).T
param_table
# Out:
#      eval_metric n_estimators subsample colsample_bytree min_child_weight  \
# set0     logloss          500       0.9              0.5                1
# set1     logloss         1000       0.9              0.7                1
# set2     logloss         1000       0.9              0.3                1
# set3     logloss         1000       0.7              0.7                1
# set4     logloss          500       0.7              0.9                1
# set5     logloss          500       0.9              0.5                1
# set6     logloss         1000       0.9              0.7                1
# set7     logloss         1000       0.9              0.3                1
# set8     logloss         1000       0.9              0.7                1
# set9     logloss          300       0.7              0.7                1
#
#      max_depth learning_rate reg_alpha reg_lambda
# set0        15         0.325  0.010212    0.01131
# set1        15         0.075  0.178598   6.182634
# set2        12         0.275  0.102402   0.397213
# set3         6         0.275  0.012398   2.662575
# set4         9         0.225  0.081156   0.067519
# set5        15         0.225  0.021763   8.587887
# set6         9         0.075  0.357443   1.666389
# set7        15         0.125  0.126673   0.077292
# set8        15         0.275  0.015352   0.886796
# set9        12         0.175    0.0123   0.410235

# %% [markdown]
# ##

# %% [markdown]
# ### Classifier

# %%
table_setC = runall_XGBoostC(10, run_train_x, run_test_x, run_train_y, run_test_y, best_paramC)
line_chart(table_setC, title = 'XGBoost Classfifer')
# Out:
#  Dataset 0:
# Precision: 0.0
# Recall: 0.0
# Aging Rate: 6.166622129951284e-05
#
#  Dataset 1:
# Precision: 0.0013936535162950257
# Recall: 0.2549019607843137
# Aging Rate: 0.19174083742728526
#
#  Dataset 2:
# Precision: 0.0012575286253226554
# Recall: 0.37254901960784315
# Aging Rate: 0.3105716458714465
#
#  Dataset 3:
# Precision: 0.0009455858334049686
# Recall: 0.21568627450980393
# Aging Rate: 0.23912105079241094
#
#  Dataset 4:
# Precision: 0.0016666666666666668
# Recall: 0.27450980392156865
# Aging Rate: 0.17266541963863594
#
#  Dataset 5:
# Precision: 0.0013597513597513598
# Recall: 0.27450980392156865
# Aging Rate: 0.21163847149992807
#
#  Dataset 6:
# Precision: 0.0010503413609423062
# Recall: 0.27450980392156865
# Aging Rate: 0.2739830212337355
#
#  Dataset 7:
# Precision: 0.001455604075691412
# Recall: 0.21568627450980393
# Aging Rate: 0.15533721145347285
#
#  Dataset 8:
# Precision: 0.0016343429941163652
# Recall: 0.29411764705882354
# Aging Rate: 0.18865752636230962
#
#  Dataset 9:
# Precision: 0.0012095273539263118
# Recall: 0.2549019607843137
# Aging Rate: 0.22092951550905465

# %%
table_setC
# Out:
#            Balance Ratio  Train_OK  Train_NG    TP       FP    FN       TN  \
# dataset 0     515.934211  156844.0     304.0   0.0      3.0  51.0  48595.0
# dataset 1       1.333225    4089.0    3067.0  13.0   9315.0  38.0  39283.0
# dataset 2       1.333111    4006.0    3005.0  19.0  15090.0  32.0  33508.0
# dataset 3       1.333004    4043.0    3033.0  11.0  11622.0  40.0  36976.0
# dataset 4       1.332785    4049.0    3038.0  14.0   8386.0  37.0  40212.0
# dataset 5       1.330706    4052.0    3045.0  14.0  10282.0  37.0  38316.0
# dataset 6       1.357454    4052.0    2985.0  14.0  13315.0  37.0  35283.0
# dataset 7       1.430286    4052.0    2833.0  11.0   7546.0  40.0  41052.0
# dataset 8       1.333772    4052.0    3038.0  15.0   9163.0  36.0  39435.0
# dataset 9      10.000000    3040.0     304.0  13.0  10735.0  38.0  37863.0
#
#            Precision    Recall  Aging Rate  Efficiency     Score
# dataset 0   0.000000  0.000000    0.000062    0.000000  0.000000
# dataset 1   0.001394  0.254902    0.191741    1.329409  0.215549
# dataset 2   0.001258  0.372549    0.310572    1.199559  0.293664
# dataset 3   0.000946  0.215686    0.239121    0.901996  0.000000
# dataset 4   0.001667  0.274510    0.172665    1.589837  0.261222
# dataset 5   0.001360  0.274510    0.211638    1.297069  0.228292
# dataset 6   0.001050  0.274510    0.273983    1.001923  0.190539
# dataset 7   0.001456  0.215686    0.155337    1.388504  0.187791
# dataset 8   0.001634  0.294118    0.188658    1.559003  0.276358
# dataset 9   0.001210  0.254902    0.220930    1.153771  0.195566

# %% [markdown]
# ### Regression

# %%
pr_dict, table_setR = runall_XGBoostR(10, run_train_x, run_test_x, run_train_y, run_test_y, best_paramR, 
                                       thres_target = 'Recall', threshold = 0.7)
line_chart(table_setR, title = 'XGBoost Regressor')

# %%
multiple_curve(4, 3, pr_dict, table_setR, target = 'Aging Rate')
multiple_curve(4, 3, pr_dict, table_setR, target = 'Precision')
table_setR

# %% [markdown]
# ### export

# %%
savedate = '20220301'
TPE_multi = False

table_setC['sampler'] = 'multivariate-TPE' if TPE_multi else 'univariate-TPE'
table_setC['model'] = 'XGBoost_br1.33'
with pd.ExcelWriter(f'{savedate}_Classifier.xlsx', mode = 'a') as writer:
    table_setC.to_excel(writer, sheet_name = 'XGBoost_br1.33')
