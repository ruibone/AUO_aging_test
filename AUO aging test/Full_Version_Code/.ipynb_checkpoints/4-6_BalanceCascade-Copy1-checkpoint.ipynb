# %%
import os
import numpy as np
import pandas as pd
import pickle
import random
from tqdm.auto import tqdm
import matplotlib.pyplot as plt

from lightgbm import LGBMClassifier
import optuna
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

from library.Data_Preprocessing import Balance_Ratio
from library.Imbalance_Sampling import label_divide, under_over, over_under
from library.Aging_Score_Contour import score1
from library.AdaBoost import train_set, multiple_set, multiple_month, line_chart, cf_matrix, all_optuna, optuna_history

os.chdir('C:/Users/user/Desktop/Darui_R08621110') 
os.getcwd()
# Out:
# 'C:\\Users\\user\\Desktop\\Darui_R08621110'

# %% [markdown]
# ##

# %% [markdown]
# ### Balance Cascade

# %%
# train & test of balance cascade (scheme 1 & 2)
class BalanceCascade:
    
    def __init__(self, base_clf = 'LightGBM', num_iter = 10, over_method = None, under_method = 'NM', 
                 over_num = 5, verbose = True):
        self.classifier = base_clf
        self.num_iter = num_iter
        self.over_method = over_method
        self.under_method = under_method
        self.over_num = over_num if over_method else 1
        self.verbose = verbose
        if over_method not in ['ADASYN', 'SMOTEN', None]:
            raise Exception(f'{over_method} is not implemented !') 
        if under_method not in ['NM', 'random']:
            raise Exception(f'{under_method} is not implemented !') 
        if base_clf not in ['LightGBM', 'RandomForest']:
            raise Exception(f'{base_clf} is not implemented !') 
    
    
    def training(self, train_data, clf_config):
        origin_good = train_data[train_data.GB == 0]
        origin_bad = train_data[train_data.GB == 1] 
        br_0 = (len(origin_bad)*self.over_num) / len(origin_good)
        false_rate = br_0**(1/(self.num_iter - 1))
        
        keep_bad = origin_bad.copy()
        keep_good = {0: origin_good.copy()}
        br_list = []
        clf_threshold = []
        clf_cascade = {}
        for j in range(self.num_iter):
            temp_train = pd.concat([keep_good[j], keep_bad], axis = 0)
            if self.verbose:
                print(f'\nIteration {j+1}:')
                print('Size before undersampling:', len(temp_train))
            temp_br = len(keep_bad) / len(keep_good[j])
            br_list.append(temp_br)

            # undersampling
            under_ratio = (len(keep_bad)*self.over_num) / len(keep_good[j])
            if under_ratio <= 0.99:
                under_X, under_Y = over_under(temp_train, None, self.under_method, 0, under_ratio)
                temp_combine = pd.concat([under_X, under_Y], axis = 1)
                under_good = temp_combine[temp_combine.GB == 0]
            else:
                temp_combine = temp_train.copy()
                if self.verbose:
                    print('Stop Undersampling !')            
            
            # oversampling
            if all([self.over_method, len(under_good) > len(keep_bad)]):
                over_ratio = 1
                over_X, over_Y = under_over(temp_combine, self.over_method, None, over_ratio, 0)
                over_sample = pd.concat([over_X, over_Y], axis = 1)
                train_combine = over_sample.rename({0: 'GB'}, axis = 'columns')
            else:
                train_combine = temp_combine.copy()
                if self.verbose:
                    print('Stop Oversampling !')

            # train the base learner, find the threshold, and discard the redundant good instances
            valid_good = keep_good[j].copy()
            train_x, train_y, valid_x, valid_y = label_divide(train_combine, valid_good, 'GB', train_only = False)
            if self.classifier == 'LightGBM':
                clf = LGBMClassifier(**clf_config)
            elif self.classifier == 'RandomForest':
                clf = RandomForestClassifier(**clf_config)
            clf.fit(train_x, train_y)
            predict = clf.predict_proba(valid_x)[:, 1]
            predict_df = pd.DataFrame(dict(predict = predict), index = valid_x.index)
            predict_df = predict_df.sort_values(by = 'predict', ascending = False)
            keep_num = int(len(predict_df)*false_rate) + 1
            keep_index = predict_df.index[:keep_num]
            threshold = predict_df.loc[keep_index[-1]].values[0]
            clf_threshold.append(threshold)
            clf_cascade[j] = clf
            
            if j != (self.num_iter - 1):
                keep_good[j+1] = keep_good[j].loc[keep_index].copy()        
        self.good_data = keep_good
        self.bad_data = keep_bad
        self.threshold = clf_threshold
        self.cascade = clf_cascade
        self.balance_ratio = br_list
    
    
    def testing(self, test_data):
        clf_cascade = self.cascade
        if isinstance(self.threshold, int):
            clf_threshold = [self.threshold]*len(clf_cascade)
        else:
            clf_threshold = self.threshold

        test_x, test_y = label_divide(test_data, 'GB', train_only = True)
        predict_df = pd.DataFrame()
        for i in range(len(clf_cascade)):
            clf = clf_cascade[i]
            predict = clf.predict_proba(test_x)[:, 1]
            answer = (predict > clf_threshold[i]).astype(int)
            predict = pd.DataFrame({str(i): answer})
            predict_df = pd.concat([predict_df, predict], axis = 1)
        predict_y = (predict_df.apply(sum, axis = 1) == len(clf_cascade)).astype(int)
        result = pd.DataFrame(dict(predict = predict_y, truth = test_y))

        return result


# run all resampling datasets
def runall_cascade(train_set, test_data, base_config, base_clf = 'LightGBM', num_iter = 10, meta_config = None):
    
    num_set = len(train_set)
    table_set = pd.DataFrame()
    for i in range(1, num_set):
        print('\n', f'Dataset {i}:')
        if isinstance(meta_config, dict):
            BC = BalanceCascade(base_clf = base_clf, **meta_config[f'set{i}'])
        else:
            BC = BalanceCascade(base_clf = base_clf, num_iter = num_iter)
        BC.training(train_set[f'set{i}'], base_config[f'set{i}'])
        result = BC.testing(test_data)
        table = cf_matrix(result, train_set[f'set{i}'].GB)
        table_set = pd.concat([table_set, table]).rename(index = {0: f'dataset {i}'})
    
    return table_set

# %% [markdown]
# ### Optuna

# %%
# creator of optuna study for balance cascade
def BalanceCascade_creator(train_data, mode, num_valid = 3, label = 'GB') :

    def objective(trial) :
    
        base_param = {
            'n_estimators': trial.suggest_categorical('n_estimators', [100, 300, 500, 1000]),
            'learning_rate': trial.suggest_float('learning_rate', 0.025, 0.325, step = 0.05),
            'max_depth': trial.suggest_int('max_depth', 3, 12, step = 3),
            'num_leaves': trial.suggest_int('num_leaves', 10, 130, step = 20),
            'min_child_samples': trial.suggest_categorical('min_child_samples', [10, 50, 100, 500, 1000, 5000]),
            'min_split_gain': trial.suggest_int('min_split_gain', 0, 12, step = 2),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.3, 0.9, step = 0.2),
            'subsample': trial.suggest_float('subsample', 0.3, 0.9, step = 0.2),
            'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-2, 10), # alpha
            'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-2, 10) # lambda
        }
    
        meta_param = {
            'num_iter': trial.suggest_int('num_iter', 5, 5, step = 5),
            'over_num': trial.suggest_int('over_num', 5, 5, step = 5),
            'over_method': trial.suggest_categorical('over_method', ['ADASYN']),
            'under_method': trial.suggest_categorical('under_method', ['NM'])
        }  

        result_list = []
        for i in range(num_valid):

            train_good = train_data[train_data.GB == 0]
            train_bad = train_data[train_data.GB == 1]
            train_good_x, train_good_y = label_divide(train_good, None, label, train_only = True)
            train_bad_x, train_bad_y = label_divide(train_bad, None, label, train_only = True)
            train_g_x, valid_g_x, train_g_y, valid_g_y = train_test_split(train_good_x, train_good_y, test_size = 0.25)
            train_b_x, valid_b_x, train_b_y, valid_b_y = train_test_split(train_bad_x, train_bad_y, test_size = 0.25)
            train_x = pd.concat([train_g_x, train_b_x], axis = 0)
            train_y = pd.concat([train_g_y, train_b_y], axis = 0)
            valid_x = pd.concat([valid_g_x, valid_b_x], axis = 0)
            valid_y = pd.concat([valid_g_y, valid_b_y], axis = 0)
            all_train = pd.concat([train_x, train_y], axis = 1)
            all_valid = pd.concat([valid_x, valid_y], axis = 1)

            if mode == 1:
                BC = BalanceCascade(num_iter = meta_param['num_iter'], under_method = meta_param['under_method'])
            elif mode == 2:
                BC = BalanceCascade(num_iter = meta_param['num_iter'], over_method = meta_param['over_method'], 
                                    under_method = meta_param['under_method'], over_num = meta_param['over_num'])
            BC.training(all_train, base_param)
            result = BC.testing(all_valid)
            table = cf_matrix(result, valid_y)
            recall = table['Recall'].values
            precision = table['Precision'].values
            beta = 1
            if recall > 0:
                fscore = ((1+beta**2)*recall*precision) / (recall+(beta**2)*precision) 
            else:
                fscore = 0
            result_list.append(fscore)

        return np.mean(result_list)
    return objective

# %% [markdown]
# ##

# %% [markdown]
# ### Load Data

# %%
### training data ###
training_month = range(2, 5)

data_dict, trainset_x, trainset_y = multiple_month(training_month, num_set = 10, filename = 'dataset')

print('\nCombined training data:\n')
run_train = multiple_set(num_set = 10)
run_train_x, run_train_y = train_set(run_train, num_set = 10)

### testing data ###
run_test = pd.read_csv('test_runhist.csv').iloc[:, 2:]
run_test_x, run_test_y = label_divide(run_test, None, 'GB', train_only = True)
print('\n', 'Dimension of testing data:', run_test.shape)
# Out:
# Month 2:
#
# Dimension of dataset 0 : (39009, 88)  balance ratio: 564.35
# Dimension of dataset 1 : (8970, 88)  balance ratio: 25.0
# Dimension of dataset 2 : (8892, 88)  balance ratio: 25.0
# Dimension of dataset 3 : (8944, 88)  balance ratio: 25.0
# Dimension of dataset 4 : (8944, 88)  balance ratio: 25.0
# Dimension of dataset 5 : (8970, 88)  balance ratio: 25.0
# Dimension of dataset 6 : (8969, 88)  balance ratio: 25.07
# Dimension of dataset 7 : (8967, 88)  balance ratio: 25.22
# Dimension of dataset 8 : (8970, 88)  balance ratio: 25.0
# Dimension of dataset 9 : (1794, 88)  balance ratio: 25.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
# Month 3:
#
# Dimension of dataset 0 : (60396, 97)  balance ratio: 533.48
# Dimension of dataset 1 : (14924, 97)  balance ratio: 25.0
# Dimension of dataset 2 : (14560, 97)  balance ratio: 25.0
# Dimension of dataset 3 : (14664, 97)  balance ratio: 25.0
# Dimension of dataset 4 : (14664, 97)  balance ratio: 25.0
# Dimension of dataset 5 : (14674, 97)  balance ratio: 25.73
# Dimension of dataset 6 : (14689, 97)  balance ratio: 25.04
# Dimension of dataset 7 : (14686, 97)  balance ratio: 25.18
# Dimension of dataset 8 : (14690, 97)  balance ratio: 25.0
# Dimension of dataset 9 : (2938, 97)  balance ratio: 25.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
# Month 4:
#
# Dimension of dataset 0 : (57743, 100)  balance ratio: 472.3
# Dimension of dataset 1 : (16198, 100)  balance ratio: 25.0
# Dimension of dataset 2 : (15834, 100)  balance ratio: 25.0
# Dimension of dataset 3 : (15808, 100)  balance ratio: 25.0
# Dimension of dataset 4 : (15860, 100)  balance ratio: 25.0
# Dimension of dataset 5 : (15873, 100)  balance ratio: 24.48
# Dimension of dataset 6 : (15855, 100)  balance ratio: 25.21
# Dimension of dataset 7 : (15856, 100)  balance ratio: 25.17
# Dimension of dataset 8 : (15860, 100)  balance ratio: 25.0
# Dimension of dataset 9 : (3172, 100)  balance ratio: 25.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
# Combined training data:
#
# Dimension of dataset 0 : (157148, 128)  balance ratio: 515.93
# Dimension of dataset 1 : (40092, 128)  balance ratio: 25.0
# Dimension of dataset 2 : (39286, 128)  balance ratio: 25.0
# Dimension of dataset 3 : (39416, 128)  balance ratio: 25.0
# Dimension of dataset 4 : (39468, 128)  balance ratio: 25.0
# Dimension of dataset 5 : (39517, 128)  balance ratio: 25.05
# Dimension of dataset 6 : (39513, 128)  balance ratio: 25.12
# Dimension of dataset 7 : (39509, 128)  balance ratio: 25.18
# Dimension of dataset 8 : (39520, 128)  balance ratio: 25.0
# Dimension of dataset 9 : (7904, 128)  balance ratio: 25.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
#  Dimension of testing data: (48649, 128)

# %% [markdown]
# ### Search for the Best Hyperparameters

# %%
best_paramC, all_scoreC = all_optuna(all_data = run_train, 
                                     mode = 2, 
                                     TPE_multi = False, 
                                     n_iter = 1,
                                     filename = 'runhist_array_m2m4_m5_3criteria_iter5_over5_random_BalanceCascade',
                                     creator = BalanceCascade_creator
                                    )

meta_item = ['num_iter', 'over_num', 'over_method', 'under_method']
base_paramC = {}
meta_paramC = {}
for i in range(1, len(run_train)):
    base_paramC.update({f'set{i}': {}})
    meta_paramC.update({f'set{i}': {}})
    [base_paramC[f'set{i}'].update({a: b}) for (a, b) in best_paramC[f'set{i}'].items() if a not in meta_item]
    [meta_paramC[f'set{i}'].update({a: b}) for (a, b) in best_paramC[f'set{i}'].items() if a in meta_item]
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# [I 2022-03-07 13:59:33,486] A new study created in memory with name: no-name-d5d27e08-05d2-479c-8ed3-e5ce67b8f7b5
# Dataset 1 :
# C:\Users\user\anaconda3\envs\aging\lib\site-packages\optuna\progress_bar.py:47: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
#   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration 1:
# Size before undersampling: 30068
# Size after Undersampling: 6938
# Size before Oversampling: 6938
# Size after Oversampling: 11537
#
# Iteration 2:
# Size before undersampling: 20489
# Size after Undersampling: 5022
# Size before Oversampling: 5022
# Size after Oversampling: 7711
#
# Iteration 3:
# Size before undersampling: 14084
# Size after Undersampling: 3741
# Size before Oversampling: 3741
# Size after Oversampling: 5155
#
# Iteration 4:
# Size before undersampling: 9801
# Size after Undersampling: 2885
# Size before Oversampling: 2885
# Size after Oversampling: 3437
#
# Iteration 5:
# Size before undersampling: 6937
# Stop Undersampling !
# Size before Oversampling: 6937
# Size after Oversampling: 11593
# Precision: 0.029953917050691243
# Recall: 0.17105263157894737
# Aging Rate: 0.17079889807162535
#
# Iteration 1:
# Size before undersampling: 30068
# Size after Undersampling: 6938
# Size before Oversampling: 6938
# Size after Oversampling: 11624
#
# Iteration 2:
# Size before undersampling: 20489
# Size after Undersampling: 5022
# Size before Oversampling: 5022
# Size after Oversampling: 7701
#
# Iteration 3:
# Size before undersampling: 14084
# Size after Undersampling: 3741
# Size before Oversampling: 3741
# Size after Oversampling: 5147
#
# Iteration 4:
# Size before undersampling: 9801
# Size after Undersampling: 2885
# Size before Oversampling: 2885
# Size after Oversampling: 3447
#
# Iteration 5:
# Size before undersampling: 6937
# Stop Undersampling !
# Size before Oversampling: 6937
# Size after Oversampling: 11577
# Precision: 0.03350515463917526
# Recall: 0.1511627906976744
# Aging Rate: 0.15830273357813138
#
# Iteration 1:
# Size before undersampling: 30068
# Size after Undersampling: 6938
# Size before Oversampling: 6938
# Size after Oversampling: 11580
#
# Iteration 2:
# Size before undersampling: 20489
# Size after Undersampling: 5022
# Size before Oversampling: 5022
# Size after Oversampling: 7734
#
# Iteration 3:
# Size before undersampling: 14084
# Size after Undersampling: 3741
# Size before Oversampling: 3741
# Size after Oversampling: 5192
#
# Iteration 4:
# Size before undersampling: 9801
# Size after Undersampling: 2885
# Size before Oversampling: 2885
# Size after Oversampling: 3464
#
# Iteration 5:
# Size before undersampling: 6937
# Stop Undersampling !
# Size before Oversampling: 6937
# Size after Oversampling: 11535
# [I 2022-03-07 13:59:49,017] A new study created in memory with name: no-name-a6770758-ddc4-4d77-ad73-a3fff1150f32
# Precision: 0.016826923076923076
# Recall: 0.08536585365853659
# Aging Rate: 0.16560509554140126
# [I 2022-03-07 13:59:48,952] Trial 0 finished with value: 0.04464838754372167 and parameters: {'n_estimators': 1000, 'learning_rate': 0.025, 'max_depth': 3, 'num_leaves': 130, 'min_child_samples': 100, 'min_split_gain': 2, 'colsample_bytree': 0.3, 'subsample': 0.3, 'reg_alpha': 0.014162175350228855, 'reg_lambda': 8.655130102126268, 'num_iter': 5, 'over_num': 5, 'over_method': 'ADASYN', 'under_method': 'random'}. Best is trial 0 with value: 0.04464838754372167.
# Sampler is TPESampler
# Dataset 2 :
# C:\Users\user\anaconda3\envs\aging\lib\site-packages\optuna\progress_bar.py:47: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
#   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration 1:
# Size before undersampling: 29464
# Size after Undersampling: 6799
# Size before Oversampling: 6799
# Size after Oversampling: 11372
#
# Iteration 2:
# Size before undersampling: 20079
# Size after Undersampling: 4922
# Size before Oversampling: 4922
# Size after Oversampling: 7651
#
# Iteration 3:
# Size before undersampling: 13803
# Size after Undersampling: 3667
# Size before Oversampling: 3667
# Size after Oversampling: 5029
#
# Iteration 4:
# Size before undersampling: 9606
# Size after Undersampling: 2827
# Size before Oversampling: 2827
# Size after Oversampling: 3362
#
# Iteration 5:
# Size before undersampling: 6799
# Stop Undersampling !
# Size before Oversampling: 6799
# Size after Oversampling: 11369
# Precision: 0.024024024024024024
# Recall: 0.09302325581395349
# Aging Rate: 0.13692434210526316
#
# Iteration 1:
# Size before undersampling: 29464
# Size after Undersampling: 6799
# Size before Oversampling: 6799
# Size after Oversampling: 11367
#
# Iteration 2:
# Size before undersampling: 20079
# Size after Undersampling: 4922
# Size before Oversampling: 4922
# Size after Oversampling: 7541
#
# Iteration 3:
# Size before undersampling: 13803
# Size after Undersampling: 3667
# Size before Oversampling: 3667
# Size after Oversampling: 5129
#
# Iteration 4:
# Size before undersampling: 9606
# Size after Undersampling: 2827
# Size before Oversampling: 2827
# Size after Oversampling: 3369
#
# Iteration 5:
# Size before undersampling: 6799
# Stop Undersampling !
# Size before Oversampling: 6799
# Size after Oversampling: 11376
# Precision: 0.020172910662824207
# Recall: 0.0875
# Aging Rate: 0.14088509947218839
#
# Iteration 1:
# Size before undersampling: 29464
# Size after Undersampling: 6799
# Size before Oversampling: 6799
# Size after Oversampling: 11323
#
# Iteration 2:
# Size before undersampling: 20079
# Size after Undersampling: 4922
# Size before Oversampling: 4922
# Size after Oversampling: 7524
#
# Iteration 3:
# Size before undersampling: 13803
# Size after Undersampling: 3667
# Size before Oversampling: 3667
# Size after Oversampling: 5099
#
# Iteration 4:
# Size before undersampling: 9606
# Size after Undersampling: 2827
# Size before Oversampling: 2827
# Size after Oversampling: 3407
#
# Iteration 5:
# Size before undersampling: 6799
# Stop Undersampling !
# Size before Oversampling: 6799
# Size after Oversampling: 11263
# [I 2022-03-07 13:59:58,015] A new study created in memory with name: no-name-e90e10c3-fabc-47f2-9562-95355830c1e2
# Precision: 0.023054755043227664
# Recall: 0.1
# Aging Rate: 0.14094232331437856
# [I 2022-03-07 13:59:57,942] Trial 0 finished with value: 0.03614792291970585 and parameters: {'n_estimators': 1000, 'learning_rate': 0.275, 'max_depth': 3, 'num_leaves': 110, 'min_child_samples': 10, 'min_split_gain': 12, 'colsample_bytree': 0.9, 'subsample': 0.3, 'reg_alpha': 0.2570009733557758, 'reg_lambda': 0.011109551180214982, 'num_iter': 5, 'over_num': 5, 'over_method': 'ADASYN', 'under_method': 'random'}. Best is trial 0 with value: 0.03614792291970585.
# Sampler is TPESampler
# Dataset 3 :
# C:\Users\user\anaconda3\envs\aging\lib\site-packages\optuna\progress_bar.py:47: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
#   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration 1:
# Size before undersampling: 29562
# Size after Undersampling: 6822
# Size before Oversampling: 6822
# Size after Oversampling: 11574
#
# Iteration 2:
# Size before undersampling: 20146
# Size after Undersampling: 4938
# Size before Oversampling: 4938
# Size after Oversampling: 7740
#
# Iteration 3:
# Size before undersampling: 13850
# Size after Undersampling: 3679
# Size before Oversampling: 3679
# Size after Oversampling: 5186
#
# Iteration 4:
# Size before undersampling: 9639
# Size after Undersampling: 2837
# Size before Oversampling: 2837
# Size after Oversampling: 3356
#
# Iteration 5:
# Size before undersampling: 6823
# Stop Undersampling !
# Size before Oversampling: 6823
# Size after Oversampling: 11455
# Precision: 0.04009433962264151
# Recall: 0.20481927710843373
# Aging Rate: 0.1730612244897959
#
# Iteration 1:
# Size before undersampling: 29562
# Size after Undersampling: 6822
# Size before Oversampling: 6822
# Size after Oversampling: 11345
#
# Iteration 2:
# Size before undersampling: 20146
# Size after Undersampling: 4938
# Size before Oversampling: 4938
# Size after Oversampling: 7658
#
# Iteration 3:
# Size before undersampling: 13850
# Size after Undersampling: 3679
# Size before Oversampling: 3679
# Size after Oversampling: 5141
#
# Iteration 4:
# Size before undersampling: 9639
# Size after Undersampling: 2837
# Size before Oversampling: 2837
# Size after Oversampling: 3283
#
# Iteration 5:
# Size before undersampling: 6823
# Stop Undersampling !
# Size before Oversampling: 6823
# Size after Oversampling: 11363
# Precision: 0.047619047619047616
# Recall: 0.1958762886597938
# Aging Rate: 0.1601766358892011
#
# Iteration 1:
# Size before undersampling: 29562
# Size after Undersampling: 6822
# Size before Oversampling: 6822
# Size after Oversampling: 11191
#
# Iteration 2:
# Size before undersampling: 20146
# Size after Undersampling: 4938
# Size before Oversampling: 4938
# Size after Oversampling: 7723
#
# Iteration 3:
# Size before undersampling: 13850
# Size after Undersampling: 3679
# Size before Oversampling: 3679
# Size after Oversampling: 5205
#
# Iteration 4:
# Size before undersampling: 9639
# Size after Undersampling: 2837
# Size before Oversampling: 2837
# Size after Oversampling: 3327
#
# Iteration 5:
# Size before undersampling: 6823
# Stop Undersampling !
# Size before Oversampling: 6823
# Size after Oversampling: 11545
# [I 2022-03-07 14:00:05,172] A new study created in memory with name: no-name-3baf23d6-83f4-4339-bb6a-34d65eda04c6
# Precision: 0.02631578947368421
# Recall: 0.14102564102564102
# Aging Rate: 0.1735159817351598
# [I 2022-03-07 14:00:05,093] Trial 0 finished with value: 0.06267629530656826 and parameters: {'n_estimators': 300, 'learning_rate': 0.17500000000000002, 'max_depth': 12, 'num_leaves': 110, 'min_child_samples': 10, 'min_split_gain': 2, 'colsample_bytree': 0.3, 'subsample': 0.5, 'reg_alpha': 0.01709855379808299, 'reg_lambda': 0.04020546542362343, 'num_iter': 5, 'over_num': 5, 'over_method': 'ADASYN', 'under_method': 'random'}. Best is trial 0 with value: 0.06267629530656826.
# Sampler is TPESampler
# Dataset 4 :
# C:\Users\user\anaconda3\envs\aging\lib\site-packages\optuna\progress_bar.py:47: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
#   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration 1:
# Size before undersampling: 29600
# Size after Undersampling: 6830
# Size before Oversampling: 6830
# Size after Oversampling: 11390
#
# Iteration 2:
# Size before undersampling: 20170
# Size after Undersampling: 4944
# Size before Oversampling: 4944
# Size after Oversampling: 7592
#
# Iteration 3:
# Size before undersampling: 13865
# Size after Undersampling: 3683
# Size before Oversampling: 3683
# Size after Oversampling: 5093
#
# Iteration 4:
# Size before undersampling: 9649
# Size after Undersampling: 2840
# Size before Oversampling: 2840
# Size after Oversampling: 3393
#
# Iteration 5:
# Size before undersampling: 6830
# Stop Undersampling !
# Size before Oversampling: 6830
# Size after Oversampling: 11372
# Precision: 0.019464720194647202
# Recall: 0.1
# Aging Rate: 0.16837361736993037
#
# Iteration 1:
# Size before undersampling: 29600
# Size after Undersampling: 6830
# Size before Oversampling: 6830
# Size after Oversampling: 11398
#
# Iteration 2:
# Size before undersampling: 20170
# Size after Undersampling: 4944
# Size before Oversampling: 4944
# Size after Oversampling: 7632
#
# Iteration 3:
# Size before undersampling: 13865
# Size after Undersampling: 3683
# Size before Oversampling: 3683
# Size after Oversampling: 5077
#
# Iteration 4:
# Size before undersampling: 9649
# Size after Undersampling: 2840
# Size before Oversampling: 2840
# Size after Oversampling: 3388
#
# Iteration 5:
# Size before undersampling: 6830
# Stop Undersampling !
# Size before Oversampling: 6830
# Size after Oversampling: 11372
# Precision: 0.02088167053364269
# Recall: 0.12162162162162163
# Aging Rate: 0.17219336795844986
#
# Iteration 1:
# Size before undersampling: 29600
# Size after Undersampling: 6830
# Size before Oversampling: 6830
# Size after Oversampling: 11418
#
# Iteration 2:
# Size before undersampling: 20170
# Size after Undersampling: 4944
# Size before Oversampling: 4944
# Size after Oversampling: 7606
#
# Iteration 3:
# Size before undersampling: 13865
# Size after Undersampling: 3683
# Size before Oversampling: 3683
# Size after Oversampling: 5118
#
# Iteration 4:
# Size before undersampling: 9649
# Size after Undersampling: 2840
# Size before Oversampling: 2840
# Size after Oversampling: 3406
#
# Iteration 5:
# Size before undersampling: 6830
# Stop Undersampling !
# Size before Oversampling: 6830
# Size after Oversampling: 11378
# [I 2022-03-07 14:00:18,182] A new study created in memory with name: no-name-63b6a6d7-77fa-44f5-88ea-846379bb9df7
# Precision: 0.023706896551724137
# Recall: 0.12222222222222222
# Aging Rate: 0.18282111899133174
# [I 2022-03-07 14:00:18,078] Trial 0 finished with value: 0.03598043791232741 and parameters: {'n_estimators': 500, 'learning_rate': 0.025, 'max_depth': 9, 'num_leaves': 130, 'min_child_samples': 500, 'min_split_gain': 0, 'colsample_bytree': 0.3, 'subsample': 0.7, 'reg_alpha': 0.027286999685739596, 'reg_lambda': 0.3557991997980532, 'num_iter': 5, 'over_num': 5, 'over_method': 'ADASYN', 'under_method': 'random'}. Best is trial 0 with value: 0.03598043791232741.
# Sampler is TPESampler
# Dataset 5 :
# C:\Users\user\anaconda3\envs\aging\lib\site-packages\optuna\progress_bar.py:47: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
#   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration 1:
# Size before undersampling: 29637
# Size after Undersampling: 6837
# Size before Oversampling: 6837
# Size after Oversampling: 11373
#
# Iteration 2:
# Size before undersampling: 20184
# Size after Undersampling: 4946
# Size before Oversampling: 4946
# Size after Oversampling: 7631
#
# Iteration 3:
# Size before undersampling: 13867
# Size after Undersampling: 3683
# Size before Oversampling: 3683
# Size after Oversampling: 5075
#
# Iteration 4:
# Size before undersampling: 9645
# Size after Undersampling: 2838
# Size before Oversampling: 2838
# Size after Oversampling: 3393
#
# Iteration 5:
# Size before undersampling: 6823
# Stop Undersampling !
# Size before Oversampling: 6823
# Size after Oversampling: 11383
# Precision: 0.03684210526315789
# Recall: 0.14893617021276595
# Aging Rate: 0.1531640467553406
#
# Iteration 1:
# Size before undersampling: 29637
# Size after Undersampling: 6837
# Size before Oversampling: 6837
# Size after Oversampling: 11414
#
# Iteration 2:
# Size before undersampling: 20184
# Size after Undersampling: 4946
# Size before Oversampling: 4946
# Size after Oversampling: 7591
#
# Iteration 3:
# Size before undersampling: 13867
# Size after Undersampling: 3683
# Size before Oversampling: 3683
# Size after Oversampling: 5128
#
# Iteration 4:
# Size before undersampling: 9645
# Size after Undersampling: 2838
# Size before Oversampling: 2838
# Size after Oversampling: 3419
#
# Iteration 5:
# Size before undersampling: 6823
# Stop Undersampling !
# Size before Oversampling: 6823
# Size after Oversampling: 11349
# Precision: 0.02981029810298103
# Recall: 0.13414634146341464
# Aging Rate: 0.15067374438546347
#
# Iteration 1:
# Size before undersampling: 29637
# Size after Undersampling: 6837
# Size before Oversampling: 6837
# Size after Oversampling: 11397
#
# Iteration 2:
# Size before undersampling: 20184
# Size after Undersampling: 4946
# Size before Oversampling: 4946
# Size after Oversampling: 7649
#
# Iteration 3:
# Size before undersampling: 13867
# Size after Undersampling: 3683
# Size before Oversampling: 3683
# Size after Oversampling: 5117
#
# Iteration 4:
# Size before undersampling: 9645
# Size after Undersampling: 2838
# Size before Oversampling: 2838
# Size after Oversampling: 3418
#
# Iteration 5:
# Size before undersampling: 6823
# Stop Undersampling !
# Size before Oversampling: 6823
# Size after Oversampling: 11332
# [I 2022-03-07 14:00:24,985] A new study created in memory with name: no-name-f3049256-f36a-4adc-addf-7a47b413a99f
# Precision: 0.017811704834605598
# Recall: 0.08433734939759036
# Aging Rate: 0.16133004926108374
# [I 2022-03-07 14:00:24,921] Trial 0 finished with value: 0.04575466082285543 and parameters: {'n_estimators': 500, 'learning_rate': 0.325, 'max_depth': 9, 'num_leaves': 130, 'min_child_samples': 1000, 'min_split_gain': 2, 'colsample_bytree': 0.9, 'subsample': 0.7, 'reg_alpha': 1.1190164503921598, 'reg_lambda': 4.5153356920593115, 'num_iter': 5, 'over_num': 5, 'over_method': 'ADASYN', 'under_method': 'random'}. Best is trial 0 with value: 0.04575466082285543.
# Sampler is TPESampler
# Dataset 6 :
# C:\Users\user\anaconda3\envs\aging\lib\site-packages\optuna\progress_bar.py:47: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
#   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration 1:
# Size before undersampling: 29634
# Size after Undersampling: 6834
# Size before Oversampling: 6834
# Size after Oversampling: 11417
#
# Iteration 2:
# Size before undersampling: 20168
# Size after Undersampling: 4940
# Size before Oversampling: 4940
# Size after Oversampling: 7566
#
# Iteration 3:
# Size before undersampling: 13847
# Size after Undersampling: 3676
# Size before Oversampling: 3676
# Size after Oversampling: 5068
#
# Iteration 4:
# Size before undersampling: 9625
# Size after Undersampling: 2832
# Size before Oversampling: 2832
# Size after Oversampling: 3424
#
# Iteration 5:
# Size before undersampling: 6805
# Stop Undersampling !
# Size before Oversampling: 6805
# Size after Oversampling: 11341
# Precision: 0.019753086419753086
# Recall: 0.1095890410958904
# Aging Rate: 0.16924362724613456
#
# Iteration 1:
# Size before undersampling: 29634
# Size after Undersampling: 6834
# Size before Oversampling: 6834
# Size after Oversampling: 11365
#
# Iteration 2:
# Size before undersampling: 20168
# Size after Undersampling: 4940
# Size before Oversampling: 4940
# Size after Oversampling: 7579
#
# Iteration 3:
# Size before undersampling: 13847
# Size after Undersampling: 3676
# Size before Oversampling: 3676
# Size after Oversampling: 5042
#
# Iteration 4:
# Size before undersampling: 9625
# Size after Undersampling: 2832
# Size before Oversampling: 2832
# Size after Oversampling: 3404
#
# Iteration 5:
# Size before undersampling: 6805
# Stop Undersampling !
# Size before Oversampling: 6805
# Size after Oversampling: 11364
# Precision: 0.0267639902676399
# Recall: 0.12790697674418605
# Aging Rate: 0.16619490497371614
#
# Iteration 1:
# Size before undersampling: 29634
# Size after Undersampling: 6834
# Size before Oversampling: 6834
# Size after Oversampling: 11419
#
# Iteration 2:
# Size before undersampling: 20168
# Size after Undersampling: 4940
# Size before Oversampling: 4940
# Size after Oversampling: 7576
#
# Iteration 3:
# Size before undersampling: 13847
# Size after Undersampling: 3676
# Size before Oversampling: 3676
# Size after Oversampling: 5009
#
# Iteration 4:
# Size before undersampling: 9625
# Size after Undersampling: 2832
# Size before Oversampling: 2832
# Size after Oversampling: 3436
#
# Iteration 5:
# Size before undersampling: 6805
# Stop Undersampling !
# Size before Oversampling: 6805
# Size after Oversampling: 11317
# [I 2022-03-07 14:00:31,846] A new study created in memory with name: no-name-560ef510-c194-4f6f-a1e5-61c995ed79f6
# Precision: 0.024875621890547265
# Recall: 0.10989010989010989
# Aging Rate: 0.16262135922330098
# [I 2022-03-07 14:00:31,781] Trial 0 finished with value: 0.03943544940903565 and parameters: {'n_estimators': 100, 'learning_rate': 0.17500000000000002, 'max_depth': 12, 'num_leaves': 110, 'min_child_samples': 10, 'min_split_gain': 4, 'colsample_bytree': 0.7, 'subsample': 0.3, 'reg_alpha': 1.1095208142320436, 'reg_lambda': 1.8152848999578315, 'num_iter': 5, 'over_num': 5, 'over_method': 'ADASYN', 'under_method': 'random'}. Best is trial 0 with value: 0.03943544940903565.
# Sampler is TPESampler
# Dataset 7 :
# C:\Users\user\anaconda3\envs\aging\lib\site-packages\optuna\progress_bar.py:47: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
#   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration 1:
# Size before undersampling: 29631
# Size after Undersampling: 6831
# Size before Oversampling: 6831
# Size after Oversampling: 11429
#
# Iteration 2:
# Size before undersampling: 20153
# Size after Undersampling: 4935
# Size before Oversampling: 4935
# Size after Oversampling: 7614
#
# Iteration 3:
# Size before undersampling: 13827
# Size after Undersampling: 3670
# Size before Oversampling: 3670
# Size after Oversampling: 5114
#
# Iteration 4:
# Size before undersampling: 9605
# Size after Undersampling: 2825
# Size before Oversampling: 2825
# Size after Oversampling: 3292
#
# Iteration 5:
# Size before undersampling: 6787
# Stop Undersampling !
# Size before Oversampling: 6787
# Size after Oversampling: 11356
# Precision: 0.029411764705882353
# Recall: 0.15384615384615385
# Aging Rate: 0.163855421686747
#
# Iteration 1:
# Size before undersampling: 29631
# Size after Undersampling: 6831
# Size before Oversampling: 6831
# Size after Oversampling: 11452
#
# Iteration 2:
# Size before undersampling: 20153
# Size after Undersampling: 4935
# Size before Oversampling: 4935
# Size after Oversampling: 7660
#
# Iteration 3:
# Size before undersampling: 13827
# Size after Undersampling: 3670
# Size before Oversampling: 3670
# Size after Oversampling: 5160
#
# Iteration 4:
# Size before undersampling: 9605
# Size after Undersampling: 2825
# Size before Oversampling: 2825
# Size after Oversampling: 3270
#
# Iteration 5:
# Size before undersampling: 6787
# Stop Undersampling !
# Size before Oversampling: 6787
# Size after Oversampling: 11314
# Precision: 0.03333333333333333
# Recall: 0.189873417721519
# Aging Rate: 0.17765495459928937
#
# Iteration 1:
# Size before undersampling: 29631
# Size after Undersampling: 6831
# Size before Oversampling: 6831
# Size after Oversampling: 11354
#
# Iteration 2:
# Size before undersampling: 20153
# Size after Undersampling: 4935
# Size before Oversampling: 4935
# Size after Oversampling: 7635
#
# Iteration 3:
# Size before undersampling: 13827
# Size after Undersampling: 3670
# Size before Oversampling: 3670
# Size after Oversampling: 5163
#
# Iteration 4:
# Size before undersampling: 9605
# Size after Undersampling: 2825
# Size before Oversampling: 2825
# Size after Oversampling: 3304
#
# Iteration 5:
# Size before undersampling: 6787
# Stop Undersampling !
# Size before Oversampling: 6787
# Size after Oversampling: 11424
# [I 2022-03-07 14:00:41,235] A new study created in memory with name: no-name-305f83b1-d02c-491b-9870-de5b4673c37a
# Precision: 0.0390625
# Recall: 0.17045454545454544
# Aging Rate: 0.15527699150828952
# [I 2022-03-07 14:00:41,176] Trial 0 finished with value: 0.056550937710179994 and parameters: {'n_estimators': 1000, 'learning_rate': 0.225, 'max_depth': 12, 'num_leaves': 130, 'min_child_samples': 50, 'min_split_gain': 2, 'colsample_bytree': 0.3, 'subsample': 0.7, 'reg_alpha': 0.33742704729167206, 'reg_lambda': 6.896482415855276, 'num_iter': 5, 'over_num': 5, 'over_method': 'ADASYN', 'under_method': 'random'}. Best is trial 0 with value: 0.056550937710179994.
# Sampler is TPESampler
# Dataset 8 :
# C:\Users\user\anaconda3\envs\aging\lib\site-packages\optuna\progress_bar.py:47: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
#   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration 1:
# Size before undersampling: 29640
# Size after Undersampling: 6840
# Size before Oversampling: 6840
# Size after Oversampling: 11409
#
# Iteration 2:
# Size before undersampling: 20200
# Size after Undersampling: 4952
# Size before Oversampling: 4952
# Size after Oversampling: 7594
#
# Iteration 3:
# Size before undersampling: 13887
# Size after Undersampling: 3689
# Size before Oversampling: 3689
# Size after Oversampling: 5104
#
# Iteration 4:
# Size before undersampling: 9665
# Size after Undersampling: 2845
# Size before Oversampling: 2845
# Size after Oversampling: 3407
#
# Iteration 5:
# Size before undersampling: 6842
# Stop Undersampling !
# Size before Oversampling: 6842
# Size after Oversampling: 11385
# Precision: 0.03816793893129771
# Recall: 0.16129032258064516
# Aging Rate: 0.16099959033183123
#
# Iteration 1:
# Size before undersampling: 29640
# Size after Undersampling: 6840
# Size before Oversampling: 6840
# Size after Oversampling: 11399
#
# Iteration 2:
# Size before undersampling: 20200
# Size after Undersampling: 4952
# Size before Oversampling: 4952
# Size after Oversampling: 7619
#
# Iteration 3:
# Size before undersampling: 13887
# Size after Undersampling: 3689
# Size before Oversampling: 3689
# Size after Oversampling: 5118
#
# Iteration 4:
# Size before undersampling: 9665
# Size after Undersampling: 2845
# Size before Oversampling: 2845
# Size after Oversampling: 3397
#
# Iteration 5:
# Size before undersampling: 6842
# Stop Undersampling !
# Size before Oversampling: 6842
# Size after Oversampling: 11428
# Precision: 0.036057692307692304
# Recall: 0.16853932584269662
# Aging Rate: 0.16965742251223492
#
# Iteration 1:
# Size before undersampling: 29640
# Size after Undersampling: 6840
# Size before Oversampling: 6840
# Size after Oversampling: 11374
#
# Iteration 2:
# Size before undersampling: 20200
# Size after Undersampling: 4952
# Size before Oversampling: 4952
# Size after Oversampling: 7642
#
# Iteration 3:
# Size before undersampling: 13887
# Size after Undersampling: 3689
# Size before Oversampling: 3689
# Size after Oversampling: 5103
#
# Iteration 4:
# Size before undersampling: 9665
# Size after Undersampling: 2845
# Size before Oversampling: 2845
# Size after Oversampling: 3414
#
# Iteration 5:
# Size before undersampling: 6842
# Stop Undersampling !
# Size before Oversampling: 6842
# Size after Oversampling: 11392
# [I 2022-03-07 14:00:51,809] A new study created in memory with name: no-name-53b37061-faf8-44c7-8a41-d75779f7bd0c
# Precision: 0.0343980343980344
# Recall: 0.15384615384615385
# Aging Rate: 0.16585167074164628
# [I 2022-03-07 14:00:51,718] Trial 0 finished with value: 0.05911974508472712 and parameters: {'n_estimators': 1000, 'learning_rate': 0.225, 'max_depth': 6, 'num_leaves': 70, 'min_child_samples': 50, 'min_split_gain': 12, 'colsample_bytree': 0.3, 'subsample': 0.5, 'reg_alpha': 0.6936351050733729, 'reg_lambda': 0.3217761012893563, 'num_iter': 5, 'over_num': 5, 'over_method': 'ADASYN', 'under_method': 'random'}. Best is trial 0 with value: 0.05911974508472712.
# Sampler is TPESampler
# Dataset 9 :
# C:\Users\user\anaconda3\envs\aging\lib\site-packages\optuna\progress_bar.py:47: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
#   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration 1:
# Size before undersampling: 5928
# Size after Undersampling: 1368
# Size before Oversampling: 1368
# Size after Oversampling: 2298
#
# Iteration 2:
# Size before undersampling: 4040
# Size after Undersampling: 990
# Size before Oversampling: 990
# Size after Oversampling: 1516
#
# Iteration 3:
# Size before undersampling: 2778
# Size after Undersampling: 738
# Size before Oversampling: 738
# Size after Oversampling: 993
#
# Iteration 4:
# Size before undersampling: 1934
# Size after Undersampling: 569
# Size before Oversampling: 569
# Size after Oversampling: 687
#
# Iteration 5:
# Size before undersampling: 1369
# Stop Undersampling !
# Size before Oversampling: 1369
# Size after Oversampling: 2288
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# C:\Users\user\Desktop\Darui_R08621110\Master_Thesis\AUO aging test\Full_Version_Code\library\Aging_Score_Contour.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   eff = r/ag
# Iteration 1:
# Size before undersampling: 5928
# Size after Undersampling: 1368
# Size before Oversampling: 1368
# Size after Oversampling: 2281
#
# Iteration 2:
# Size before undersampling: 4040
# Size after Undersampling: 990
# Size before Oversampling: 990
# Size after Oversampling: 1527
#
# Iteration 3:
# Size before undersampling: 2778
# Size after Undersampling: 738
# Size before Oversampling: 738
# Size after Oversampling: 1001
#
# Iteration 4:
# Size before undersampling: 1934
# Size after Undersampling: 569
# Size before Oversampling: 569
# Size after Oversampling: 697
#
# Iteration 5:
# Size before undersampling: 1369
# Stop Undersampling !
# Size before Oversampling: 1369
# Size after Oversampling: 2294
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# C:\Users\user\Desktop\Darui_R08621110\Master_Thesis\AUO aging test\Full_Version_Code\library\Aging_Score_Contour.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   eff = r/ag
# Iteration 1:
# Size before undersampling: 5928
# Size after Undersampling: 1368
# Size before Oversampling: 1368
# Size after Oversampling: 2294
#
# Iteration 2:
# Size before undersampling: 4040
# Size after Undersampling: 990
# Size before Oversampling: 990
# Size after Oversampling: 1564
#
# Iteration 3:
# Size before undersampling: 2778
# Size after Undersampling: 738
# Size before Oversampling: 738
# Size after Oversampling: 1070
#
# Iteration 4:
# Size before undersampling: 1934
# Size after Undersampling: 569
# Size before Oversampling: 569
# Size after Oversampling: 670
#
# Iteration 5:
# Size before undersampling: 1369
# Stop Undersampling !
# Size before Oversampling: 1369
# Size after Oversampling: 2298
# C:\Users\user\Desktop\Darui_R08621110\Master_Thesis\AUO aging test\Full_Version_Code\library\Aging_Score_Contour.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   eff = r/ag
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# [I 2022-03-07 14:00:53,446] Trial 0 finished with value: 0.0 and parameters: {'n_estimators': 1000, 'learning_rate': 0.225, 'max_depth': 3, 'num_leaves': 90, 'min_child_samples': 5000, 'min_split_gain': 8, 'colsample_bytree': 0.5, 'subsample': 0.3, 'reg_alpha': 0.02313737669987231, 'reg_lambda': 0.09418373336239326, 'num_iter': 5, 'over_num': 5, 'over_method': 'ADASYN', 'under_method': 'random'}. Best is trial 0 with value: 0.0.
# Sampler is TPESampler

# %%
##### optimization history plot #####
optuna_history(best_paramC, all_scoreC, num_row = 3, num_col = 3, model = 'Balance Cascade Classifier')
            
##### best hyperparameter table #####
param_table = pd.DataFrame(best_paramC).T
param_table
# Out:
#      n_estimators learning_rate max_depth num_leaves min_child_samples  \
# set1         1000         0.025         3        130               100
# set2         1000         0.275         3        110                10
# set3          300         0.175        12        110                10
# set4          500         0.025         9        130               500
# set5          500         0.325         9        130              1000
# set6          100         0.175        12        110                10
# set7         1000         0.225        12        130                50
# set8         1000         0.225         6         70                50
# set9         1000         0.225         3         90              5000
#
#      min_split_gain colsample_bytree subsample reg_alpha reg_lambda num_iter  \
# set1              2              0.3       0.3  0.014162    8.65513        5
# set2             12              0.9       0.3  0.257001    0.01111        5
# set3              2              0.3       0.5  0.017099   0.040205        5
# set4              0              0.3       0.7  0.027287   0.355799        5
# set5              2              0.9       0.7  1.119016   4.515336        5
# set6              4              0.7       0.3  1.109521   1.815285        5
# set7              2              0.3       0.7  0.337427   6.896482        5
# set8             12              0.3       0.5  0.693635   0.321776        5
# set9              8              0.5       0.3  0.023137   0.094184        5
#
#      over_num over_method under_method
# set1        5      ADASYN       random
# set2        5      ADASYN       random
# set3        5      ADASYN       random
# set4        5      ADASYN       random
# set5        5      ADASYN       random
# set6        5      ADASYN       random
# set7        5      ADASYN       random
# set8        5      ADASYN       random
# set9        5      ADASYN       random

# %% [markdown]
# ### Classifier

# %% [markdown]
# #### Scheme 1

# %%
table_setC = runall_cascade(run_train, run_test, base_paramC, num_iter = 5)
line_chart(table_setC, title = 'Balance Cascade Classifier Scheme 1 (LightGBM)')

# %%
table_setC

# %% [markdown]
# #### Scheme 2

# %%
table_setC = runall_cascade(run_train, run_test, base_config = base_paramC, meta_config = meta_paramC)
line_chart(table_setC, title = 'Balance Cascade Classifier Scheme 2 (LightGBM)')
# Out:
#  Dataset 1:
#
# Iteration 1:
# Size before undersampling: 40092
# Size after Undersampling: 9252
# Size before Oversampling: 9252
# Size after Oversampling: 15435
#
# Iteration 2:
# Size before undersampling: 27322
# Size after Undersampling: 6698
# Size before Oversampling: 6698
# Size after Oversampling: 10330
#
# Iteration 3:
# Size before undersampling: 18783
# Size after Undersampling: 4990
# Size before Oversampling: 4990
# Size after Oversampling: 6919
#
# Iteration 4:
# Size before undersampling: 13072
# Size after Undersampling: 3848
# Size before Oversampling: 3848
# Size after Oversampling: 4620
#
# Iteration 5:
# Size before undersampling: 9253
# Stop Undersampling !
# Size before Oversampling: 9253
# Size after Oversampling: 15445
# Precision: 0.001349527665317139
# Recall: 0.29411764705882354
# Aging Rate: 0.22847334991469506
#
#  Dataset 2:
#
# Iteration 1:
# Size before undersampling: 39286
# Size after Undersampling: 9066
# Size before Oversampling: 9066
# Size after Oversampling: 15096
#
# Iteration 2:
# Size before undersampling: 26773
# Size after Undersampling: 6563
# Size before Oversampling: 6563
# Size after Oversampling: 10123
#
# Iteration 3:
# Size before undersampling: 18405
# Size after Undersampling: 4889
# Size before Oversampling: 4889
# Size after Oversampling: 6700
#
# Iteration 4:
# Size before undersampling: 12809
# Size after Undersampling: 3770
# Size before Oversampling: 3770
# Size after Oversampling: 4485
#
# Iteration 5:
# Size before undersampling: 9067
# Stop Undersampling !
# Size before Oversampling: 9067
# Size after Oversampling: 15068
# Precision: 0.0009445546424860678
# Recall: 0.19607843137254902
# Aging Rate: 0.2176200949659808
#
#  Dataset 3:
#
# Iteration 1:
# Size before undersampling: 39416
# Size after Undersampling: 9096
# Size before Oversampling: 9096
# Size after Oversampling: 15324
#
# Iteration 2:
# Size before undersampling: 26862
# Size after Undersampling: 6585
# Size before Oversampling: 6585
# Size after Oversampling: 10043
#
# Iteration 3:
# Size before undersampling: 18466
# Size after Undersampling: 4906
# Size before Oversampling: 4906
# Size after Oversampling: 6621
#
# Iteration 4:
# Size before undersampling: 12852
# Size after Undersampling: 3783
# Size before Oversampling: 3783
# Size after Oversampling: 4631
#
# Iteration 5:
# Size before undersampling: 9097
# Stop Undersampling !
# Size before Oversampling: 9097
# Size after Oversampling: 15077
# Precision: 0.001249869805228622
# Recall: 0.23529411764705882
# Aging Rate: 0.19735246356554093
#
#  Dataset 4:
#
# Iteration 1:
# Size before undersampling: 39468
# Size after Undersampling: 9108
# Size before Oversampling: 9108
# Size after Oversampling: 15140
#
# Iteration 2:
# Size before undersampling: 26897
# Size after Undersampling: 6593
# Size before Oversampling: 6593
# Size after Oversampling: 10125
#
# Iteration 3:
# Size before undersampling: 18490
# Size after Undersampling: 4912
# Size before Oversampling: 4912
# Size after Oversampling: 6798
#
# Iteration 4:
# Size before undersampling: 12868
# Size after Undersampling: 3788
# Size before Oversampling: 3788
# Size after Oversampling: 4570
#
# Iteration 5:
# Size before undersampling: 9109
# Stop Undersampling !
# Size before Oversampling: 9109
# Size after Oversampling: 15180
# Precision: 0.0008887673480549668
# Recall: 0.2549019607843137
# Aging Rate: 0.30066393964932475
#
#  Dataset 5:
#
# Iteration 1:
# Size before undersampling: 39517
# Size after Undersampling: 9117
# Size before Oversampling: 9117
# Size after Oversampling: 15253
#
# Iteration 2:
# Size before undersampling: 26917
# Size after Undersampling: 6597
# Size before Oversampling: 6597
# Size after Oversampling: 10122
#
# Iteration 3:
# Size before undersampling: 18495
# Size after Undersampling: 4912
# Size before Oversampling: 4912
# Size after Oversampling: 6813
#
# Iteration 4:
# Size before undersampling: 12866
# Size after Undersampling: 3786
# Size before Oversampling: 3786
# Size after Oversampling: 4567
#
# Iteration 5:
# Size before undersampling: 9103
# Stop Undersampling !
# Size before Oversampling: 9103
# Size after Oversampling: 15151
# Precision: 0.0017205469528207915
# Recall: 0.37254901960784315
# Aging Rate: 0.22699336060350675
#
#  Dataset 6:
#
# Iteration 1:
# Size before undersampling: 39513
# Size after Undersampling: 9113
# Size before Oversampling: 9113
# Size after Oversampling: 15231
#
# Iteration 2:
# Size before undersampling: 26896
# Size after Undersampling: 6589
# Size before Oversampling: 6589
# Size after Oversampling: 10125
#
# Iteration 3:
# Size before undersampling: 18469
# Size after Undersampling: 4904
# Size before Oversampling: 4904
# Size after Oversampling: 6733
#
# Iteration 4:
# Size before undersampling: 12840
# Size after Undersampling: 3778
# Size before Oversampling: 3778
# Size after Oversampling: 4503
#
# Iteration 5:
# Size before undersampling: 9080
# Stop Undersampling !
# Size before Oversampling: 9080
# Size after Oversampling: 15083
# Precision: 0.000979948741142771
# Recall: 0.2549019607843137
# Aging Rate: 0.27268803058644575
#
#  Dataset 7:
#
# Iteration 1:
# Size before undersampling: 39509
# Size after Undersampling: 9109
# Size before Oversampling: 9109
# Size after Oversampling: 15147
#
# Iteration 2:
# Size before undersampling: 26876
# Size after Undersampling: 6582
# Size before Oversampling: 6582
# Size after Oversampling: 10052
#
# Iteration 3:
# Size before undersampling: 18443
# Size after Undersampling: 4895
# Size before Oversampling: 4895
# Size after Oversampling: 6594
#
# Iteration 4:
# Size before undersampling: 12813
# Size after Undersampling: 3769
# Size before Oversampling: 3769
# Size after Oversampling: 4688
#
# Iteration 5:
# Size before undersampling: 9055
# Stop Undersampling !
# Size before Oversampling: 9055
# Size after Oversampling: 15008
# Precision: 0.0010378412901165576
# Recall: 0.2549019607843137
# Aging Rate: 0.25747702933256594
#
#  Dataset 8:
#
# Iteration 1:
# Size before undersampling: 39520
# Size after Undersampling: 9120
# Size before Oversampling: 9120
# Size after Oversampling: 15198
#
# Iteration 2:
# Size before undersampling: 26933
# Size after Undersampling: 6602
# Size before Oversampling: 6602
# Size after Oversampling: 10135
#
# Iteration 3:
# Size before undersampling: 18515
# Size after Undersampling: 4919
# Size before Oversampling: 4919
# Size after Oversampling: 6808
#
# Iteration 4:
# Size before undersampling: 12886
# Size after Undersampling: 3793
# Size before Oversampling: 3793
# Size after Oversampling: 4553
#
# Iteration 5:
# Size before undersampling: 9121
# Stop Undersampling !
# Size before Oversampling: 9121
# Size after Oversampling: 15178
# Precision: 0.001536540862383559
# Recall: 0.3137254901960784
# Aging Rate: 0.21404345413060905
#
#  Dataset 9:
#
# Iteration 1:
# Size before undersampling: 7904
# Size after Undersampling: 1824
# Size before Oversampling: 1824
# Size after Oversampling: 3061
#
# Iteration 2:
# Size before undersampling: 5387
# Size after Undersampling: 1320
# Size before Oversampling: 1320
# Size after Oversampling: 2092
#
# Iteration 3:
# Size before undersampling: 3704
# Size after Undersampling: 984
# Size before Oversampling: 984
# Size after Oversampling: 1400
#
# Iteration 4:
# Size before undersampling: 2578
# Size after Undersampling: 758
# Size before Oversampling: 758
# Size after Oversampling: 891
#
# Iteration 5:
# Size before undersampling: 1825
# Stop Undersampling !
# Size before Oversampling: 1825
# Size after Oversampling: 3050
# Precision: 0
# Recall: 0.0
# Aging Rate: 0.0
# C:\Users\user\Desktop\Darui_R08621110\Master_Thesis\AUO aging test\Full_Version_Code\library\Aging_Score_Contour.py:43: RuntimeWarning: invalid value encountered in double_scalars
#   eff = r/ag

# %%
table_setC
# Out:
#            Balance Ratio  Train_OK  Train_NG    TP       FP    FN       TN  \
# dataset 1      25.000000   38550.0    1542.0  15.0  11100.0  36.0  37498.0
# dataset 2      25.000000   37775.0    1511.0  10.0  10577.0  41.0  38021.0
# dataset 3      25.000000   37900.0    1516.0  12.0   9589.0  39.0  39009.0
# dataset 4      25.000000   37950.0    1518.0  13.0  14614.0  38.0  33984.0
# dataset 5      25.049440   38000.0    1517.0  19.0  11024.0  32.0  37574.0
# dataset 6      25.115664   38000.0    1513.0  13.0  13253.0  38.0  35345.0
# dataset 7      25.182240   38000.0    1509.0  13.0  12513.0  38.0  36085.0
# dataset 8      25.000000   38000.0    1520.0  16.0  10397.0  35.0  38201.0
# dataset 9      25.000000    7600.0     304.0   0.0      0.0  51.0  48598.0
#
#            Precision    Recall  Aging Rate  Efficiency  F1 Score     Score
# dataset 1   0.001350  0.294118    0.228473    1.287317  0.001343  0.243347
# dataset 2   0.000945  0.196078    0.217620    0.901013  0.000940  0.000000
# dataset 3   0.001250  0.235294    0.197352    1.192253  0.001243  0.184689
# dataset 4   0.000889  0.254902    0.300664    0.847797  0.000886  0.000000
# dataset 5   0.001721  0.372549    0.226993    1.641233  0.001713  0.361837
# dataset 6   0.000980  0.254902    0.272688    0.934775  0.000976  0.000000
# dataset 7   0.001038  0.254902    0.257477    0.989999  0.001034  0.000000
# dataset 8   0.001537  0.313725    0.214043    1.465709  0.001529  0.283131
# dataset 9   0.000000  0.000000    0.000000    0.000000  0.000000       NaN

# %% [markdown]
# ### Export

# %%
savedate = '20220308'
TPE_multi = False
scheme = 2

table_setC['sampler'] = 'multivariate-TPE' if TPE_multi else 'univariate-TPE'
table_setC['model'] = f'BC_scheme{scheme}_iter10_over5_rlast'
with pd.ExcelWriter(f'{savedate}_Classifier.xlsx', mode = 'a') as writer:
    table_setC.to_excel(writer, sheet_name = f'BC_scheme{scheme}_iter10_over5_rlast')
