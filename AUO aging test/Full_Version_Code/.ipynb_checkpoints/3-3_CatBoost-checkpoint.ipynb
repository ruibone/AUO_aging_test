# %%
import os
import random
import numpy as np
import pandas as pd
import pickle
from tqdm.auto import tqdm
import matplotlib.pyplot as plt

from catboost import CatBoostClassifier, CatBoostRegressor
import optuna
from sklearn.model_selection import train_test_split
from sklearn.calibration import CalibratedClassifierCV
from scipy.optimize import minimize

from library.Data_Preprocessing import Balance_Ratio
from library.Imbalance_Sampling import label_divide
from library.Aging_Score_Contour import score1
from library.AdaBoost import train_set, multiple_set, multiple_month, line_chart, cf_matrix, AUC, PR_curve, \
     multiple_curve, PR_matrix, best_threshold, all_optuna, optuna_history 

os.chdir('C:/Users/user/Desktop/Darui_R08621110') 
os.getcwd()
# Out:
# 'C:\\Users\\user\\Desktop\\Darui_R08621110'

# %% [markdown]
# ##

# %% [markdown]
# ### CatBoost

# %%
# classifier
def CatBoostC(train_x, test_x, train_y, test_y, config):
    
    clf = CatBoostClassifier(**config, verbose = 0)
    clf.fit(train_x, train_y)
    predict_y = clf.predict(test_x)
    result = pd.DataFrame({'truth': test_y, 'predict': predict_y})
    
    return result


# regressor
def CatBoostR(train_x, test_x, train_y, test_y, config):
    
    reg = CatBoostRegressor(**config, verbose = 0)
    reg.fit(train_x, train_y)
    predict_y = reg.predict(test_x)
    result = pd.DataFrame({'truth': test_y, 'predict': predict_y})

    return result


# classifier for all resampling datasets
def runall_CatBoostC(trainset_x, test_x, trainset_y, test_y, config):
    
    table_set = pd.DataFrame()
    bad_set = pd.DataFrame()
    set_index = list(config.keys())
    judge = set_index[0]

    for i, j in tqdm(enumerate(set_index)):
        print('\n', f'Data{j}:')
        if isinstance(config[judge], dict) :
            best_config = config[j]
        else :
            best_config = config
        
        result = CatBoostC(trainset_x[j], test_x, trainset_y[j], test_y, best_config)
        table = cf_matrix(result, trainset_y[j])
        table_set = pd.concat([table_set, table]).rename(index = {0: f'data{j}'})

    return table_set


# regressor for all resampling datasets
def runall_CatBoostR(num_set, trainset_x, test_x, trainset_y, test_y, config, thres_target = 'Recall', threshold = 0.8):
    
    table_set = pd.DataFrame()
    bad_set = pd.DataFrame()
    pr_dict = {}
    judge = list(config.keys())[0]

    for i in range(num_set):
        print('\n', f'Dataset {i}:')
        
        if isinstance(config[judge], dict) :
            best_config = config[f'set{i}']
        else :
            best_config = config

        predict = CatBoostR(trainset_x[f'set{i}'], test_x, trainset_y[f'set{i}'], test_y, best_config)
        pr_matrix = PR_matrix(predict, trainset_y[f'set{i}'])
        pr_dict[f'set{i}'] = pr_matrix
        
        best_data, best_thres = best_threshold(pr_matrix, target = thres_target, threshold = threshold)
        table_set = pd.concat([table_set, best_data]).rename(index = {best_data.index.values[0]: f'dataset {i}'})

    return pr_dict, table_set

# %% [markdown]
# ### Probability Calibration (optional)

# %%
def beta_map(s, a, b, c):
    return 1 / (1 + 1 / (np.power(np.exp(1), c)*(np.power(s, a) / np.power(1-s, b))))
                

def self_loss(three, test_y, predict_y):
    a, b, c = three
    new_s = beta_map(predict_y, a, b, c)
    loss = np.mean(test_y*np.log(new_s) + (1 - test_y)*np.log(1 - new_s))*(-1)
    return loss


def stratified_data(train_data, cv):
    
    good = train_data[train_data.GB == 0]
    bad = train_data[train_data.GB == 1]
    good_index = random.sample(good.index.to_list(), k = len(good))
    bad_index = random.sample(bad.index.to_list(), k = len(bad))
    
    train_x_dict = {}
    train_y_dict = {}
    valid_x_dict = {}
    valid_y_dict = {}
    for i in range(cv):
        
        if (i+1) == cv:
            good_valid_index = good_index[int(np.floor((i/cv)*len(good))): ]
            bad_valid_index = bad_index[int(np.floor((i/cv)*len(bad))): ]
        else:
            good_valid_index = good_index[int(np.floor((i/cv)*len(good))) : int(np.floor(((i+1)/cv)*len(good)))]
            bad_valid_index = bad_index[int(np.floor((i/cv)*len(bad))) : int(np.floor(((i+1)/cv)*len(bad)))]
        good_train_index = [x for x in good_index if x not in good_valid_index]
        bad_train_index = [x for x in bad_index if x not in bad_valid_index]
        
        good_train = good.loc[good_train_index]
        good_valid = good.loc[good_valid_index]
        bad_train = bad.loc[bad_train_index]
        bad_valid = bad.loc[bad_valid_index]
        train = pd.concat([good_train, bad_train], axis = 0)
        valid = pd.concat([good_valid, bad_valid], axis = 0)
        train_x_dict[i], train_y_dict[i], valid_x_dict[i], valid_y_dict[i] = label_divide(train, valid, train_only = False)

    return train_x_dict, train_y_dict, valid_x_dict, valid_y_dict


def cali_CatBoostC(train_x, train_y, test_x, test_y, config, method):
    
    clf = CatBoostClassifier(**config, silent = True)
    cali_clf = CalibratedClassifierCV(clf, method = method, cv = 5)
    cali_clf.fit(train_x, train_y)
    predict_y = cali_clf.predict_proba(test_x)[:, 1]
    predict = (predict_y > 0.5).astype(int)
    result = pd.DataFrame({'truth': test_y, 'predict': predict})
    
    return result 


def beta_CatBoostC(train_x, train_y, test_x, test_y, config, loss_function = self_loss):
    
    train = pd.concat([train_x, train_y], axis = 1)
    train_x_dict, train_y_dict, valid_x_dict, valid_y_dict = stratified_data(train, cv = 5)
    
    cali_param = {}
    for i in range(len(train_x_dict)):
        clf = CatBoostClassifier(**config, silent = True)
        clf.fit(train_x_dict[i], train_y_dict[i])
        predict_y = clf.predict_proba(valid_x_dict[i])[:, 1]
        mini_result = minimize(loss_function, [0.5, 0.5, 0.5], (valid_y_dict[i], predict_y))
        cali_param[i] = mini_result.x
        
    clf = CatBoostClassifier(**config, silent = True)
    clf.fit(train_x, train_y)
    predict_y = clf.predict_proba(test_x)[:, 1]
    
    cali_predict = np.array(0).astype(float)
    for i in range(len(cali_param)):
        cali_result = beta_map(predict_y, *cali_param[i])
        cali_predict = cali_predict + cali_result
    cali_predict /= len(cali_param)
      
    predict = (cali_predict > 0.5).astype(int)
    result = pd.DataFrame({'truth': test_y, 'predict': predict})

    return result


def all_cali_CatBoostC(trainset_x, trainset_y, test_x, test_y, config_dict, method):
    
    keys = config_dict.keys()
    all_result = pd.DataFrame()
    for i in keys:
        print('\n', f'Data{i}:')
        
        if method in ['isotonic', 'sigmoid']:
            table = cali_CatBoostC(trainset_x[i], trainset_y[i], test_x, test_y, config_dict[i], method)
        elif method == 'beta':
            table = beta_CatBoostC(trainset_x[i], trainset_y[i], test_x, test_y, config_dict[i])
        result_df = cf_matrix(table, trainset_y[i])
        all_result = pd.concat([all_result, result_df], axis = 0).rename(index = {0: f'data{i}'})
        
    return all_result

# %% [markdown]
# ### Optuna

# %%
# creator of optuna study for CatBoost
def CatBoost_creator(train_data, mode, num_valid = 5, label = 'GB') :

    def objective(trial) :
    
        param_1 = {
            'grow_policy': trial.suggest_categorical('grow_policy', ['SymmetricTree', 'Depthwise', 'Lossguide']),
            'iterations': trial.suggest_categorical('iterations', [100, 300, 500]),
            'depth': trial.suggest_int('depth', 2, 12, step = 2),
            'learning_rate': trial.suggest_float('learning_rate', 0.025, 0.325, step = 0.05),
            'subsample': trial.suggest_float('subsample', 0.3, 0.9, step = 0.2),
            'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-2, 10) 
        }

        if param_1['grow_policy'] == 'Depthwise' :
            param_2 = {
                'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 5, 60, step = 5)
            }
            param = {**param_1, **param_2}
        
        elif param_1['grow_policy'] == 'Lossguide' :
            param_3 = {
                'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 5, 60, step = 5),
                'max_leaves': trial.suggest_int('max_leaves', 10, 50, step = 5)
            }
            param = {**param_1, **param_3}
        
        else :
            param = param_1

        result_list = []
        for i in range(num_valid):

            train_good = train_data[train_data.GB == 0]
            train_bad = train_data[train_data.GB == 1]
            train_good_x, train_good_y = label_divide(train_good, None, label, train_only = True)
            train_bad_x, train_bad_y = label_divide(train_bad, None, label, train_only = True)
            train_g_x, valid_g_x, train_g_y, valid_g_y = train_test_split(train_good_x, train_good_y, test_size = 0.25)
            train_b_x, valid_b_x, train_b_y, valid_b_y = train_test_split(train_bad_x, train_bad_y, test_size = 0.25)
            train_x = pd.concat([train_g_x, train_b_x], axis = 0)
            train_y = pd.concat([train_g_y, train_b_y], axis = 0)
            valid_x = pd.concat([valid_g_x, valid_b_x], axis = 0)
            valid_y = pd.concat([valid_g_y, valid_b_y], axis = 0)

            if mode == 'C':
                result = CatBoostC(train_x, valid_x, train_y, valid_y, param)
                table = cf_matrix(result, valid_y)
                recall = table['Recall']
                precision = table['Precision']
                beta = 1
                if recall.values > 0:
                    fscore = ((1+beta**2)*recall*precision) / (recall+(beta**2)*precision) 
                else:
                    fscore = 0
                result_list.append(fscore)

            elif mode == 'R':
                result = CatBoostR(train_x, valid_x, train_y, valid_y, param)
                pr_matrix = PR_matrix(result, valid_y)
                auc = AUC(pr_matrix['Recall'], pr_matrix['Aging Rate'])
                result_list.append((-1)*auc)

        return np.mean(result_list)

    return objective

# %% [markdown]
# ##

# %% [markdown]
# ### Load Data

# %%
### training data ### 
training_month = range(2, 5)

data_dict, trainset_x, trainset_y = multiple_month(training_month, num_set = 10, filename = 'dataset')

print('\nCombined training data:\n')
run_train = multiple_set(num_set = 10)
run_train_x, run_train_y = train_set(run_train, num_set = 10)

### testing data ###
run_test = pd.read_csv('test_runhist.csv').iloc[:, 2:]
run_test_x, run_test_y = label_divide(run_test, None, 'GB', train_only = True)
print('\n', 'Dimension of testing data:', run_test.shape)
# Out:
# Month 2:
#
# Dimension of dataset 0 : (39009, 88)  balance ratio: 564.35
# Dimension of dataset 1 : (1404, 88)  balance ratio: 1.0
# Dimension of dataset 2 : (1368, 88)  balance ratio: 1.0
# Dimension of dataset 3 : (1376, 88)  balance ratio: 1.0
# Dimension of dataset 4 : (1378, 88)  balance ratio: 1.0
# Dimension of dataset 5 : (1370, 88)  balance ratio: 1.01
# Dimension of dataset 6 : (1369, 88)  balance ratio: 1.02
# Dimension of dataset 7 : (1317, 88)  balance ratio: 1.1
# Dimension of dataset 8 : (1380, 88)  balance ratio: 1.0
# Dimension of dataset 9 : (759, 88)  balance ratio: 10.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
# Month 3:
#
# Dimension of dataset 0 : (60396, 97)  balance ratio: 533.48
# Dimension of dataset 1 : (2304, 97)  balance ratio: 1.0
# Dimension of dataset 2 : (2226, 97)  balance ratio: 1.0
# Dimension of dataset 3 : (2256, 97)  balance ratio: 1.0
# Dimension of dataset 4 : (2258, 97)  balance ratio: 1.0
# Dimension of dataset 5 : (2271, 97)  balance ratio: 0.99
# Dimension of dataset 6 : (2243, 97)  balance ratio: 1.02
# Dimension of dataset 7 : (2158, 97)  balance ratio: 1.1
# Dimension of dataset 8 : (2260, 97)  balance ratio: 1.0
# Dimension of dataset 9 : (1243, 97)  balance ratio: 10.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
# Month 4:
#
# Dimension of dataset 0 : (57743, 100)  balance ratio: 472.3
# Dimension of dataset 1 : (2426, 100)  balance ratio: 1.0
# Dimension of dataset 2 : (2404, 100)  balance ratio: 1.0
# Dimension of dataset 3 : (2434, 100)  balance ratio: 1.0
# Dimension of dataset 4 : (2440, 100)  balance ratio: 1.0
# Dimension of dataset 5 : (2419, 100)  balance ratio: 1.02
# Dimension of dataset 6 : (2425, 100)  balance ratio: 1.01
# Dimension of dataset 7 : (2330, 100)  balance ratio: 1.1
# Dimension of dataset 8 : (2440, 100)  balance ratio: 1.0
# Dimension of dataset 9 : (1342, 100)  balance ratio: 10.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
# Combined training data:
#
# Dimension of dataset 0 : (157148, 128)  balance ratio: 515.93
# Dimension of dataset 1 : (6134, 128)  balance ratio: 1.0
# Dimension of dataset 2 : (5998, 128)  balance ratio: 1.0
# Dimension of dataset 3 : (6066, 128)  balance ratio: 1.0
# Dimension of dataset 4 : (6076, 128)  balance ratio: 1.0
# Dimension of dataset 5 : (6060, 128)  balance ratio: 1.01
# Dimension of dataset 6 : (6037, 128)  balance ratio: 1.01
# Dimension of dataset 7 : (5805, 128)  balance ratio: 1.1
# Dimension of dataset 8 : (6080, 128)  balance ratio: 1.0
# Dimension of dataset 9 : (3344, 128)  balance ratio: 10.0
#
#  10 datasets are loaded.
#
# Labels of  10 datasets are divided.
#
#  Dimension of testing data: (48649, 128)

# %% [markdown]
# ### Search for Best Hyperparameters

# %%
best_paramC, all_scoreC = all_optuna(all_data = run_train, 
                                     mode = 'C', 
                                     TPE_multi = False, 
                                     n_iter = 100, 
                                     filename = 'runhist_array_m2m4_m5_3criteria_CatBoost_6', 
                                     creator = CatBoost_creator
                                    )
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# [I 2022-03-04 19:00:05,326] A new study created in memory with name: no-name-f6a08fb8-f261-4263-aa44-660d09bde54e
# Dataset 1 :
# C:\Users\user\anaconda3\envs\aging\lib\site-packages\optuna\progress_bar.py:47: ExperimentalWarning: Progress bar is experimental (supported from v1.2.0). The interface can change in the future.
#   self._init_valid()
#   0%|          | 0/100 [00:00<?, ?it/s]
# Precision: 0.9895697522816167
# Recall: 0.9895697522816167
# Aging Rate: 0.5
# Precision: 0.9973787680209698
# Recall: 0.9921773142112125
# Aging Rate: 0.4973924380704042
# Precision: 0.9883720930232558
# Recall: 0.9973924380704041
# Aging Rate: 0.5045632333767927
# [I 2022-03-04 19:00:07,613] Trial 0 finished with value: 0.9924009240592909 and parameters: {'grow_policy': 'Lossguide', 'iterations': 300, 'depth': 4, 'learning_rate': 0.17500000000000002, 'subsample': 0.9, 'l2_leaf_reg': 0.08736869071966823, 'min_data_in_leaf': 20, 'max_leaves': 50}. Best is trial 0 with value: 0.9924009240592909.
# Precision: 0.9934810951760105
# Recall: 0.9934810951760105
# Aging Rate: 0.5
# Precision: 0.9896103896103896
# Recall: 0.9934810951760105
# Aging Rate: 0.5019556714471969
# Precision: 0.9870298313878081
# Recall: 0.9921773142112125
# Aging Rate: 0.5026075619295959
# [I 2022-03-04 19:00:10,036] Trial 1 finished with value: 0.9915399797021177 and parameters: {'grow_policy': 'Lossguide', 'iterations': 300, 'depth': 6, 'learning_rate': 0.125, 'subsample': 0.5, 'l2_leaf_reg': 0.9130398439191354, 'min_data_in_leaf': 45, 'max_leaves': 15}. Best is trial 0 with value: 0.9924009240592909.
# Precision: 0.9895697522816167
# Recall: 0.9895697522816167
# Aging Rate: 0.5
# Precision: 0.9857697283311773
# Recall: 0.9934810951760105
# Aging Rate: 0.5039113428943938
# Precision: 0.9973787680209698
# Recall: 0.9921773142112125
# Aging Rate: 0.4973924380704042
# [I 2022-03-04 19:00:14,224] Trial 2 finished with value: 0.9913171279073572 and parameters: {'grow_policy': 'Depthwise', 'iterations': 500, 'depth': 10, 'learning_rate': 0.125, 'subsample': 0.7, 'l2_leaf_reg': 0.027591545646027147, 'min_data_in_leaf': 60}. Best is trial 0 with value: 0.9924009240592909.
# Precision: 0.9973579920739762
# Recall: 0.984354628422425
# Aging Rate: 0.4934810951760104
# Precision: 0.9908616187989556
# Recall: 0.9895697522816167
# Aging Rate: 0.49934810951760106
# Precision: 0.984516129032258
# Recall: 0.9947848761408083
# Aging Rate: 0.5052151238591917
# [I 2022-03-04 19:00:15,649] Trial 3 finished with value: 0.9902175925306923 and parameters: {'grow_policy': 'Lossguide', 'iterations': 100, 'depth': 10, 'learning_rate': 0.225, 'subsample': 0.5, 'l2_leaf_reg': 1.563152315932752, 'min_data_in_leaf': 50, 'max_leaves': 40}. Best is trial 0 with value: 0.9924009240592909.
# Precision: 0.9133425034387895
# Recall: 0.8657105606258149
# Aging Rate: 0.47392438070404175
# Precision: 0.8974358974358975
# Recall: 0.8670143415906127
# Aging Rate: 0.4830508474576271
# Precision: 0.8925619834710744
# Recall: 0.8448500651890483
# Aging Rate: 0.47327249022164275
# [I 2022-03-04 19:00:16,980] Trial 4 finished with value: 0.8796342192766886 and parameters: {'grow_policy': 'Depthwise', 'iterations': 300, 'depth': 2, 'learning_rate': 0.025, 'subsample': 0.3, 'l2_leaf_reg': 3.8936234805552474, 'min_data_in_leaf': 45}. Best is trial 0 with value: 0.9924009240592909.
# Precision: 0.9921875
# Recall: 0.9934810951760105
# Aging Rate: 0.500651890482399
# Precision: 0.9921671018276762
# Recall: 0.9908735332464146
# Aging Rate: 0.49934810951760106
# Precision: 0.9883268482490273
# Recall: 0.9934810951760105
# Aging Rate: 0.5026075619295959
# [I 2022-03-04 19:00:20,745] Trial 5 finished with value: 0.9917503470105791 and parameters: {'grow_policy': 'Depthwise', 'iterations': 500, 'depth': 10, 'learning_rate': 0.225, 'subsample': 0.3, 'l2_leaf_reg': 4.823774736669112, 'min_data_in_leaf': 60}. Best is trial 0 with value: 0.9924009240592909.
# Precision: 0.9921773142112125
# Recall: 0.9921773142112125
# Aging Rate: 0.5
# Precision: 0.9934810951760105
# Recall: 0.9934810951760105
# Aging Rate: 0.5
# Precision: 0.9960681520314548
# Recall: 0.9908735332464146
# Aging Rate: 0.4973924380704042
# [I 2022-03-04 19:00:24,912] Trial 6 finished with value: 0.9930408205582681 and parameters: {'grow_policy': 'Depthwise', 'iterations': 500, 'depth': 10, 'learning_rate': 0.07500000000000001, 'subsample': 0.3, 'l2_leaf_reg': 0.513442403411607, 'min_data_in_leaf': 50}. Best is trial 6 with value: 0.9930408205582681.
# Precision: 0.9726918075422627
# Recall: 0.9752281616688396
# Aging Rate: 0.5013037809647979
# Precision: 0.9725130890052356
# Recall: 0.9687092568448501
# Aging Rate: 0.4980443285528031
# Precision: 0.9712041884816754
# Recall: 0.9674054758800521
# Aging Rate: 0.4980443285528031
# [I 2022-03-04 19:00:26,229] Trial 7 finished with value: 0.9712889632774512 and parameters: {'grow_policy': 'SymmetricTree', 'iterations': 300, 'depth': 2, 'learning_rate': 0.225, 'subsample': 0.3, 'l2_leaf_reg': 4.1630273237238775}. Best is trial 6 with value: 0.9930408205582681.
# Precision: 0.9908376963350786
# Recall: 0.9869621903520208
# Aging Rate: 0.4980443285528031
# Precision: 0.9870801033591732
# Recall: 0.9960886571056062
# Aging Rate: 0.5045632333767927
# Precision: 0.990909090909091
# Recall: 0.9947848761408083
# Aging Rate: 0.5019556714471969
# [I 2022-03-04 19:00:32,758] Trial 8 finished with value: 0.9911010889611204 and parameters: {'grow_policy': 'SymmetricTree', 'iterations': 300, 'depth': 6, 'learning_rate': 0.07500000000000001, 'subsample': 0.9, 'l2_leaf_reg': 8.16324588782188}. Best is trial 6 with value: 0.9930408205582681.
# Precision: 0.9858064516129033
# Recall: 0.9960886571056062
# Aging Rate: 0.5052151238591917
# Precision: 0.9908972691807543
# Recall: 0.9934810951760105
# Aging Rate: 0.5013037809647979
# Precision: 0.9869621903520208
# Recall: 0.9869621903520208
# Aging Rate: 0.5
# [I 2022-03-04 19:00:33,727] Trial 9 finished with value: 0.9900235241078289 and parameters: {'grow_policy': 'SymmetricTree', 'iterations': 100, 'depth': 4, 'learning_rate': 0.325, 'subsample': 0.5, 'l2_leaf_reg': 0.19824212400169275}. Best is trial 6 with value: 0.9930408205582681.
# Precision: 0.997364953886693
# Recall: 0.9869621903520208
# Aging Rate: 0.49478487614080835
# Precision: 0.9921773142112125
# Recall: 0.9921773142112125
# Aging Rate: 0.5
# Precision: 0.9934383202099738
# Recall: 0.9869621903520208
# Aging Rate: 0.49674054758800523
# [I 2022-03-04 19:00:41,645] Trial 10 finished with value: 0.9915010949075937 and parameters: {'grow_policy': 'Depthwise', 'iterations': 500, 'depth': 12, 'learning_rate': 0.025, 'subsample': 0.7, 'l2_leaf_reg': 0.010563217248504687, 'min_data_in_leaf': 25}. Best is trial 6 with value: 0.9930408205582681.
# Precision: 0.9922077922077922
# Recall: 0.9960886571056062
# Aging Rate: 0.5019556714471969
# Precision: 0.9947780678851175
# Recall: 0.9934810951760105
# Aging Rate: 0.49934810951760106
# Precision: 0.9921773142112125
# Recall: 0.9921773142112125
# Aging Rate: 0.5
# [I 2022-03-04 19:00:48,261] Trial 11 finished with value: 0.9934836366464291 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.125, 'subsample': 0.9, 'l2_leaf_reg': 0.10291764796403086, 'min_data_in_leaf': 5, 'max_leaves': 50}. Best is trial 11 with value: 0.9934836366464291.
# Precision: 0.9973787680209698
# Recall: 0.9921773142112125
# Aging Rate: 0.4973924380704042
# Precision: 0.9908854166666666
# Recall: 0.9921773142112125
# Aging Rate: 0.500651890482399
# Precision: 0.9947848761408083
# Recall: 0.9947848761408083
# Aging Rate: 0.5
# [I 2022-03-04 19:00:53,854] Trial 12 finished with value: 0.9936956875320937 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.07500000000000001, 'subsample': 0.9, 'l2_leaf_reg': 0.38439911031035706, 'min_data_in_leaf': 5, 'max_leaves': 25}. Best is trial 12 with value: 0.9936956875320937.
# Precision: 0.9947575360419397
# Recall: 0.9895697522816167
# Aging Rate: 0.4973924380704042
# Precision: 0.9973718791064389
# Recall: 0.9895697522816167
# Aging Rate: 0.49608865710560623
# Precision: 0.9883116883116884
# Recall: 0.9921773142112125
# Aging Rate: 0.5019556714471969
# [I 2022-03-04 19:00:58,845] Trial 13 finished with value: 0.9919510296065183 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.125, 'subsample': 0.9, 'l2_leaf_reg': 0.08908085926350146, 'min_data_in_leaf': 5, 'max_leaves': 20}. Best is trial 12 with value: 0.9936956875320937.
# Precision: 0.9883268482490273
# Recall: 0.9934810951760105
# Aging Rate: 0.5026075619295959
# Precision: 0.9934810951760105
# Recall: 0.9934810951760105
# Aging Rate: 0.5
# Precision: 0.9921976592977894
# Recall: 0.9947848761408083
# Aging Rate: 0.5013037809647979
# [I 2022-03-04 19:01:04,715] Trial 14 finished with value: 0.9926226492300327 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.07500000000000001, 'subsample': 0.7, 'l2_leaf_reg': 0.1908946958617389, 'min_data_in_leaf': 5, 'max_leaves': 30}. Best is trial 12 with value: 0.9936956875320937.
# Precision: 0.9947916666666666
# Recall: 0.9960886571056062
# Aging Rate: 0.500651890482399
# Precision: 0.9857881136950905
# Recall: 0.9947848761408083
# Aging Rate: 0.5045632333767927
# Precision: 0.990909090909091
# Recall: 0.9947848761408083
# Aging Rate: 0.5019556714471969
# [I 2022-03-04 19:01:10,551] Trial 15 finished with value: 0.9928496671513402 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.17500000000000002, 'subsample': 0.9, 'l2_leaf_reg': 0.02884382802067728, 'min_data_in_leaf': 15, 'max_leaves': 30}. Best is trial 12 with value: 0.9936956875320937.
# Precision: 0.9934725848563969
# Recall: 0.9921773142112125
# Aging Rate: 0.49934810951760106
# Precision: 0.9895561357702349
# Recall: 0.9882659713168188
# Aging Rate: 0.49934810951760106
# Precision: 0.9908972691807543
# Recall: 0.9934810951760105
# Aging Rate: 0.5013037809647979
# [I 2022-03-04 19:01:20,081] Trial 16 finished with value: 0.9913075532724506 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 12, 'learning_rate': 0.025, 'subsample': 0.9, 'l2_leaf_reg': 0.07758492106131624, 'min_data_in_leaf': 10, 'max_leaves': 50}. Best is trial 12 with value: 0.9936956875320937.
# Precision: 0.9921976592977894
# Recall: 0.9947848761408083
# Aging Rate: 0.5013037809647979
# Precision: 0.9921671018276762
# Recall: 0.9908735332464146
# Aging Rate: 0.49934810951760106
# Precision: 0.9831387808041504
# Recall: 0.9882659713168188
# Aging Rate: 0.5026075619295959
# [I 2022-03-04 19:01:21,133] Trial 17 finished with value: 0.9902350625584773 and parameters: {'grow_policy': 'Lossguide', 'iterations': 100, 'depth': 6, 'learning_rate': 0.325, 'subsample': 0.7, 'l2_leaf_reg': 0.47616476680521436, 'min_data_in_leaf': 35, 'max_leaves': 25}. Best is trial 12 with value: 0.9936956875320937.
# Precision: 0.996078431372549
# Recall: 0.9934810951760105
# Aging Rate: 0.49869621903520206
# Precision: 0.993455497382199
# Recall: 0.9895697522816167
# Aging Rate: 0.4980443285528031
# Precision: 0.9934980494148244
# Recall: 0.9960886571056062
# Aging Rate: 0.5013037809647979
# [I 2022-03-04 19:01:27,932] Trial 18 finished with value: 0.99369285077265 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.07500000000000001, 'subsample': 0.9, 'l2_leaf_reg': 0.23079492041698807, 'min_data_in_leaf': 5, 'max_leaves': 40}. Best is trial 12 with value: 0.9936956875320937.
# Precision: 0.9844961240310077
# Recall: 0.9934810951760105
# Aging Rate: 0.5045632333767927
# Precision: 0.9883116883116884
# Recall: 0.9921773142112125
# Aging Rate: 0.5019556714471969
# Precision: 0.9960732984293194
# Recall: 0.9921773142112125
# Aging Rate: 0.4980443285528031
# [I 2022-03-04 19:01:31,211] Trial 19 finished with value: 0.9911101401269731 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 4, 'learning_rate': 0.07500000000000001, 'subsample': 0.7, 'l2_leaf_reg': 1.551843260579743, 'min_data_in_leaf': 30, 'max_leaves': 40}. Best is trial 12 with value: 0.9936956875320937.
# Precision: 0.9960681520314548
# Recall: 0.9908735332464146
# Aging Rate: 0.4973924380704042
# Precision: 0.9947643979057592
# Recall: 0.9908735332464146
# Aging Rate: 0.4980443285528031
# Precision: 0.9960835509138382
# Recall: 0.9947848761408083
# Aging Rate: 0.49934810951760106
# [I 2022-03-04 19:01:37,480] Trial 20 finished with value: 0.9939043319121225 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 6, 'learning_rate': 0.025, 'subsample': 0.9, 'l2_leaf_reg': 0.269346310024769, 'min_data_in_leaf': 15, 'max_leaves': 40}. Best is trial 20 with value: 0.9939043319121225.
# Precision: 0.9883268482490273
# Recall: 0.9934810951760105
# Aging Rate: 0.5026075619295959
# Precision: 0.9908854166666666
# Recall: 0.9921773142112125
# Aging Rate: 0.500651890482399
# Precision: 0.9986754966887417
# Recall: 0.9830508474576272
# Aging Rate: 0.4921773142112125
# [I 2022-03-04 19:01:43,679] Trial 21 finished with value: 0.9910765968928992 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 6, 'learning_rate': 0.025, 'subsample': 0.9, 'l2_leaf_reg': 0.2883663306642239, 'min_data_in_leaf': 15, 'max_leaves': 40}. Best is trial 20 with value: 0.9939043319121225.
# Precision: 0.9883419689119171
# Recall: 0.9947848761408083
# Aging Rate: 0.5032594524119948
# Precision: 0.9909326424870466
# Recall: 0.9973924380704041
# Aging Rate: 0.5032594524119948
# Precision: 0.9934895833333334
# Recall: 0.9947848761408083
# Aging Rate: 0.500651890482399
# [I 2022-03-04 19:01:49,303] Trial 22 finished with value: 0.9932806036888175 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.07500000000000001, 'subsample': 0.9, 'l2_leaf_reg': 0.7776706861736206, 'min_data_in_leaf': 10, 'max_leaves': 35}. Best is trial 20 with value: 0.9939043319121225.
# Precision: 0.9908972691807543
# Recall: 0.9934810951760105
# Aging Rate: 0.5013037809647979
# Precision: 0.9896103896103896
# Recall: 0.9934810951760105
# Aging Rate: 0.5019556714471969
# Precision: 0.988296488946684
# Recall: 0.9908735332464146
# Aging Rate: 0.5013037809647979
# [I 2022-03-04 19:01:55,347] Trial 23 finished with value: 0.9911042660666523 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 6, 'learning_rate': 0.025, 'subsample': 0.9, 'l2_leaf_reg': 0.18075232337658095, 'min_data_in_leaf': 15, 'max_leaves': 35}. Best is trial 20 with value: 0.9939043319121225.
# Precision: 0.9934383202099738
# Recall: 0.9869621903520208
# Aging Rate: 0.49674054758800523
# Precision: 0.9908616187989556
# Recall: 0.9895697522816167
# Aging Rate: 0.49934810951760106
# Precision: 0.9908854166666666
# Recall: 0.9921773142112125
# Aging Rate: 0.500651890482399
# [I 2022-03-04 19:02:01,894] Trial 24 finished with value: 0.9906452917539778 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.07500000000000001, 'subsample': 0.7, 'l2_leaf_reg': 0.3861539845900162, 'min_data_in_leaf': 5, 'max_leaves': 45}. Best is trial 20 with value: 0.9939043319121225.
# Precision: 0.9909208819714657
# Recall: 0.9960886571056062
# Aging Rate: 0.5026075619295959
# Precision: 0.9895968790637191
# Recall: 0.9921773142112125
# Aging Rate: 0.5013037809647979
# Precision: 0.9908735332464146
# Recall: 0.9908735332464146
# Aging Rate: 0.5
# [I 2022-03-04 19:02:05,587] Trial 25 finished with value: 0.9917523331093019 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 4, 'learning_rate': 0.025, 'subsample': 0.9, 'l2_leaf_reg': 0.03425458480038014, 'min_data_in_leaf': 10, 'max_leaves': 25}. Best is trial 20 with value: 0.9939043319121225.
# Precision: 0.9908854166666666
# Recall: 0.9921773142112125
# Aging Rate: 0.500651890482399
# Precision: 0.9934810951760105
# Recall: 0.9934810951760105
# Aging Rate: 0.5
# Precision: 0.9896103896103896
# Recall: 0.9934810951760105
# Aging Rate: 0.5019556714471969
# [I 2022-03-04 19:02:09,143] Trial 26 finished with value: 0.9921846682226803 and parameters: {'grow_policy': 'SymmetricTree', 'iterations': 100, 'depth': 10, 'learning_rate': 0.125, 'subsample': 0.7, 'l2_leaf_reg': 0.9068533902779788}. Best is trial 20 with value: 0.9939043319121225.
# Precision: 0.9895968790637191
# Recall: 0.9921773142112125
# Aging Rate: 0.5013037809647979
# Precision: 0.990909090909091
# Recall: 0.9947848761408083
# Aging Rate: 0.5019556714471969
# Precision: 0.9921773142112125
# Recall: 0.9921773142112125
# Aging Rate: 0.5
# [I 2022-03-04 19:02:12,861] Trial 27 finished with value: 0.9919686439729561 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 6, 'learning_rate': 0.07500000000000001, 'subsample': 0.9, 'l2_leaf_reg': 0.28311185596909033, 'min_data_in_leaf': 20, 'max_leaves': 10}. Best is trial 20 with value: 0.9939043319121225.
# Precision: 0.98828125
# Recall: 0.9895697522816167
# Aging Rate: 0.500651890482399
# Precision: 0.9921773142112125
# Recall: 0.9921773142112125
# Aging Rate: 0.5
# Precision: 0.9908735332464146
# Recall: 0.9908735332464146
# Aging Rate: 0.5
# [I 2022-03-04 19:02:19,513] Trial 28 finished with value: 0.9906586429636173 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.025, 'subsample': 0.9, 'l2_leaf_reg': 1.8359211523347674, 'min_data_in_leaf': 20, 'max_leaves': 35}. Best is trial 20 with value: 0.9939043319121225.
# Precision: 0.987012987012987
# Recall: 0.9908735332464146
# Aging Rate: 0.5019556714471969
# Precision: 0.9934383202099738
# Recall: 0.9869621903520208
# Aging Rate: 0.49674054758800523
# Precision: 0.9947643979057592
# Recall: 0.9908735332464146
# Aging Rate: 0.4980443285528031
# [I 2022-03-04 19:02:22,620] Trial 29 finished with value: 0.9906481041536664 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 4, 'learning_rate': 0.17500000000000002, 'subsample': 0.9, 'l2_leaf_reg': 0.05737506023723328, 'min_data_in_leaf': 10, 'max_leaves': 45}. Best is trial 20 with value: 0.9939043319121225.
# Precision: 0.9921875
# Recall: 0.9934810951760105
# Aging Rate: 0.500651890482399
# Precision: 0.9921976592977894
# Recall: 0.9947848761408083
# Aging Rate: 0.5013037809647979
# Precision: 0.9947712418300654
# Recall: 0.9921773142112125
# Aging Rate: 0.49869621903520206
# [I 2022-03-04 19:02:26,417] Trial 30 finished with value: 0.9932653481370762 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 6, 'learning_rate': 0.17500000000000002, 'subsample': 0.7, 'l2_leaf_reg': 0.12744784993289382, 'min_data_in_leaf': 30, 'max_leaves': 25}. Best is trial 20 with value: 0.9939043319121225.
# Precision: 0.9921976592977894
# Recall: 0.9947848761408083
# Aging Rate: 0.5013037809647979
# Precision: 0.9934810951760105
# Recall: 0.9934810951760105
# Aging Rate: 0.5
# Precision: 0.9934640522875817
# Recall: 0.9908735332464146
# Aging Rate: 0.49869621903520206
# [I 2022-03-04 19:02:32,278] Trial 31 finished with value: 0.9930459267790067 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.125, 'subsample': 0.9, 'l2_leaf_reg': 0.09332515297694814, 'min_data_in_leaf': 5, 'max_leaves': 45}. Best is trial 20 with value: 0.9939043319121225.
# Precision: 0.9921875
# Recall: 0.9934810951760105
# Aging Rate: 0.500651890482399
# Precision: 0.9960835509138382
# Recall: 0.9947848761408083
# Aging Rate: 0.49934810951760106
# Precision: 0.9960886571056062
# Recall: 0.9960886571056062
# Aging Rate: 0.5
# [I 2022-03-04 19:02:38,362] Trial 32 finished with value: 0.9947854410938142 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.125, 'subsample': 0.9, 'l2_leaf_reg': 0.1408281705134894, 'min_data_in_leaf': 5, 'max_leaves': 50}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9921773142112125
# Recall: 0.9921773142112125
# Aging Rate: 0.5
# Precision: 0.9895833333333334
# Recall: 0.9908735332464146
# Aging Rate: 0.500651890482399
# Precision: 0.9869960988296489
# Recall: 0.9895697522816167
# Aging Rate: 0.5013037809647979
# [I 2022-03-04 19:02:43,396] Trial 33 finished with value: 0.9902288590801761 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 10, 'learning_rate': 0.125, 'subsample': 0.9, 'l2_leaf_reg': 0.049187756182341814, 'min_data_in_leaf': 10, 'max_leaves': 20}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.993455497382199
# Recall: 0.9895697522816167
# Aging Rate: 0.4980443285528031
# Precision: 0.9960835509138382
# Recall: 0.9947848761408083
# Aging Rate: 0.49934810951760106
# Precision: 0.9921052631578947
# Recall: 0.9830508474576272
# Aging Rate: 0.4954367666232073
# [I 2022-03-04 19:02:47,906] Trial 34 finished with value: 0.9914999698732174 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 6, 'learning_rate': 0.07500000000000001, 'subsample': 0.9, 'l2_leaf_reg': 0.6341647244770069, 'min_data_in_leaf': 15, 'max_leaves': 45}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.989501312335958
# Recall: 0.9830508474576272
# Aging Rate: 0.49674054758800523
# Precision: 0.9921976592977894
# Recall: 0.9947848761408083
# Aging Rate: 0.5013037809647979
# Precision: 0.9934640522875817
# Recall: 0.9908735332464146
# Aging Rate: 0.49869621903520206
# [I 2022-03-04 19:02:52,387] Trial 35 finished with value: 0.9906407393963775 and parameters: {'grow_policy': 'Lossguide', 'iterations': 300, 'depth': 10, 'learning_rate': 0.125, 'subsample': 0.9, 'l2_leaf_reg': 0.13866008932852678, 'min_data_in_leaf': 5, 'max_leaves': 35}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9895968790637191
# Recall: 0.9921773142112125
# Aging Rate: 0.5013037809647979
# Precision: 0.9947643979057592
# Recall: 0.9908735332464146
# Aging Rate: 0.4980443285528031
# Precision: 0.9896238651102465
# Recall: 0.9947848761408083
# Aging Rate: 0.5026075619295959
# [I 2022-03-04 19:02:58,035] Trial 36 finished with value: 0.9919660764863014 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.07500000000000001, 'subsample': 0.7, 'l2_leaf_reg': 0.26342651067180256, 'min_data_in_leaf': 25, 'max_leaves': 40}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9973890339425587
# Recall: 0.9960886571056062
# Aging Rate: 0.49934810951760106
# Precision: 0.9921363040629095
# Recall: 0.9869621903520208
# Aging Rate: 0.4973924380704042
# Precision: 0.9934895833333334
# Recall: 0.9947848761408083
# Aging Rate: 0.500651890482399
# [I 2022-03-04 19:02:59,844] Trial 37 finished with value: 0.9934725709578919 and parameters: {'grow_policy': 'Depthwise', 'iterations': 100, 'depth': 10, 'learning_rate': 0.125, 'subsample': 0.9, 'l2_leaf_reg': 0.3881800860409194, 'min_data_in_leaf': 10}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9947368421052631
# Recall: 0.9856584093872229
# Aging Rate: 0.4954367666232073
# Precision: 0.9986928104575163
# Recall: 0.9960886571056062
# Aging Rate: 0.49869621903520206
# Precision: 0.99609375
# Recall: 0.9973924380704041
# Aging Rate: 0.500651890482399
# [I 2022-03-04 19:03:05,358] Trial 38 finished with value: 0.9947695074137108 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 6, 'learning_rate': 0.025, 'subsample': 0.5, 'l2_leaf_reg': 0.017256919150292177, 'min_data_in_leaf': 15, 'max_leaves': 30}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9921156373193167
# Recall: 0.984354628422425
# Aging Rate: 0.49608865710560623
# Precision: 0.987012987012987
# Recall: 0.9908735332464146
# Aging Rate: 0.5019556714471969
# Precision: 0.9921773142112125
# Recall: 0.9921773142112125
# Aging Rate: 0.5
# [I 2022-03-04 19:03:11,914] Trial 39 finished with value: 0.9897789006723542 and parameters: {'grow_policy': 'SymmetricTree', 'iterations': 300, 'depth': 6, 'learning_rate': 0.025, 'subsample': 0.5, 'l2_leaf_reg': 0.010951076521909558}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.920410783055199
# Recall: 0.9348109517601043
# Aging Rate: 0.5078226857887875
# Precision: 0.9337837837837838
# Recall: 0.9009126466753585
# Aging Rate: 0.48239895697522817
# Precision: 0.9169960474308301
# Recall: 0.9074315514993481
# Aging Rate: 0.49478487614080835
# [I 2022-03-04 19:03:14,202] Trial 40 finished with value: 0.9189324861560374 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 2, 'learning_rate': 0.025, 'subsample': 0.5, 'l2_leaf_reg': 1.2101618159860283, 'min_data_in_leaf': 25, 'max_leaves': 20}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9947643979057592
# Recall: 0.9908735332464146
# Aging Rate: 0.4980443285528031
# Precision: 0.9934725848563969
# Recall: 0.9921773142112125
# Aging Rate: 0.49934810951760106
# Precision: 0.9960474308300395
# Recall: 0.9856584093872229
# Aging Rate: 0.49478487614080835
# [I 2022-03-04 19:03:20,283] Trial 41 finished with value: 0.9921551228796485 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.07500000000000001, 'subsample': 0.5, 'l2_leaf_reg': 0.020416464631065348, 'min_data_in_leaf': 15, 'max_leaves': 30}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9986893840104849
# Recall: 0.9934810951760105
# Aging Rate: 0.4973924380704042
# Precision: 0.993421052631579
# Recall: 0.984354628422425
# Aging Rate: 0.4954367666232073
# Precision: 0.9960835509138382
# Recall: 0.9947848761408083
# Aging Rate: 0.49934810951760106
# [I 2022-03-04 19:03:24,871] Trial 42 finished with value: 0.9934597603069539 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 6, 'learning_rate': 0.07500000000000001, 'subsample': 0.3, 'l2_leaf_reg': 0.01682251234915824, 'min_data_in_leaf': 20, 'max_leaves': 50}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.993455497382199
# Recall: 0.9895697522816167
# Aging Rate: 0.4980443285528031
# Precision: 0.9960681520314548
# Recall: 0.9908735332464146
# Aging Rate: 0.4973924380704042
# Precision: 0.9960629921259843
# Recall: 0.9895697522816167
# Aging Rate: 0.49674054758800523
# [I 2022-03-04 19:03:30,623] Trial 43 finished with value: 0.9925928751498104 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.025, 'subsample': 0.5, 'l2_leaf_reg': 0.6061766232512341, 'min_data_in_leaf': 5, 'max_leaves': 25}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9857697283311773
# Recall: 0.9934810951760105
# Aging Rate: 0.5039113428943938
# Precision: 0.9947712418300654
# Recall: 0.9921773142112125
# Aging Rate: 0.49869621903520206
# Precision: 0.9869960988296489
# Recall: 0.9895697522816167
# Aging Rate: 0.5013037809647979
# [I 2022-03-04 19:03:33,728] Trial 44 finished with value: 0.9904547414889288 and parameters: {'grow_policy': 'Depthwise', 'iterations': 500, 'depth': 6, 'learning_rate': 0.125, 'subsample': 0.5, 'l2_leaf_reg': 0.21787342303871396, 'min_data_in_leaf': 40}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.993455497382199
# Recall: 0.9895697522816167
# Aging Rate: 0.4980443285528031
# Precision: 0.9934810951760105
# Recall: 0.9934810951760105
# Aging Rate: 0.5
# Precision: 0.9895561357702349
# Recall: 0.9882659713168188
# Aging Rate: 0.49934810951760106
# [I 2022-03-04 19:03:38,661] Trial 45 finished with value: 0.9913001818961419 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.07500000000000001, 'subsample': 0.5, 'l2_leaf_reg': 2.5503598227995035, 'min_data_in_leaf': 20, 'max_leaves': 30}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9781209781209781
# Recall: 0.9908735332464146
# Aging Rate: 0.5065189048239895
# Precision: 0.979381443298969
# Recall: 0.9908735332464146
# Aging Rate: 0.5058670143415906
# Precision: 0.9947368421052631
# Recall: 0.9856584093872229
# Aging Rate: 0.4954367666232073
# [I 2022-03-04 19:03:41,357] Trial 46 finished with value: 0.9865755828727741 and parameters: {'grow_policy': 'Lossguide', 'iterations': 300, 'depth': 6, 'learning_rate': 0.025, 'subsample': 0.7, 'l2_leaf_reg': 0.14574854803500464, 'min_data_in_leaf': 10, 'max_leaves': 15}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9921773142112125
# Recall: 0.9921773142112125
# Aging Rate: 0.5
# Precision: 0.9922077922077922
# Recall: 0.9960886571056062
# Aging Rate: 0.5019556714471969
# Precision: 0.9921671018276762
# Recall: 0.9908735332464146
# Aging Rate: 0.49934810951760106
# [I 2022-03-04 19:03:57,798] Trial 47 finished with value: 0.9926138823520172 and parameters: {'grow_policy': 'SymmetricTree', 'iterations': 500, 'depth': 10, 'learning_rate': 0.07500000000000001, 'subsample': 0.9, 'l2_leaf_reg': 0.4023961448605499}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9857697283311773
# Recall: 0.9934810951760105
# Aging Rate: 0.5039113428943938
# Precision: 0.9934640522875817
# Recall: 0.9908735332464146
# Aging Rate: 0.49869621903520206
# Precision: 0.9806451612903225
# Recall: 0.9908735332464146
# Aging Rate: 0.5052151238591917
# [I 2022-03-04 19:04:00,621] Trial 48 finished with value: 0.9891701019882183 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 4, 'learning_rate': 0.275, 'subsample': 0.9, 'l2_leaf_reg': 0.06337396602719912, 'min_data_in_leaf': 15, 'max_leaves': 40}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9870633893919794
# Recall: 0.9947848761408083
# Aging Rate: 0.5039113428943938
# Precision: 0.9947780678851175
# Recall: 0.9934810951760105
# Aging Rate: 0.49934810951760106
# Precision: 0.9934296977660972
# Recall: 0.9856584093872229
# Aging Rate: 0.49608865710560623
# [I 2022-03-04 19:04:01,945] Trial 49 finished with value: 0.9915223484111099 and parameters: {'grow_policy': 'Depthwise', 'iterations': 100, 'depth': 8, 'learning_rate': 0.17500000000000002, 'subsample': 0.3, 'l2_leaf_reg': 0.04466459709556856, 'min_data_in_leaf': 5}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9934980494148244
# Recall: 0.9960886571056062
# Aging Rate: 0.5013037809647979
# Precision: 0.9921671018276762
# Recall: 0.9908735332464146
# Aging Rate: 0.49934810951760106
# Precision: 0.9921875
# Recall: 0.9934810951760105
# Aging Rate: 0.500651890482399
# [I 2022-03-04 19:04:06,255] Trial 50 finished with value: 0.9930484795058833 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 6, 'learning_rate': 0.125, 'subsample': 0.9, 'l2_leaf_reg': 0.2054036297486359, 'min_data_in_leaf': 5, 'max_leaves': 35}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9986876640419947
# Recall: 0.9921773142112125
# Aging Rate: 0.49674054758800523
# Precision: 0.9908616187989556
# Recall: 0.9895697522816167
# Aging Rate: 0.49934810951760106
# Precision: 0.9921773142112125
# Recall: 0.9921773142112125
# Aging Rate: 0.5
# [I 2022-03-04 19:04:12,673] Trial 51 finished with value: 0.9926048075805958 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.125, 'subsample': 0.9, 'l2_leaf_reg': 0.09757404815423756, 'min_data_in_leaf': 5, 'max_leaves': 50}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9882659713168188
# Recall: 0.9882659713168188
# Aging Rate: 0.5
# Precision: 0.9883116883116884
# Recall: 0.9921773142112125
# Aging Rate: 0.5019556714471969
# Precision: 0.9908972691807543
# Recall: 0.9934810951760105
# Aging Rate: 0.5013037809647979
# [I 2022-03-04 19:04:17,749] Trial 52 finished with value: 0.9902314000030255 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.17500000000000002, 'subsample': 0.9, 'l2_leaf_reg': 0.3321746383459415, 'min_data_in_leaf': 10, 'max_leaves': 45}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9973821989528796
# Recall: 0.9934810951760105
# Aging Rate: 0.4980443285528031
# Precision: 0.9921875
# Recall: 0.9934810951760105
# Aging Rate: 0.500651890482399
# Precision: 0.9973753280839895
# Recall: 0.9908735332464146
# Aging Rate: 0.49674054758800523
# [I 2022-03-04 19:04:24,838] Trial 53 finished with value: 0.9941251670139021 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.07500000000000001, 'subsample': 0.9, 'l2_leaf_reg': 0.13374659325779908, 'min_data_in_leaf': 5, 'max_leaves': 50}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9947916666666666
# Recall: 0.9960886571056062
# Aging Rate: 0.500651890482399
# Precision: 0.9908376963350786
# Recall: 0.9869621903520208
# Aging Rate: 0.4980443285528031
# Precision: 0.9960732984293194
# Recall: 0.9921773142112125
# Aging Rate: 0.4980443285528031
# [I 2022-03-04 19:04:30,959] Trial 54 finished with value: 0.9928191249820042 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.07500000000000001, 'subsample': 0.9, 'l2_leaf_reg': 0.153630355890689, 'min_data_in_leaf': 10, 'max_leaves': 50}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9947643979057592
# Recall: 0.9908735332464146
# Aging Rate: 0.4980443285528031
# Precision: 0.9921568627450981
# Recall: 0.9895697522816167
# Aging Rate: 0.49869621903520206
# Precision: 0.9908616187989556
# Recall: 0.9895697522816167
# Aging Rate: 0.49934810951760106
# [I 2022-03-04 19:04:40,064] Trial 55 finished with value: 0.9912973454937569 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 10, 'learning_rate': 0.025, 'subsample': 0.7, 'l2_leaf_reg': 0.5349299361189622, 'min_data_in_leaf': 5, 'max_leaves': 50}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9896238651102465
# Recall: 0.9947848761408083
# Aging Rate: 0.5026075619295959
# Precision: 0.9908616187989556
# Recall: 0.9895697522816167
# Aging Rate: 0.49934810951760106
# Precision: 0.994750656167979
# Recall: 0.9882659713168188
# Aging Rate: 0.49674054758800523
# [I 2022-03-04 19:04:45,575] Trial 56 finished with value: 0.9913035448026092 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.07500000000000001, 'subsample': 0.9, 'l2_leaf_reg': 0.2822019602417757, 'min_data_in_leaf': 15, 'max_leaves': 30}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9895697522816167
# Recall: 0.9895697522816167
# Aging Rate: 0.5
# Precision: 0.9844760672703752
# Recall: 0.9921773142112125
# Aging Rate: 0.5039113428943938
# Precision: 0.9908972691807543
# Recall: 0.9934810951760105
# Aging Rate: 0.5013037809647979
# [I 2022-03-04 19:04:50,697] Trial 57 finished with value: 0.9900229801977684 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 6, 'learning_rate': 0.025, 'subsample': 0.9, 'l2_leaf_reg': 0.7276152862118277, 'min_data_in_leaf': 25, 'max_leaves': 25}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9909443725743855
# Recall: 0.9986962190352021
# Aging Rate: 0.5039113428943938
# Precision: 0.9921773142112125
# Recall: 0.9921773142112125
# Aging Rate: 0.5
# Precision: 0.9895833333333334
# Recall: 0.9908735332464146
# Aging Rate: 0.500651890482399
# [I 2022-03-04 19:04:56,006] Trial 58 finished with value: 0.9924035073485745 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.07500000000000001, 'subsample': 0.9, 'l2_leaf_reg': 0.07445170505169134, 'min_data_in_leaf': 55, 'max_leaves': 40}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9960629921259843
# Recall: 0.9895697522816167
# Aging Rate: 0.49674054758800523
# Precision: 0.9921976592977894
# Recall: 0.9947848761408083
# Aging Rate: 0.5013037809647979
# Precision: 0.9896373056994818
# Recall: 0.9960886571056062
# Aging Rate: 0.5032594524119948
# [I 2022-03-04 19:05:02,548] Trial 59 finished with value: 0.9930492801178161 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 6, 'learning_rate': 0.025, 'subsample': 0.9, 'l2_leaf_reg': 0.11762853453672095, 'min_data_in_leaf': 10, 'max_leaves': 45}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9908616187989556
# Recall: 0.9895697522816167
# Aging Rate: 0.49934810951760106
# Precision: 0.9947780678851175
# Recall: 0.9934810951760105
# Aging Rate: 0.49934810951760106
# Precision: 0.9934640522875817
# Recall: 0.9908735332464146
# Aging Rate: 0.49869621903520206
# [I 2022-03-04 19:05:10,075] Trial 60 finished with value: 0.9921705081760878 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 10, 'learning_rate': 0.07500000000000001, 'subsample': 0.5, 'l2_leaf_reg': 9.907514357625743, 'min_data_in_leaf': 5, 'max_leaves': 50}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9934640522875817
# Recall: 0.9908735332464146
# Aging Rate: 0.49869621903520206
# Precision: 0.9782330345710627
# Recall: 0.9960886571056062
# Aging Rate: 0.5091264667535854
# Precision: 0.9947643979057592
# Recall: 0.9908735332464146
# Aging Rate: 0.4980443285528031
# [I 2022-03-04 19:05:16,508] Trial 61 finished with value: 0.9906874528937658 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.125, 'subsample': 0.9, 'l2_leaf_reg': 0.23219892908849, 'min_data_in_leaf': 5, 'max_leaves': 50}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9947780678851175
# Recall: 0.9934810951760105
# Aging Rate: 0.49934810951760106
# Precision: 0.9921568627450981
# Recall: 0.9895697522816167
# Aging Rate: 0.49869621903520206
# Precision: 0.9909208819714657
# Recall: 0.9960886571056062
# Aging Rate: 0.5026075619295959
# [I 2022-03-04 19:05:22,206] Trial 62 finished with value: 0.9928296089088334 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.125, 'subsample': 0.9, 'l2_leaf_reg': 0.170603055725641, 'min_data_in_leaf': 10, 'max_leaves': 45}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9934810951760105
# Recall: 0.9934810951760105
# Aging Rate: 0.5
# Precision: 0.9947575360419397
# Recall: 0.9895697522816167
# Aging Rate: 0.4973924380704042
# Precision: 0.987012987012987
# Recall: 0.9908735332464146
# Aging Rate: 0.5019556714471969
# [I 2022-03-04 19:05:28,545] Trial 63 finished with value: 0.9915258168130001 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.125, 'subsample': 0.9, 'l2_leaf_reg': 0.10780259477621547, 'min_data_in_leaf': 5, 'max_leaves': 50}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9973787680209698
# Recall: 0.9921773142112125
# Aging Rate: 0.4973924380704042
# Precision: 0.9960474308300395
# Recall: 0.9856584093872229
# Aging Rate: 0.49478487614080835
# Precision: 0.9934725848563969
# Recall: 0.9921773142112125
# Aging Rate: 0.49934810951760106
# [I 2022-03-04 19:05:33,010] Trial 64 finished with value: 0.9928071523248541 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 6, 'learning_rate': 0.07500000000000001, 'subsample': 0.9, 'l2_leaf_reg': 0.4566642026335955, 'min_data_in_leaf': 10, 'max_leaves': 25}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9882506527415144
# Recall: 0.9869621903520208
# Aging Rate: 0.49934810951760106
# Precision: 0.9947712418300654
# Recall: 0.9921773142112125
# Aging Rate: 0.49869621903520206
# Precision: 0.9934810951760105
# Recall: 0.9934810951760105
# Aging Rate: 0.5
# [I 2022-03-04 19:05:37,427] Trial 65 finished with value: 0.9915198937790128 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.225, 'subsample': 0.9, 'l2_leaf_reg': 0.34800315817688265, 'min_data_in_leaf': 15, 'max_leaves': 20}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9813581890812251
# Recall: 0.9608865710560626
# Aging Rate: 0.4895697522816167
# Precision: 0.9511568123393316
# Recall: 0.9647979139504563
# Aging Rate: 0.5071707953063885
# Precision: 0.9697368421052631
# Recall: 0.9608865710560626
# Aging Rate: 0.4954367666232073
# [I 2022-03-04 19:05:39,948] Trial 66 finished with value: 0.9647449054765729 and parameters: {'grow_policy': 'SymmetricTree', 'iterations': 100, 'depth': 6, 'learning_rate': 0.025, 'subsample': 0.7, 'l2_leaf_reg': 0.077285229524969}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9857881136950905
# Recall: 0.9947848761408083
# Aging Rate: 0.5045632333767927
# Precision: 0.9947848761408083
# Recall: 0.9947848761408083
# Aging Rate: 0.5
# Precision: 0.9908616187989556
# Recall: 0.9895697522816167
# Aging Rate: 0.49934810951760106
# [I 2022-03-04 19:05:47,557] Trial 67 finished with value: 0.9917554004426755 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 10, 'learning_rate': 0.07500000000000001, 'subsample': 0.9, 'l2_leaf_reg': 0.17840564732767944, 'min_data_in_leaf': 5, 'max_leaves': 40}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9934725848563969
# Recall: 0.9921773142112125
# Aging Rate: 0.49934810951760106
# Precision: 0.993455497382199
# Recall: 0.9895697522816167
# Aging Rate: 0.4980443285528031
# Precision: 0.9896238651102465
# Recall: 0.9947848761408083
# Aging Rate: 0.5026075619295959
# [I 2022-03-04 19:05:51,132] Trial 68 finished with value: 0.9921770013783525 and parameters: {'grow_policy': 'Lossguide', 'iterations': 300, 'depth': 8, 'learning_rate': 0.225, 'subsample': 0.9, 'l2_leaf_reg': 0.03543118485046051, 'min_data_in_leaf': 10, 'max_leaves': 30}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9896238651102465
# Recall: 0.9947848761408083
# Aging Rate: 0.5026075619295959
# Precision: 0.9870466321243523
# Recall: 0.9934810951760105
# Aging Rate: 0.5032594524119948
# Precision: 0.9895697522816167
# Recall: 0.9895697522816167
# Aging Rate: 0.5
# [I 2022-03-04 19:05:54,096] Trial 69 finished with value: 0.9906736076284831 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 4, 'learning_rate': 0.17500000000000002, 'subsample': 0.7, 'l2_leaf_reg': 0.24419418548823535, 'min_data_in_leaf': 30, 'max_leaves': 45}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9909208819714657
# Recall: 0.9960886571056062
# Aging Rate: 0.5026075619295959
# Precision: 0.9895697522816167
# Recall: 0.9895697522816167
# Aging Rate: 0.5
# Precision: 0.9960578186596584
# Recall: 0.9882659713168188
# Aging Rate: 0.49608865710560623
# [I 2022-03-04 19:05:57,405] Trial 70 finished with value: 0.9917381328516933 and parameters: {'grow_policy': 'Depthwise', 'iterations': 500, 'depth': 6, 'learning_rate': 0.125, 'subsample': 0.9, 'l2_leaf_reg': 0.12936361996501267, 'min_data_in_leaf': 15}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9883268482490273
# Recall: 0.9934810951760105
# Aging Rate: 0.5026075619295959
# Precision: 0.9896507115135834
# Recall: 0.9973924380704041
# Aging Rate: 0.5039113428943938
# Precision: 0.9869791666666666
# Recall: 0.9882659713168188
# Aging Rate: 0.500651890482399
# [I 2022-03-04 19:05:59,978] Trial 71 finished with value: 0.9906753041747938 and parameters: {'grow_policy': 'Depthwise', 'iterations': 100, 'depth': 12, 'learning_rate': 0.125, 'subsample': 0.9, 'l2_leaf_reg': 0.4251284943995248, 'min_data_in_leaf': 10}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9883268482490273
# Recall: 0.9934810951760105
# Aging Rate: 0.5026075619295959
# Precision: 0.9947780678851175
# Recall: 0.9934810951760105
# Aging Rate: 0.49934810951760106
# Precision: 0.9895833333333334
# Recall: 0.9908735332464146
# Aging Rate: 0.500651890482399
# [I 2022-03-04 19:06:02,224] Trial 72 finished with value: 0.9917514802409301 and parameters: {'grow_policy': 'Depthwise', 'iterations': 100, 'depth': 10, 'learning_rate': 0.125, 'subsample': 0.9, 'l2_leaf_reg': 0.331811982238751, 'min_data_in_leaf': 5}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9908136482939632
# Recall: 0.984354628422425
# Aging Rate: 0.49674054758800523
# Precision: 0.9960474308300395
# Recall: 0.9856584093872229
# Aging Rate: 0.49478487614080835
# Precision: 0.99609375
# Recall: 0.9973924380704041
# Aging Rate: 0.500651890482399
# [I 2022-03-04 19:06:04,144] Trial 73 finished with value: 0.9917139788616005 and parameters: {'grow_policy': 'Depthwise', 'iterations': 100, 'depth': 10, 'learning_rate': 0.125, 'subsample': 0.9, 'l2_leaf_reg': 0.5769023395973603, 'min_data_in_leaf': 10}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9986859395532195
# Recall: 0.9908735332464146
# Aging Rate: 0.49608865710560623
# Precision: 0.9895697522816167
# Recall: 0.9895697522816167
# Aging Rate: 0.5
# Precision: 0.9896238651102465
# Recall: 0.9947848761408083
# Aging Rate: 0.5026075619295959
# [I 2022-03-04 19:06:05,843] Trial 74 finished with value: 0.9921772698283884 and parameters: {'grow_policy': 'Depthwise', 'iterations': 100, 'depth': 8, 'learning_rate': 0.07500000000000001, 'subsample': 0.9, 'l2_leaf_reg': 0.19446360632632123, 'min_data_in_leaf': 5}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9947643979057592
# Recall: 0.9908735332464146
# Aging Rate: 0.4980443285528031
# Precision: 0.9960629921259843
# Recall: 0.9895697522816167
# Aging Rate: 0.49674054758800523
# Precision: 0.9921671018276762
# Recall: 0.9908735332464146
# Aging Rate: 0.49934810951760106
# [I 2022-03-04 19:06:07,995] Trial 75 finished with value: 0.9923802681732053 and parameters: {'grow_policy': 'Depthwise', 'iterations': 100, 'depth': 12, 'learning_rate': 0.17500000000000002, 'subsample': 0.9, 'l2_leaf_reg': 0.01359011693270382, 'min_data_in_leaf': 20}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9857697283311773
# Recall: 0.9934810951760105
# Aging Rate: 0.5039113428943938
# Precision: 0.9908616187989556
# Recall: 0.9895697522816167
# Aging Rate: 0.49934810951760106
# Precision: 0.9882198952879581
# Recall: 0.984354628422425
# Aging Rate: 0.4980443285528031
# [I 2022-03-04 19:06:14,866] Trial 76 finished with value: 0.9887030428837646 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 8, 'learning_rate': 0.025, 'subsample': 0.9, 'l2_leaf_reg': 0.7869283960877039, 'min_data_in_leaf': 10, 'max_leaves': 35}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9934980494148244
# Recall: 0.9960886571056062
# Aging Rate: 0.5013037809647979
# Precision: 0.9794608472400513
# Recall: 0.9947848761408083
# Aging Rate: 0.5078226857887875
# Precision: 0.9857512953367875
# Recall: 0.9921773142112125
# Aging Rate: 0.5032594524119948
# [I 2022-03-04 19:06:19,974] Trial 77 finished with value: 0.9902696407351649 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 10, 'learning_rate': 0.07500000000000001, 'subsample': 0.9, 'l2_leaf_reg': 0.27793081915020135, 'min_data_in_leaf': 15, 'max_leaves': 20}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9934725848563969
# Recall: 0.9921773142112125
# Aging Rate: 0.49934810951760106
# Precision: 0.9947780678851175
# Recall: 0.9934810951760105
# Aging Rate: 0.49934810951760106
# Precision: 0.9921976592977894
# Recall: 0.9947848761408083
# Aging Rate: 0.5013037809647979
# [I 2022-03-04 19:06:21,361] Trial 78 finished with value: 0.9934810896390521 and parameters: {'grow_policy': 'Lossguide', 'iterations': 100, 'depth': 6, 'learning_rate': 0.125, 'subsample': 0.9, 'l2_leaf_reg': 1.2127533522642768, 'min_data_in_leaf': 5, 'max_leaves': 40}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9844961240310077
# Recall: 0.9934810951760105
# Aging Rate: 0.5045632333767927
# Precision: 0.984516129032258
# Recall: 0.9947848761408083
# Aging Rate: 0.5052151238591917
# Precision: 0.9986893840104849
# Recall: 0.9934810951760105
# Aging Rate: 0.4973924380704042
# [I 2022-03-04 19:06:27,387] Trial 79 finished with value: 0.9915568329829089 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 6, 'learning_rate': 0.025, 'subsample': 0.9, 'l2_leaf_reg': 1.290602879796822, 'min_data_in_leaf': 5, 'max_leaves': 40}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9883570504527813
# Recall: 0.9960886571056062
# Aging Rate: 0.5039113428943938
# Precision: 0.9947643979057592
# Recall: 0.9908735332464146
# Aging Rate: 0.4980443285528031
# Precision: 0.996078431372549
# Recall: 0.9934810951760105
# Aging Rate: 0.49869621903520206
# [I 2022-03-04 19:06:31,650] Trial 80 finished with value: 0.9932670045291193 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 6, 'learning_rate': 0.07500000000000001, 'subsample': 0.9, 'l2_leaf_reg': 2.477432322231888, 'min_data_in_leaf': 35, 'max_leaves': 40}. Best is trial 32 with value: 0.9947854410938142.
# Precision: 0.9921773142112125
# Recall: 0.9921773142112125
# Aging Rate: 0.5
# Precision: 0.9896238651102465
# Recall: 0.9947848761408083
# Aging Rate: 0.5026075619295959
# ...
# Precision: 0.9726027397260274
# Recall: 0.9342105263157895
# Aging Rate: 0.08732057416267942
# Precision: 0.9375
# Recall: 0.7894736842105263
# Aging Rate: 0.07655502392344497
# Precision: 0.9420289855072463
# Recall: 0.8552631578947368
# Aging Rate: 0.08253588516746412
# [I 2022-03-05 00:42:35,083] Trial 72 finished with value: 0.902238238502992 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 12, 'learning_rate': 0.225, 'subsample': 0.7, 'l2_leaf_reg': 3.4621888230822986, 'min_data_in_leaf': 40, 'max_leaves': 50}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 0.9016393442622951
# Recall: 0.7236842105263158
# Aging Rate: 0.0729665071770335
# Precision: 0.9666666666666667
# Recall: 0.7631578947368421
# Aging Rate: 0.07177033492822966
# Precision: 0.9552238805970149
# Recall: 0.8421052631578947
# Aging Rate: 0.08014354066985646
# [I 2022-03-05 00:42:40,298] Trial 73 finished with value: 0.8503219265348934 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 12, 'learning_rate': 0.17500000000000002, 'subsample': 0.7, 'l2_leaf_reg': 4.099704512340779, 'min_data_in_leaf': 40, 'max_leaves': 45}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 0.9710144927536232
# Recall: 0.881578947368421
# Aging Rate: 0.08253588516746412
# Precision: 0.9344262295081968
# Recall: 0.75
# Aging Rate: 0.0729665071770335
# Precision: 0.9411764705882353
# Recall: 0.8421052631578947
# Aging Rate: 0.08133971291866028
# [I 2022-03-05 00:42:45,309] Trial 74 finished with value: 0.8817145360815132 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 12, 'learning_rate': 0.275, 'subsample': 0.9, 'l2_leaf_reg': 2.484760112677024, 'min_data_in_leaf': 45, 'max_leaves': 50}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 0.9838709677419355
# Recall: 0.8026315789473685
# Aging Rate: 0.07416267942583732
# Precision: 1.0
# Recall: 0.7763157894736842
# Aging Rate: 0.07057416267942583
# Precision: 1.0
# Recall: 0.8289473684210527
# Aging Rate: 0.07535885167464115
# [I 2022-03-05 00:43:39,987] Trial 75 finished with value: 0.8882022884108173 and parameters: {'grow_policy': 'SymmetricTree', 'iterations': 500, 'depth': 12, 'learning_rate': 0.275, 'subsample': 0.7, 'l2_leaf_reg': 0.8795510727960718}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 0.967741935483871
# Recall: 0.7894736842105263
# Aging Rate: 0.07416267942583732
# Precision: 0.9344262295081968
# Recall: 0.75
# Aging Rate: 0.0729665071770335
# Precision: 0.9692307692307692
# Recall: 0.8289473684210527
# Aging Rate: 0.07775119617224881
# [I 2022-03-05 00:43:53,127] Trial 76 finished with value: 0.8650996756630226 and parameters: {'grow_policy': 'SymmetricTree', 'iterations': 500, 'depth': 10, 'learning_rate': 0.225, 'subsample': 0.9, 'l2_leaf_reg': 6.541872214303481}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 0.9253731343283582
# Recall: 0.8157894736842105
# Aging Rate: 0.08014354066985646
# Precision: 0.9710144927536232
# Recall: 0.881578947368421
# Aging Rate: 0.08253588516746412
# Precision: 0.984375
# Recall: 0.8289473684210527
# Aging Rate: 0.07655502392344497
# [I 2022-03-05 00:43:57,967] Trial 77 finished with value: 0.8970902660557832 and parameters: {'grow_policy': 'Lossguide', 'iterations': 500, 'depth': 12, 'learning_rate': 0.17500000000000002, 'subsample': 0.5, 'l2_leaf_reg': 1.5464362441789845, 'min_data_in_leaf': 25, 'max_leaves': 50}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 0.9482758620689655
# Recall: 0.7236842105263158
# Aging Rate: 0.06937799043062201
# Precision: 1.0
# Recall: 0.8552631578947368
# Aging Rate: 0.07775119617224881
# Precision: 0.9672131147540983
# Recall: 0.7763157894736842
# Aging Rate: 0.0729665071770335
# [I 2022-03-05 00:44:08,742] Trial 78 finished with value: 0.8680650688680118 and parameters: {'grow_policy': 'SymmetricTree', 'iterations': 100, 'depth': 12, 'learning_rate': 0.125, 'subsample': 0.9, 'l2_leaf_reg': 0.3779898022709502}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 0.9701492537313433
# Recall: 0.8552631578947368
# Aging Rate: 0.08014354066985646
# Precision: 0.9365079365079365
# Recall: 0.7763157894736842
# Aging Rate: 0.07535885167464115
# Precision: 1.0
# Recall: 0.8947368421052632
# Aging Rate: 0.08133971291866028
# [I 2022-03-05 00:44:09,926] Trial 79 finished with value: 0.9008187389482355 and parameters: {'grow_policy': 'Lossguide', 'iterations': 100, 'depth': 10, 'learning_rate': 0.225, 'subsample': 0.7, 'l2_leaf_reg': 0.1901774068979354, 'min_data_in_leaf': 40, 'max_leaves': 45}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 0.9649122807017544
# Recall: 0.7236842105263158
# Aging Rate: 0.06818181818181818
# Precision: 0.9838709677419355
# Recall: 0.8026315789473685
# Aging Rate: 0.07416267942583732
# Precision: 0.953125
# Recall: 0.8026315789473685
# Aging Rate: 0.07655502392344497
# [I 2022-03-05 00:44:11,048] Trial 80 finished with value: 0.8608514038719989 and parameters: {'grow_policy': 'Lossguide', 'iterations': 100, 'depth': 10, 'learning_rate': 0.225, 'subsample': 0.7, 'l2_leaf_reg': 2.0313655818778247, 'min_data_in_leaf': 40, 'max_leaves': 45}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 0.9104477611940298
# Recall: 0.8026315789473685
# Aging Rate: 0.08014354066985646
# Precision: 0.9848484848484849
# Recall: 0.8552631578947368
# Aging Rate: 0.07894736842105263
# Precision: 0.96875
# Recall: 0.8157894736842105
# Aging Rate: 0.07655502392344497
# [I 2022-03-05 00:44:11,812] Trial 81 finished with value: 0.8847846988692059 and parameters: {'grow_policy': 'Lossguide', 'iterations': 100, 'depth': 6, 'learning_rate': 0.225, 'subsample': 0.7, 'l2_leaf_reg': 0.19020066169960326, 'min_data_in_leaf': 45, 'max_leaves': 40}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 0.9402985074626866
# Recall: 0.8289473684210527
# Aging Rate: 0.08014354066985646
# Precision: 0.9558823529411765
# Recall: 0.8552631578947368
# Aging Rate: 0.08133971291866028
# Precision: 1.0
# Recall: 0.8157894736842105
# Aging Rate: 0.07416267942583732
# [I 2022-03-05 00:44:12,996] Trial 82 finished with value: 0.8941491278447801 and parameters: {'grow_policy': 'Lossguide', 'iterations': 100, 'depth': 10, 'learning_rate': 0.275, 'subsample': 0.7, 'l2_leaf_reg': 0.10902425626145859, 'min_data_in_leaf': 35, 'max_leaves': 45}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 0.9565217391304348
# Recall: 0.868421052631579
# Aging Rate: 0.08253588516746412
# Precision: 0.8688524590163934
# Recall: 0.6973684210526315
# Aging Rate: 0.0729665071770335
# Precision: 0.9402985074626866
# Recall: 0.8289473684210527
# Aging Rate: 0.08014354066985646
# [I 2022-03-05 00:44:14,350] Trial 83 finished with value: 0.8550621121474381 and parameters: {'grow_policy': 'Lossguide', 'iterations': 100, 'depth': 12, 'learning_rate': 0.225, 'subsample': 0.7, 'l2_leaf_reg': 0.5069112704779435, 'min_data_in_leaf': 40, 'max_leaves': 50}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 0.9428571428571428
# Recall: 0.868421052631579
# Aging Rate: 0.08373205741626795
# Precision: 0.9682539682539683
# Recall: 0.8026315789473685
# Aging Rate: 0.07535885167464115
# Precision: 0.9538461538461539
# Recall: 0.8157894736842105
# Aging Rate: 0.07775119617224881
# [I 2022-03-05 00:44:15,863] Trial 84 finished with value: 0.8870800182937298 and parameters: {'grow_policy': 'Lossguide', 'iterations': 100, 'depth': 12, 'learning_rate': 0.17500000000000002, 'subsample': 0.9, 'l2_leaf_reg': 0.23863441519914227, 'min_data_in_leaf': 30, 'max_leaves': 50}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 1.0
# Recall: 0.7894736842105263
# Aging Rate: 0.07177033492822966
# Precision: 0.9818181818181818
# Recall: 0.7105263157894737
# Aging Rate: 0.06578947368421052
# Precision: 0.9836065573770492
# Recall: 0.7894736842105263
# Aging Rate: 0.0729665071770335
# [I 2022-03-05 00:44:34,210] Trial 85 finished with value: 0.8608976102838751 and parameters: {'grow_policy': 'SymmetricTree', 'iterations': 500, 'depth': 8, 'learning_rate': 0.325, 'subsample': 0.7, 'l2_leaf_reg': 0.3480490991101033}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 0.9206349206349206
# Recall: 0.7631578947368421
# Aging Rate: 0.07535885167464115
# Precision: 0.9558823529411765
# Recall: 0.8552631578947368
# Aging Rate: 0.08133971291866028
# Precision: 0.9411764705882353
# Recall: 0.8421052631578947
# Aging Rate: 0.08133971291866028
# [I 2022-03-05 00:44:35,367] Trial 86 finished with value: 0.8753996802557954 and parameters: {'grow_policy': 'Lossguide', 'iterations': 100, 'depth': 12, 'learning_rate': 0.275, 'subsample': 0.5, 'l2_leaf_reg': 0.6683295325989685, 'min_data_in_leaf': 55, 'max_leaves': 40}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 0.9710144927536232
# Recall: 0.881578947368421
# Aging Rate: 0.08253588516746412
# Precision: 1.0
# Recall: 0.8157894736842105
# Aging Rate: 0.07416267942583732
# Precision: 0.9420289855072463
# Recall: 0.8552631578947368
# Aging Rate: 0.08253588516746412
# [I 2022-03-05 00:44:38,754] Trial 87 finished with value: 0.9064134599366982 and parameters: {'grow_policy': 'SymmetricTree', 'iterations': 100, 'depth': 10, 'learning_rate': 0.225, 'subsample': 0.9, 'l2_leaf_reg': 0.48012178084945883}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 0.9622641509433962
# Recall: 0.6710526315789473
# Aging Rate: 0.06339712918660287
# Precision: 0.9696969696969697
# Recall: 0.8421052631578947
# Aging Rate: 0.07894736842105263
# Precision: 0.9516129032258065
# Recall: 0.7763157894736842
# Aging Rate: 0.07416267942583732
# [I 2022-03-05 00:44:40,127] Trial 88 finished with value: 0.8490595296303155 and parameters: {'grow_policy': 'Lossguide', 'iterations': 100, 'depth': 12, 'learning_rate': 0.225, 'subsample': 0.9, 'l2_leaf_reg': 1.062181366027136, 'min_data_in_leaf': 40, 'max_leaves': 45}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 1.0
# Recall: 0.7105263157894737
# Aging Rate: 0.0645933014354067
# Precision: 1.0
# Recall: 0.7236842105263158
# Aging Rate: 0.06578947368421052
# Precision: 0.9375
# Recall: 0.7894736842105263
# Aging Rate: 0.07655502392344497
# [I 2022-03-05 00:44:43,576] Trial 89 finished with value: 0.8425355814668792 and parameters: {'grow_policy': 'SymmetricTree', 'iterations': 100, 'depth': 10, 'learning_rate': 0.17500000000000002, 'subsample': 0.9, 'l2_leaf_reg': 0.46767618615228307}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 0.9824561403508771
# Recall: 0.7368421052631579
# Aging Rate: 0.06818181818181818
# Precision: 0.9672131147540983
# Recall: 0.7763157894736842
# Aging Rate: 0.0729665071770335
# Precision: 1.0
# Recall: 0.7368421052631579
# Aging Rate: 0.06698564593301436
# [I 2022-03-05 00:44:44,806] Trial 90 finished with value: 0.850634660085294 and parameters: {'grow_policy': 'Lossguide', 'iterations': 100, 'depth': 12, 'learning_rate': 0.225, 'subsample': 0.7, 'l2_leaf_reg': 0.1203783665389824, 'min_data_in_leaf': 45, 'max_leaves': 35}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 0.9516129032258065
# Recall: 0.7763157894736842
# Aging Rate: 0.07416267942583732
# Precision: 0.9811320754716981
# Recall: 0.6842105263157895
# Aging Rate: 0.06339712918660287
# Precision: 0.9818181818181818
# Recall: 0.7105263157894737
# Aging Rate: 0.06578947368421052
# [I 2022-03-05 00:44:48,161] Trial 91 finished with value: 0.8285671650239145 and parameters: {'grow_policy': 'SymmetricTree', 'iterations': 100, 'depth': 10, 'learning_rate': 0.225, 'subsample': 0.9, 'l2_leaf_reg': 0.7821344111437326}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 0.967741935483871
# Recall: 0.7894736842105263
# Aging Rate: 0.07416267942583732
# Precision: 0.9696969696969697
# Recall: 0.8421052631578947
# Aging Rate: 0.07894736842105263
# Precision: 1.0
# Recall: 0.7631578947368421
# Aging Rate: 0.06937799043062201
# [I 2022-03-05 00:44:51,642] Trial 92 finished with value: 0.8788817699621916 and parameters: {'grow_policy': 'SymmetricTree', 'iterations': 100, 'depth': 10, 'learning_rate': 0.325, 'subsample': 0.9, 'l2_leaf_reg': 0.326068389523348}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 1.0
# Recall: 0.8289473684210527
# Aging Rate: 0.07535885167464115
# Precision: 0.9428571428571428
# Recall: 0.868421052631579
# Aging Rate: 0.08373205741626795
# Precision: 1.0
# Recall: 0.7763157894736842
# Aging Rate: 0.07057416267942583
# [I 2022-03-05 00:44:55,145] Trial 93 finished with value: 0.8948861610863518 and parameters: {'grow_policy': 'SymmetricTree', 'iterations': 100, 'depth': 8, 'learning_rate': 0.275, 'subsample': 0.9, 'l2_leaf_reg': 0.285218827224392}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 0.9838709677419355
# Recall: 0.8026315789473685
# Aging Rate: 0.07416267942583732
# Precision: 0.9310344827586207
# Recall: 0.7105263157894737
# Aging Rate: 0.06937799043062201
# Precision: 0.9846153846153847
# Recall: 0.8421052631578947
# Aging Rate: 0.07775119617224881
# [I 2022-03-05 00:44:58,561] Trial 94 finished with value: 0.8659431795693134 and parameters: {'grow_policy': 'SymmetricTree', 'iterations': 100, 'depth': 10, 'learning_rate': 0.225, 'subsample': 0.9, 'l2_leaf_reg': 0.5478034744594731}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 0.9552238805970149
# Recall: 0.8421052631578947
# Aging Rate: 0.08014354066985646
# Precision: 0.9710144927536232
# Recall: 0.881578947368421
# Aging Rate: 0.08253588516746412
# Precision: 0.9682539682539683
# Recall: 0.8026315789473685
# Aging Rate: 0.07535885167464115
# [I 2022-03-05 00:45:53,085] Trial 95 finished with value: 0.8989802226219988 and parameters: {'grow_policy': 'SymmetricTree', 'iterations': 500, 'depth': 12, 'learning_rate': 0.275, 'subsample': 0.9, 'l2_leaf_reg': 0.4402772053744941}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 0.8888888888888888
# Recall: 0.7368421052631579
# Aging Rate: 0.07535885167464115
# Precision: 0.9821428571428571
# Recall: 0.7236842105263158
# Aging Rate: 0.06698564593301436
# Precision: 0.9423076923076923
# Recall: 0.6447368421052632
# Aging Rate: 0.06220095693779904
# [I 2022-03-05 00:45:53,818] Trial 96 finished with value: 0.8015712430055956 and parameters: {'grow_policy': 'Lossguide', 'iterations': 100, 'depth': 10, 'learning_rate': 0.125, 'subsample': 0.9, 'l2_leaf_reg': 0.16839111540816187, 'min_data_in_leaf': 50, 'max_leaves': 10}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 1.0
# Recall: 0.6842105263157895
# Aging Rate: 0.06220095693779904
# Precision: 1.0
# Recall: 0.8157894736842105
# Aging Rate: 0.07416267942583732
# Precision: 0.9696969696969697
# Recall: 0.8421052631578947
# Aging Rate: 0.07894736842105263
# [I 2022-03-05 00:45:57,944] Trial 97 finished with value: 0.8708197251139689 and parameters: {'grow_policy': 'SymmetricTree', 'iterations': 100, 'depth': 8, 'learning_rate': 0.17500000000000002, 'subsample': 0.9, 'l2_leaf_reg': 0.6808573117954607}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 0.9726027397260274
# Recall: 0.9342105263157895
# Aging Rate: 0.08732057416267942
# Precision: 0.9838709677419355
# Recall: 0.8026315789473685
# Aging Rate: 0.07416267942583732
# Precision: 0.9384615384615385
# Recall: 0.8026315789473685
# Aging Rate: 0.07775119617224881
# [I 2022-03-05 00:45:59,097] Trial 98 finished with value: 0.9007754440643452 and parameters: {'grow_policy': 'Depthwise', 'iterations': 100, 'depth': 12, 'learning_rate': 0.325, 'subsample': 0.9, 'l2_leaf_reg': 1.4148198488541122, 'min_data_in_leaf': 25}. Best is trial 9 with value: 0.9148454286216415.
# Precision: 1.0
# Recall: 0.868421052631579
# Aging Rate: 0.07894736842105263
# Precision: 0.9264705882352942
# Recall: 0.8289473684210527
# Aging Rate: 0.08133971291866028
# Precision: 0.9696969696969697
# Recall: 0.8421052631578947
# Aging Rate: 0.07894736842105263
# [I 2022-03-05 00:46:00,185] Trial 99 finished with value: 0.9019953051643194 and parameters: {'grow_policy': 'Depthwise', 'iterations': 100, 'depth': 12, 'learning_rate': 0.325, 'subsample': 0.9, 'l2_leaf_reg': 2.0815132999171593, 'min_data_in_leaf': 25}. Best is trial 9 with value: 0.9148454286216415.
# Sampler is TPESampler

# %%
##### optimization history plot #####
optuna_history(best_paramC, all_scoreC, num_row = 3, num_col = 3, model = 'CatBoost Classifier')
            
##### best hyperparameter table #####
param_table = pd.DataFrame(best_paramC).T
param_table
# Out:
#         grow_policy iterations depth learning_rate subsample l2_leaf_reg  \
# set1      Lossguide        500     8         0.125       0.9    0.140828
# set2  SymmetricTree        300    12         0.075       0.5    2.698314
# set3      Depthwise        100    12         0.325       0.5    1.673086
# set4      Depthwise        500    10         0.025       0.7    0.094339
# set5  SymmetricTree        300     8         0.325       0.7    2.422472
# set6      Lossguide        500    12         0.125       0.7    0.019115
# set7      Lossguide        300    10         0.175       0.9    4.144227
# set8      Depthwise        500    10         0.125       0.5    0.044559
# set9  SymmetricTree        100    12         0.175       0.9    0.512616
#
#      min_data_in_leaf max_leaves
# set1                5         50
# set2              NaN        NaN
# set3               40        NaN
# set4               40        NaN
# set5              NaN        NaN
# set6               60         45
# set7               60         20
# set8               35        NaN
# set9              NaN        NaN

# %% [markdown]
# ##

# %% [markdown]
# ### Classifier

# %%
table_setC = runall_CatBoostC(run_train_x, run_test_x, run_train_y, run_test_y, best_paramC)
line_chart(table_setC, title = 'CatBoost Classifier')
# Out:
# 0it [00:00, ?it/s]
#  Dataset1:
# Precision: 0.0016032492518170158
# Recall: 0.29411764705882354
# Aging Rate: 0.1923163888260807
#
#  Dataset2:
# Precision: 0.001501626762325853
# Recall: 0.35294117647058826
# Aging Rate: 0.24639766490575346
#
#  Dataset3:
# Precision: 0.0010465226905146988
# Recall: 0.21568627450980393
# Aging Rate: 0.21605788402639314
#
#  Dataset4:
# Precision: 0.0012898470609913396
# Recall: 0.13725490196078433
# Aging Rate: 0.11155419433081872
#
#  Dataset5:
# Precision: 0.00145602795573675
# Recall: 0.29411764705882354
# Aging Rate: 0.21176180394252708
#
#  Dataset6:
# Precision: 0.0012318642211880647
# Recall: 0.35294117647058826
# Aging Rate: 0.30035560854282717
#
#  Dataset7:
# Precision: 0.0013012361743656475
# Recall: 0.27450980392156865
# Aging Rate: 0.22115562498715288
#
#  Dataset8:
# Precision: 0.0009385265133740028
# Recall: 0.11764705882352941
# Aging Rate: 0.13141071758926184
#
#  Dataset9:
# Precision: 0.0011594202898550724
# Recall: 0.0392156862745098
# Aging Rate: 0.03545807724721988

# %%
table_setC
# Out:
#           Balance Ratio  Train_OK  Train_NG    TP       FP    FN       TN  \
# dataset1       1.000000    3067.0    3067.0  15.0   9341.0  36.0  39257.0
# dataset2       1.000000    2999.0    2999.0  18.0  11969.0  33.0  36629.0
# dataset3       1.000000    3033.0    3033.0  11.0  10500.0  40.0  38098.0
# dataset4       1.000000    3038.0    3038.0   7.0   5420.0  44.0  43178.0
# dataset5       1.006623    3040.0    3020.0  15.0  10287.0  36.0  38311.0
# dataset6       1.014348    3040.0    2997.0  18.0  14594.0  33.0  34004.0
# dataset7       1.099458    3040.0    2765.0  14.0  10745.0  37.0  37853.0
# dataset8       1.000000    3040.0    3040.0   6.0   6387.0  45.0  42211.0
# dataset9      10.000000    3040.0     304.0   2.0   1723.0  49.0  46875.0
#
#           Precision    Recall  Aging Rate  Efficiency  F1 Score     Score
# dataset1   0.001603  0.294118    0.192316    1.529343  0.001595  0.272929
# dataset2   0.001502  0.352941    0.246398    1.432405  0.001495  0.313722
# dataset3   0.001047  0.215686    0.216058    0.998280  0.001041  0.000000
# dataset4   0.001290  0.137255    0.111554    1.230388  0.001278  0.110103
# dataset5   0.001456  0.294118    0.211762    1.388908  0.001449  0.256128
# dataset6   0.001232  0.352941    0.300356    1.175078  0.001228  0.274258
# dataset7   0.001301  0.274510    0.221156    1.241252  0.001295  0.221539
# dataset8   0.000939  0.117647    0.131411    0.895262  0.000931  0.000000
# dataset9   0.001159  0.039216    0.035458    1.105973  0.001126  0.029207

# %% [markdown]
# ### Calibrated Classifier (optional)

# %%
tableC_1 = all_cali_CatBoostC(run_train_x, run_train_y, run_test_x, run_test_y, best_paramC, method = 'isotonic')
tableC_2 = all_cali_CatBoostC(run_train_x, run_train_y, run_test_x, run_test_y, best_paramC, method = 'sigmoid')
tableC_3 = all_cali_CatBoostC(run_train_x, run_train_y, run_test_x, run_test_y, best_paramC, method = 'beta')

# %% [markdown]
# ### Regressor (optional)

# %%
best_paramR, all_scoreR = all_optuna(num_set = 10, 
                                     all_data = run_train, 
                                     mode = 'R', 
                                     TPE_multi = False, 
                                     n_iter = 200,
                                     filename = 'runhist_array_m2m5_4selection_CatBoost',
                                     creator = CatBoost_creator
                                    )

# %%
pr_dict, table_setR = runall_CatBoostR(10, trainset_x, run_test_x, trainset_y, run_test_y, best_paramR, cat_feature = [], 
                                       thres_target = 'Recall', threshold = 0.8)
line_chart(table_setR, title = 'CatBoost Regressor')

# %%
multiple_curve(4, 3, pr_dict, table_setR, target = 'Aging Rate')
multiple_curve(4, 3, pr_dict, table_setR, target = 'Precision')
table_setR

# %% [markdown]
# ### Export

# %%
savedate = '20220308'
TPE_multi = False

table_setC['sampler'] = 'multivariate-TPE' if TPE_multi else 'univariate-TPE'
table_setC['model'] = 'CatBoost_6'
with pd.ExcelWriter(f'{savedate}_Classifier.xlsx', mode = 'a') as writer:
    table_setC.to_excel(writer, sheet_name = 'CatBoost_6')
